# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

import json

from fycharts.SpotifyCharts import SpotifyCharts
import sqlalchemy

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from datetime import datetime
from sklearn.model_selection import train_test_split

import statsmodels.api as sm

# We are required to do this in order to avoid "FutureWarning" issues.
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller  

from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %matplotlib inline

import warnings
warnings.simplefilter(action="ignore")

# %%
italy_17_19 = pd.read_pickle('../data/it_17_19_v50_feat.pkl')
spain_17_19 = pd.read_pickle('../data/sp_17_19_v50_feat.pkl')
greece_17_19 = pd.read_pickle('../data/gr_17_19_v50_feat.pkl')

italy_20 = pd.read_pickle('../data/it_20_v50_feat.pkl')
spain_20 = pd.read_pickle('../data/sp_20_v50_feat.pkl')
greece_20 = pd.read_pickle('../data/gr_20_v50_feat.pkl')

# %%
spain_20.tail()
# Out:
#             Position                     Track Name               Artist  \
# date
# 2021-02-13        46                    Hasta Abajo         Kevin Roldan
# 2021-02-13        47  Strange (feat. Hillary Smith)          Kris Bowers
# 2021-02-13        48                   Hecha Pa' Mi                 Boza
# 2021-02-13        49         La Luz - A COLORS SHOW    María José Llergo
# 2021-02-13        50       Boku no Sensou - TV Size  Shinsei Kamattechan
#
#            region              spotify_id  danceability  energy  key  \
# date
# 2021-02-13     es  4PEfJZpVjdclfzZ9XO8uDw         0.714   0.671    5
# 2021-02-13     es  2bPWLtJe3v33z1j40sWB8a         0.251   0.150    2
# 2021-02-13     es  3VvA1wSxukMLsvXoXtlwWx         0.725   0.756    4
# 2021-02-13     es  5jRnVQbjB6qgN3MARS4xw7         0.722   0.357    9
# 2021-02-13     es  3tRPfCFAEv6wWyQO0YnGGV         0.447   0.891    9
#
#             loudness  mode  speechiness  acousticness  instrumentalness  \
# date
# 2021-02-13    -5.119     1       0.3620       0.28900          0.000000
# 2021-02-13   -15.076     1       0.0342       0.98900          0.972000
# 2021-02-13    -5.013     1       0.0572       0.36200          0.000685
# 2021-02-13   -10.487     0       0.0996       0.81400          0.155000
# 2021-02-13    -4.776     1       0.0788       0.00447          0.000905
#
#             liveness  valence    tempo  duration_ms  time_signature
# date
# 2021-02-13    0.3250   0.6410  169.732       229827               4
# 2021-02-13    0.1130   0.0727   70.453       198640               4
# 2021-02-13    0.1030   0.8280  100.070       186133               4
# 2021-02-13    0.0863   0.6410  149.895       191599               4
# 2021-02-13    0.3900   0.5170  143.976        90960               4

# %% [markdown]
# **Resampling by month**
#
# _`rm` denotes resampling by month._

# %%
rm_italy_17_19 = italy_17_19.resample("M").mean()
rm_spain_17_19 = spain_17_19.resample("M").mean()
rm_greece_17_19 = greece_17_19.resample("M").mean()

rm_italy_20 = italy_20.resample("M").mean()
rm_spain_20 = spain_20.resample("M").mean()
rm_greece_20 = greece_20.resample("M").mean()

# %% [markdown]
# **Resampling by week**
#
# _`rw` denotes resampling by week._

# %%
rw_italy_17_19 = italy_17_19.resample("W").mean()
rw_spain_17_19 = spain_17_19.resample("W").mean()
rw_greece_17_19 = greece_17_19.resample("W").mean()

rw_italy_20 = italy_20.resample("W").mean()
rw_spain_20 = spain_20.resample("W").mean()
rw_greece_20 = greece_20.resample("W").mean()

# %% [markdown]
# #### Combining weekly resampled data for all years (2017-2020)

# %%
alltime_italy = pd.concat([italy_17_19, italy_20])
alltime_spain = pd.concat([spain_17_19, spain_20])
alltime_greece = pd.concat([greece_17_19, greece_20])

alltime_rw_italy = alltime_italy.resample("W").mean()
alltime_rw_spain = alltime_spain.resample("W").mean()
alltime_rw_greece = alltime_greece.resample("W").mean()

# %% [markdown]
# ### Dickey-Fuller and Differencing

# %% [markdown]
# Augmented Dickey-Fuller test to estimate whether data are stationary.

# %%
audio_features = [
'danceability', 
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo']

# %%
# Code by Joseph Nelson! 

def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:3], index=['Test Statistic', 'p-value', 'lags_used'])
    return dfoutput

# %% [markdown]
# _Dickey-Fuller on original dataframes_

# %%
adfuller(alltime_rw)

# %%
for feature in audio_features:
    print(f'Dickey-Fuller Interpretation for {feature}:\n{interpret_dftest(adfuller(alltime_rw_italy[feature]))}')
# Out:
# Dickey-Fuller Interpretation for danceability:
# Test Statistic   -3.013333
# p-value           0.033668
# lags_used         4.000000
# dtype: float64
# Dickey-Fuller Interpretation for energy:
# Test Statistic   -3.470516
# p-value           0.008777
# lags_used         9.000000
# dtype: float64
# Dickey-Fuller Interpretation for key:
# Test Statistic   -6.335745e+00
# p-value           2.833617e-08
# lags_used         4.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for loudness:
# Test Statistic   -3.355416
# p-value           0.012576
# lags_used         7.000000
# dtype: float64
# Dickey-Fuller Interpretation for mode:
# Test Statistic   -6.787062e+00
# p-value           2.417084e-09
# lags_used         0.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for speechiness:
# Test Statistic   -4.108187
# p-value           0.000939
# lags_used         2.000000
# dtype: float64
# Dickey-Fuller Interpretation for acousticness:
# Test Statistic   -4.022911
# p-value           0.001295
# lags_used         2.000000
# dtype: float64
# Dickey-Fuller Interpretation for instrumentalness:
# Test Statistic   -3.783046
# p-value           0.003086
# lags_used         7.000000
# dtype: float64
# Dickey-Fuller Interpretation for liveness:
# Test Statistic   -4.990812
# p-value           0.000023
# lags_used         1.000000
# dtype: float64
# Dickey-Fuller Interpretation for valence:
# Test Statistic    -3.181356
# p-value            0.021090
# lags_used         14.000000
# dtype: float64
# Dickey-Fuller Interpretation for tempo:
# Test Statistic   -5.893790e+00
# p-value           2.883083e-07
# lags_used         5.000000e+00
# dtype: float64

# %% [markdown]
# ### DataFrame with once-differenced data

# %%
lag_df_italy = alltime_rw_italy.copy()

# %%
for feature in audio_features: 
    lag_df_italy[f'{feature}_once_differenced'] = lag_df_italy[feature].diff(1).fillna(0)

# %%
lag_df_italy.tail()
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2021-01-17      25.5      0.648654  0.575126  5.777143 -7.367766  0.591429
# 2021-01-24      25.5      0.657583  0.601891  5.514286 -7.057797  0.622857
# 2021-01-31      25.5      0.658066  0.605014  5.222857 -6.992654  0.648571
# 2021-02-07      25.5      0.666561  0.634389  5.402857 -6.677991  0.680000
# 2021-02-14      25.5      0.671104  0.647343  5.516667 -6.842603  0.656667
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2021-01-17     0.110776      0.358029          0.019525  0.186532  ...
# 2021-01-24     0.112212      0.363183          0.019110  0.216798  ...
# 2021-01-31     0.110351      0.341578          0.037043  0.217935  ...
# 2021-02-07     0.109192      0.268234          0.035348  0.223654  ...
# 2021-02-14     0.120716      0.277941          0.054173  0.220087  ...
#
#             energy_once_differenced  key_once_differenced  \
# date
# 2021-01-17                -0.019957              0.174286
# 2021-01-24                 0.026766             -0.262857
# 2021-01-31                 0.003123             -0.291429
# 2021-02-07                 0.029374              0.180000
# 2021-02-14                 0.012955              0.113810
#
#             loudness_once_differenced  mode_once_differenced  \
# date
# 2021-01-17                   0.367906              -0.020000
# 2021-01-24                   0.309969               0.031429
# 2021-01-31                   0.065143               0.025714
# 2021-02-07                   0.314663               0.031429
# 2021-02-14                  -0.164612              -0.023333
#
#             speechiness_once_differenced  acousticness_once_differenced  \
# date
# 2021-01-17                     -0.009854                       0.024697
# 2021-01-24                      0.001436                       0.005155
# 2021-01-31                     -0.001861                      -0.021605
# 2021-02-07                     -0.001159                      -0.073344
# 2021-02-14                      0.011523                       0.009707
#
#             instrumentalness_once_differenced  liveness_once_differenced  \
# date
# 2021-01-17                          -0.001551                   0.015144
# 2021-01-24                          -0.000415                   0.030267
# 2021-01-31                           0.017933                   0.001137
# 2021-02-07                          -0.001695                   0.005719
# 2021-02-14                           0.018826                  -0.003567
#
#             valence_once_differenced  tempo_once_differenced
# date
# 2021-01-17                 -0.007326                0.952746
# 2021-01-24                  0.029103                2.151463
# 2021-01-31                  0.001768               -1.597763
# 2021-02-07                 -0.006398                3.285271
# 2021-02-14                  0.049983                1.041837
#
# [5 rows x 25 columns]

# %% [markdown]
# _Dickey-Fuller on lag dataframe_

# %%
for feature in audio_features:
    print(f'Dickey-Fuller Interpretation for {feature}, once-differenced:\n{interpret_dftest(adfuller(lag_df_italy[feature].diff(1).fillna(0)))}')
# Out:
# Dickey-Fuller Interpretation for danceability, once-differenced:
# Test Statistic   -9.142255e+00
# p-value           2.828632e-15
# dtype: float64
# Dickey-Fuller Interpretation for energy, once-differenced:
# Test Statistic   -6.782611e+00
# p-value           2.477455e-09
# dtype: float64
# Dickey-Fuller Interpretation for key, once-differenced:
# Test Statistic   -8.518281e+00
# p-value           1.118537e-13
# dtype: float64
# Dickey-Fuller Interpretation for loudness, once-differenced:
# Test Statistic   -7.002232e+00
# p-value           7.272028e-10
# dtype: float64
# Dickey-Fuller Interpretation for mode, once-differenced:
# Test Statistic   -9.845662e+00
# p-value           4.627101e-17
# dtype: float64
# Dickey-Fuller Interpretation for speechiness, once-differenced:
# Test Statistic   -8.291616e+00
# p-value           4.246658e-13
# dtype: float64
# Dickey-Fuller Interpretation for acousticness, once-differenced:
# Test Statistic   -1.160866e+01
# p-value           2.544491e-21
# dtype: float64
# Dickey-Fuller Interpretation for instrumentalness, once-differenced:
# Test Statistic   -7.471488e+00
# p-value           5.041115e-11
# dtype: float64
# Dickey-Fuller Interpretation for liveness, once-differenced:
# Test Statistic   -7.236294e+00
# p-value           1.935642e-10
# dtype: float64
# Dickey-Fuller Interpretation for valence, once-differenced:
# Test Statistic   -5.043085
# p-value           0.000018
# dtype: float64
# Dickey-Fuller Interpretation for tempo, once-differenced:
# Test Statistic   -6.454214e+00
# p-value           1.497350e-08
# dtype: float64

# %%
interpret_dftest(adfuller(lag_df_italy['tempo_once_differenced']))
# Out:
# Test Statistic   -6.454214e+00
# p-value           1.497350e-08
# dtype: float64

# %%
interpret_dftest(adfuller(lag_df_italy['tempo'].diff(1).fillna(0)))
# Out:
# Test Statistic   -6.454214e+00
# p-value           1.497350e-08
# dtype: float64

# %% [markdown]
# ### Using `ndiffs` to figure out how many orders of difference $d$ I need in oder to have stationarity

# %%
from pmdarima.arima.utils import ndiffs

# %%
ndiffs(alltime_italy['acousticness'], test = 'adf')
# Out:
# 0

# %%
ndiffs(alltime_rw_italy['acousticness'], test = 'adf' )
# Out:
# 0

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ adf test: {ndiffs(alltime_italy[feature], test= "adf")}')
# Out:
# ndiffs for danceability stationarity w/ adf test: 0
# ndiffs for energy stationarity w/ adf test: 0
# ndiffs for key stationarity w/ adf test: 0
# ndiffs for loudness stationarity w/ adf test: 0
# ndiffs for mode stationarity w/ adf test: 0
# ndiffs for speechiness stationarity w/ adf test: 0
# ndiffs for acousticness stationarity w/ adf test: 0
# ndiffs for instrumentalness stationarity w/ adf test: 0
# ndiffs for liveness stationarity w/ adf test: 0
# ndiffs for valence stationarity w/ adf test: 0
# ndiffs for tempo stationarity w/ adf test: 0

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ adf test: {ndiffs(alltime_rw_italy[feature], test= "adf")}')
# Out:
# ndiffs for danceability stationarity w/ adf test: 1
# ndiffs for energy stationarity w/ adf test: 0
# ndiffs for key stationarity w/ adf test: 0
# ndiffs for loudness stationarity w/ adf test: 0
# ndiffs for mode stationarity w/ adf test: 1
# ndiffs for speechiness stationarity w/ adf test: 0
# ndiffs for acousticness stationarity w/ adf test: 0
# ndiffs for instrumentalness stationarity w/ adf test: 0
# ndiffs for liveness stationarity w/ adf test: 0
# ndiffs for valence stationarity w/ adf test: 0
# ndiffs for tempo stationarity w/ adf test: 0

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ kpss test: {ndiffs(alltime_italy[feature])}')
# Out:
# ndiffs for danceability stationarity w/ kpss test: 1
# ndiffs for energy stationarity w/ kpss test: 1
# ndiffs for key stationarity w/ kpss test: 1
# ndiffs for loudness stationarity w/ kpss test: 1
# ndiffs for mode stationarity w/ kpss test: 1
# ndiffs for speechiness stationarity w/ kpss test: 1
# ndiffs for acousticness stationarity w/ kpss test: 1
# ndiffs for instrumentalness stationarity w/ kpss test: 1
# ndiffs for liveness stationarity w/ kpss test: 1
# ndiffs for valence stationarity w/ kpss test: 1
# ndiffs for tempo stationarity w/ kpss test: 1

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ kpss test: {ndiffs(alltime_rw_italy[feature])}')
# Out:
# ndiffs for danceability stationarity w/ kpss test: 1
# ndiffs for energy stationarity w/ kpss test: 1
# ndiffs for key stationarity w/ kpss test: 0
# ndiffs for loudness stationarity w/ kpss test: 0
# ndiffs for mode stationarity w/ kpss test: 0
# ndiffs for speechiness stationarity w/ kpss test: 1
# ndiffs for acousticness stationarity w/ kpss test: 1
# ndiffs for instrumentalness stationarity w/ kpss test: 1
# ndiffs for liveness stationarity w/ kpss test: 1
# ndiffs for valence stationarity w/ kpss test: 1
# ndiffs for tempo stationarity w/ kpss test: 0

# %% [markdown]
# ### Finding `p`, `d`, and `q` values

# %% [markdown]
# _Using only the five audio features that are the most relevant or show some sort of pattern_

# %%
five_features = ['danceability', 'mode', 'acousticness', 'valence', 'tempo']

# %% [markdown]
# _Building dataframe with `ndifffs` for stationarity for each feature_

# %%
ndiff_dict = {
    'audio_feature':[],
    'ndiffs for stationarity':[]    
}

for feature in five_features:
    ndiff_dict['audio_feature'].append(feature)
    ndiff_dict['ndiffs for stationarity'].append(ndiffs(alltime_rw_italy[feature], test= "adf"))

ndiff_df = pd.DataFrame(ndiff_dict)
ndiff_df
# Out:
#   audio_feature  ndiffs for stationarity
# 0  danceability                        1
# 1          mode                        1
# 2  acousticness                        0
# 3       valence                        0
# 4         tempo                        0

# %%
arima_dict = {
    'audio_feature':[],
    'AIC':[],
    'ndiffs(d)':[],
    'best_p':[],
    'best_q':[],
    'order':[],
    'ARIMA_model':[]
}

def find_p_and_q(df, feature, n=6):
    
    train = df[feature][0:162]
    
    d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]

    # starting with large start AIC
    best_aic = 99 * (10 * 16)
    # creating variables to store best values ofd p and q 
    best_p = 0
    best_q = 0 

    # use nested for loop to iterate over values of p and q
    for p in range(n):

        for q in range(n):

            # insert try and and except statements
            try: 

                # fitting on ARIMA(p, 1, q) model 
                print(f'Attempting to fit ARIMA({p}, {d}, {q})')

                # instantiate ARIMA model
                arima = ARIMA(train, order=(p,d,q))

                # fit ARIMA model 
                model = arima.fit()

                # print out AIC for ARIMA(p, 1, q) model 
                print(f'For {feature}, the AIC for ARIMA({p},{d},{q}) is: {model.aic}')

                # Is this current model's AIC better than the OF best_aic? 
                if model.aic < best_aic:
                    # we want aic to be lower so we are setting a high aic and hoping for something lower 

                    # if it is, we overwrite the best_aic, best_p, and best_q
                    best_aic = model.aic
                    best_p = p 
                    best_q = q

            except:
                pass 

        order = (best_p, d, best_q)
    
    arima_dict['audio_feature'].append(feature)
    arima_dict['AIC'].append(best_aic)
    arima_dict['ndiffs(d)'].append(d)
    arima_dict['best_p'].append(best_p)
    arima_dict['best_q'].append(best_q)
    arima_dict['order'].append(order)
    arima_dict['ARIMA_model'].append(f'ARIMA({best_p},{d},{best_q})')

    print()
    print(f'{feature.capitalize()} MODEL FINISHED!')
    print(f'The model for {feature} that minimizes AIC on the training data is the ARIMA({best_p},{d},{best_q}).')
    print(f'The model has an aIC of {best_aic}.')
    print()

# %%
arima_dict
# Out:
# {'audio_feature': [],
#  'AIC': [],
#  'ndiffs(d)': [],
#  'best_p': [],
#  'best_q': [],
#  'order': [],
#  'ARIMA_model': []}

# %%
find_p_and_q(alltime_rw_italy, 'danceability')
# Out:
# Attempting to fit ARIMA(0, 1, 0)
# For danceability, the AIC for ARIMA(0,1,0) is: -725.8837710601316
# Attempting to fit ARIMA(0, 1, 1)
# For danceability, the AIC for ARIMA(0,1,1) is: -741.6315380820415
# Attempting to fit ARIMA(0, 1, 2)
# For danceability, the AIC for ARIMA(0,1,2) is: -741.0303860542913
# Attempting to fit ARIMA(0, 1, 3)
# For danceability, the AIC for ARIMA(0,1,3) is: -740.5524780247699
# Attempting to fit ARIMA(0, 1, 4)
# For danceability, the AIC for ARIMA(0,1,4) is: -739.7901121166813
# Attempting to fit ARIMA(0, 1, 5)
# For danceability, the AIC for ARIMA(0,1,5) is: -737.8819998993706
# Attempting to fit ARIMA(1, 1, 0)
# For danceability, the AIC for ARIMA(1,1,0) is: -737.8870828958725
# Attempting to fit ARIMA(1, 1, 1)
# For danceability, the AIC for ARIMA(1,1,1) is: -742.5043022824921
# Attempting to fit ARIMA(1, 1, 2)
# For danceability, the AIC for ARIMA(1,1,2) is: -746.7977296013453
# Attempting to fit ARIMA(1, 1, 3)
# Attempting to fit ARIMA(1, 1, 4)
# Attempting to fit ARIMA(1, 1, 5)
# Attempting to fit ARIMA(2, 1, 0)
# For danceability, the AIC for ARIMA(2,1,0) is: -738.2944348381241
# Attempting to fit ARIMA(2, 1, 1)
# For danceability, the AIC for ARIMA(2,1,1) is: -746.6353975548682
# Attempting to fit ARIMA(2, 1, 2)
# For danceability, the AIC for ARIMA(2,1,2) is: -744.8015438623029
# Attempting to fit ARIMA(2, 1, 3)
# Attempting to fit ARIMA(2, 1, 4)
# For danceability, the AIC for ARIMA(2,1,4) is: -739.8689878453513
# Attempting to fit ARIMA(2, 1, 5)
# Attempting to fit ARIMA(3, 1, 0)
# For danceability, the AIC for ARIMA(3,1,0) is: -737.475203876252
# Attempting to fit ARIMA(3, 1, 1)
# For danceability, the AIC for ARIMA(3,1,1) is: -744.7797883165797
# Attempting to fit ARIMA(3, 1, 2)
# For danceability, the AIC for ARIMA(3,1,2) is: -743.3086562186486
# Attempting to fit ARIMA(3, 1, 3)
# For danceability, the AIC for ARIMA(3,1,3) is: -739.5269839692373
# Attempting to fit ARIMA(3, 1, 4)
# For danceability, the AIC for ARIMA(3,1,4) is: -743.987647843016
# Attempting to fit ARIMA(3, 1, 5)
# Attempting to fit ARIMA(4, 1, 0)
# For danceability, the AIC for ARIMA(4,1,0) is: -738.380965870728
# Attempting to fit ARIMA(4, 1, 1)
# For danceability, the AIC for ARIMA(4,1,1) is: -742.7820190733194
# Attempting to fit ARIMA(4, 1, 2)
# For danceability, the AIC for ARIMA(4,1,2) is: -740.9059730976023
# Attempting to fit ARIMA(4, 1, 3)
# For danceability, the AIC for ARIMA(4,1,3) is: -740.0356870710514
# Attempting to fit ARIMA(4, 1, 4)
# For danceability, the AIC for ARIMA(4,1,4) is: -737.4919438785103
# Attempting to fit ARIMA(4, 1, 5)
# For danceability, the AIC for ARIMA(4,1,5) is: -736.0322271630284
# Attempting to fit ARIMA(5, 1, 0)
# For danceability, the AIC for ARIMA(5,1,0) is: -736.4059858159242
# Attempting to fit ARIMA(5, 1, 1)
# For danceability, the AIC for ARIMA(5,1,1) is: -741.4678593608312
# Attempting to fit ARIMA(5, 1, 2)
# For danceability, the AIC for ARIMA(5,1,2) is: -739.4048242931233
# Attempting to fit ARIMA(5, 1, 3)
# For danceability, the AIC for ARIMA(5,1,3) is: -738.5742371384392
# Attempting to fit ARIMA(5, 1, 4)
# For danceability, the AIC for ARIMA(5,1,4) is: -738.8028100694864
# Attempting to fit ARIMA(5, 1, 5)
# For danceability, the AIC for ARIMA(5,1,5) is: -736.6443742189408
#
# Danceability MODEL FINISHED!
# The model for danceability that minimizes AIC on the training data is the ARIMA(1,1,2).
# The model has an aIC of -746.7977296013453.

# %%
for feature in five_features:
    find_p_and_q(alltime_rw_italy, feature)
# Out:
# Attempting to fit ARIMA(0, 1, 0)
# For danceability, the AIC for ARIMA(0,1,0) is: -725.8837710601316
# Attempting to fit ARIMA(0, 1, 1)
# For danceability, the AIC for ARIMA(0,1,1) is: -741.6315380820415
# Attempting to fit ARIMA(0, 1, 2)
# For danceability, the AIC for ARIMA(0,1,2) is: -741.0303860542913
# Attempting to fit ARIMA(0, 1, 3)
# For danceability, the AIC for ARIMA(0,1,3) is: -740.5524780247699
# Attempting to fit ARIMA(0, 1, 4)
# For danceability, the AIC for ARIMA(0,1,4) is: -739.7901121166813
# Attempting to fit ARIMA(0, 1, 5)
# For danceability, the AIC for ARIMA(0,1,5) is: -737.8819998993706
# Attempting to fit ARIMA(1, 1, 0)
# For danceability, the AIC for ARIMA(1,1,0) is: -737.8870828958725
# Attempting to fit ARIMA(1, 1, 1)
# For danceability, the AIC for ARIMA(1,1,1) is: -742.5043022824921
# Attempting to fit ARIMA(1, 1, 2)
# For danceability, the AIC for ARIMA(1,1,2) is: -746.7977296013453
# Attempting to fit ARIMA(1, 1, 3)
# Attempting to fit ARIMA(1, 1, 4)
# Attempting to fit ARIMA(1, 1, 5)
# Attempting to fit ARIMA(2, 1, 0)
# For danceability, the AIC for ARIMA(2,1,0) is: -738.2944348381241
# Attempting to fit ARIMA(2, 1, 1)
# For danceability, the AIC for ARIMA(2,1,1) is: -746.6353975548682
# Attempting to fit ARIMA(2, 1, 2)
# For danceability, the AIC for ARIMA(2,1,2) is: -744.8015438623029
# Attempting to fit ARIMA(2, 1, 3)
# Attempting to fit ARIMA(2, 1, 4)
# For danceability, the AIC for ARIMA(2,1,4) is: -739.8689878453513
# Attempting to fit ARIMA(2, 1, 5)
# Attempting to fit ARIMA(3, 1, 0)
# For danceability, the AIC for ARIMA(3,1,0) is: -737.475203876252
# Attempting to fit ARIMA(3, 1, 1)
# For danceability, the AIC for ARIMA(3,1,1) is: -744.7797883165797
# Attempting to fit ARIMA(3, 1, 2)
# For danceability, the AIC for ARIMA(3,1,2) is: -743.3086562186486
# Attempting to fit ARIMA(3, 1, 3)
# For danceability, the AIC for ARIMA(3,1,3) is: -739.5269839692373
# Attempting to fit ARIMA(3, 1, 4)
# For danceability, the AIC for ARIMA(3,1,4) is: -743.987647843016
# Attempting to fit ARIMA(3, 1, 5)
# Attempting to fit ARIMA(4, 1, 0)
# For danceability, the AIC for ARIMA(4,1,0) is: -738.380965870728
# Attempting to fit ARIMA(4, 1, 1)
# For danceability, the AIC for ARIMA(4,1,1) is: -742.7820190733194
# Attempting to fit ARIMA(4, 1, 2)
# For danceability, the AIC for ARIMA(4,1,2) is: -740.9059730976023
# Attempting to fit ARIMA(4, 1, 3)
# For danceability, the AIC for ARIMA(4,1,3) is: -740.0356870710514
# Attempting to fit ARIMA(4, 1, 4)
# For danceability, the AIC for ARIMA(4,1,4) is: -737.4919438785103
# Attempting to fit ARIMA(4, 1, 5)
# For danceability, the AIC for ARIMA(4,1,5) is: -736.0322271630284
# Attempting to fit ARIMA(5, 1, 0)
# For danceability, the AIC for ARIMA(5,1,0) is: -736.4059858159242
# Attempting to fit ARIMA(5, 1, 1)
# For danceability, the AIC for ARIMA(5,1,1) is: -741.4678593608312
# Attempting to fit ARIMA(5, 1, 2)
# For danceability, the AIC for ARIMA(5,1,2) is: -739.4048242931233
# Attempting to fit ARIMA(5, 1, 3)
# For danceability, the AIC for ARIMA(5,1,3) is: -738.5742371384392
# Attempting to fit ARIMA(5, 1, 4)
# For danceability, the AIC for ARIMA(5,1,4) is: -738.8028100694864
# Attempting to fit ARIMA(5, 1, 5)
# For danceability, the AIC for ARIMA(5,1,5) is: -736.6443742189408
#
# Danceability MODEL FINISHED!
# The model for danceability that minimizes AIC on the training data is the ARIMA(1,1,2).
# The model has an aIC of -746.7977296013453.
#
# Attempting to fit ARIMA(0, 1, 0)
# For mode, the AIC for ARIMA(0,1,0) is: -411.4546745530347
# Attempting to fit ARIMA(0, 1, 1)
# For mode, the AIC for ARIMA(0,1,1) is: -436.3204166536013
# Attempting to fit ARIMA(0, 1, 2)
# For mode, the AIC for ARIMA(0,1,2) is: -439.02029617089755
# Attempting to fit ARIMA(0, 1, 3)
# For mode, the AIC for ARIMA(0,1,3) is: -437.02941374971493
# Attempting to fit ARIMA(0, 1, 4)
# For mode, the AIC for ARIMA(0,1,4) is: -435.1096032606301
# Attempting to fit ARIMA(0, 1, 5)
# For mode, the AIC for ARIMA(0,1,5) is: -436.9734791751302
# Attempting to fit ARIMA(1, 1, 0)
# For mode, the AIC for ARIMA(1,1,0) is: -423.88361206701853
# Attempting to fit ARIMA(1, 1, 1)
# For mode, the AIC for ARIMA(1,1,1) is: -438.61084578139145
# Attempting to fit ARIMA(1, 1, 2)
# For mode, the AIC for ARIMA(1,1,2) is: -437.0306492414564
# Attempting to fit ARIMA(1, 1, 3)
# For mode, the AIC for ARIMA(1,1,3) is: -435.25453825056974
# Attempting to fit ARIMA(1, 1, 4)
# Attempting to fit ARIMA(1, 1, 5)
# Attempting to fit ARIMA(2, 1, 0)
# For mode, the AIC for ARIMA(2,1,0) is: -434.58548695250846
# Attempting to fit ARIMA(2, 1, 1)
# For mode, the AIC for ARIMA(2,1,1) is: -436.78106279424975
# Attempting to fit ARIMA(2, 1, 2)
# For mode, the AIC for ARIMA(2,1,2) is: -435.0330853876333
# Attempting to fit ARIMA(2, 1, 3)
# For mode, the AIC for ARIMA(2,1,3) is: -441.8315228667199
# Attempting to fit ARIMA(2, 1, 4)
# Attempting to fit ARIMA(2, 1, 5)
# Attempting to fit ARIMA(3, 1, 0)
# For mode, the AIC for ARIMA(3,1,0) is: -434.64166168385094
# Attempting to fit ARIMA(3, 1, 1)
# For mode, the AIC for ARIMA(3,1,1) is: -442.27620580175136
# Attempting to fit ARIMA(3, 1, 2)
# For mode, the AIC for ARIMA(3,1,2) is: -440.4015642040309
# Attempting to fit ARIMA(3, 1, 3)
# For mode, the AIC for ARIMA(3,1,3) is: -443.23144843652864
# Attempting to fit ARIMA(3, 1, 4)
# Attempting to fit ARIMA(3, 1, 5)
# Attempting to fit ARIMA(4, 1, 0)
# For mode, the AIC for ARIMA(4,1,0) is: -432.71312065495607
# Attempting to fit ARIMA(4, 1, 1)
# For mode, the AIC for ARIMA(4,1,1) is: -431.1441548133553
# Attempting to fit ARIMA(4, 1, 2)
# For mode, the AIC for ARIMA(4,1,2) is: -439.44043652577494
# Attempting to fit ARIMA(4, 1, 3)
# For mode, the AIC for ARIMA(4,1,3) is: -446.5317229820524
# Attempting to fit ARIMA(4, 1, 4)
# Attempting to fit ARIMA(4, 1, 5)
# For mode, the AIC for ARIMA(4,1,5) is: -443.38300004213175
# Attempting to fit ARIMA(5, 1, 0)
# For mode, the AIC for ARIMA(5,1,0) is: -437.17252245557455
# Attempting to fit ARIMA(5, 1, 1)
# For mode, the AIC for ARIMA(5,1,1) is: -435.26957354008874
# Attempting to fit ARIMA(5, 1, 2)
# For mode, the AIC for ARIMA(5,1,2) is: -437.4047781346607
# Attempting to fit ARIMA(5, 1, 3)
# For mode, the AIC for ARIMA(5,1,3) is: -442.1989440057901
# Attempting to fit ARIMA(5, 1, 4)
# For mode, the AIC for ARIMA(5,1,4) is: -441.2254889095338
# Attempting to fit ARIMA(5, 1, 5)
# For mode, the AIC for ARIMA(5,1,5) is: -438.56917420147823
#
# Mode MODEL FINISHED!
# The model for mode that minimizes AIC on the training data is the ARIMA(4,1,3).
# The model has an aIC of -446.5317229820524.
#
# Attempting to fit ARIMA(0, 0, 0)
# For acousticness, the AIC for ARIMA(0,0,0) is: -484.8727506697037
# Attempting to fit ARIMA(0, 0, 1)
# For acousticness, the AIC for ARIMA(0,0,1) is: -562.8851303403668
# Attempting to fit ARIMA(0, 0, 2)
# For acousticness, the AIC for ARIMA(0,0,2) is: -588.8455892219896
# Attempting to fit ARIMA(0, 0, 3)
# For acousticness, the AIC for ARIMA(0,0,3) is: -595.3605348324553
# Attempting to fit ARIMA(0, 0, 4)
# For acousticness, the AIC for ARIMA(0,0,4) is: -600.2662567863118
# Attempting to fit ARIMA(0, 0, 5)
# For acousticness, the AIC for ARIMA(0,0,5) is: -601.5747278998871
# Attempting to fit ARIMA(1, 0, 0)
# For acousticness, the AIC for ARIMA(1,0,0) is: -615.3995388872605
# Attempting to fit ARIMA(1, 0, 1)
# For acousticness, the AIC for ARIMA(1,0,1) is: -615.8158117177214
# Attempting to fit ARIMA(1, 0, 2)
# For acousticness, the AIC for ARIMA(1,0,2) is: -617.0166949974206
# Attempting to fit ARIMA(1, 0, 3)
# For acousticness, the AIC for ARIMA(1,0,3) is: -615.5628435549773
# Attempting to fit ARIMA(1, 0, 4)
# Attempting to fit ARIMA(1, 0, 5)
# Attempting to fit ARIMA(2, 0, 0)
# For acousticness, the AIC for ARIMA(2,0,0) is: -615.0283120619346
# Attempting to fit ARIMA(2, 0, 1)
# For acousticness, the AIC for ARIMA(2,0,1) is: -616.858206799208
# Attempting to fit ARIMA(2, 0, 2)
# For acousticness, the AIC for ARIMA(2,0,2) is: -615.3458429672038
# Attempting to fit ARIMA(2, 0, 3)
# For acousticness, the AIC for ARIMA(2,0,3) is: -614.0944297493812
# Attempting to fit ARIMA(2, 0, 4)
# For acousticness, the AIC for ARIMA(2,0,4) is: -612.2433716483266
# Attempting to fit ARIMA(2, 0, 5)
# Attempting to fit ARIMA(3, 0, 0)
# For acousticness, the AIC for ARIMA(3,0,0) is: -614.9498422859591
# Attempting to fit ARIMA(3, 0, 1)
# For acousticness, the AIC for ARIMA(3,0,1) is: -615.5274222937654
# Attempting to fit ARIMA(3, 0, 2)
# For acousticness, the AIC for ARIMA(3,0,2) is: -619.9861698605054
# Attempting to fit ARIMA(3, 0, 3)
# For acousticness, the AIC for ARIMA(3,0,3) is: -612.2068270144656
# Attempting to fit ARIMA(3, 0, 4)
# For acousticness, the AIC for ARIMA(3,0,4) is: -617.4383468928298
# Attempting to fit ARIMA(3, 0, 5)
# For acousticness, the AIC for ARIMA(3,0,5) is: -614.0372069492579
# Attempting to fit ARIMA(4, 0, 0)
# For acousticness, the AIC for ARIMA(4,0,0) is: -615.0890852345159
# Attempting to fit ARIMA(4, 0, 1)
# For acousticness, the AIC for ARIMA(4,0,1) is: -614.0055932350725
# Attempting to fit ARIMA(4, 0, 2)
# For acousticness, the AIC for ARIMA(4,0,2) is: -612.4109825860352
# Attempting to fit ARIMA(4, 0, 3)
# For acousticness, the AIC for ARIMA(4,0,3) is: -612.054430950268
# Attempting to fit ARIMA(4, 0, 4)
# For acousticness, the AIC for ARIMA(4,0,4) is: -609.531566240042
# Attempting to fit ARIMA(4, 0, 5)
# For acousticness, the AIC for ARIMA(4,0,5) is: -609.6192771414684
# Attempting to fit ARIMA(5, 0, 0)
# For acousticness, the AIC for ARIMA(5,0,0) is: -613.5068543494809
# Attempting to fit ARIMA(5, 0, 1)
# For acousticness, the AIC for ARIMA(5,0,1) is: -612.0371327958807
# Attempting to fit ARIMA(5, 0, 2)
# For acousticness, the AIC for ARIMA(5,0,2) is: -610.5462932734023
# Attempting to fit ARIMA(5, 0, 3)
# For acousticness, the AIC for ARIMA(5,0,3) is: -609.9168734751087
# Attempting to fit ARIMA(5, 0, 4)
# For acousticness, the AIC for ARIMA(5,0,4) is: -609.0343309333906
# Attempting to fit ARIMA(5, 0, 5)
#
# Acousticness MODEL FINISHED!
# The model for acousticness that minimizes AIC on the training data is the ARIMA(3,0,2).
# The model has an aIC of -619.9861698605054.
#
# Attempting to fit ARIMA(0, 0, 0)
# For valence, the AIC for ARIMA(0,0,0) is: -546.5410215093714
# Attempting to fit ARIMA(0, 0, 1)
# For valence, the AIC for ARIMA(0,0,1) is: -609.7721952834592
# Attempting to fit ARIMA(0, 0, 2)
# For valence, the AIC for ARIMA(0,0,2) is: -621.2232304930216
# Attempting to fit ARIMA(0, 0, 3)
# For valence, the AIC for ARIMA(0,0,3) is: -636.787252165855
# Attempting to fit ARIMA(0, 0, 4)
# For valence, the AIC for ARIMA(0,0,4) is: -635.339790356952
# Attempting to fit ARIMA(0, 0, 5)
# For valence, the AIC for ARIMA(0,0,5) is: -640.0276924636945
# Attempting to fit ARIMA(1, 0, 0)
# For valence, the AIC for ARIMA(1,0,0) is: -642.6351957621176
# Attempting to fit ARIMA(1, 0, 1)
# For valence, the AIC for ARIMA(1,0,1) is: -645.9516522231762
# Attempting to fit ARIMA(1, 0, 2)
# For valence, the AIC for ARIMA(1,0,2) is: -645.9131134582295
# Attempting to fit ARIMA(1, 0, 3)
# For valence, the AIC for ARIMA(1,0,3) is: -643.93539839312
# Attempting to fit ARIMA(1, 0, 4)
# Attempting to fit ARIMA(1, 0, 5)
# Attempting to fit ARIMA(2, 0, 0)
# For valence, the AIC for ARIMA(2,0,0) is: -644.4130827457203
# Attempting to fit ARIMA(2, 0, 1)
# For valence, the AIC for ARIMA(2,0,1) is: -646.1258952645029
# Attempting to fit ARIMA(2, 0, 2)
# For valence, the AIC for ARIMA(2,0,2) is: -647.40963308537
# Attempting to fit ARIMA(2, 0, 3)
# For valence, the AIC for ARIMA(2,0,3) is: -646.1924102587221
# Attempting to fit ARIMA(2, 0, 4)
# Attempting to fit ARIMA(2, 0, 5)
# For valence, the AIC for ARIMA(2,0,5) is: -642.3319847430313
# Attempting to fit ARIMA(3, 0, 0)
# For valence, the AIC for ARIMA(3,0,0) is: -644.5960962599887
# Attempting to fit ARIMA(3, 0, 1)
# For valence, the AIC for ARIMA(3,0,1) is: -644.1263366342656
# Attempting to fit ARIMA(3, 0, 2)
# For valence, the AIC for ARIMA(3,0,2) is: -646.6942702431103
# Attempting to fit ARIMA(3, 0, 3)
# For valence, the AIC for ARIMA(3,0,3) is: -644.8407401530488
# Attempting to fit ARIMA(3, 0, 4)
# For valence, the AIC for ARIMA(3,0,4) is: -644.8482447570558
# Attempting to fit ARIMA(3, 0, 5)
# For valence, the AIC for ARIMA(3,0,5) is: -642.4359269768332
# Attempting to fit ARIMA(4, 0, 0)
# For valence, the AIC for ARIMA(4,0,0) is: -642.6207677689594
# Attempting to fit ARIMA(4, 0, 1)
# For valence, the AIC for ARIMA(4,0,1) is: -643.4131073634054
# Attempting to fit ARIMA(4, 0, 2)
# For valence, the AIC for ARIMA(4,0,2) is: -643.692100179762
# Attempting to fit ARIMA(4, 0, 3)
# For valence, the AIC for ARIMA(4,0,3) is: -643.9175848204387
# Attempting to fit ARIMA(4, 0, 4)
# For valence, the AIC for ARIMA(4,0,4) is: -645.2467175662626
# Attempting to fit ARIMA(4, 0, 5)
# For valence, the AIC for ARIMA(4,0,5) is: -643.2542123723312
# Attempting to fit ARIMA(5, 0, 0)
# For valence, the AIC for ARIMA(5,0,0) is: -645.1674652673624
# Attempting to fit ARIMA(5, 0, 1)
# For valence, the AIC for ARIMA(5,0,1) is: -644.4442996429549
# Attempting to fit ARIMA(5, 0, 2)
# For valence, the AIC for ARIMA(5,0,2) is: -642.9324483806785
# Attempting to fit ARIMA(5, 0, 3)
# For valence, the AIC for ARIMA(5,0,3) is: -642.5853165998363
# Attempting to fit ARIMA(5, 0, 4)
# For valence, the AIC for ARIMA(5,0,4) is: -644.8070659865413
# Attempting to fit ARIMA(5, 0, 5)
# For valence, the AIC for ARIMA(5,0,5) is: -642.5941469962748
#
# Valence MODEL FINISHED!
# The model for valence that minimizes AIC on the training data is the ARIMA(2,0,2).
# The model has an aIC of -647.40963308537.
#
# Attempting to fit ARIMA(0, 0, 0)
# For tempo, the AIC for ARIMA(0,0,0) is: 879.9192071076823
# Attempting to fit ARIMA(0, 0, 1)
# For tempo, the AIC for ARIMA(0,0,1) is: 829.4188015285736
# Attempting to fit ARIMA(0, 0, 2)
# For tempo, the AIC for ARIMA(0,0,2) is: 815.8980034622024
# Attempting to fit ARIMA(0, 0, 3)
# For tempo, the AIC for ARIMA(0,0,3) is: 811.3215724224943
# Attempting to fit ARIMA(0, 0, 4)
# For tempo, the AIC for ARIMA(0,0,4) is: 812.7407140308959
# Attempting to fit ARIMA(0, 0, 5)
# For tempo, the AIC for ARIMA(0,0,5) is: 796.9048836504389
# Attempting to fit ARIMA(1, 0, 0)
# For tempo, the AIC for ARIMA(1,0,0) is: 805.5303111769767
# Attempting to fit ARIMA(1, 0, 1)
# For tempo, the AIC for ARIMA(1,0,1) is: 805.9533943607224
# Attempting to fit ARIMA(1, 0, 2)
# For tempo, the AIC for ARIMA(1,0,2) is: 807.8211609168243
# Attempting to fit ARIMA(1, 0, 3)
# For tempo, the AIC for ARIMA(1,0,3) is: 808.6549249096608
# Attempting to fit ARIMA(1, 0, 4)
# For tempo, the AIC for ARIMA(1,0,4) is: 810.5866639253529
# Attempting to fit ARIMA(1, 0, 5)
# Attempting to fit ARIMA(2, 0, 0)
# For tempo, the AIC for ARIMA(2,0,0) is: 805.8904012734422
# Attempting to fit ARIMA(2, 0, 1)
# For tempo, the AIC for ARIMA(2,0,1) is: 807.8869272290817
# Attempting to fit ARIMA(2, 0, 2)
# For tempo, the AIC for ARIMA(2,0,2) is: 807.8620371572175
# Attempting to fit ARIMA(2, 0, 3)
# For tempo, the AIC for ARIMA(2,0,3) is: 808.47473613439
# Attempting to fit ARIMA(2, 0, 4)
# For tempo, the AIC for ARIMA(2,0,4) is: 810.4581449634929
# Attempting to fit ARIMA(2, 0, 5)
# For tempo, the AIC for ARIMA(2,0,5) is: 799.5251978900004
# Attempting to fit ARIMA(3, 0, 0)
# For tempo, the AIC for ARIMA(3,0,0) is: 807.8819228697744
# Attempting to fit ARIMA(3, 0, 1)
# For tempo, the AIC for ARIMA(3,0,1) is: 806.7538129757463
# Attempting to fit ARIMA(3, 0, 2)
# For tempo, the AIC for ARIMA(3,0,2) is: 806.5587958871713
# Attempting to fit ARIMA(3, 0, 3)
# For tempo, the AIC for ARIMA(3,0,3) is: 809.3415717612384
# Attempting to fit ARIMA(3, 0, 4)
# For tempo, the AIC for ARIMA(3,0,4) is: 810.839388908015
# Attempting to fit ARIMA(3, 0, 5)
# For tempo, the AIC for ARIMA(3,0,5) is: 800.8532152887079
# Attempting to fit ARIMA(4, 0, 0)
# For tempo, the AIC for ARIMA(4,0,0) is: 809.0312382484665
# Attempting to fit ARIMA(4, 0, 1)
# For tempo, the AIC for ARIMA(4,0,1) is: 807.4107374805192
# Attempting to fit ARIMA(4, 0, 2)
# For tempo, the AIC for ARIMA(4,0,2) is: 808.9347262458799
# Attempting to fit ARIMA(4, 0, 3)
# For tempo, the AIC for ARIMA(4,0,3) is: 809.2891630664775
# Attempting to fit ARIMA(4, 0, 4)
# For tempo, the AIC for ARIMA(4,0,4) is: 806.560013954863
# Attempting to fit ARIMA(4, 0, 5)
# For tempo, the AIC for ARIMA(4,0,5) is: 800.3680253777875
# Attempting to fit ARIMA(5, 0, 0)
# For tempo, the AIC for ARIMA(5,0,0) is: 811.0182341415007
# Attempting to fit ARIMA(5, 0, 1)
# For tempo, the AIC for ARIMA(5,0,1) is: 809.0617728853392
# Attempting to fit ARIMA(5, 0, 2)
# For tempo, the AIC for ARIMA(5,0,2) is: 810.7810213718867
# Attempting to fit ARIMA(5, 0, 3)
# For tempo, the AIC for ARIMA(5,0,3) is: 811.2596029262997
# Attempting to fit ARIMA(5, 0, 4)
# For tempo, the AIC for ARIMA(5,0,4) is: 814.6065750797954
# Attempting to fit ARIMA(5, 0, 5)
# For tempo, the AIC for ARIMA(5,0,5) is: 800.3081947059718
#
# Tempo MODEL FINISHED!
# The model for tempo that minimizes AIC on the training data is the ARIMA(0,0,5).
# The model has an aIC of 796.9048836504389.

# %%
arima_param_df = pd.DataFrame(arima_dict)
arima_param_df
# Out:
#   audio_feature         AIC  ndiffs(d)  best_p  best_q      order  \
# 0  danceability -746.797730          1       1       2  (1, 1, 2)
# 1  danceability -746.797730          1       1       2  (1, 1, 2)
# 2          mode -446.531723          1       4       3  (4, 1, 3)
# 3  acousticness -619.986170          0       3       2  (3, 0, 2)
# 4       valence -647.409633          0       2       2  (2, 0, 2)
# 5         tempo  796.904884          0       0       5  (0, 0, 5)
#
#     ARIMA_model
# 0  ARIMA(1,1,2)
# 1  ARIMA(1,1,2)
# 2  ARIMA(4,1,3)
# 3  ARIMA(3,0,2)
# 4  ARIMA(2,0,2)
# 5  ARIMA(0,0,5)

# %%
arima_param_df = arima_param_df.drop([0])
arima_param_df
# Out:
#   audio_feature         AIC  ndiffs(d)  best_p  best_q      order  \
# 1  danceability -746.797730          1       1       2  (1, 1, 2)
# 2          mode -446.531723          1       4       3  (4, 1, 3)
# 3  acousticness -619.986170          0       3       2  (3, 0, 2)
# 4       valence -647.409633          0       2       2  (2, 0, 2)
# 5         tempo  796.904884          0       0       5  (0, 0, 5)
#
#     ARIMA_model
# 1  ARIMA(1,1,2)
# 2  ARIMA(4,1,3)
# 3  ARIMA(3,0,2)
# 4  ARIMA(2,0,2)
# 5  ARIMA(0,0,5)

# %% [markdown]
# ### Building dataframes in year-long chunks

# %%
lag_df_italy
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2017-01-01      25.5      0.604800  0.591096  5.840000 -9.008200  0.600000
# 2017-01-08      25.5      0.592829  0.596115  5.602857 -8.670323  0.717143
# 2017-01-15      25.5      0.590561  0.584263  5.025714 -8.433451  0.625714
# 2017-01-22      25.5      0.570760  0.618591  4.497143 -7.809969  0.588571
# 2017-01-29      25.5      0.549560  0.672368  4.888571 -6.910569  0.705714
# ...              ...           ...       ...       ...       ...       ...
# 2021-01-17      25.5      0.648654  0.575126  5.777143 -7.367766  0.591429
# 2021-01-24      25.5      0.657583  0.601891  5.514286 -7.057797  0.622857
# 2021-01-31      25.5      0.658066  0.605014  5.222857 -6.992654  0.648571
# 2021-02-07      25.5      0.666561  0.634389  5.402857 -6.677991  0.680000
# 2021-02-14      25.5      0.671104  0.647343  5.516667 -6.842603  0.656667
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2017-01-01     0.081670      0.303003          0.061578  0.172262  ...
# 2017-01-08     0.091595      0.355359          0.182476  0.175617  ...
# 2017-01-15     0.091436      0.340648          0.141121  0.204428  ...
# 2017-01-22     0.093505      0.348782          0.111421  0.163771  ...
# 2017-01-29     0.087994      0.302466          0.069887  0.175481  ...
# ...                 ...           ...               ...       ...  ...
# 2021-01-17     0.110776      0.358029          0.019525  0.186532  ...
# 2021-01-24     0.112212      0.363183          0.019110  0.216798  ...
# 2021-01-31     0.110351      0.341578          0.037043  0.217935  ...
# 2021-02-07     0.109192      0.268234          0.035348  0.223654  ...
# 2021-02-14     0.120716      0.277941          0.054173  0.220087  ...
#
#             energy_once_differenced  key_once_differenced  \
# date
# 2017-01-01                 0.000000              0.000000
# 2017-01-08                 0.005019             -0.237143
# 2017-01-15                -0.011853             -0.577143
# 2017-01-22                 0.034328             -0.528571
# 2017-01-29                 0.053777              0.391429
# ...                             ...                   ...
# 2021-01-17                -0.019957              0.174286
# 2021-01-24                 0.026766             -0.262857
# 2021-01-31                 0.003123             -0.291429
# 2021-02-07                 0.029374              0.180000
# 2021-02-14                 0.012955              0.113810
#
#             loudness_once_differenced  mode_once_differenced  \
# date
# 2017-01-01                   0.000000               0.000000
# 2017-01-08                   0.337877               0.117143
# 2017-01-15                   0.236871              -0.091429
# 2017-01-22                   0.623483              -0.037143
# 2017-01-29                   0.899400               0.117143
# ...                               ...                    ...
# 2021-01-17                   0.367906              -0.020000
# 2021-01-24                   0.309969               0.031429
# 2021-01-31                   0.065143               0.025714
# 2021-02-07                   0.314663               0.031429
# 2021-02-14                  -0.164612              -0.023333
#
#             speechiness_once_differenced  acousticness_once_differenced  \
# date
# 2017-01-01                      0.000000                       0.000000
# 2017-01-08                      0.009925                       0.052356
# 2017-01-15                     -0.000159                      -0.014711
# 2017-01-22                      0.002069                       0.008134
# 2017-01-29                     -0.005511                      -0.046316
# ...                                  ...                            ...
# 2021-01-17                     -0.009854                       0.024697
# 2021-01-24                      0.001436                       0.005155
# 2021-01-31                     -0.001861                      -0.021605
# 2021-02-07                     -0.001159                      -0.073344
# 2021-02-14                      0.011523                       0.009707
#
#             instrumentalness_once_differenced  liveness_once_differenced  \
# date
# 2017-01-01                           0.000000                   0.000000
# 2017-01-08                           0.120898                   0.003355
# 2017-01-15                          -0.041355                   0.028811
# 2017-01-22                          -0.029699                  -0.040657
# 2017-01-29                          -0.041534                   0.011710
# ...                                       ...                        ...
# 2021-01-17                          -0.001551                   0.015144
# 2021-01-24                          -0.000415                   0.030267
# 2021-01-31                           0.017933                   0.001137
# 2021-02-07                          -0.001695                   0.005719
# 2021-02-14                           0.018826                  -0.003567
#
#             valence_once_differenced  tempo_once_differenced
# date
# 2017-01-01                  0.000000                0.000000
# 2017-01-08                 -0.075560                3.052389
# 2017-01-15                  0.011662               -0.406554
# 2017-01-22                 -0.005162                1.572900
# 2017-01-29                  0.072090                2.910506
# ...                              ...                     ...
# 2021-01-17                 -0.007326                0.952746
# 2021-01-24                  0.029103                2.151463
# 2021-01-31                  0.001768               -1.597763
# 2021-02-07                 -0.006398                3.285271
# 2021-02-14                  0.049983                1.041837
#
# [216 rows x 25 columns]

# %%
it_rw_17 = lag_df_italy[0:53]
it_rw_18 = lag_df_italy[53:105]
it_rw_19 = lag_df_italy[105:158]

# %%
it_rw_17.tail(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2017-12-24      25.5      0.612843  0.674063  5.302857 -6.309091  0.657143
# 2017-12-31      25.5      0.610449  0.656787  5.637143 -6.322729  0.688571
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2017-12-24     0.123394      0.253601          0.013014  0.179737  ...
# 2017-12-31     0.102279      0.209149          0.022378  0.171537  ...
#
#             energy_once_differenced  key_once_differenced  \
# date
# 2017-12-24                -0.017777              0.740000
# 2017-12-31                -0.017276              0.334286
#
#             loudness_once_differenced  mode_once_differenced  \
# date
# 2017-12-24                  -0.155729               0.045714
# 2017-12-31                  -0.013637               0.031429
#
#             speechiness_once_differenced  acousticness_once_differenced  \
# date
# 2017-12-24                      0.006183                      -0.011564
# 2017-12-31                     -0.021116                      -0.044452
#
#             instrumentalness_once_differenced  liveness_once_differenced  \
# date
# 2017-12-24                          -0.003578                   0.025182
# 2017-12-31                           0.009364                  -0.008199
#
#             valence_once_differenced  tempo_once_differenced
# date
# 2017-12-24                 -0.027138               -2.956506
# 2017-12-31                 -0.028425                7.831740
#
# [2 rows x 25 columns]

# %%
it_rw_18.tail(2)
# Out:
#             Position  danceability   energy       key  loudness      mode  \
# date
# 2018-12-23      25.5      0.652526  0.62446  5.345714 -7.126363  0.548571
# 2018-12-30      25.5      0.637171  0.63514  4.971429 -6.814571  0.528571
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2018-12-23     0.098575      0.315516          0.058491  0.126928  ...
# 2018-12-30     0.104640      0.342631          0.066215  0.139117  ...
#
#             energy_once_differenced  key_once_differenced  \
# date
# 2018-12-23                 0.040456              0.037143
# 2018-12-30                 0.010680             -0.374286
#
#             loudness_once_differenced  mode_once_differenced  \
# date
# 2018-12-23                   0.448194              -0.022857
# 2018-12-30                   0.311791              -0.020000
#
#             speechiness_once_differenced  acousticness_once_differenced  \
# date
# 2018-12-23                      0.004563                      -0.063911
# 2018-12-30                      0.006065                       0.027116
#
#             instrumentalness_once_differenced  liveness_once_differenced  \
# date
# 2018-12-23                          -0.005905                  -0.018910
# 2018-12-30                           0.007724                   0.012189
#
#             valence_once_differenced  tempo_once_differenced
# date
# 2018-12-23                  0.038279                3.064040
# 2018-12-30                 -0.004197                3.749371
#
# [2 rows x 25 columns]

# %%
it_rw_19.tail(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2019-12-29      25.5      0.666363  0.610831  6.125714 -7.189337  0.637143
# 2020-01-05      25.5      0.695900  0.643483  6.314286 -6.612169  0.634286
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2019-12-29     0.109331      0.278767          0.041290  0.171111  ...
# 2020-01-05     0.127259      0.225605          0.030068  0.184051  ...
#
#             energy_once_differenced  key_once_differenced  \
# date
# 2019-12-29                 0.013563             -0.114286
# 2020-01-05                 0.032651              0.188571
#
#             loudness_once_differenced  mode_once_differenced  \
# date
# 2019-12-29                  -0.110054              -0.031429
# 2020-01-05                   0.577169              -0.002857
#
#             speechiness_once_differenced  acousticness_once_differenced  \
# date
# 2019-12-29                      0.010711                      -0.032194
# 2020-01-05                      0.017928                      -0.053161
#
#             instrumentalness_once_differenced  liveness_once_differenced  \
# date
# 2019-12-29                           0.026400                   0.002468
# 2020-01-05                          -0.011222                   0.012940
#
#             valence_once_differenced  tempo_once_differenced
# date
# 2019-12-29                  0.021791               -0.141337
# 2020-01-05                  0.015639                0.658831
#
# [2 rows x 25 columns]

# %%
arima_param_df
# Out:
#   audio_feature         AIC  ndiffs(d)  best_p  best_q      order  \
# 1  danceability -746.797730          1       1       2  (1, 1, 2)
# 2          mode -446.531723          1       4       3  (4, 1, 3)
# 3  acousticness -619.986170          0       3       2  (3, 0, 2)
# 4       valence -647.409633          0       2       2  (2, 0, 2)
# 5         tempo  796.904884          0       0       5  (0, 0, 5)
#
#     ARIMA_model
# 1  ARIMA(1,1,2)
# 2  ARIMA(4,1,3)
# 3  ARIMA(3,0,2)
# 4  ARIMA(2,0,2)
# 5  ARIMA(0,0,5)

# %%
arima_param_df.loc[arima_param_df['audio_feature'] == 'danceability', 'order'].iloc[0]
# Out:
# (1, 1, 2)

# %%
ndiff_df.loc[ndiff_df['audio_feature'] == 'danceability', 'ndiffs for stationarity'].iloc[0]

# %%
def arima_fit_predict_evaluate(df, feature, year, order, d=0):
    
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # find ndiffs for stationarity from ndiff dataframe
    # d = ndiff_df.loc[ndiff_df['audio_feature'] == ndiff_feature, 'ndiffs for stationarity'].iloc[0]

    # find order from arima parameters dataframe 
    # order = arima_param_df.loc[arima_param_df['audio_feature'] == ndiff_feature, 'order'].iloc[0]
   
    # instantiate ARIMA model
    model = ARIMA(train, order=order)

    # fit ARIMA model
    arima = model.fit()
    
    # get predictions for train and test sets 
    preds_train = model.predict(params=arima.params, start=train.index[d], end=train.index[-1], typ='levels')
    preds_test = model.predict(params=arima.params, start=test.index[0], end=test.index[-1], typ='levels')
    
    # calculate and print RMSE for train and test setes 
    train_rmse = mean_squared_error(train[d::], preds_train)**0.5
    print(f'{feature.capitalize()} train RMSE ({year}) - ARIMA({order}): {train_rmse}')

    test_rmse = mean_squared_error(test, preds_test)**0.5
    print(f'{feature.capitalize()} test RMSE ({year}) - ARIMA({order}): {test_rmse}')
    
    # add RMSEs to arima parameters dataframe 
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'train_rmse'] = train_rmse    
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'test_rmse'] = test_rmse
    
    # calculate residuals
    residuals = test - preds_test
    
    return train, test, preds_test, residuals

# %%
def arima_plot(train, test, preds_test, title='title', figsize=(15,5)):
    
    # set up plot
    plt.figure(figsize=figsize)
    
    # plot training data 
    plt.plot(train, color='blue')
    
    # plot testing data 
    plt.plot(test.index, test, color='orange')
    
    # plot predicted values for test set 
    plt.plot(test.index, preds_test, color='green')
    
    # plot confidence interval 
#     ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
#     plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 
    
    # make plot with title! 
    plt.title(title, fontsize=16)
    plt.show() ;

# %%
arima_param_df
# Out:
#   audio_feature         AIC  ndiffs(d)  best_p  best_q      order  \
# 1  danceability -746.797730          1       1       2  (1, 1, 2)
# 2          mode -446.531723          1       4       3  (4, 1, 3)
# 3  acousticness -619.986170          0       3       2  (3, 0, 2)
# 4       valence -647.409633          0       2       2  (2, 0, 2)
# 5         tempo  796.904884          0       0       5  (0, 0, 5)
#
#     ARIMA_model  train_rmse  test_rmse
# 1  ARIMA(1,1,2)    0.618315   0.603174
# 2  ARIMA(4,1,3)    0.070201   0.078988
# 3  ARIMA(3,0,2)         NaN        NaN
# 4  ARIMA(2,0,2)         NaN        NaN
# 5  ARIMA(0,0,5)         NaN        NaN

# %% [markdown]
# ### Creating and plotting ARIMA Models - 2017

# %%
it_rw_17.head()
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2017-01-01      25.5      0.604800  0.591096  5.840000 -9.008200  0.600000
# 2017-01-08      25.5      0.592829  0.596115  5.602857 -8.670323  0.717143
# 2017-01-15      25.5      0.590561  0.584263  5.025714 -8.433451  0.625714
# 2017-01-22      25.5      0.570760  0.618591  4.497143 -7.809969  0.588571
# 2017-01-29      25.5      0.549560  0.672368  4.888571 -6.910569  0.705714
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2017-01-01     0.081670      0.303003          0.061578  0.172262  ...
# 2017-01-08     0.091595      0.355359          0.182476  0.175617  ...
# 2017-01-15     0.091436      0.340648          0.141121  0.204428  ...
# 2017-01-22     0.093505      0.348782          0.111421  0.163771  ...
# 2017-01-29     0.087994      0.302466          0.069887  0.175481  ...
#
#             energy_once_differenced  key_once_differenced  \
# date
# 2017-01-01                 0.000000              0.000000
# 2017-01-08                 0.005019             -0.237143
# 2017-01-15                -0.011853             -0.577143
# 2017-01-22                 0.034328             -0.528571
# 2017-01-29                 0.053777              0.391429
#
#             loudness_once_differenced  mode_once_differenced  \
# date
# 2017-01-01                   0.000000               0.000000
# 2017-01-08                   0.337877               0.117143
# 2017-01-15                   0.236871              -0.091429
# 2017-01-22                   0.623483              -0.037143
# 2017-01-29                   0.899400               0.117143
#
#             speechiness_once_differenced  acousticness_once_differenced  \
# date
# 2017-01-01                      0.000000                       0.000000
# 2017-01-08                      0.009925                       0.052356
# 2017-01-15                     -0.000159                      -0.014711
# 2017-01-22                      0.002069                       0.008134
# 2017-01-29                     -0.005511                      -0.046316
#
#             instrumentalness_once_differenced  liveness_once_differenced  \
# date
# 2017-01-01                           0.000000                   0.000000
# 2017-01-08                           0.120898                   0.003355
# 2017-01-15                          -0.041355                   0.028811
# 2017-01-22                          -0.029699                  -0.040657
# 2017-01-29                          -0.041534                   0.011710
#
#             valence_once_differenced  tempo_once_differenced
# date
# 2017-01-01                  0.000000                0.000000
# 2017-01-08                 -0.075560                3.052389
# 2017-01-15                  0.011662               -0.406554
# 2017-01-22                 -0.005162                1.572900
# 2017-01-29                  0.072090                2.910506
#
# [5 rows x 25 columns]

# %%
dance_train, dance_test, dance_preds, dance_resids = arima_fit_predict_evaluate(it_rw_17, 'danceability', 2017, order=(1,1,2), d=1)

arima_plot(dance_train, dance_test, dance_preds, title='Dancebility Score Italy 2017')
# Out:
# Danceability train RMSE (2017) - ARIMA((1, 1, 2)): 0.025578078192420372
# Danceability test RMSE (2017) - ARIMA((1, 1, 2)): 0.033635247962769725

# %%
# def plot_predict(df, feature, year, order, d=0, title='title'):
    
#     train, test, residuals, preds_test = arima_fit_predict_evaluate(train, test, residuals, preds_test)
    
#     arima(train, test, preds_test, title='title', figsize=(15,5))

# plot_predict(it_rw_17, 'danceability_once_differenced', 2017, order=(1,0,2), d=0)

# %%
mode_train, mode_test, mode_preds, mode_resids = arima_fit_predict_evaluate(it_rw_17, 'mode', 2017, order=(4,0,3), d=0)

arima_plot(mode_train, mode_test, mode_preds, title='Mode Score Italy 2017')
# Out:
# Mode train RMSE (2017) - ARIMA((4, 0, 3)): 0.07020094335386197
# Mode test RMSE (2017) - ARIMA((4, 0, 3)): 0.07898751915408961

# %%
acoustic_train, acoustic_test, acoustic_preds, acoustic_resids = arima_fit_predict_evaluate(it_rw_17, 'acousticness', 2017, order=(3,0,2), d=0)

arima_plot(acoustic_train, acoustic_test, acoustic_preds, title='Acousticness Score Italy 2017')
# Out:
# Acousticness train RMSE (2017) - ARIMA((3, 0, 2)): 0.038503210673536924
# Acousticness test RMSE (2017) - ARIMA((3, 0, 2)): 0.031290359571656025

# %%
valence_train, valence_test, valence_preds, valence_resids = arima_fit_predict_evaluate(it_rw_17, 'valence', 2017, order=(2,0,2), d=0)

arima_plot(valence_train, valence_test, valence_preds, title='Valence Score Italy 2017')
# Out:
# Valence train RMSE (2017) - ARIMA((2, 0, 2)): 0.035572561609325974
# Valence test RMSE (2017) - ARIMA((2, 0, 2)): 0.03332529150268263

# %%
tempo_train, tempo_test, tempo_preds, tempo_resids = arima_fit_predict_evaluate(it_rw_17, 'tempo', 2017, order=(0,0,5), d=0)

arima_plot(tempo_train, tempo_test, tempo_preds, title='Tempo Score Italy 2017')
# Out:
# Tempo train RMSE (2017) - ARIMA((0, 0, 5)): 2.937924521744971
# Tempo test RMSE (2017) - ARIMA((0, 0, 5)): 7.1202523963668725

# %% [markdown]
# ### Attempting SARIMAX model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
P, D, Q, S = 2, 0 ,2, 52
train = it_rw_17['valence'][0:48]
test = it_rw_17['valence'][48:]

# %%
sarima = SARIMAX(endog = train, order = (2, 0, 2), seasonal_order = (P, D, Q, S), exog=).fit()
# sarima_pred = sarima.predict(start=start, end = end)

# %%
sarima_preds_train = sarima.predict(start=train.index[0], end=train.index[-1])
sarima_preds_test = sarima.predict(start=test.index[0], end=test.index[-1])

# %%
print(f'RMSE = {round(mean_squared_error(test, sarima_preds_test)**.5, 2)}')
# Out:
# RMSE = 0.05

# %%
arima_plot(train, test, sarima_preds_test, title="Valence SARIMA 2017")

# %%
arima_plot(valence_train, valence_test, valence_preds, title='Valence Score Italy 2017')

# %% [markdown]
# ## SARIMAX

# %% [markdown]
# #### Incorporating Exogenous Variables

# %% [markdown]
# _SARIMAX for danceability with no exogenous variables_

# %%
train_dance = it_rw_17['danceability'][0:47]
test_dance = it_rw_17['danceability'][47:]

sarima = SARIMAX(endog=train_dance, order=(1,1,2)).fit()

# fit ARIMA model
# sarima_fit = sarima.fit()

# get predictions for train and test sets 
preds_train = sarima.predict(params=sarima.params, start=train_dance.index[1], end=train_dance.index[-1], typ='levels')
preds_test = sarima.predict(params=sarima.params, start=test_dance.index[0], end=test_dance.index[-1], typ='levels')
    

train_rmse_dance_no_exog = mean_squared_error(train_dance[1::], preds_train)**0.5
print(train_rmse_dance_no_exog)

test_rmse_dance_no_exog = mean_squared_error(test_dance, preds_test)**0.5
print(test_rmse_dance_no_exog)

arima_plot(train_dance, test_dance, preds_test, title='dancebility 2017 no exogenous variables')
# Out:
# 0.024446620670556092
# 0.026355071927261404

# %% [markdown]
# _SARIMAX model with exogenous variables: 4 main audio features that aren't danceability_

# %%
# exog = it_rw_17.loc[['mode', 'acousticness', 'valence', 'tempo']]

# %%
exog = it_rw_17.loc[:, ['valence']]

# %%
# exog[0:47]

# %%
train_dance = it_rw_17['danceability'][0:47]
test_dance = it_rw_17['danceability'][47:]

sarima_ex = SARIMAX(endog=train_dance, exog=exog[0:47], order=(1,1,2), seasonal_order=(1,1,2,52)).fit()

# fit ARIMA model
# sarima_fit = sarima.fit()

# get predictions for train and test sets 
preds_train_ex = sarima_ex.predict(start=train_dance.index[1], end=train_dance.index[-1], typ='levels', exog=exog[0:47])
preds_test_ex = sarima_ex.predict(start=test_dance.index[0], end=test_dance.index[-1], typ='levels', exog=exog[47:])
    

train_rmse_dance_ex= mean_squared_error(train_dance[1::], preds_train_ex)**0.5
print(train_rmse_dance_ex)

test_rmse_dance_ex = mean_squared_error(test_dance, preds_test_ex)**0.5
print(test_rmse_dance_ex)

arima_plot(train_dance, test_dance, preds_test_ex, title='dancebility 2017 with exogenous variables')
# Out:
# 0.025916229077650923
# 0.13104112426083286

# %%
train_dance = it_rw_17['danceability'][0:47]
test_dance = it_rw_17['danceability'][47:]

sarima_ex = SARIMAX(endog=train_dance, exog=exog[0:47], order=(1,1,2), seasonal_order=(1,1,2,52)).fit()

# fit ARIMA model
# sarima_fit = sarima.fit()

# get predictions for train and test sets 
preds_train_ex = sarima_ex.predict(start=train_dance.index[1], end=train_dance.index[-1], typ='levels', exog=exog[0:47])
preds_test_ex = sarima_ex.predict(start=test_dance.index[0], end=test_dance.index[-1], typ='levels', exog=exog[47:])
    

train_rmse_dance_ex= mean_squared_error(train_dance[1::], preds_train_ex)**0.5
print(train_rmse_dance_ex)

test_rmse_dance_ex = mean_squared_error(test_dance, preds_test_ex)**0.5
print(test_rmse_dance_ex)

arima_plot(train_dance, test_dance, preds_test_ex, title='dancebility 2017 with exogenous variables', figsize=(9,4))
# Out:
# 0.025916229077650923
# 0.13104112426083286

# %% [markdown]
# ### Building, evaluating, plotting SARIMAX using a function

# %%
def sarimas_predict_plot(df, feature, exog, year, order, seasonal_order, d=0):
     
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # instantiate and fit SARIMAX model 
    sarima = SARIMAX(endog=train, exog=exog[0:n_rows], order=(1,1,2), seasonal_order=(1,1,2,52)).fit()

    
    # find ndiffs for stationarity from ndiff dataframe
    # d = ndiff_df.loc[ndiff_df['audio_feature'] == ndiff_feature, 'ndiffs for stationarity'].iloc[0]

    # find order from arima parameters dataframe 
    # order = arima_param_df.loc[arima_param_df['audio_feature'] == ndiff_feature, 'order'].iloc[0]
    
    
    # get predictions for train and test sets 
    preds_train = sarima_ex.predict(start=train.index[d], end=train.index[-1], typ='levels', exog=exog[0:n_rows)
    preds_test = sarima_ex.predict(start=test.index[0], end=test.index[-1], typ='levels', exog=exog[n_rows]:])
    

train_rmse_dance_ex= mean_squared_error(train_dance[1::], preds_train_ex)**0.5
print(train_rmse_dance_ex)

test_rmse_dance_ex = mean_squared_error(test_dance, preds_test_ex)**0.5
print(test_rmse_dance_ex)

arima_plot(train_dance, test_dance, preds_test_ex, title='dancebility 2017 with exogenous variables')
    
    # get predictions for train and test sets 
    preds_train = model.predict(params=arima.params, start=train.index[d], end=train.index[-1], typ='levels')
    preds_test = model.predict(params=arima.params, start=test.index[0], end=test.index[-1], typ='levels')
    
    # calculate and print RMSE for train and test setes 
    train_rmse = mean_squared_error(train[d::], preds_train)**0.5
    print(f'{feature.capitalize()} train RMSE ({year}) - ARIMA({order}): {train_rmse}')

    test_rmse = mean_squared_error(test, preds_test)**0.5
    print(f'{feature.capitalize()} test RMSE ({year}) - ARIMA({order}): {test_rmse}')
    
    # add RMSEs to arima parameters dataframe 
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'train_rmse'] = train_rmse    
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'test_rmse'] = test_rmse
    
    # calculate residuals
    residuals = test - preds_test
    
    return train, test, preds_test, residuals

# %%
it_rw_17.head(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2017-01-01      25.5      0.604800  0.591096  5.840000 -9.008200  0.600000
# 2017-01-08      25.5      0.592829  0.596115  5.602857 -8.670323  0.717143
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2017-01-01     0.081670      0.303003          0.061578  0.172262  ...
# 2017-01-08     0.091595      0.355359          0.182476  0.175617  ...
#
#             energy_once_differenced  key_once_differenced  \
# date
# 2017-01-01                 0.000000              0.000000
# 2017-01-08                 0.005019             -0.237143
#
#             loudness_once_differenced  mode_once_differenced  \
# date
# 2017-01-01                   0.000000               0.000000
# 2017-01-08                   0.337877               0.117143
#
#             speechiness_once_differenced  acousticness_once_differenced  \
# date
# 2017-01-01                      0.000000                       0.000000
# 2017-01-08                      0.009925                       0.052356
#
#             instrumentalness_once_differenced  liveness_once_differenced  \
# date
# 2017-01-01                           0.000000                   0.000000
# 2017-01-08                           0.120898                   0.003355
#
#             valence_once_differenced  tempo_once_differenced
# date
# 2017-01-01                   0.00000                0.000000
# 2017-01-08                  -0.07556                3.052389
#
# [2 rows x 25 columns]

# %%
type(it_rw_17[['mode', 'instrumentalness']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(it_rw_17.iloc[:,1:])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### SARIMAX Gridsearch

# %%
arima_dict = {
    'audio_feature':[],
    'AIC':[],
    'ndiffs(d)':[],
    'best_p':[],
    'best_q':[],
    'order':[],
    'ARIMA_model':[]
}



import time


def sarima_params(df, feature, n_rows=162):
    
    t0 = time.time()
    final_mae = 1000000000000
    final_S = 0
    final_D = 0
    final_P = 0
    final_Q = 0

    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    order = arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'order'].iloc[0]

    for S in range(48,53):
        for D in range(2):
            for P in range(4):
                for Q in range(4):
                    print(f'Checking ({P}, {D}, {Q}, {S}) at {round(time.time() - t0)} seconds.')
                    try:
                        sarima = SARIMAX(endog = train,
                                         order = order,
                                         seasonal_order = (P, D, Q, S)).fit()

                        sarima_pred = sarima.predict(start=start, end=end)

                        if mean_absolute_error(test, sarima_pred) < final_mae:
                            final_mae = mean_absolute_error(test, sarima_pred)
                            final_S = S
                            final_D = D
                            final_P = P
                            final_Q = Q

                        print(f'We just fit a SARIMAX({order})x({P}, {D}, {Q}, {S}) model for {feature} with {mean_absolute_error(test_values, sarima_pred)} MAE.')
                            
                    except:
                        pass
                
                seasonal_order = (final_P, final_D, final_Q, final_S)    
                
                
# dfm.loc[(dfm['jolie'] == 1) , 'jolie'] = dfm['folie']
# dfm.loc[(dfm['jolie'] == 1) , 'jolie'] = dfm.loc[(dfm['jolie'] == 1) ,'folie']
                
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'P'] = final_P
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'D'] = final_D
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'Q'] = final_Q    
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'S'] = final_S
#     arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'seasonal_order '] = seasonal_order
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'MAE '] = final_mae

    print(f'The final model for {feature} is SARIMAX({order})x({final_P}, {final_D}, {final_Q}, {final_S}).')

# %%
arima_dict
# Out:
# {'audio_feature': [],
#  'AIC': [],
#  'ndiffs(d)': [],
#  'best_p': [],
#  'best_q': [],
#  'order': [],
#  'ARIMA_model': []}

# %%
arima_param_df
# Out:
#   audio_feature         AIC  ndiffs(d)  best_p  best_q      order  \
# 1  danceability -746.797730          1       1       2  (1, 1, 2)
# 2          mode -446.531723          1       4       3  (4, 1, 3)
# 3  acousticness -619.986170          0       3       2  (3, 0, 2)
# 4       valence -647.409633          0       2       2  (2, 0, 2)
# 5         tempo  796.904884          0       0       5  (0, 0, 5)
#
#     ARIMA_model  train_rmse  test_rmse    P    D    Q    S  seasonal_order   \
# 1  ARIMA(1,1,2)         NaN        NaN  0.0  0.0  0.0  0.0              NaN
# 2  ARIMA(4,1,3)    0.070201   0.078988  0.0  0.0  0.0  0.0              NaN
# 3  ARIMA(3,0,2)    0.038503   0.031290  NaN  NaN  NaN  NaN              NaN
# 4  ARIMA(2,0,2)    0.035573   0.033325  NaN  NaN  NaN  NaN              NaN
# 5  ARIMA(0,0,5)    2.937925   7.120252  NaN  NaN  NaN  NaN              NaN
#
#            MAE
# 1  1.000000e+12
# 2  1.000000e+12
# 3           NaN
# 4           NaN
# 5           NaN

# %%
alltime_rw_italy.shape
# Out:
# (216, 14)

# %%
sarima_params(alltime_rw_italy, 'danceability')
# Out:
# Checking (0, 0, 0, 48) at 0 seconds.
# Checking (0, 0, 1, 48) at 1 seconds.
# Checking (0, 0, 2, 48) at 3 seconds.
# Checking (0, 0, 3, 48) at 15 seconds.
# Checking (1, 0, 0, 48) at 56 seconds.
# Checking (1, 0, 1, 48) at 57 seconds.
# Checking (1, 0, 2, 48) at 61 seconds.
# Checking (1, 0, 3, 48) at 74 seconds.
# Checking (2, 0, 0, 48) at 116 seconds.
# Checking (2, 0, 1, 48) at 128 seconds.
# Checking (2, 0, 2, 48) at 150 seconds.
# Checking (2, 0, 3, 48) at 168 seconds.
# Checking (3, 0, 0, 48) at 214 seconds.
# Checking (3, 0, 1, 48) at 251 seconds.
# Checking (3, 0, 2, 48) at 314 seconds.
# Checking (3, 0, 3, 48) at 387 seconds.
# Checking (0, 1, 0, 48) at 452 seconds.
# Checking (0, 1, 1, 48) at 453 seconds.
# Checking (0, 1, 2, 48) at 472 seconds.
# Checking (0, 1, 3, 48) at 518 seconds.
# Checking (1, 1, 0, 48) at 569 seconds.
# Checking (1, 1, 1, 48) at 576 seconds.
# Checking (1, 1, 2, 48) at 603 seconds.
# Checking (1, 1, 3, 48) at 663 seconds.
# Checking (2, 1, 0, 48) at 781 seconds.
# Checking (2, 1, 1, 48) at 816 seconds.
# Checking (2, 1, 2, 48) at 848 seconds.
# Checking (2, 1, 3, 48) at 897 seconds.
# Checking (3, 1, 0, 48) at 1034 seconds.
# Checking (3, 1, 1, 48) at 1104 seconds.
# Checking (3, 1, 2, 48) at 1188 seconds.
# Checking (3, 1, 3, 48) at 1289 seconds.
# Checking (0, 0, 0, 49) at 1372 seconds.
# Checking (0, 0, 1, 49) at 1372 seconds.
# Checking (0, 0, 2, 49) at 1379 seconds.
# Checking (0, 0, 3, 49) at 1393 seconds.
# Checking (1, 0, 0, 49) at 1442 seconds.
# Checking (1, 0, 1, 49) at 1444 seconds.
# Checking (1, 0, 2, 49) at 1448 seconds.
# Checking (1, 0, 3, 49) at 1472 seconds.
# Checking (2, 0, 0, 49) at 1521 seconds.
# Checking (2, 0, 1, 49) at 1530 seconds.
# Checking (2, 0, 2, 49) at 1544 seconds.
# Checking (2, 0, 3, 49) at 1559 seconds.
# Checking (3, 0, 0, 49) at 1629 seconds.
# Checking (3, 0, 1, 49) at 1716 seconds.
# Checking (3, 0, 2, 49) at 1790 seconds.
# Checking (3, 0, 3, 49) at 1861 seconds.
# Checking (0, 1, 0, 49) at 1931 seconds.
# Checking (0, 1, 1, 49) at 1933 seconds.
# Checking (0, 1, 2, 49) at 1941 seconds.
# Checking (0, 1, 3, 49) at 1995 seconds.
# Checking (1, 1, 0, 49) at 2066 seconds.
# Checking (1, 1, 1, 49) at 2069 seconds.
# Checking (1, 1, 2, 49) at 2086 seconds.
# Checking (1, 1, 3, 49) at 2123 seconds.
# Checking (2, 1, 0, 49) at 2240 seconds.
# Checking (2, 1, 1, 49) at 2258 seconds.
# Checking (2, 1, 2, 49) at 2312 seconds.
# Checking (2, 1, 3, 49) at 2399 seconds.
# Checking (3, 1, 0, 49) at 2506 seconds.
# Checking (3, 1, 1, 49) at 2613 seconds.
# Checking (3, 1, 2, 49) at 2699 seconds.
# Checking (3, 1, 3, 49) at 2803 seconds.
# Checking (0, 0, 0, 50) at 2874 seconds.
# Checking (0, 0, 1, 50) at 2875 seconds.
# Checking (0, 0, 2, 50) at 2877 seconds.
# Checking (0, 0, 3, 50) at 2888 seconds.
# Checking (1, 0, 0, 50) at 2937 seconds.
# Checking (1, 0, 1, 50) at 2940 seconds.
# Checking (1, 0, 2, 50) at 2944 seconds.
# Checking (1, 0, 3, 50) at 2957 seconds.
# Checking (2, 0, 0, 50) at 3001 seconds.
# Checking (2, 0, 1, 50) at 3018 seconds.
# Checking (2, 0, 2, 50) at 3043 seconds.
# Checking (2, 0, 3, 50) at 3066 seconds.
# Checking (3, 0, 0, 50) at 3123 seconds.
# Checking (3, 0, 1, 50) at 3165 seconds.
# Checking (3, 0, 2, 50) at 3209 seconds.
# Checking (3, 0, 3, 50) at 3258 seconds.
# Checking (0, 1, 0, 50) at 3325 seconds.
# Checking (0, 1, 1, 50) at 3327 seconds.
# Checking (0, 1, 2, 50) at 3338 seconds.
# Checking (0, 1, 3, 50) at 3376 seconds.
# Checking (1, 1, 0, 50) at 3464 seconds.
# Checking (1, 1, 1, 50) at 3474 seconds.
# Checking (1, 1, 2, 50) at 3485 seconds.
# Checking (1, 1, 3, 50) at 3540 seconds.
# Checking (2, 1, 0, 50) at 3652 seconds.
# Checking (2, 1, 1, 50) at 3686 seconds.
# Checking (2, 1, 2, 50) at 3724 seconds.
# Checking (2, 1, 3, 50) at 3776 seconds.
# Checking (3, 1, 0, 50) at 3843 seconds.
# Checking (3, 1, 1, 50) at 3942 seconds.
# Checking (3, 1, 2, 50) at 4089 seconds.
# Checking (3, 1, 3, 50) at 4164 seconds.
# Checking (0, 0, 0, 51) at 4287 seconds.
# Checking (0, 0, 1, 51) at 4287 seconds.
# Checking (0, 0, 2, 51) at 4290 seconds.
# Checking (0, 0, 3, 51) at 4303 seconds.
# Checking (1, 0, 0, 51) at 4340 seconds.
# Checking (1, 0, 1, 51) at 4342 seconds.
# Checking (1, 0, 2, 51) at 4346 seconds.
# Checking (1, 0, 3, 51) at 4374 seconds.
# Checking (2, 0, 0, 51) at 4439 seconds.
# Checking (2, 0, 1, 51) at 4454 seconds.
# Checking (2, 0, 2, 51) at 4478 seconds.
# Checking (2, 0, 3, 51) at 4503 seconds.
# Checking (3, 0, 0, 51) at 4575 seconds.
# Checking (3, 0, 1, 51) at 4640 seconds.
# Checking (3, 0, 2, 51) at 4701 seconds.
# Checking (3, 0, 3, 51) at 4796 seconds.
# Checking (0, 1, 0, 51) at 4921 seconds.
# Checking (0, 1, 1, 51) at 4924 seconds.
# Checking (0, 1, 2, 51) at 4948 seconds.
# Checking (0, 1, 3, 51) at 4978 seconds.
# Checking (1, 1, 0, 51) at 5181 seconds.
# Checking (1, 1, 1, 51) at 5201 seconds.
# Checking (1, 1, 2, 51) at 5233 seconds.
# Checking (1, 1, 3, 51) at 5359 seconds.
# Checking (2, 1, 0, 51) at 5539 seconds.
# Checking (2, 1, 1, 51) at 5640 seconds.
# Checking (2, 1, 2, 51) at 5695 seconds.
# Checking (2, 1, 3, 51) at 5771 seconds.
# Checking (3, 1, 0, 51) at 5865 seconds.
# Checking (3, 1, 1, 51) at 6008 seconds.
# Checking (3, 1, 2, 51) at 6176 seconds.
# Checking (3, 1, 3, 51) at 6298 seconds.
# Checking (0, 0, 0, 52) at 6378 seconds.
# Checking (0, 0, 1, 52) at 6378 seconds.
# Checking (0, 0, 2, 52) at 6380 seconds.
# Checking (0, 0, 3, 52) at 6393 seconds.
# Checking (1, 0, 0, 52) at 6432 seconds.
# Checking (1, 0, 1, 52) at 6434 seconds.
# Checking (1, 0, 2, 52) at 6437 seconds.
# Checking (1, 0, 3, 52) at 6448 seconds.
# Checking (2, 0, 0, 52) at 6485 seconds.
# Checking (2, 0, 1, 52) at 6497 seconds.
# Checking (2, 0, 2, 52) at 6516 seconds.
# Checking (2, 0, 3, 52) at 6538 seconds.
# Checking (3, 0, 0, 52) at 6595 seconds.
# Checking (3, 0, 1, 52) at 6687 seconds.
# Checking (3, 0, 2, 52) at 6763 seconds.
# Checking (3, 0, 3, 52) at 6827 seconds.
# Checking (0, 1, 0, 52) at 6906 seconds.
# Checking (0, 1, 1, 52) at 6908 seconds.
# Checking (0, 1, 2, 52) at 6920 seconds.
# Checking (0, 1, 3, 52) at 6984 seconds.
# Checking (1, 1, 0, 52) at 7112 seconds.
# Checking (1, 1, 1, 52) at 7132 seconds.
# Checking (1, 1, 2, 52) at 7152 seconds.
# Checking (1, 1, 3, 52) at 7222 seconds.
# Checking (2, 1, 0, 52) at 7377 seconds.
# Checking (2, 1, 1, 52) at 7434 seconds.
# Checking (2, 1, 2, 52) at 7480 seconds.
# Checking (2, 1, 3, 52) at 7566 seconds.
# Checking (3, 1, 0, 52) at 7761 seconds.
# Checking (3, 1, 1, 52) at 7888 seconds.
# Checking (3, 1, 2, 52) at 7996 seconds.
# Checking (3, 1, 3, 52) at 8155 seconds.
# The final model for danceability is SARIMAX((1, 1, 2))x(0, 0, 0, 0).

# %%
len(alltime_rw_italy['valence'])
# Out:
# 216

# %%
import time
t0 = time.time()
final_mae = 1000000000000
final_S = 0
final_D = 0
final_P = 0
final_Q = 0

train_values = alltime_rw_italy['valence'][0:162]
test_values = alltime_rw_italy['valence'][162:]

for S in range(48,53):
    for D in range(2):
        for P in range(4):
            for Q in range(4):
                print(f'Checking ({P}, {D}, {Q}, {S}) at {round(time.time() - t0)} seconds.')
                try:
                    sarima = SARIMAX(endog = alltime_rw_italy['valence'],
                                     order = (2, 0, 2),
                                     seasonal_order = (P, D, Q, S)).fit()

                    sarima_pred = sarima.predict(start=start, end = end)

                    if mean_absolute_error(test_values, sarima_pred) < final_mae:
                        final_mae = mean_absolute_error(test_values, sarima_pred)
                        final_S = S
                        final_D = D
                        final_P = P
                        final_Q = Q
                        
                    print(f'We just fit a SARIMAX(2, 0, 2)x({P}, {D}, {Q}, {S}) model with {mean_absolute_error(test_values, sarima_pred)} MAE.')
                    
                except:
                    pass

print(f'The final model is SARIMAX(2, 0, 2)x({final_P}, {final_D}, {final_Q}, {final_S}).')
# Out:
# Checking (0, 0, 0, 48) at 0 seconds.
# Checking (0, 0, 1, 48) at 1 seconds.
# Checking (0, 0, 2, 48) at 4 seconds.
# Checking (0, 0, 3, 48) at 37 seconds.
# Checking (1, 0, 0, 48) at 138 seconds.
# Checking (1, 0, 1, 48) at 144 seconds.
# Checking (1, 0, 2, 48) at 152 seconds.
# Checking (1, 0, 3, 48) at 211 seconds.
# Checking (2, 0, 0, 48) at 327 seconds.
# Checking (2, 0, 1, 48) at 365 seconds.
# Checking (2, 0, 2, 48) at 440 seconds.
# Checking (2, 0, 3, 48) at 505 seconds.
# Checking (3, 0, 0, 48) at 642 seconds.
# Checking (3, 0, 1, 48) at 738 seconds.
# Checking (3, 0, 2, 48) at 857 seconds.
# Checking (3, 0, 3, 48) at 1046 seconds.
# Checking (0, 1, 0, 48) at 1502 seconds.
# Checking (0, 1, 1, 48) at 1508 seconds.
# Checking (0, 1, 2, 48) at 1538 seconds.
# Checking (0, 1, 3, 48) at 1645 seconds.
# Checking (1, 1, 0, 48) at 2058 seconds.
# Checking (1, 1, 1, 48) at 2164 seconds.
# Checking (1, 1, 2, 48) at 2198 seconds.
# Checking (1, 1, 3, 48) at 2311 seconds.
# Checking (2, 1, 0, 48) at 2348 seconds.
# Checking (2, 1, 1, 48) at 2387 seconds.

# %% [markdown]
# ### Building and plotting SARIMAX models

# %%
def sarima_fit_predict_evaluate(df, feature, year, order, seasonal_order, d=0):
    
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # find ndiffs for stationarity from ndiff dataframe
    # d = ndiff_df.loc[ndiff_df['audio_feature'] == ndiff_feature, 'ndiffs for stationarity'].iloc[0]

    # find order from arima parameters dataframe 
    # order = arima_param_df.loc[arima_param_df['audio_feature'] == ndiff_feature, 'order'].iloc[0]
   
    # instantiate and fit ARIMA model
    sarima = SARIMAX(endog = train,
                     exog = ..., 
                     order = order,
                     seasonal_order = seasonal_order).fit()
    
    # get predictions for train and test sets 
    preds_train = sarima.predict(start=train.index[d], end=train.index[-1])
    preds_test = sarima.predict(start=test.index[0], end=test.index[-1])
    
    # calculate and print RMSE for train and test setes 
    train_rmse = mean_squared_error(train[d::], preds_train)**0.5
    print(f'{feature.capitalize()} train RMSE ({year}) - ARIMA({order}): {train_rmse}')

    test_rmse = mean_squared_error(test, preds_test)**0.5
    print(f'{feature.capitalize()} test RMSE ({year}) - ARIMA({order}): {test_rmse}')
    
    # calculate and print MAE for train and test setes 
    train_rmse = mean_squared_error(train[d::], preds_train)**0.5
    print(f'{feature.capitalize()} train RMSE ({year}) - ARIMA({order}): {train_rmse}')

    test_rmse = mean_squared_error(test, preds_test)**0.5
    print(f'{feature.capitalize()} test RMSE ({year}) - ARIMA({order}): {test_rmse}')
    
    # add RMSEs to arima parameters dataframe 
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'train_rmse'] = train_rmse    
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'test_rmse'] = test_rmse
    
    # calculate residuals
    residuals = test - preds_test
    
    return train, test, preds_test, residuals
