# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

import json

from fycharts.SpotifyCharts import SpotifyCharts
import sqlalchemy

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from datetime import datetime
from sklearn.model_selection import train_test_split

import statsmodels.api as sm

# We are required to do this in order to avoid "FutureWarning" issues.
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller  

from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %matplotlib inline

import warnings
warnings.simplefilter(action="ignore")

# %% [markdown]
# # Reading in data

# %%
italy_17_19 = pd.read_pickle('../data/it_17_19_v50_feat.pkl')
spain_17_19 = pd.read_pickle('../data/sp_17_19_v50_feat.pkl')
greece_17_19 = pd.read_pickle('../data/gr_17_19_v50_feat.pkl')

italy_20 = pd.read_pickle('../data/it_20_v50_feat.pkl')
spain_20 = pd.read_pickle('../data/sp_20_v50_feat.pkl')
greece_20 = pd.read_pickle('../data/gr_20_v50_feat.pkl')

# %%
spain_20.tail(2)
# Out:
#             Position                Track Name               Artist region  \
# date
# 2021-02-13        49    La Luz - A COLORS SHOW    María José Llergo     es
# 2021-02-13        50  Boku no Sensou - TV Size  Shinsei Kamattechan     es
#
#                         spotify_id  danceability  energy  key  loudness  mode  \
# date
# 2021-02-13  5jRnVQbjB6qgN3MARS4xw7         0.722   0.357    9   -10.487     0
# 2021-02-13  3tRPfCFAEv6wWyQO0YnGGV         0.447   0.891    9    -4.776     1
#
#             speechiness  acousticness  instrumentalness  liveness  valence  \
# date
# 2021-02-13       0.0996       0.81400          0.155000    0.0863    0.641
# 2021-02-13       0.0788       0.00447          0.000905    0.3900    0.517
#
#               tempo  duration_ms  time_signature
# date
# 2021-02-13  149.895       191599               4
# 2021-02-13  143.976        90960               4

# %% [markdown]
# # Preprocessing data

# %% [markdown]
# #### _Data for each country is split into different dataframes as different combinations and aggregations are needed for different functions._

# %% [markdown]
# **Resampling by month**
#
# _`rm` denotes resampling by month._

# %%
rm_italy_17_19 = italy_17_19.resample("M").mean()
rm_spain_17_19 = spain_17_19.resample("M").mean()
rm_greece_17_19 = greece_17_19.resample("M").mean()

rm_italy_20 = italy_20.resample("M").mean()
rm_spain_20 = spain_20.resample("M").mean()
rm_greece_20 = greece_20.resample("M").mean()

# %% [markdown]
# **Resampling by week**
#
# _`rw` denotes resampling by week._

# %%
rw_italy_17_19 = italy_17_19.resample("W").mean()
rw_spain_17_19 = spain_17_19.resample("W").mean()
rw_greece_17_19 = greece_17_19.resample("W").mean()

rw_italy_20 = italy_20.resample("W").mean()
rw_spain_20 = spain_20.resample("W").mean()
rw_greece_20 = greece_20.resample("W").mean()

# %% [markdown]
# #### Combining weekly resampled data for all years (2017-2020)

# %%
alltime_italy = pd.concat([italy_17_19, italy_20])
alltime_spain = pd.concat([spain_17_19, spain_20])
alltime_greece = pd.concat([greece_17_19, greece_20])

alltime_rw_italy = alltime_italy.resample("W").mean()
alltime_rw_spain = alltime_spain.resample("W").mean()
alltime_rw_greece = alltime_greece.resample("W").mean()

# %% [markdown]
# #### Splitting into dataframes for each year!

# %%
it_rw_17 = alltime_rw_italy[0:53]
it_rw_18 = alltime_rw_italy[53:105]
it_rw_19 = alltime_rw_italy[105:158]

# %%
it_rw_18.tail(2)
# Out:
#             Position  danceability   energy       key  loudness      mode  \
# date
# 2018-12-23      25.5      0.652526  0.62446  5.345714 -7.126363  0.548571
# 2018-12-30      25.5      0.637171  0.63514  4.971429 -6.814571  0.528571
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2018-12-23     0.098575      0.315516          0.058491  0.126928  0.464983
# 2018-12-30     0.104640      0.342631          0.066215  0.139117  0.460786
#
#                  tempo    duration_ms  time_signature
# date
# 2018-12-23  117.940511  209852.965714        3.985714
# 2018-12-30  121.689883  216545.840000        3.934286

# %% [markdown]
# # Differencing Data for Stationarity

# %% [markdown]
# ### Augmented Dickey-Fuller test to estimate whether data are stationary.

# %%
audio_features = [
'danceability', 
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'energy']

# %%
# Code by Joseph Nelson! 

def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:3], index=['Test Statistic', 'p-value', 'lags_used'])
    return dfoutput

# %% [markdown]
# _Dickey-Fuller on original dataframes_

# %%
for feature in audio_features:
    print(f'Dickey-Fuller Interpretation for {feature}:\n{interpret_dftest(adfuller(alltime_rw_italy[feature]))}')
# Out:
# Dickey-Fuller Interpretation for danceability:
# Test Statistic   -3.013333
# p-value           0.033668
# lags_used         4.000000
# dtype: float64
# Dickey-Fuller Interpretation for energy:
# Test Statistic   -3.470516
# p-value           0.008777
# lags_used         9.000000
# dtype: float64
# Dickey-Fuller Interpretation for key:
# Test Statistic   -6.335745e+00
# p-value           2.833617e-08
# lags_used         4.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for loudness:
# Test Statistic   -3.355416
# p-value           0.012576
# lags_used         7.000000
# dtype: float64
# Dickey-Fuller Interpretation for mode:
# Test Statistic   -6.787062e+00
# p-value           2.417084e-09
# lags_used         0.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for speechiness:
# Test Statistic   -4.108187
# p-value           0.000939
# lags_used         2.000000
# dtype: float64
# Dickey-Fuller Interpretation for acousticness:
# Test Statistic   -4.022911
# p-value           0.001295
# lags_used         2.000000
# dtype: float64
# Dickey-Fuller Interpretation for instrumentalness:
# Test Statistic   -3.783046
# p-value           0.003086
# lags_used         7.000000
# dtype: float64
# Dickey-Fuller Interpretation for liveness:
# Test Statistic   -4.990812
# p-value           0.000023
# lags_used         1.000000
# dtype: float64
# Dickey-Fuller Interpretation for valence:
# Test Statistic    -3.181356
# p-value            0.021090
# lags_used         14.000000
# dtype: float64
# Dickey-Fuller Interpretation for energy:
# Test Statistic   -3.470516
# p-value           0.008777
# lags_used         9.000000
# dtype: float64

# %% [markdown]
# ### DataFrame with once-differenced data

# %%
lag_df_italy = alltime_rw_italy.copy()

# %%
for feature in audio_features: 
    lag_df_italy[f'{feature}_once_differenced'] = lag_df_italy[feature].diff(1).fillna(0)

# %%
lag_df_italy.tail(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2021-02-07      25.5      0.666561  0.634389  5.402857 -6.677991  0.680000
# 2021-02-14      25.5      0.671104  0.647343  5.516667 -6.842603  0.656667
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2021-02-07     0.109192      0.268234          0.035348  0.223654  ...
# 2021-02-14     0.120716      0.277941          0.054173  0.220087  ...
#
#             danceability_once_differenced  energy_once_differenced  \
# date
# 2021-02-07                       0.008495                 0.029374
# 2021-02-14                       0.004543                 0.012955
#
#             key_once_differenced  loudness_once_differenced  \
# date
# 2021-02-07               0.18000                   0.314663
# 2021-02-14               0.11381                  -0.164612
#
#             mode_once_differenced  speechiness_once_differenced  \
# date
# 2021-02-07               0.031429                     -0.001159
# 2021-02-14              -0.023333                      0.011523
#
#             acousticness_once_differenced  instrumentalness_once_differenced  \
# date
# 2021-02-07                      -0.073344                          -0.001695
# 2021-02-14                       0.009707                           0.018826
#
#             liveness_once_differenced  valence_once_differenced
# date
# 2021-02-07                   0.005719                 -0.006398
# 2021-02-14                  -0.003567                  0.049983
#
# [2 rows x 24 columns]

# %% [markdown]
# _Dickey-Fuller on lag dataframe_

# %%
for feature in audio_features:
    print(f'Dickey-Fuller Interpretation for {feature}, once-differenced:\n{interpret_dftest(adfuller(lag_df_italy[feature].diff(1).fillna(0)))}')
# Out:
# Dickey-Fuller Interpretation for danceability, once-differenced:
# Test Statistic   -9.142255e+00
# p-value           2.828632e-15
# lags_used         5.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for energy, once-differenced:
# Test Statistic   -6.782611e+00
# p-value           2.477455e-09
# lags_used         7.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for key, once-differenced:
# Test Statistic   -8.518281e+00
# p-value           1.118537e-13
# lags_used         7.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for loudness, once-differenced:
# Test Statistic   -7.002232e+00
# p-value           7.272028e-10
# lags_used         6.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for mode, once-differenced:
# Test Statistic   -9.845662e+00
# p-value           4.627101e-17
# lags_used         4.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for speechiness, once-differenced:
# Test Statistic   -8.291616e+00
# p-value           4.246658e-13
# lags_used         5.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for acousticness, once-differenced:
# Test Statistic   -1.160866e+01
# p-value           2.544491e-21
# lags_used         2.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for instrumentalness, once-differenced:
# Test Statistic   -7.471488e+00
# p-value           5.041115e-11
# lags_used         6.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for liveness, once-differenced:
# Test Statistic   -7.236294e+00
# p-value           1.935642e-10
# lags_used         8.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for valence, once-differenced:
# Test Statistic    -5.043085
# p-value            0.000018
# lags_used         12.000000
# dtype: float64
# Dickey-Fuller Interpretation for energy, once-differenced:
# Test Statistic   -6.782611e+00
# p-value           2.477455e-09
# lags_used         7.000000e+00
# dtype: float64

# %% [markdown]
# _Checking that these are the same_

# %%
interpret_dftest(adfuller(lag_df_italy['energy_once_differenced']))
# Out:
# Test Statistic   -6.782611e+00
# p-value           2.477455e-09
# lags_used         7.000000e+00
# dtype: float64

# %%
interpret_dftest(adfuller(lag_df_italy['energy'].diff(1).fillna(0)))
# Out:
# Test Statistic   -6.782611e+00
# p-value           2.477455e-09
# lags_used         7.000000e+00
# dtype: float64

# %% [markdown]
# ### Using `ndiffs` to figure out how many orders of difference $d$ I need in oder to have stationarity

# %%
from pmdarima.arima.utils import ndiffs

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ adf test: {ndiffs(alltime_italy[feature], test= "adf")}')
# Out:
# ndiffs for danceability stationarity w/ adf test: 0
# ndiffs for energy stationarity w/ adf test: 0
# ndiffs for key stationarity w/ adf test: 0
# ndiffs for loudness stationarity w/ adf test: 0
# ndiffs for mode stationarity w/ adf test: 0
# ndiffs for speechiness stationarity w/ adf test: 0
# ndiffs for acousticness stationarity w/ adf test: 0
# ndiffs for instrumentalness stationarity w/ adf test: 0
# ndiffs for liveness stationarity w/ adf test: 0
# ndiffs for valence stationarity w/ adf test: 0
# ndiffs for energy stationarity w/ adf test: 0

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ adf test: {ndiffs(alltime_rw_italy[feature], test= "adf")}')
# Out:
# ndiffs for danceability stationarity w/ adf test: 1
# ndiffs for energy stationarity w/ adf test: 0
# ndiffs for key stationarity w/ adf test: 0
# ndiffs for loudness stationarity w/ adf test: 0
# ndiffs for mode stationarity w/ adf test: 1
# ndiffs for speechiness stationarity w/ adf test: 0
# ndiffs for acousticness stationarity w/ adf test: 0
# ndiffs for instrumentalness stationarity w/ adf test: 0
# ndiffs for liveness stationarity w/ adf test: 0
# ndiffs for valence stationarity w/ adf test: 0
# ndiffs for energy stationarity w/ adf test: 0

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ kpss test: {ndiffs(alltime_italy[feature])}')
# Out:
# ndiffs for danceability stationarity w/ kpss test: 1
# ndiffs for energy stationarity w/ kpss test: 1
# ndiffs for key stationarity w/ kpss test: 1
# ndiffs for loudness stationarity w/ kpss test: 1
# ndiffs for mode stationarity w/ kpss test: 1
# ndiffs for speechiness stationarity w/ kpss test: 1
# ndiffs for acousticness stationarity w/ kpss test: 1
# ndiffs for instrumentalness stationarity w/ kpss test: 1
# ndiffs for liveness stationarity w/ kpss test: 1
# ndiffs for valence stationarity w/ kpss test: 1
# ndiffs for tempo stationarity w/ kpss test: 1

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ kpss test: {ndiffs(alltime_rw_italy[feature])}')
# Out:
# ndiffs for danceability stationarity w/ kpss test: 1
# ndiffs for energy stationarity w/ kpss test: 1
# ndiffs for key stationarity w/ kpss test: 0
# ndiffs for loudness stationarity w/ kpss test: 0
# ndiffs for mode stationarity w/ kpss test: 0
# ndiffs for speechiness stationarity w/ kpss test: 1
# ndiffs for acousticness stationarity w/ kpss test: 1
# ndiffs for instrumentalness stationarity w/ kpss test: 1
# ndiffs for liveness stationarity w/ kpss test: 1
# ndiffs for valence stationarity w/ kpss test: 1
# ndiffs for tempo stationarity w/ kpss test: 0

# %% [markdown]
# ### Finding `p`, `d`, and `q` values

# %% [markdown]
# _Using only the five audio features that are the most relevant or show some sort of pattern_

# %%
five_features = ['danceability', 'mode', 'acousticness', 'valence', 'energy']

# %% [markdown]
# _Building dataframe with `ndifffs` for stationarity for each feature_

# %%
ndiff_dict = {
    'audio_feature':[],
    'ndiffs for stationarity':[]    
}

for feature in five_features:
    ndiff_dict['audio_feature'].append(feature)
    ndiff_dict['ndiffs for stationarity'].append(ndiffs(alltime_rw_italy[feature], test= "adf"))

ndiff_df = pd.DataFrame(ndiff_dict)
ndiff_df
# Out:
#   audio_feature  ndiffs for stationarity
# 0  danceability                        1
# 1          mode                        1
# 2  acousticness                        0
# 3       valence                        0
# 4        energy                        0

# %%
arima_dict = {
    'audio_feature':[],
    'ndiffs(d)':[],
    'best_p':[],
    'best_q':[],
    'order':[],
    'ARIMA_model':[],
    'ARIMA_AIC':[]
}

def find_p_and_q(df, feature, n=6):
    
    train = df[feature][0:162]
    
    d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]

    # starting with large start AIC
    best_aic = 99 * (10 * 16)
    # creating variables to store best values ofd p and q 
    best_p = 0
    best_q = 0 

    # use nested for loop to iterate over values of p and q
    for p in range(n):

        for q in range(n):

            # insert try and and except statements
            try: 

                # fitting on ARIMA(p, 1, q) model 
                print(f'Attempting to fit ARIMA({p}, {d}, {q})')

                # instantiate ARIMA model
                arima = ARIMA(train, order=(p,d,q))

                # fit ARIMA model 
                model = arima.fit()

                # print out AIC for ARIMA(p, 1, q) model 
                print(f'For {feature}, the AIC for ARIMA({p},{d},{q}) is: {model.aic}')

                # Is this current model's AIC better than the OF best_aic? 
                if model.aic < best_aic:
                    # we want aic to be lower so we are setting a high aic and hoping for something lower 

                    # if it is, we overwrite the best_aic, best_p, and best_q
                    best_aic = model.aic
                    best_p = p 
                    best_q = q

            except:
                pass 

        order = (best_p, d, best_q)
    
    arima_dict['audio_feature'].append(feature)
    arima_dict['ndiffs(d)'].append(d)
    arima_dict['best_p'].append(best_p)
    arima_dict['best_q'].append(best_q)
    arima_dict['order'].append(order)
    arima_dict['ARIMA_model'].append(f'ARIMA({best_p},{d},{best_q})')
    arima_dict['ARIMA_AIC'].append(best_aic)

    print()
    print(f'{feature.upper()} MODEL FINISHED!')
    print(f'The model for {feature} that minimizes AIC on the training data is the ARIMA({best_p},{d},{best_q}).')
    print(f'The model has an aIC of {best_aic}.')
    print()

# %%
arima_dict
# Out:
# {'audio_feature': [],
#  'ndiffs(d)': [],
#  'best_p': [],
#  'best_q': [],
#  'order': [],
#  'ARIMA_model': [],
#  'ARIMA_AIC': []}

# %%
for feature in five_features:
    find_p_and_q(rw_italy_17_19, feature)
# Out:
# Attempting to fit ARIMA(0, 1, 0)
# For danceability, the AIC for ARIMA(0,1,0) is: -705.1269635218952
# Attempting to fit ARIMA(0, 1, 1)
# For danceability, the AIC for ARIMA(0,1,1) is: -719.9078122241333
# Attempting to fit ARIMA(0, 1, 2)
# For danceability, the AIC for ARIMA(0,1,2) is: -719.3145992186896
# Attempting to fit ARIMA(0, 1, 3)
# For danceability, the AIC for ARIMA(0,1,3) is: -719.0058383050268
# Attempting to fit ARIMA(0, 1, 4)
# For danceability, the AIC for ARIMA(0,1,4) is: -718.7836792929766
# Attempting to fit ARIMA(0, 1, 5)
# For danceability, the AIC for ARIMA(0,1,5) is: -716.8215644624875
# Attempting to fit ARIMA(1, 1, 0)
# For danceability, the AIC for ARIMA(1,1,0) is: -716.4336321379885
# Attempting to fit ARIMA(1, 1, 1)
# For danceability, the AIC for ARIMA(1,1,1) is: -725.3103525337362
# Attempting to fit ARIMA(1, 1, 2)
# For danceability, the AIC for ARIMA(1,1,2) is: -726.847242195727
# Attempting to fit ARIMA(1, 1, 3)
# Attempting to fit ARIMA(1, 1, 4)
# Attempting to fit ARIMA(1, 1, 5)
# Attempting to fit ARIMA(2, 1, 0)
# For danceability, the AIC for ARIMA(2,1,0) is: -716.6729523427532
# Attempting to fit ARIMA(2, 1, 1)
# For danceability, the AIC for ARIMA(2,1,1) is: -726.8787188263225
# Attempting to fit ARIMA(2, 1, 2)
# For danceability, the AIC for ARIMA(2,1,2) is: -724.9106163643469
# Attempting to fit ARIMA(2, 1, 3)
# Attempting to fit ARIMA(2, 1, 4)
# For danceability, the AIC for ARIMA(2,1,4) is: -718.583631707018
# Attempting to fit ARIMA(2, 1, 5)
# Attempting to fit ARIMA(3, 1, 0)
# For danceability, the AIC for ARIMA(3,1,0) is: -715.7051165784076
# Attempting to fit ARIMA(3, 1, 1)
# For danceability, the AIC for ARIMA(3,1,1) is: -724.9161326450173
# Attempting to fit ARIMA(3, 1, 2)
# For danceability, the AIC for ARIMA(3,1,2) is: -723.538979195459
# Attempting to fit ARIMA(3, 1, 3)
# For danceability, the AIC for ARIMA(3,1,3) is: -718.2405570341189
# Attempting to fit ARIMA(3, 1, 4)
# For danceability, the AIC for ARIMA(3,1,4) is: -720.9945281910273
# Attempting to fit ARIMA(3, 1, 5)
# Attempting to fit ARIMA(4, 1, 0)
# For danceability, the AIC for ARIMA(4,1,0) is: -716.7577975355082
# Attempting to fit ARIMA(4, 1, 1)
# For danceability, the AIC for ARIMA(4,1,1) is: -722.9611214160441
# Attempting to fit ARIMA(4, 1, 2)
# For danceability, the AIC for ARIMA(4,1,2) is: -721.3427598310791
# Attempting to fit ARIMA(4, 1, 3)
# For danceability, the AIC for ARIMA(4,1,3) is: -720.3651981217779
# Attempting to fit ARIMA(4, 1, 4)
# For danceability, the AIC for ARIMA(4,1,4) is: -714.0777015108811
# Attempting to fit ARIMA(4, 1, 5)
# For danceability, the AIC for ARIMA(4,1,5) is: -706.9368514666442
# Attempting to fit ARIMA(5, 1, 0)
# For danceability, the AIC for ARIMA(5,1,0) is: -714.8016527544642
# Attempting to fit ARIMA(5, 1, 1)
# For danceability, the AIC for ARIMA(5,1,1) is: -721.4552324256626
# Attempting to fit ARIMA(5, 1, 2)
# For danceability, the AIC for ARIMA(5,1,2) is: -719.563316663558
# Attempting to fit ARIMA(5, 1, 3)
# For danceability, the AIC for ARIMA(5,1,3) is: -717.5277896222406
# Attempting to fit ARIMA(5, 1, 4)
# For danceability, the AIC for ARIMA(5,1,4) is: -714.0937043880037
# Attempting to fit ARIMA(5, 1, 5)
# For danceability, the AIC for ARIMA(5,1,5) is: -717.6488437676051
#
# DANCEABILITY MODEL FINISHED!
# The model for danceability that minimizes AIC on the training data is the ARIMA(2,1,1).
# The model has an aIC of -726.8787188263225.
#
# Attempting to fit ARIMA(0, 1, 0)
# For mode, the AIC for ARIMA(0,1,0) is: -397.6097712207545
# Attempting to fit ARIMA(0, 1, 1)
# For mode, the AIC for ARIMA(0,1,1) is: -422.6775038000461
# Attempting to fit ARIMA(0, 1, 2)
# For mode, the AIC for ARIMA(0,1,2) is: -425.24903531584664
# Attempting to fit ARIMA(0, 1, 3)
# For mode, the AIC for ARIMA(0,1,3) is: -423.269723858176
# Attempting to fit ARIMA(0, 1, 4)
# For mode, the AIC for ARIMA(0,1,4) is: -421.3049929480617
# Attempting to fit ARIMA(0, 1, 5)
# For mode, the AIC for ARIMA(0,1,5) is: -421.74251444658455
# Attempting to fit ARIMA(1, 1, 0)
# For mode, the AIC for ARIMA(1,1,0) is: -409.9852083741247
# Attempting to fit ARIMA(1, 1, 1)
# For mode, the AIC for ARIMA(1,1,1) is: -424.7499817071257
# Attempting to fit ARIMA(1, 1, 2)
# For mode, the AIC for ARIMA(1,1,2) is: -423.27069443256266
# Attempting to fit ARIMA(1, 1, 3)
# For mode, the AIC for ARIMA(1,1,3) is: -421.51049263937875
# Attempting to fit ARIMA(1, 1, 4)
# Attempting to fit ARIMA(1, 1, 5)
# Attempting to fit ARIMA(2, 1, 0)
# For mode, the AIC for ARIMA(2,1,0) is: -420.6400491062751
# Attempting to fit ARIMA(2, 1, 1)
# For mode, the AIC for ARIMA(2,1,1) is: -423.0461890265183
# Attempting to fit ARIMA(2, 1, 2)
# For mode, the AIC for ARIMA(2,1,2) is: -421.27112891780837
# Attempting to fit ARIMA(2, 1, 3)
# For mode, the AIC for ARIMA(2,1,3) is: -427.61338504548496
# Attempting to fit ARIMA(2, 1, 4)
# Attempting to fit ARIMA(2, 1, 5)
# Attempting to fit ARIMA(3, 1, 0)
# For mode, the AIC for ARIMA(3,1,0) is: -420.7801279416359
# Attempting to fit ARIMA(3, 1, 1)
# For mode, the AIC for ARIMA(3,1,1) is: -427.05817921857454
# Attempting to fit ARIMA(3, 1, 2)
# For mode, the AIC for ARIMA(3,1,2) is: -425.2534957062235
# Attempting to fit ARIMA(3, 1, 3)
# For mode, the AIC for ARIMA(3,1,3) is: -427.42546824622275
# Attempting to fit ARIMA(3, 1, 4)
# Attempting to fit ARIMA(3, 1, 5)
# Attempting to fit ARIMA(4, 1, 0)
# For mode, the AIC for ARIMA(4,1,0) is: -418.8727149785469
# Attempting to fit ARIMA(4, 1, 1)
# For mode, the AIC for ARIMA(4,1,1) is: -417.3198854798643
# Attempting to fit ARIMA(4, 1, 2)
# For mode, the AIC for ARIMA(4,1,2) is: -424.38780419127806
# Attempting to fit ARIMA(4, 1, 3)
# For mode, the AIC for ARIMA(4,1,3) is: -430.79497925106773
# Attempting to fit ARIMA(4, 1, 4)
# Attempting to fit ARIMA(4, 1, 5)
# For mode, the AIC for ARIMA(4,1,5) is: -427.8030919434109
# Attempting to fit ARIMA(5, 1, 0)
# For mode, the AIC for ARIMA(5,1,0) is: -423.63907623887167
# Attempting to fit ARIMA(5, 1, 1)
# For mode, the AIC for ARIMA(5,1,1) is: -421.725669277881
# Attempting to fit ARIMA(5, 1, 2)
# For mode, the AIC for ARIMA(5,1,2) is: -423.50268207371937
# Attempting to fit ARIMA(5, 1, 3)
# For mode, the AIC for ARIMA(5,1,3) is: -426.8184829907078
# Attempting to fit ARIMA(5, 1, 4)
# Attempting to fit ARIMA(5, 1, 5)
# For mode, the AIC for ARIMA(5,1,5) is: -423.43420025546993
#
# MODE MODEL FINISHED!
# The model for mode that minimizes AIC on the training data is the ARIMA(4,1,3).
# The model has an aIC of -430.79497925106773.
#
# Attempting to fit ARIMA(0, 0, 0)
# For acousticness, the AIC for ARIMA(0,0,0) is: -469.5185481755017
# Attempting to fit ARIMA(0, 0, 1)
# For acousticness, the AIC for ARIMA(0,0,1) is: -545.3070306783486
# Attempting to fit ARIMA(0, 0, 2)
# For acousticness, the AIC for ARIMA(0,0,2) is: -570.3702412722635
# Attempting to fit ARIMA(0, 0, 3)
# For acousticness, the AIC for ARIMA(0,0,3) is: -576.4701284221103
# Attempting to fit ARIMA(0, 0, 4)
# For acousticness, the AIC for ARIMA(0,0,4) is: -580.9955132785315
# Attempting to fit ARIMA(0, 0, 5)
# For acousticness, the AIC for ARIMA(0,0,5) is: -582.1694881663084
# Attempting to fit ARIMA(1, 0, 0)
# For acousticness, the AIC for ARIMA(1,0,0) is: -595.8780529639746
# Attempting to fit ARIMA(1, 0, 1)
# For acousticness, the AIC for ARIMA(1,0,1) is: -596.2475877815928
# Attempting to fit ARIMA(1, 0, 2)
# For acousticness, the AIC for ARIMA(1,0,2) is: -598.0203505825707
# Attempting to fit ARIMA(1, 0, 3)
# Attempting to fit ARIMA(1, 0, 4)
# Attempting to fit ARIMA(1, 0, 5)
# Attempting to fit ARIMA(2, 0, 0)
# For acousticness, the AIC for ARIMA(2,0,0) is: -595.4216654896622
# Attempting to fit ARIMA(2, 0, 1)
# For acousticness, the AIC for ARIMA(2,0,1) is: -597.7107017975447
# Attempting to fit ARIMA(2, 0, 2)
# For acousticness, the AIC for ARIMA(2,0,2) is: -596.3326022206459
# Attempting to fit ARIMA(2, 0, 3)
# For acousticness, the AIC for ARIMA(2,0,3) is: -595.1571819647579
# Attempting to fit ARIMA(2, 0, 4)
# For acousticness, the AIC for ARIMA(2,0,4) is: -593.2950099984248
# Attempting to fit ARIMA(2, 0, 5)
# Attempting to fit ARIMA(3, 0, 0)
# For acousticness, the AIC for ARIMA(3,0,0) is: -595.4623060728034
# Attempting to fit ARIMA(3, 0, 1)
# For acousticness, the AIC for ARIMA(3,0,1) is: -596.6054931140793
# Attempting to fit ARIMA(3, 0, 2)
# For acousticness, the AIC for ARIMA(3,0,2) is: -600.5736244738932
# Attempting to fit ARIMA(3, 0, 3)
# For acousticness, the AIC for ARIMA(3,0,3) is: -593.2542260095067
# Attempting to fit ARIMA(3, 0, 4)
# For acousticness, the AIC for ARIMA(3,0,4) is: -597.3381053670803
# Attempting to fit ARIMA(3, 0, 5)
# For acousticness, the AIC for ARIMA(3,0,5) is: -594.6702166800769
# Attempting to fit ARIMA(4, 0, 0)
# For acousticness, the AIC for ARIMA(4,0,0) is: -595.9795353330271
# Attempting to fit ARIMA(4, 0, 1)
# For acousticness, the AIC for ARIMA(4,0,1) is: -595.2556941117509
# Attempting to fit ARIMA(4, 0, 2)
# For acousticness, the AIC for ARIMA(4,0,2) is: -593.5714802592981
# Attempting to fit ARIMA(4, 0, 3)
# For acousticness, the AIC for ARIMA(4,0,3) is: -595.3164253291161
# Attempting to fit ARIMA(4, 0, 4)
# For acousticness, the AIC for ARIMA(4,0,4) is: -591.2107940099147
# Attempting to fit ARIMA(4, 0, 5)
# For acousticness, the AIC for ARIMA(4,0,5) is: -590.5112650490071
# Attempting to fit ARIMA(5, 0, 0)
# For acousticness, the AIC for ARIMA(5,0,0) is: -594.5876709202723
# Attempting to fit ARIMA(5, 0, 1)
# For acousticness, the AIC for ARIMA(5,0,1) is: -593.3205506400075
# Attempting to fit ARIMA(5, 0, 2)
# For acousticness, the AIC for ARIMA(5,0,2) is: -591.8080247651312
# Attempting to fit ARIMA(5, 0, 3)
# For acousticness, the AIC for ARIMA(5,0,3) is: -591.1025221366519
# Attempting to fit ARIMA(5, 0, 4)
# For acousticness, the AIC for ARIMA(5,0,4) is: -594.7139163944939
# Attempting to fit ARIMA(5, 0, 5)
#
# ACOUSTICNESS MODEL FINISHED!
# The model for acousticness that minimizes AIC on the training data is the ARIMA(3,0,2).
# The model has an aIC of -600.5736244738932.
#
# Attempting to fit ARIMA(0, 0, 0)
# For valence, the AIC for ARIMA(0,0,0) is: -531.0040181570068
# Attempting to fit ARIMA(0, 0, 1)
# For valence, the AIC for ARIMA(0,0,1) is: -592.2730937789067
# Attempting to fit ARIMA(0, 0, 2)
# For valence, the AIC for ARIMA(0,0,2) is: -603.6227617239799
# Attempting to fit ARIMA(0, 0, 3)
# For valence, the AIC for ARIMA(0,0,3) is: -618.4083715635593
# Attempting to fit ARIMA(0, 0, 4)
# For valence, the AIC for ARIMA(0,0,4) is: -616.9043766642753
# Attempting to fit ARIMA(0, 0, 5)
# For valence, the AIC for ARIMA(0,0,5) is: -621.3822065461259
# Attempting to fit ARIMA(1, 0, 0)
# For valence, the AIC for ARIMA(1,0,0) is: -623.995283025673
# Attempting to fit ARIMA(1, 0, 1)
# For valence, the AIC for ARIMA(1,0,1) is: -626.7461793076723
# Attempting to fit ARIMA(1, 0, 2)
# For valence, the AIC for ARIMA(1,0,2) is: -626.3703208881893
# Attempting to fit ARIMA(1, 0, 3)
# For valence, the AIC for ARIMA(1,0,3) is: -624.418668950759
# Attempting to fit ARIMA(1, 0, 4)
# Attempting to fit ARIMA(1, 0, 5)
# Attempting to fit ARIMA(2, 0, 0)
# For valence, the AIC for ARIMA(2,0,0) is: -625.4910540581459
# Attempting to fit ARIMA(2, 0, 1)
# For valence, the AIC for ARIMA(2,0,1) is: -626.6946072814706
# Attempting to fit ARIMA(2, 0, 2)
# For valence, the AIC for ARIMA(2,0,2) is: -627.9191636258342
# Attempting to fit ARIMA(2, 0, 3)
# For valence, the AIC for ARIMA(2,0,3) is: -626.5056629226287
# Attempting to fit ARIMA(2, 0, 4)
# Attempting to fit ARIMA(2, 0, 5)
# For valence, the AIC for ARIMA(2,0,5) is: -622.773537966784
# Attempting to fit ARIMA(3, 0, 0)
# For valence, the AIC for ARIMA(3,0,0) is: -625.3073341497918
# Attempting to fit ARIMA(3, 0, 1)
# For valence, the AIC for ARIMA(3,0,1) is: -624.6984358984623
# Attempting to fit ARIMA(3, 0, 2)
# For valence, the AIC for ARIMA(3,0,2) is: -627.0498499508753
# Attempting to fit ARIMA(3, 0, 3)
# For valence, the AIC for ARIMA(3,0,3) is: -625.244963000923
# Attempting to fit ARIMA(3, 0, 4)
# For valence, the AIC for ARIMA(3,0,4) is: -625.3117934824911
# Attempting to fit ARIMA(3, 0, 5)
# For valence, the AIC for ARIMA(3,0,5) is: -624.7042476951472
# Attempting to fit ARIMA(4, 0, 0)
# For valence, the AIC for ARIMA(4,0,0) is: -623.3538020139315
# Attempting to fit ARIMA(4, 0, 1)
# For valence, the AIC for ARIMA(4,0,1) is: -624.1367052770531
# Attempting to fit ARIMA(4, 0, 2)
# For valence, the AIC for ARIMA(4,0,2) is: -624.485888846729
# Attempting to fit ARIMA(4, 0, 3)
# For valence, the AIC for ARIMA(4,0,3) is: -624.6420879519571
# Attempting to fit ARIMA(4, 0, 4)
# Attempting to fit ARIMA(4, 0, 5)
# For valence, the AIC for ARIMA(4,0,5) is: -625.0901380791563
# Attempting to fit ARIMA(5, 0, 0)
# For valence, the AIC for ARIMA(5,0,0) is: -625.6143834971288
# Attempting to fit ARIMA(5, 0, 1)
# For valence, the AIC for ARIMA(5,0,1) is: -624.8998328743883
# Attempting to fit ARIMA(5, 0, 2)
# For valence, the AIC for ARIMA(5,0,2) is: -623.410394437506
# Attempting to fit ARIMA(5, 0, 3)
# For valence, the AIC for ARIMA(5,0,3) is: -622.9643328206287
# Attempting to fit ARIMA(5, 0, 4)
# For valence, the AIC for ARIMA(5,0,4) is: -624.8340927184354
# Attempting to fit ARIMA(5, 0, 5)
# For valence, the AIC for ARIMA(5,0,5) is: -622.9157449536451
#
# VALENCE MODEL FINISHED!
# The model for valence that minimizes AIC on the training data is the ARIMA(2,0,2).
# The model has an aIC of -627.9191636258342.
#
# Attempting to fit ARIMA(0, 0, 0)
# For energy, the AIC for ARIMA(0,0,0) is: -593.6857934369365
# Attempting to fit ARIMA(0, 0, 1)
# For energy, the AIC for ARIMA(0,0,1) is: -653.6735389303055
# Attempting to fit ARIMA(0, 0, 2)
# For energy, the AIC for ARIMA(0,0,2) is: -670.8075890789587
# Attempting to fit ARIMA(0, 0, 3)
# For energy, the AIC for ARIMA(0,0,3) is: -673.1606960768449
# Attempting to fit ARIMA(0, 0, 4)
# For energy, the AIC for ARIMA(0,0,4) is: -674.6449533067021
# Attempting to fit ARIMA(0, 0, 5)
# For energy, the AIC for ARIMA(0,0,5) is: -681.6460623307826
# Attempting to fit ARIMA(1, 0, 0)
# For energy, the AIC for ARIMA(1,0,0) is: -684.6935023774158
# Attempting to fit ARIMA(1, 0, 1)
# For energy, the AIC for ARIMA(1,0,1) is: -684.0763452584777
# Attempting to fit ARIMA(1, 0, 2)
# For energy, the AIC for ARIMA(1,0,2) is: -683.1070407510799
# Attempting to fit ARIMA(1, 0, 3)
# For energy, the AIC for ARIMA(1,0,3) is: -681.2327258529981
# Attempting to fit ARIMA(1, 0, 4)
# Attempting to fit ARIMA(1, 0, 5)
# For energy, the AIC for ARIMA(1,0,5) is: -678.1009831411334
# Attempting to fit ARIMA(2, 0, 0)
# For energy, the AIC for ARIMA(2,0,0) is: -683.7501887468511
# Attempting to fit ARIMA(2, 0, 1)
# For energy, the AIC for ARIMA(2,0,1) is: -682.9841446436533
# Attempting to fit ARIMA(2, 0, 2)
# For energy, the AIC for ARIMA(2,0,2) is: -684.1570339311531
# Attempting to fit ARIMA(2, 0, 3)
# For energy, the AIC for ARIMA(2,0,3) is: -679.2990529021843
# Attempting to fit ARIMA(2, 0, 4)
# For energy, the AIC for ARIMA(2,0,4) is: -681.1325389652527
# Attempting to fit ARIMA(2, 0, 5)
# For energy, the AIC for ARIMA(2,0,5) is: -682.1971001720865
# Attempting to fit ARIMA(3, 0, 0)
# For energy, the AIC for ARIMA(3,0,0) is: -682.6284674113328
# Attempting to fit ARIMA(3, 0, 1)
# For energy, the AIC for ARIMA(3,0,1) is: -681.2267865738022
# Attempting to fit ARIMA(3, 0, 2)
# For energy, the AIC for ARIMA(3,0,2) is: -679.0206189734995
# Attempting to fit ARIMA(3, 0, 3)
# For energy, the AIC for ARIMA(3,0,3) is: -681.1817733883968
# Attempting to fit ARIMA(3, 0, 4)
# For energy, the AIC for ARIMA(3,0,4) is: -679.5453502875055
# Attempting to fit ARIMA(3, 0, 5)
# For energy, the AIC for ARIMA(3,0,5) is: -686.7508767301051
# Attempting to fit ARIMA(4, 0, 0)
# For energy, the AIC for ARIMA(4,0,0) is: -681.5677349182222
# Attempting to fit ARIMA(4, 0, 1)
# For energy, the AIC for ARIMA(4,0,1) is: -679.5757065761438
# Attempting to fit ARIMA(4, 0, 2)
# For energy, the AIC for ARIMA(4,0,2) is: -679.0966951067699
# Attempting to fit ARIMA(4, 0, 3)
# For energy, the AIC for ARIMA(4,0,3) is: -678.1468149293244
# Attempting to fit ARIMA(4, 0, 4)
# For energy, the AIC for ARIMA(4,0,4) is: -676.1928418136122
# Attempting to fit ARIMA(4, 0, 5)
# For energy, the AIC for ARIMA(4,0,5) is: -685.7020679830437
# Attempting to fit ARIMA(5, 0, 0)
# For energy, the AIC for ARIMA(5,0,0) is: -679.5899755313358
# Attempting to fit ARIMA(5, 0, 1)
# For energy, the AIC for ARIMA(5,0,1) is: -684.219771101715
# Attempting to fit ARIMA(5, 0, 2)
# For energy, the AIC for ARIMA(5,0,2) is: -690.8714765262669
# Attempting to fit ARIMA(5, 0, 3)
# For energy, the AIC for ARIMA(5,0,3) is: -689.3746576009933
# Attempting to fit ARIMA(5, 0, 4)
# Attempting to fit ARIMA(5, 0, 5)
# For energy, the AIC for ARIMA(5,0,5) is: -687.9339227179787
#
# ENERGY MODEL FINISHED!
# The model for energy that minimizes AIC on the training data is the ARIMA(5,0,2).
# The model has an aIC of -690.8714765262669.

# %%
arima_param_df = pd.DataFrame(arima_dict)
arima_param_df
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
# 1          mode          1       4       3  (4, 1, 3)  ARIMA(4,1,3)
# 2  acousticness          0       3       2  (3, 0, 2)  ARIMA(3,0,2)
# 3       valence          0       2       2  (2, 0, 2)  ARIMA(2,0,2)
# 4        energy          0       5       2  (5, 0, 2)  ARIMA(5,0,2)
#
#     ARIMA_AIC
# 0 -726.878719
# 1 -430.794979
# 2 -600.573624
# 3 -627.919164
# 4 -690.871477

# %% [markdown]
# # ARIMA Models

# %% [markdown]
# ### Function to create, evaluate, and plot `ARIMA` models

# %%
def arima_predict_plot(df, feature, year, title='title', figsize=(15,5), order=None, d=None, ci=True):
  
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    if order is None:
        # find order from arima parameters dataframe 
        order = arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
   
    # instantiate ARIMA model
    model = ARIMA(train, order=order)

    # fit ARIMA model
    arima = model.fit()
    
    # get predictions for train and test sets 
    preds_train = model.predict(params=arima.params, start=train.index[d], end=train.index[-1], typ='levels')
    preds_test = model.predict(params=arima.params, start=test.index[0], end=test.index[-1], typ='levels')
    
    # calculate and print RMSE for train and test setes 
    train_rmse = mean_squared_error(train[d::], preds_train)**0.5
    print(f'{feature.capitalize()} train RMSE ({year}) - ARIMA({order}): {train_rmse}')

    test_rmse = mean_squared_error(test, preds_test)**0.5
    print(f'{feature.capitalize()} test RMSE ({year}) - ARIMA({order}): {test_rmse}')
    
    # add RMSEs to arima parameters dataframe 
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'arima_train_rmse'] = train_rmse    
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'arima_test_rmse'] = test_rmse
    
      # set up plot
    plt.figure(figsize=figsize)
    
    # plot training data 
    plt.plot(train, color='blue')
    
    # plot testing data 
    plt.plot(test.index, test, color='orange')
    
    # plot predicted values for test set 
    plt.plot(test.index, preds_test, color='green')
    
    # add line for the baseline model (mean value of feature)
    plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')
    
    # plot confidence interval
    if ci:
        ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
        plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 

    # make plot with title! 
    plt.title(title, fontsize=16)
    plt.show() ;

# %% [markdown]
# _Function soley for creating and fitting the ARIMA model._

# %%
def arima_fit_eval(df, feature, year, param_df, title='title', figsize=(15,5), order=None, d=None):
  
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    if order is None:
        # find order from arima parameters dataframe 
        order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
   
    # instantiate ARIMA model
    model = ARIMA(train, order=order)

    # fit ARIMA model
    arima = model.fit()
    
    # get predictions for train and test sets 
    preds_train = model.predict(params=arima.params, start=train.index[d], end=train.index[-1], typ='levels')
    preds_test = model.predict(params=arima.params, start=test.index[0], end=test.index[-1], typ='levels')
    
    # calculate and print RMSE for train and test setes 
    train_rmse = mean_squared_error(train[d::], preds_train)**0.5
    print(f'{feature.capitalize()} train RMSE ({year}) - ARIMA({order}): {train_rmse}')

    test_rmse = mean_squared_error(test, preds_test)**0.5
    print(f'{feature.capitalize()} test RMSE ({year}) - ARIMA({order}): {test_rmse}')
    
    # add RMSEs to arima parameters dataframe 
    param_df.loc[param_df['audio_feature'] == feature, 'arima_train_rmse'] = train_rmse    
    param_df.loc[param_df['audio_feature'] == feature, 'arima_test_rmse'] = test_rmse
    
    return arima

# %% [markdown]
# _Function soley for plotting to be used when needed._

# %%
def arima_plot(train, test, preds_test, title='title', figsize=(15,5), ci=True):
    
    # set up plot
    plt.figure(figsize=figsize)
    
    # plot training data 
    plt.plot(train, color='blue')
    
    # plot testing data 
    plt.plot(test.index, test, color='orange')
    
    # plot predicted values for test set 
    plt.plot(test.index, preds_test, color='green')
    
    # add line for the baseline model (mean value of feature)
    # plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')
    
    # plot confidence interval 
    if ci:
        ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
        plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 
    
    # make plot with title! 
    plt.title(title, fontsize=16)
    plt.show() ;

# %% [markdown]
# ### ARIMA Models - 2017
#
# _Using `arima_predict_plot` function to run ARIMA model for each feature and show plot of actual vs. test._
#
# _This will also add columns for `arima_train_rmse` and `arima_test_rmse`._

# %%
it_rw_17.head(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2017-01-01      25.5      0.604800  0.591096  5.840000 -9.008200  0.600000
# 2017-01-08      25.5      0.592829  0.596115  5.602857 -8.670323  0.717143
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2017-01-01     0.081670      0.303003          0.061578  0.172262  0.466054
# 2017-01-08     0.091595      0.355359          0.182476  0.175617  0.390494
#
#                  tempo    duration_ms  time_signature
# date
# 2017-01-01  115.511720  257468.600000        3.860000
# 2017-01-08  118.564109  279987.502857        3.908571

# %%
it_rw_17.tail(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2017-12-24      25.5      0.612843  0.674063  5.302857 -6.309091  0.657143
# 2017-12-31      25.5      0.610449  0.656787  5.637143 -6.322729  0.688571
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2017-12-24     0.123394      0.253601          0.013014  0.179737  0.443628
# 2017-12-31     0.102279      0.209149          0.022378  0.171537  0.415203
#
#                 tempo    duration_ms  time_signature
# date
# 2017-12-24  108.77560  221529.465714        3.900000
# 2017-12-31  116.60734  218028.402857        3.908571

# %%
for feature in five_features: 
    arima_predict_plot(it_rw_17, feature, 2017, title=f'Mean {feature.capitalize()} Score, Italy 2017 (ARIMA)')
# Out:
# d = 1
# order = (2, 1, 1)
# Danceability train RMSE (2017) - ARIMA((2, 1, 1)): 0.026155679271466482
# Danceability test RMSE (2017) - ARIMA((2, 1, 1)): 0.012447651046008791
# d = 1
# order = (4, 1, 3)
# Mode train RMSE (2017) - ARIMA((4, 1, 3)): 0.06930739102964396
# Mode test RMSE (2017) - ARIMA((4, 1, 3)): 0.1453825018651371
# d = 0
# order = (3, 0, 2)
# Acousticness train RMSE (2017) - ARIMA((3, 0, 2)): 0.038503210673536924
# Acousticness test RMSE (2017) - ARIMA((3, 0, 2)): 0.031290359571656025
# d = 0
# order = (2, 0, 2)
# Valence train RMSE (2017) - ARIMA((2, 0, 2)): 0.035572561609325974
# Valence test RMSE (2017) - ARIMA((2, 0, 2)): 0.03332529150268263
# d = 0
# order = (5, 0, 2)
# Energy train RMSE (2017) - ARIMA((5, 0, 2)): 0.02718477959740595
# Energy test RMSE (2017) - ARIMA((5, 0, 2)): 0.021975424213331

# %% [markdown]
# #### _Updated `arima_param_df`_

# %%
arima_param_df
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
# 1          mode          1       4       3  (4, 1, 3)  ARIMA(4,1,3)
# 2  acousticness          0       3       2  (3, 0, 2)  ARIMA(3,0,2)
# 3       valence          0       2       2  (2, 0, 2)  ARIMA(2,0,2)
# 4        energy          0       5       2  (5, 0, 2)  ARIMA(5,0,2)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse
# 0 -726.878719          0.026156         0.012448
# 1 -430.794979          0.069307         0.145383
# 2 -600.573624          0.038503         0.031290
# 3 -627.919164          0.035573         0.033325
# 4 -690.871477          0.027185         0.021975

# %% [markdown]
# # SARIMAX models

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# #### _As baseline, Fitting SARIMAX with `seasonal_order = (2, 0, 2, 52)` and no exogenous variables before incorporating/engineering those components._

# %%
P, D, Q, S = 2, 0 ,2, 52
train_val = it_rw_17['valence'][0:48]
test_val = it_rw_17['valence'][48:]

sarima_val = SARIMAX(endog = train_val, order = (2, 0, 2), seasonal_order = (P, D, Q, S)).fit()
# sarima_pred = sarima.predict(start=start, end = end)

preds_train_sarima_val = sarima_val.predict(start=train_val.index[0], end=train_val.index[-1])
preds_test_sarima_val = sarima_val.predict(start=test_val.index[0], end=test_val.index[-1])

print(f'RMSE = {round(mean_squared_error(test_val, preds_test_sarima_val)**.5, 2)}')

arima_plot(train_val, test_val, preds_test_sarima_val, title="Basic SARIMA model - Valence, Italy 2017", figsize=(10,3))
# Out:
# RMSE = 0.05

# %% [markdown]
# #### Plotting ARIMA plot from above again, for comparison:

# %%
arima_predict_plot(it_rw_17, 'valence', 2017, title=f'Mean Valence Score, Italy 2017', figsize=(10,3))
# Out:
# d = 0
# order = (2, 0, 2)
# Valence train RMSE (2017) - ARIMA((2, 0, 2)): 0.035572561609325974
# Valence test RMSE (2017) - ARIMA((2, 0, 2)): 0.03332529150268263

# %% [markdown]
# ### SARIMAX Seasonal Parameters

# %% [markdown]
# #### _Grid search to find best `P`, `D`, `Q`, and `s` values_

# %%
def find_sarima_parameters(df, feature, n_rows=47):    
    
    import time
    t0 = time.time()
    final_mae = 1000000000000
    final_S = 0
    final_D = 0
    final_P = 0
    final_Q = 0
    
    # find order from arima parameters dataframe 
    order = arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'order'].iloc[0]

    train_values = df[feature][0:n_rows]
    test_values = df[feature][n_rows:]

    for S in range(48,53):
        for D in range(2):
            for P in range(4):
                for Q in range(4):
                    print(f'Checking ({P}, {D}, {Q}, {S}) at {round(time.time() - t0)} seconds.')
                    try:
                        sarima = SARIMAX(endog = train_values,
                                         order = order,
                                         seasonal_order = (P, D, Q, S)).fit()

                        sarima_pred = sarima.predict(start=test_values.index[0], end=test_values.index[-1], typ='levels')

                        if mean_absolute_error(test_values, sarima_pred) < final_mae:
                            final_mae = mean_absolute_error(test_values, sarima_pred)
                            final_S = S
                            final_D = D
                            final_P = P
                            final_Q = Q

                        print(f'We just fit a SARIMAX(2, 0, 2)x({P}, {D}, {Q}, {S}) model with {mean_absolute_error(test_values, sarima_pred)} MAE and {mean_squared_error(test_values, sarima_pred)**0.5} RMSE.')

                    except:
                        print('problem!')
                        raise

    print()
    print(f'The final model for {feature} is SARIMAX(2, 0, 2)x({final_P}, {final_D}, {final_Q}, {final_S}).')
    print()

# %%
five_features
# Out:
# ['danceability', 'mode', 'acousticness', 'valence', 'tempo']

# %%
for feature in five_features:
    find_sarima_parameters(alltime_rw_italy, feature)
# Out:
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.05753386489055584 MAE and 0.06516625912711418 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.057244647772963383 MAE and 0.06489035081204642 RMSE.
# Checking (0, 0, 2, 48) at 1 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.057356183192151494 MAE and 0.06500243980415928 RMSE.
# Checking (0, 0, 3, 48) at 5 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.05738887528626105 MAE and 0.06503604179073746 RMSE.
# Checking (1, 0, 0, 48) at 13 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.05742365142378605 MAE and 0.06506007287612735 RMSE.
# Checking (1, 0, 1, 48) at 15 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.05711023161189308 MAE and 0.06477479310037171 RMSE.
# Checking (1, 0, 2, 48) at 16 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.06613950024815429 MAE and 0.07341363493423356 RMSE.
# Checking (1, 0, 3, 48) at 21 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.05704538310432748 MAE and 0.06470158162122851 RMSE.
# Checking (2, 0, 0, 48) at 38 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.0572941009722543 MAE and 0.06494091993611573 RMSE.
# Checking (2, 0, 1, 48) at 42 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.05715434584732023 MAE and 0.0648138165272515 RMSE.
# Checking (2, 0, 2, 48) at 48 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.057291702070848896 MAE and 0.06494185938451454 RMSE.
# Checking (2, 0, 3, 48) at 56 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.05700831111436105 MAE and 0.06466799486612008 RMSE.
# Checking (3, 0, 0, 48) at 79 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.05737009216599976 MAE and 0.06501652681574537 RMSE.
# Checking (3, 0, 1, 48) at 97 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.05707631747358167 MAE and 0.06473258722881498 RMSE.
# Checking (3, 0, 2, 48) at 114 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.05710551131487965 MAE and 0.06476589709322685 RMSE.
# Checking (3, 0, 3, 48) at 135 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.05703405648753182 MAE and 0.06469595668110863 RMSE.
# Checking (0, 1, 0, 48) at 155 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (0, 1, 1, 48) at 156 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (0, 1, 2, 48) at 157 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (0, 1, 3, 48) at 158 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (1, 1, 0, 48) at 160 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (1, 1, 1, 48) at 160 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (1, 1, 2, 48) at 160 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (1, 1, 3, 48) at 161 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (2, 1, 0, 48) at 163 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (2, 1, 1, 48) at 163 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (2, 1, 2, 48) at 164 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (2, 1, 3, 48) at 165 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (3, 1, 0, 48) at 167 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (3, 1, 1, 48) at 168 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (3, 1, 2, 48) at 170 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (3, 1, 3, 48) at 172 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 48) model with 0.6599685616519654 MAE and 0.7341699005088842 RMSE.
# Checking (0, 0, 0, 49) at 174 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 49) model with 0.05753386489055584 MAE and 0.06516625912711418 RMSE.
# Checking (0, 0, 1, 49) at 174 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 49) model with 0.05748003481670212 MAE and 0.06511212173915104 RMSE.
# Checking (0, 0, 2, 49) at 175 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 49) model with 0.057623789550614916 MAE and 0.06525783621533071 RMSE.
# Checking (0, 0, 3, 49) at 179 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 49) model with 0.05758414470113414 MAE and 0.06521712437521694 RMSE.
# Checking (1, 0, 0, 49) at 187 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 49) model with 0.05744829986853997 MAE and 0.06508156513237154 RMSE.
# Checking (1, 0, 1, 49) at 188 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 49) model with 0.05759946836981053 MAE and 0.06523186752789617 RMSE.
# Checking (1, 0, 2, 49) at 189 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 49) model with 0.05757459905078579 MAE and 0.06520795368867986 RMSE.
# Checking (1, 0, 3, 49) at 193 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 49) model with 0.05753570044748106 MAE and 0.0651693073460748 RMSE.
# Checking (2, 0, 0, 49) at 203 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 49) model with 0.057593818927242434 MAE and 0.06522732229401666 RMSE.
# Checking (2, 0, 1, 49) at 207 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 49) model with 0.057557984106869 MAE and 0.0651915170854295 RMSE.
# Checking (2, 0, 2, 49) at 214 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 49) model with 0.057390396856308076 MAE and 0.06502295023045498 RMSE.
# Checking (2, 0, 3, 49) at 220 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 49) model with 0.05747134874782565 MAE and 0.06510476444647392 RMSE.
# Checking (3, 0, 0, 49) at 240 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 49) model with 0.057511454852265616 MAE and 0.06514410048830596 RMSE.
# Checking (3, 0, 1, 49) at 254 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 49) model with 0.057567699531763515 MAE and 0.06520099973550637 RMSE.
# Checking (3, 0, 2, 49) at 271 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 49) model with 0.05759054187926299 MAE and 0.0652248686493265 RMSE.
# Checking (3, 0, 3, 49) at 290 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 49) model with 0.057541451896971664 MAE and 0.0651755980580412 RMSE.
# Checking (0, 1, 0, 49) at 310 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (0, 1, 1, 49) at 310 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (0, 1, 2, 49) at 310 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (0, 1, 3, 49) at 311 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (1, 1, 0, 49) at 312 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (1, 1, 1, 49) at 312 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (1, 1, 2, 49) at 313 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (1, 1, 3, 49) at 313 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (2, 1, 0, 49) at 315 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (2, 1, 1, 49) at 316 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (2, 1, 2, 49) at 317 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (2, 1, 3, 49) at 317 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (3, 1, 0, 49) at 319 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (3, 1, 1, 49) at 321 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (3, 1, 2, 49) at 323 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (3, 1, 3, 49) at 325 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 0.6416418353200454 MAE and 0.7157996772385081 RMSE.
# Checking (0, 0, 0, 50) at 327 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 0.05753386489055584 MAE and 0.06516625912711418 RMSE.
# Checking (0, 0, 1, 50) at 327 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 0.05749822366192405 MAE and 0.06512970633867807 RMSE.
# Checking (0, 0, 2, 50) at 328 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 0.057606702355668865 MAE and 0.06523899545230243 RMSE.
# Checking (0, 0, 3, 50) at 331 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 0.05759707681707212 MAE and 0.06522955628282444 RMSE.
# Checking (1, 0, 0, 50) at 349 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 0.05760936279974577 MAE and 0.06524195750970191 RMSE.
# Checking (1, 0, 1, 50) at 350 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 0.0575693841123278 MAE and 0.0652025698149185 RMSE.
# Checking (1, 0, 2, 50) at 351 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 0.05753843489449975 MAE and 0.06517178872331711 RMSE.
# Checking (1, 0, 3, 50) at 357 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 0.05768381960142472 MAE and 0.06531667133585531 RMSE.
# Checking (2, 0, 0, 50) at 370 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 0.057587706034280164 MAE and 0.06522009333394924 RMSE.
# Checking (2, 0, 1, 50) at 376 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 0.057605791240590266 MAE and 0.06524000086355222 RMSE.
# Checking (2, 0, 2, 50) at 381 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 0.05759571693528797 MAE and 0.06522783882745668 RMSE.
# Checking (2, 0, 3, 50) at 387 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 0.05752772977677548 MAE and 0.06515838050482124 RMSE.
# Checking (3, 0, 0, 50) at 404 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 0.05750374944093023 MAE and 0.0651351081466179 RMSE.
# Checking (3, 0, 1, 50) at 416 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 0.057618843301373325 MAE and 0.0652511506810812 RMSE.
# Checking (3, 0, 2, 50) at 433 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 0.05758248019590313 MAE and 0.06521410745388795 RMSE.
# Checking (3, 0, 3, 50) at 451 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 0.057561356887487626 MAE and 0.06519192199082678 RMSE.
# Checking (0, 1, 0, 50) at 468 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (0, 1, 1, 50) at 468 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (0, 1, 2, 50) at 468 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (0, 1, 3, 50) at 469 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (1, 1, 0, 50) at 471 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (1, 1, 1, 50) at 471 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (1, 1, 2, 50) at 471 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (1, 1, 3, 50) at 472 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (2, 1, 0, 50) at 474 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (2, 1, 1, 50) at 475 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (2, 1, 2, 50) at 475 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (2, 1, 3, 50) at 476 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (3, 1, 0, 50) at 478 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (3, 1, 1, 50) at 481 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (3, 1, 2, 50) at 483 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (3, 1, 3, 50) at 486 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 0.6227812008449864 MAE and 0.6957770822015971 RMSE.
# Checking (0, 0, 0, 51) at 488 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 0.05753386489055584 MAE and 0.06516625912711418 RMSE.
# Checking (0, 0, 1, 51) at 488 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 0.05759943912006516 MAE and 0.06523232422806181 RMSE.
# Checking (0, 0, 2, 51) at 489 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 0.05776168784191818 MAE and 0.06539153966444734 RMSE.
# Checking (0, 0, 3, 51) at 493 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 0.05751009749103637 MAE and 0.06514180477646085 RMSE.
# Checking (1, 0, 0, 51) at 514 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 0.057519654350583885 MAE and 0.0651516572697527 RMSE.
# Checking (1, 0, 1, 51) at 515 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 0.05764521026963104 MAE and 0.06527865731650652 RMSE.
# Checking (1, 0, 2, 51) at 517 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 0.05752853080552282 MAE and 0.06516041356991775 RMSE.
# Checking (1, 0, 3, 51) at 521 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 0.057647336268851115 MAE and 0.0652806170748525 RMSE.
# Checking (2, 0, 0, 51) at 533 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 0.05753603026601139 MAE and 0.0651681350281413 RMSE.
# Checking (2, 0, 1, 51) at 540 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 0.05766666139586081 MAE and 0.06529831871073989 RMSE.
# Checking (2, 0, 2, 51) at 547 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 0.05759423631656179 MAE and 0.06522700621642959 RMSE.
# Checking (2, 0, 3, 51) at 553 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 0.05755935453110127 MAE and 0.06519160514624117 RMSE.
# Checking (3, 0, 0, 51) at 569 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 0.05768466576299427 MAE and 0.06531747818563077 RMSE.
# Checking (3, 0, 1, 51) at 583 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 0.05767493238859968 MAE and 0.06530818128164673 RMSE.
# Checking (3, 0, 2, 51) at 599 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 0.057555801836859814 MAE and 0.06518794241386784 RMSE.
# Checking (3, 0, 3, 51) at 616 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 0.057567863650662646 MAE and 0.0652001622076555 RMSE.
# Checking (0, 1, 0, 51) at 644 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (0, 1, 1, 51) at 644 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (0, 1, 2, 51) at 645 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (0, 1, 3, 51) at 645 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (1, 1, 0, 51) at 647 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (1, 1, 1, 51) at 648 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (1, 1, 2, 51) at 648 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (1, 1, 3, 51) at 649 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (2, 1, 0, 51) at 651 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (2, 1, 1, 51) at 652 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (2, 1, 2, 51) at 652 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (2, 1, 3, 51) at 653 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (3, 1, 0, 51) at 655 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (3, 1, 1, 51) at 657 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (3, 1, 2, 51) at 659 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (3, 1, 3, 51) at 662 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.6040638968855657 MAE and 0.6753102564601333 RMSE.
# Checking (0, 0, 0, 52) at 664 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.05753386489055584 MAE and 0.06516625912711418 RMSE.
# Checking (0, 0, 1, 52) at 664 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.057663887615627955 MAE and 0.06529767865270326 RMSE.
# Checking (0, 0, 2, 52) at 665 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.057518728275330853 MAE and 0.06515084008621763 RMSE.
# Checking (0, 0, 3, 52) at 669 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.05759599958334856 MAE and 0.06522900792935057 RMSE.
# Checking (1, 0, 0, 52) at 679 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.05760797462070632 MAE and 0.06524115090277428 RMSE.
# Checking (1, 0, 1, 52) at 680 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.05764136545493548 MAE and 0.06527454539041258 RMSE.
# Checking (1, 0, 2, 52) at 681 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.0575949409902759 MAE and 0.06522777001789709 RMSE.
# Checking (1, 0, 3, 52) at 687 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.057571691362907504 MAE and 0.06520448354435987 RMSE.
# Checking (2, 0, 0, 52) at 743 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.05758812300849402 MAE and 0.06522099049463578 RMSE.
# Checking (2, 0, 1, 52) at 748 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.05754234259204757 MAE and 0.06517472365883033 RMSE.
# Checking (2, 0, 2, 52) at 762 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.05760934184748569 MAE and 0.06524254665204761 RMSE.
# Checking (2, 0, 3, 52) at 771 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.0577529165994905 MAE and 0.06538423436711506 RMSE.
# Checking (3, 0, 0, 52) at 802 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.057630121084391736 MAE and 0.06526356812134611 RMSE.
# Checking (3, 0, 1, 52) at 814 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.057621968697311454 MAE and 0.0652551891641269 RMSE.
# Checking (3, 0, 2, 52) at 832 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.05747953093297177 MAE and 0.06511096572293863 RMSE.
# Checking (3, 0, 3, 52) at 855 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.057592832979027946 MAE and 0.0652257997850299 RMSE.
# Checking (0, 1, 0, 52) at 872 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (0, 1, 1, 52) at 873 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (0, 1, 2, 52) at 873 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (0, 1, 3, 52) at 874 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (1, 1, 0, 52) at 875 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (1, 1, 1, 52) at 876 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (1, 1, 2, 52) at 876 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (1, 1, 3, 52) at 877 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (2, 1, 0, 52) at 879 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (2, 1, 1, 52) at 880 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (2, 1, 2, 52) at 881 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (2, 1, 3, 52) at 882 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (3, 1, 0, 52) at 884 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (3, 1, 1, 52) at 886 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (3, 1, 2, 52) at 888 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
# Checking (3, 1, 3, 52) at 890 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.5859533520132119 MAE and 0.6548742306302198 RMSE.
#
# The final model for danceability is SARIMAX(2, 0, 2)x(2, 0, 3, 48).
#
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.05325121588569745 MAE and 0.07087603650800968 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.06036937135108208 MAE and 0.07540896740321847 RMSE.
# Checking (0, 0, 2, 48) at 2 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.059621249348990095 MAE and 0.0746457930892533 RMSE.
# Checking (0, 0, 3, 48) at 8 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.0555281490151642 MAE and 0.07157950078922282 RMSE.
# Checking (1, 0, 0, 48) at 23 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.05678357085198457 MAE and 0.07221496154027998 RMSE.
# Checking (1, 0, 1, 48) at 25 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.06349333764753556 MAE and 0.07810053376468944 RMSE.
# Checking (1, 0, 2, 48) at 27 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.08677385733244629 MAE and 0.10067649227087548 RMSE.
# Checking (1, 0, 3, 48) at 35 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.11434981833624228 MAE and 0.12973998157949157 RMSE.
# Checking (2, 0, 0, 48) at 59 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.12749199955507312 MAE and 0.14581879141429704 RMSE.
# Checking (2, 0, 1, 48) at 67 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.06679902598402851 MAE and 0.0811646410702165 RMSE.
# Checking (2, 0, 2, 48) at 78 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.06569297461575649 MAE and 0.08005127320878684 RMSE.
# Checking (2, 0, 3, 48) at 87 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.09531692584321357 MAE and 0.10969260129262756 RMSE.
# Checking (3, 0, 0, 48) at 109 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.06345043860680079 MAE and 0.07795526838257555 RMSE.
# Checking (3, 0, 1, 48) at 131 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.06740851439977265 MAE and 0.08162078003510935 RMSE.
# Checking (3, 0, 2, 48) at 155 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.07008535761984423 MAE and 0.08405655954098619 RMSE.
# Checking (3, 0, 3, 48) at 181 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.09124364231210126 MAE and 0.10526179638314911 RMSE.
# Checking (0, 1, 0, 48) at 211 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (0, 1, 1, 48) at 211 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (0, 1, 2, 48) at 212 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (0, 1, 3, 48) at 213 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (1, 1, 0, 48) at 215 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (1, 1, 1, 48) at 215 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (1, 1, 2, 48) at 216 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (1, 1, 3, 48) at 217 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (2, 1, 0, 48) at 225 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (2, 1, 1, 48) at 228 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (2, 1, 2, 48) at 230 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (2, 1, 3, 48) at 232 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (3, 1, 0, 48) at 234 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (3, 1, 1, 48) at 238 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (3, 1, 2, 48) at 244 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (3, 1, 3, 48) at 248 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 48) model with 0.999830848764442 MAE and 1.1049704759955599 RMSE.
# Checking (0, 0, 0, 49) at 251 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 49) model with 0.05325121588569745 MAE and 0.07087603650800968 RMSE.
# Checking (0, 0, 1, 49) at 251 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 49) model with 0.05872246238238842 MAE and 0.07737426141574552 RMSE.
# Checking (0, 0, 2, 49) at 253 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 49) model with 0.060496807034036225 MAE and 0.07991455134005537 RMSE.
# Checking (0, 0, 3, 49) at 260 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 49) model with 0.06322824741103412 MAE and 0.08286346223207877 RMSE.
# Checking (1, 0, 0, 49) at 286 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 49) model with 0.06392830887398039 MAE and 0.08271129953432543 RMSE.
# Checking (1, 0, 1, 49) at 288 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 49) model with 0.06638693493684122 MAE and 0.08609576013955085 RMSE.
# Checking (1, 0, 2, 49) at 291 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 49) model with 0.06699711715069503 MAE and 0.0868120327606057 RMSE.
# Checking (1, 0, 3, 49) at 299 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 49) model with 0.06840356846572322 MAE and 0.08839367037833058 RMSE.
# Checking (2, 0, 0, 49) at 323 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 49) model with 0.06877682927406298 MAE and 0.0878960964196833 RMSE.
# Checking (2, 0, 1, 49) at 333 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 49) model with 0.06664130978388358 MAE and 0.0864307162232704 RMSE.
# Checking (2, 0, 2, 49) at 344 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 49) model with 0.06923274945351693 MAE and 0.08923040931701294 RMSE.
# Checking (2, 0, 3, 49) at 355 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 49) model with 0.07299110788859989 MAE and 0.09326266019844066 RMSE.
# Checking (3, 0, 0, 49) at 380 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 49) model with 0.07128143977038494 MAE and 0.09088449451072604 RMSE.
# Checking (3, 0, 1, 49) at 408 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 49) model with 0.06734185298062653 MAE and 0.08718213322085083 RMSE.
# Checking (3, 0, 2, 49) at 434 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 49) model with 0.06945853506916137 MAE and 0.08944925158625101 RMSE.
# Checking (3, 0, 3, 49) at 461 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 49) model with 0.07220193602305588 MAE and 0.09244233541259936 RMSE.
# Checking (0, 1, 0, 49) at 501 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (0, 1, 1, 49) at 501 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (0, 1, 2, 49) at 501 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (0, 1, 3, 49) at 502 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (1, 1, 0, 49) at 507 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (1, 1, 1, 49) at 508 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (1, 1, 2, 49) at 509 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (1, 1, 3, 49) at 510 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (2, 1, 0, 49) at 513 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (2, 1, 1, 49) at 514 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (2, 1, 2, 49) at 515 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (2, 1, 3, 49) at 516 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (3, 1, 0, 49) at 519 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (3, 1, 1, 49) at 522 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (3, 1, 2, 49) at 525 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (3, 1, 3, 49) at 527 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 0.9779627080205747 MAE and 1.081457070797089 RMSE.
# Checking (0, 0, 0, 50) at 530 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 0.05325121588569745 MAE and 0.07087603650800968 RMSE.
# Checking (0, 0, 1, 50) at 531 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 0.05420804592812034 MAE and 0.07062115477021755 RMSE.
# Checking (0, 0, 2, 50) at 534 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 0.05375396644079947 MAE and 0.07072962489121609 RMSE.
# Checking (0, 0, 3, 50) at 541 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 0.05483704575664708 MAE and 0.07096776463992836 RMSE.
# Checking (1, 0, 0, 50) at 558 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 0.05373734640964737 MAE and 0.07032953661911025 RMSE.
# Checking (1, 0, 1, 50) at 560 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 0.057123044257340445 MAE and 0.07272190751324151 RMSE.
# Checking (1, 0, 2, 50) at 562 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 0.06082606592182338 MAE and 0.07583807200559106 RMSE.
# Checking (1, 0, 3, 50) at 571 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 0.060217294769845796 MAE and 0.07525521793428526 RMSE.
# Checking (2, 0, 0, 50) at 595 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 0.05411772176140396 MAE and 0.07048717883800205 RMSE.
# Checking (2, 0, 1, 50) at 605 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 0.059408362059416187 MAE and 0.0745823992780187 RMSE.
# Checking (2, 0, 2, 50) at 616 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 0.0593344619680822 MAE and 0.07450583737826891 RMSE.
# Checking (2, 0, 3, 50) at 628 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 0.06222133825000464 MAE and 0.07715013442749834 RMSE.
# Checking (3, 0, 0, 50) at 656 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 0.05507678401617711 MAE and 0.0710233758374408 RMSE.
# Checking (3, 0, 1, 50) at 685 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 0.055427288119396415 MAE and 0.07135749495076127 RMSE.
# Checking (3, 0, 2, 50) at 727 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 0.05541094064356173 MAE and 0.07142010396292714 RMSE.
# Checking (3, 0, 3, 50) at 767 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 0.06075262918899829 MAE and 0.075772435161053 RMSE.
# Checking (0, 1, 0, 50) at 806 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (0, 1, 1, 50) at 807 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (0, 1, 2, 50) at 808 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (0, 1, 3, 50) at 810 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (1, 1, 0, 50) at 815 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (1, 1, 1, 50) at 815 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (1, 1, 2, 50) at 816 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (1, 1, 3, 50) at 817 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (2, 1, 0, 50) at 820 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (2, 1, 1, 50) at 821 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (2, 1, 2, 50) at 822 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (2, 1, 3, 50) at 823 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (3, 1, 0, 50) at 826 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (3, 1, 1, 50) at 828 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (3, 1, 2, 50) at 831 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (3, 1, 3, 50) at 834 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 0.9539052181642818 MAE and 1.0556957655537493 RMSE.
# Checking (0, 0, 0, 51) at 837 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 0.05325121588569745 MAE and 0.07087603650800968 RMSE.
# Checking (0, 0, 1, 51) at 837 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 0.056668388001770584 MAE and 0.07235580755207854 RMSE.
# Checking (0, 0, 2, 51) at 839 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 0.05551264798121701 MAE and 0.07134607689189006 RMSE.
# Checking (0, 0, 3, 51) at 846 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 0.057043402016186386 MAE and 0.07258592669464753 RMSE.
# Checking (1, 0, 0, 51) at 868 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 0.09550106303335813 MAE and 0.11020486575242196 RMSE.
# Checking (1, 0, 1, 51) at 870 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 0.07270665717959846 MAE and 0.08711072114216756 RMSE.
# Checking (1, 0, 2, 51) at 873 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 0.06811943370223861 MAE and 0.0825275852816121 RMSE.
# Checking (1, 0, 3, 51) at 881 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 0.07307931315033028 MAE and 0.08722566395947685 RMSE.
# Checking (2, 0, 0, 51) at 904 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 0.0658275216625796 MAE and 0.08008995505921783 RMSE.
# Checking (2, 0, 1, 51) at 914 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 0.10313853085674668 MAE and 0.11859925015073328 RMSE.
# Checking (2, 0, 2, 51) at 927 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 0.0795812710679196 MAE and 0.09367300428415104 RMSE.
# Checking (2, 0, 3, 51) at 944 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 0.06766834717010985 MAE and 0.08219023997220813 RMSE.
# Checking (3, 0, 0, 51) at 975 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 0.07886656747529033 MAE and 0.09271734019177813 RMSE.
# Checking (3, 0, 1, 51) at 1003 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 0.07193491385995536 MAE and 0.0860728721417299 RMSE.
# Checking (3, 0, 2, 51) at 1031 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 0.08336849534937478 MAE and 0.09746706522684292 RMSE.
# Checking (3, 0, 3, 51) at 1064 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 0.06894116175521259 MAE and 0.0832354626775754 RMSE.
# Checking (0, 1, 0, 51) at 1098 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (0, 1, 1, 51) at 1099 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (0, 1, 2, 51) at 1099 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (0, 1, 3, 51) at 1100 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (1, 1, 0, 51) at 1103 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (1, 1, 1, 51) at 1103 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (1, 1, 2, 51) at 1104 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (1, 1, 3, 51) at 1105 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (2, 1, 0, 51) at 1108 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (2, 1, 1, 51) at 1109 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (2, 1, 2, 51) at 1110 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (2, 1, 3, 51) at 1112 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (3, 1, 0, 51) at 1115 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (3, 1, 1, 51) at 1117 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (3, 1, 2, 51) at 1120 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (3, 1, 3, 51) at 1123 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.9326879649943791 MAE and 1.0332830489407858 RMSE.
# Checking (0, 0, 0, 52) at 1127 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.05325121588569745 MAE and 0.07087603650800968 RMSE.
# Checking (0, 0, 1, 52) at 1127 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.05353172400214144 MAE and 0.07113393113160961 RMSE.
# Checking (0, 0, 2, 52) at 1129 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.053993583348723125 MAE and 0.07168014585895857 RMSE.
# Checking (0, 0, 3, 52) at 1137 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.054100684847719724 MAE and 0.07179600359842729 RMSE.
# Checking (1, 0, 0, 52) at 1157 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.054553883778224156 MAE and 0.07224657267618938 RMSE.
# Checking (1, 0, 1, 52) at 1159 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.060889601164125555 MAE and 0.07912239271740626 RMSE.
# Checking (1, 0, 2, 52) at 1162 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.05489176464942308 MAE and 0.07262330802569546 RMSE.
# Checking (1, 0, 3, 52) at 1170 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.055910031128173936 MAE and 0.07379787563039676 RMSE.
# Checking (2, 0, 0, 52) at 1192 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.05391800800434296 MAE and 0.07158791676991236 RMSE.
# Checking (2, 0, 1, 52) at 1204 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.05578342046297846 MAE and 0.07364946180019298 RMSE.
# Checking (2, 0, 2, 52) at 1218 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.05459928890505992 MAE and 0.07233877783908098 RMSE.
# Checking (2, 0, 3, 52) at 1231 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.05472395121002318 MAE and 0.07245917236222296 RMSE.
# Checking (3, 0, 0, 52) at 1259 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.05455240511334633 MAE and 0.07232531303944603 RMSE.
# Checking (3, 0, 1, 52) at 1287 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.056106495057732714 MAE and 0.07400684662045091 RMSE.
# Checking (3, 0, 2, 52) at 1317 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.059149460586188835 MAE and 0.07728537355264502 RMSE.
# Checking (3, 0, 3, 52) at 1349 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.055986157073122884 MAE and 0.07390704632962879 RMSE.
# Checking (0, 1, 0, 52) at 1387 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (0, 1, 1, 52) at 1387 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (0, 1, 2, 52) at 1387 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (0, 1, 3, 52) at 1388 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (1, 1, 0, 52) at 1391 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (1, 1, 1, 52) at 1392 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (1, 1, 2, 52) at 1392 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (1, 1, 3, 52) at 1394 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (2, 1, 0, 52) at 1398 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (2, 1, 1, 52) at 1399 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (2, 1, 2, 52) at 1401 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (2, 1, 3, 52) at 1402 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (3, 1, 0, 52) at 1405 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (3, 1, 1, 52) at 1407 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (3, 1, 2, 52) at 1410 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
# Checking (3, 1, 3, 52) at 1414 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.9094588775049499 MAE and 1.0067798259979148 RMSE.
#
# The final model for mode is SARIMAX(2, 0, 2)x(0, 0, 0, 48).
#
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.075847182835281 MAE and 0.09236779610727508 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.12482819998168002 MAE and 0.1413401144876445 RMSE.
# Checking (0, 0, 2, 48) at 1 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.15390687225241406 MAE and 0.17055343335911205 RMSE.
# Checking (0, 0, 3, 48) at 8 seconds.
# ...
# Checking (1, 1, 2, 49) at 645 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (1, 1, 3, 49) at 648 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (2, 1, 0, 49) at 651 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (2, 1, 1, 49) at 653 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (2, 1, 2, 49) at 656 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (2, 1, 3, 49) at 659 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (3, 1, 0, 49) at 663 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (3, 1, 1, 49) at 667 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (3, 1, 2, 49) at 669 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (3, 1, 3, 49) at 672 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 0.06533811603755699 MAE and 0.14186012267941986 RMSE.
# Checking (0, 0, 0, 50) at 675 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 0.0315511118462385 MAE and 0.03891742852472751 RMSE.
# Checking (0, 0, 1, 50) at 675 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 0.02689852232067971 MAE and 0.03463726964915325 RMSE.
# Checking (0, 0, 2, 50) at 677 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 0.027747313521451888 MAE and 0.03744622342815785 RMSE.
# Checking (0, 0, 3, 50) at 685 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 0.029915789938615094 MAE and 0.03808419884186527 RMSE.
# Checking (1, 0, 0, 50) at 708 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 0.048319401111515135 MAE and 0.057015405372640555 RMSE.
# Checking (1, 0, 1, 50) at 711 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 0.05043896548082958 MAE and 0.05900441862308732 RMSE.
# Checking (1, 0, 2, 50) at 714 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 0.05580944947397924 MAE and 0.06465910807691151 RMSE.
# Checking (1, 0, 3, 50) at 728 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 0.05458293083484693 MAE and 0.06314181241863961 RMSE.
# Checking (2, 0, 0, 50) at 764 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 0.05287065538405095 MAE and 0.06371298292866735 RMSE.
# Checking (2, 0, 1, 50) at 779 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 0.058208291631541405 MAE and 0.06839071202057588 RMSE.
# Checking (2, 0, 2, 50) at 792 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 0.06937218767101763 MAE and 0.08055069571090819 RMSE.
# Checking (2, 0, 3, 50) at 808 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 0.06959394701859209 MAE and 0.08057754784998238 RMSE.
# Checking (3, 0, 0, 50) at 846 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 0.04725096458991163 MAE and 0.05840058163655505 RMSE.
# Checking (3, 0, 1, 50) at 878 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 0.06205858244350445 MAE and 0.0735954211011057 RMSE.
# Checking (3, 0, 2, 50) at 913 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 0.06855467146596772 MAE and 0.08021972115831608 RMSE.
# Checking (3, 0, 3, 50) at 948 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 0.0755562149507834 MAE and 0.08793720906053139 RMSE.
# Checking (0, 1, 0, 50) at 996 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (0, 1, 1, 50) at 996 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (0, 1, 2, 50) at 996 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (0, 1, 3, 50) at 997 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (1, 1, 0, 50) at 1000 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (1, 1, 1, 50) at 1000 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (1, 1, 2, 50) at 1001 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (1, 1, 3, 50) at 1002 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (2, 1, 0, 50) at 1004 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (2, 1, 1, 50) at 1005 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (2, 1, 2, 50) at 1007 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (2, 1, 3, 50) at 1009 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (3, 1, 0, 50) at 1012 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (3, 1, 1, 50) at 1018 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (3, 1, 2, 50) at 1025 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (3, 1, 3, 50) at 1032 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 0.07487005337609115 MAE and 0.16880834198709999 RMSE.
# Checking (0, 0, 0, 51) at 1035 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 0.0315511118462385 MAE and 0.03891742852472751 RMSE.
# Checking (0, 0, 1, 51) at 1036 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 0.026351454415663854 MAE and 0.033834902018877296 RMSE.
# Checking (0, 0, 2, 51) at 1038 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 0.025786554578729935 MAE and 0.03520565215454595 RMSE.
# Checking (0, 0, 3, 51) at 1047 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 0.028954517645102342 MAE and 0.037196392375886976 RMSE.
# Checking (1, 0, 0, 51) at 1072 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 0.032362621923404646 MAE and 0.039491344260128285 RMSE.
# Checking (1, 0, 1, 51) at 1075 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 0.03065771200428178 MAE and 0.037851766585282436 RMSE.
# Checking (1, 0, 2, 51) at 1080 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 0.04544838066144819 MAE and 0.052437659979125764 RMSE.
# Checking (1, 0, 3, 51) at 1093 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 0.06614168041945084 MAE and 0.07535930168083657 RMSE.
# Checking (2, 0, 0, 51) at 1128 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 0.04431929167675562 MAE and 0.05256920391594531 RMSE.
# Checking (2, 0, 1, 51) at 1147 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 0.05427797003520077 MAE and 0.06272343450882725 RMSE.
# Checking (2, 0, 2, 51) at 1182 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 0.048924809473955846 MAE and 0.05640268510004173 RMSE.
# Checking (2, 0, 3, 51) at 1199 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 0.055379528927748646 MAE and 0.06361807540430153 RMSE.
# Checking (3, 0, 0, 51) at 1232 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 0.04066703023682752 MAE and 0.04908395966882226 RMSE.
# Checking (3, 0, 1, 51) at 1272 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 0.056587269224615724 MAE and 0.06632716711092929 RMSE.
# Checking (3, 0, 2, 51) at 1324 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 0.052965912678333296 MAE and 0.061477164153003486 RMSE.
# Checking (3, 0, 3, 51) at 1390 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 0.0596455775630858 MAE and 0.06916202809482325 RMSE.
# Checking (0, 1, 0, 51) at 1455 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (0, 1, 1, 51) at 1455 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (0, 1, 2, 51) at 1455 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (0, 1, 3, 51) at 1456 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (1, 1, 0, 51) at 1460 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (1, 1, 1, 51) at 1461 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (1, 1, 2, 51) at 1462 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (1, 1, 3, 51) at 1463 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (2, 1, 0, 51) at 1465 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (2, 1, 1, 51) at 1468 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (2, 1, 2, 51) at 1472 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (2, 1, 3, 51) at 1473 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (3, 1, 0, 51) at 1478 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (3, 1, 1, 51) at 1481 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (3, 1, 2, 51) at 1487 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (3, 1, 3, 51) at 1493 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.08601787078944705 MAE and 0.19129376327277858 RMSE.
# Checking (0, 0, 0, 52) at 1500 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.0315511118462385 MAE and 0.03891742852472751 RMSE.
# Checking (0, 0, 1, 52) at 1501 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.026923022214781357 MAE and 0.033772317777357175 RMSE.
# Checking (0, 0, 2, 52) at 1505 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.02728399513153654 MAE and 0.03587855863969896 RMSE.
# Checking (0, 0, 3, 52) at 1517 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.026722691096519924 MAE and 0.03419543241676806 RMSE.
# Checking (1, 0, 0, 52) at 1548 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.027295995240335796 MAE and 0.03336071975874624 RMSE.
# Checking (1, 0, 1, 52) at 1551 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.036362431278679615 MAE and 0.04316253151774775 RMSE.
# Checking (1, 0, 2, 52) at 1555 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.037233992900910465 MAE and 0.04402995026536687 RMSE.
# Checking (1, 0, 3, 52) at 1570 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.03672304568654038 MAE and 0.04351627277611252 RMSE.
# Checking (2, 0, 0, 52) at 1614 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.04121703010410679 MAE and 0.04908090823342538 RMSE.
# Checking (2, 0, 1, 52) at 1649 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.0619844323195279 MAE and 0.07145481911068423 RMSE.
# Checking (2, 0, 2, 52) at 1668 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.06105358795979725 MAE and 0.07004553346180904 RMSE.
# Checking (2, 0, 3, 52) at 1691 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.05838726346516252 MAE and 0.06699736642447993 RMSE.
# Checking (3, 0, 0, 52) at 1737 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.03712731700796622 MAE and 0.04570696465268086 RMSE.
# Checking (3, 0, 1, 52) at 1779 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.052079832443783364 MAE and 0.060652871210821545 RMSE.
# Checking (3, 0, 2, 52) at 1833 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.05477866547562878 MAE and 0.0633734585574329 RMSE.
# Checking (3, 0, 3, 52) at 1884 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.05942113954999676 MAE and 0.06870997000229828 RMSE.
# Checking (0, 1, 0, 52) at 1943 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (0, 1, 1, 52) at 1943 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (0, 1, 2, 52) at 1944 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (0, 1, 3, 52) at 1945 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (1, 1, 0, 52) at 1947 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (1, 1, 1, 52) at 1948 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (1, 1, 2, 52) at 1948 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (1, 1, 3, 52) at 1950 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (2, 1, 0, 52) at 1953 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (2, 1, 1, 52) at 1954 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (2, 1, 2, 52) at 1956 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (2, 1, 3, 52) at 1958 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (3, 1, 0, 52) at 1962 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (3, 1, 1, 52) at 1969 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (3, 1, 2, 52) at 1973 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
# Checking (3, 1, 3, 52) at 1977 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.10073362211998388 MAE and 0.21384929603638503 RMSE.
#
# The final model for energy is SARIMAX(2, 0, 2)x(0, 0, 2, 51).

# %% [markdown]
# Results from SARIMA seasonal order grid search using 2017-2020 data:
#
# + The final model for danceability is SARIMAX(2, 0, 2)x(2, 0, 3, 48).
# + The final model for mode is SARIMAX(2, 0, 2)x(0, 0, 0, 48).
# + The final model for acousticness is SARIMAX(2, 0, 2)x(0, 1, 0, 48).
# + The final model for valence is SARIMAX(2, 0, 2)x(1, 0, 3, 50).
# + The final model for energy is SARIMAX(2, 0, 2)x(0, 0, 2, 51).

# %%
arima_param_df.loc[arima_param_df['audio_feature'] == 'danceability', 'seasonal_order_all_data'] = '2, 0, 3, 48'
arima_param_df.loc[arima_param_df['audio_feature'] == 'mode', 'seasonal_order_all_data'] = '0, 0, 0, 48'
arima_param_df.loc[arima_param_df['audio_feature'] == 'acousticness', 'seasonal_order_all_data'] = '0, 1, 0, 48'
arima_param_df.loc[arima_param_df['audio_feature'] == 'valence', 'seasonal_order_all_data'] = '1, 0, 3, 50'
arima_param_df.loc[arima_param_df['audio_feature'] == 'energy', 'seasonal_order_all_data'] = '0, 0, 2, 51'

# %%
find_sarima_parameters(it_rw_17, 'energy')
# Out:
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.019350375250552016 MAE and 0.023903161702126183 RMSE.
# Checking (0, 0, 1, 48) at 1 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.015942847988861548 MAE and 0.021409032990458658 RMSE.
# Checking (0, 0, 2, 48) at 3 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.0199759640816126 MAE and 0.025213900453149203 RMSE.
# Checking (0, 0, 3, 48) at 13 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.022435339886466604 MAE and 0.02785512553769112 RMSE.
# Checking (1, 0, 0, 48) at 41 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.019230375424677076 MAE and 0.023718749122552937 RMSE.
# Checking (1, 0, 1, 48) at 45 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.02816639900453784 MAE and 0.034865495288712904 RMSE.
# Checking (1, 0, 2, 48) at 49 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.025044554232711864 MAE and 0.03162421602636753 RMSE.
# Checking (1, 0, 3, 48) at 64 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.025705830919609374 MAE and 0.033779209123774113 RMSE.
# Checking (2, 0, 0, 48) at 103 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.027426436847112916 MAE and 0.03464298229238779 RMSE.
# Checking (2, 0, 1, 48) at 120 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.024934454804167117 MAE and 0.03303203443485264 RMSE.
# Checking (2, 0, 2, 48) at 138 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.025732603285599936 MAE and 0.03452233388652625 RMSE.
# Checking (2, 0, 3, 48) at 156 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.025558868445312338 MAE and 0.03506797073523318 RMSE.
# Checking (3, 0, 0, 48) at 199 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.01728641945290073 MAE and 0.02204443229178232 RMSE.
# Checking (3, 0, 1, 48) at 253 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.024013217005968073 MAE and 0.03146155411651912 RMSE.
# Checking (3, 0, 2, 48) at 290 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.024909469011542562 MAE and 0.03444634161198045 RMSE.
# Checking (3, 0, 3, 48) at 336 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.024943698704230133 MAE and 0.03487957634781693 RMSE.
# Checking (0, 1, 0, 48) at 402 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (0, 1, 1, 48) at 402 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (0, 1, 2, 48) at 403 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (0, 1, 3, 48) at 405 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (1, 1, 0, 48) at 408 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (1, 1, 1, 48) at 409 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (1, 1, 2, 48) at 409 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (1, 1, 3, 48) at 411 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (2, 1, 0, 48) at 414 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (2, 1, 1, 48) at 415 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (2, 1, 2, 48) at 418 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (2, 1, 3, 48) at 420 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (3, 1, 0, 48) at 423 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (3, 1, 1, 48) at 428 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (3, 1, 2, 48) at 432 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (3, 1, 3, 48) at 438 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 48) model with 0.14885738095238116 MAE and 0.2662541823014623 RMSE.
# Checking (0, 0, 0, 49) at 448 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 49) model with 0.019350375250552016 MAE and 0.023903161702126183 RMSE.
# Checking (0, 0, 1, 49) at 449 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 49) model with 0.01802134143584862 MAE and 0.022296877727464484 RMSE.
# Checking (0, 0, 2, 49) at 451 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 49) model with 0.0178444441815049 MAE and 0.02190236553465917 RMSE.
# Checking (0, 0, 3, 49) at 466 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 49) model with 0.01858471725926647 MAE and 0.023177831775434712 RMSE.
# Checking (1, 0, 0, 49) at 504 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 49) model with 0.019307737251668216 MAE and 0.024230125041531176 RMSE.
# Checking (1, 0, 1, 49) at 507 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 49) model with 0.019117934503865102 MAE and 0.02398688803267293 RMSE.
# Checking (1, 0, 2, 49) at 513 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 49) model with 0.0214368280267066 MAE and 0.025991075483306397 RMSE.
# Checking (1, 0, 3, 49) at 527 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 49) model with 0.02188702154521956 MAE and 0.026873214840600523 RMSE.
# Checking (2, 0, 0, 49) at 572 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 49) model with 0.02044421047875966 MAE and 0.026378913455834343 RMSE.
# Checking (2, 0, 1, 49) at 588 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 49) model with 0.021238916776600336 MAE and 0.02667678138795672 RMSE.
# Checking (2, 0, 2, 49) at 605 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 49) model with 0.02214794317587911 MAE and 0.02802663839493665 RMSE.
# Checking (2, 0, 3, 49) at 624 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 49) model with 0.022160574794535204 MAE and 0.02915668761912702 RMSE.
# Checking (3, 0, 0, 49) at 670 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 49) model with 0.019767417068227378 MAE and 0.0250849966044657 RMSE.
# Checking (3, 0, 1, 49) at 725 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 49) model with 0.021594017463897774 MAE and 0.029125708939094705 RMSE.
# Checking (3, 0, 2, 49) at 771 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 49) model with 0.02205799401666773 MAE and 0.030126034230651542 RMSE.
# Checking (3, 0, 3, 49) at 818 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 49) model with 0.026636189902091434 MAE and 0.03751997156943446 RMSE.
# Checking (0, 1, 0, 49) at 859 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (0, 1, 1, 49) at 859 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (0, 1, 2, 49) at 860 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (0, 1, 3, 49) at 861 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (1, 1, 0, 49) at 863 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (1, 1, 1, 49) at 864 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (1, 1, 2, 49) at 864 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (1, 1, 3, 49) at 865 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (2, 1, 0, 49) at 867 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (2, 1, 1, 49) at 868 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (2, 1, 2, 49) at 869 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (2, 1, 3, 49) at 871 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (3, 1, 0, 49) at 873 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (3, 1, 1, 49) at 875 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (3, 1, 2, 49) at 878 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (3, 1, 3, 49) at 880 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 0.25572495238095244 MAE and 0.37238202363427686 RMSE.
# Checking (0, 0, 0, 50) at 883 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 0.019350375250552016 MAE and 0.023903161702126183 RMSE.
# Checking (0, 0, 1, 50) at 884 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 0.021155140147216107 MAE and 0.025209606748655213 RMSE.
# Checking (0, 0, 2, 50) at 886 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 0.021345266615097835 MAE and 0.02549495338143478 RMSE.
# Checking (0, 0, 3, 50) at 894 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 0.02209901858926448 MAE and 0.026143345757625277 RMSE.
# Checking (1, 0, 0, 50) at 918 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 0.02192594867074042 MAE and 0.026194594241740723 RMSE.
# Checking (1, 0, 1, 50) at 921 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 0.022265550783797716 MAE and 0.026328737624577908 RMSE.
# Checking (1, 0, 2, 50) at 924 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 0.023398439132581883 MAE and 0.027471625342826978 RMSE.
# Checking (1, 0, 3, 50) at 935 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 0.023237790266754155 MAE and 0.02732548307158572 RMSE.
# Checking (2, 0, 0, 50) at 962 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 0.023472209371531123 MAE and 0.027971379035741352 RMSE.
# Checking (2, 0, 1, 50) at 974 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 0.026449187678097914 MAE and 0.030459811736001693 RMSE.
# Checking (2, 0, 2, 50) at 987 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 0.02548068001600956 MAE and 0.029834659923366605 RMSE.
# Checking (2, 0, 3, 50) at 1001 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 0.02503514953418079 MAE and 0.029361652866120882 RMSE.
# Checking (3, 0, 0, 50) at 1033 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 0.025559423469786346 MAE and 0.030471027963314072 RMSE.
# Checking (3, 0, 1, 50) at 1064 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 0.02614740921926889 MAE and 0.030746996325869726 RMSE.
# Checking (3, 0, 2, 50) at 1102 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 0.026556202111282883 MAE and 0.03116078536880446 RMSE.
# Checking (3, 0, 3, 50) at 1142 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 0.026373589911782014 MAE and 0.03083097882317311 RMSE.
# Checking (0, 1, 0, 50) at 1202 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (0, 1, 1, 50) at 1203 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (0, 1, 2, 50) at 1203 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (0, 1, 3, 50) at 1204 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (1, 1, 0, 50) at 1207 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (1, 1, 1, 50) at 1207 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (1, 1, 2, 50) at 1208 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (1, 1, 3, 50) at 1209 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (2, 1, 0, 50) at 1212 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (2, 1, 1, 50) at 1213 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (2, 1, 2, 50) at 1215 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (2, 1, 3, 50) at 1216 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (3, 1, 0, 50) at 1219 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (3, 1, 1, 50) at 1222 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (3, 1, 2, 50) at 1225 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (3, 1, 3, 50) at 1228 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 0.3588233809523809 MAE and 0.4522298474956574 RMSE.
# Checking (0, 0, 0, 51) at 1233 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 0.019350375250552016 MAE and 0.023903161702126183 RMSE.
# Checking (0, 0, 1, 51) at 1233 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 0.016306465233509555 MAE and 0.020236204119249906 RMSE.
# Checking (0, 0, 2, 51) at 1236 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 0.015790516958128737 MAE and 0.019520006778052282 RMSE.
# Checking (0, 0, 3, 51) at 1245 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 0.014254253404414274 MAE and 0.017941759035299737 RMSE.
# Checking (1, 0, 0, 51) at 1272 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 0.015155545087652303 MAE and 0.019021760836218062 RMSE.
# Checking (1, 0, 1, 51) at 1274 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 0.016327893236352625 MAE and 0.021120559472987178 RMSE.
# Checking (1, 0, 2, 51) at 1278 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 0.015169522915866615 MAE and 0.019356328403473504 RMSE.
# Checking (1, 0, 3, 51) at 1290 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 0.014661270491977315 MAE and 0.018280246601008462 RMSE.
# Checking (2, 0, 0, 51) at 1322 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 0.016031321384996744 MAE and 0.020704072481821937 RMSE.
# Checking (2, 0, 1, 51) at 1343 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 0.016712898923184356 MAE and 0.021304055848888212 RMSE.
# Checking (2, 0, 2, 51) at 1358 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 0.01560558786735472 MAE and 0.020197454527691124 RMSE.
# Checking (2, 0, 3, 51) at 1372 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 0.016742163652769777 MAE and 0.021818610812691718 RMSE.
# Checking (3, 0, 0, 51) at 1407 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 0.016783547036906505 MAE and 0.022054741439773314 RMSE.
# Checking (3, 0, 1, 51) at 1456 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 0.018271822932747466 MAE and 0.022674619920741754 RMSE.
# Checking (3, 0, 2, 51) at 1502 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 0.018275255349694115 MAE and 0.02380181951455582 RMSE.
# Checking (3, 0, 3, 51) at 1561 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 0.018065048393797578 MAE and 0.023589676267252793 RMSE.
# Checking (0, 1, 0, 51) at 1618 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (0, 1, 1, 51) at 1619 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (0, 1, 2, 51) at 1619 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (0, 1, 3, 51) at 1620 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (1, 1, 0, 51) at 1623 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (1, 1, 1, 51) at 1623 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (1, 1, 2, 51) at 1624 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (1, 1, 3, 51) at 1625 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (2, 1, 0, 51) at 1628 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (2, 1, 1, 51) at 1629 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (2, 1, 2, 51) at 1631 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (2, 1, 3, 51) at 1632 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (3, 1, 0, 51) at 1635 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (3, 1, 1, 51) at 1638 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (3, 1, 2, 51) at 1641 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (3, 1, 3, 51) at 1645 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.45620047619047616 MAE and 0.531474865605535 RMSE.
# Checking (0, 0, 0, 52) at 1648 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.019350375250552016 MAE and 0.023903161702126183 RMSE.
# Checking (0, 0, 1, 52) at 1648 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.019576193855140884 MAE and 0.02356851506784776 RMSE.
# Checking (0, 0, 2, 52) at 1651 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.018890687516711246 MAE and 0.02329506970603418 RMSE.
# Checking (0, 0, 3, 52) at 1661 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.01844726489741964 MAE and 0.023100094802034114 RMSE.
# Checking (1, 0, 0, 52) at 1688 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.018916173839480355 MAE and 0.023307557513326742 RMSE.
# Checking (1, 0, 1, 52) at 1692 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.018558568339397452 MAE and 0.023303848795749486 RMSE.
# Checking (1, 0, 2, 52) at 1696 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.01915079388925382 MAE and 0.02413857699091481 RMSE.
# Checking (1, 0, 3, 52) at 1709 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.01924331943119752 MAE and 0.024421977866140258 RMSE.
# Checking (2, 0, 0, 52) at 1745 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.0197980310648751 MAE and 0.024205889405858754 RMSE.
# Checking (2, 0, 1, 52) at 1764 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.019031105505421215 MAE and 0.024949841876843654 RMSE.
# Checking (2, 0, 2, 52) at 1779 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.01919491625839394 MAE and 0.024843467517386433 RMSE.
# Checking (2, 0, 3, 52) at 1796 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.019656265949725544 MAE and 0.02526059739085258 RMSE.
# Checking (3, 0, 0, 52) at 1831 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.02017765955732696 MAE and 0.02507853019253772 RMSE.
# Checking (3, 0, 1, 52) at 1870 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.020146470348252343 MAE and 0.02606720594002485 RMSE.
# Checking (3, 0, 2, 52) at 1909 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.020709242096774643 MAE and 0.02660007364895906 RMSE.
# Checking (3, 0, 3, 52) at 1958 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.020750907941197622 MAE and 0.027065985655741132 RMSE.
# Checking (0, 1, 0, 52) at 2013 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (0, 1, 1, 52) at 2013 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (0, 1, 2, 52) at 2013 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (0, 1, 3, 52) at 2014 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (1, 1, 0, 52) at 2017 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (1, 1, 1, 52) at 2018 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (1, 1, 2, 52) at 2018 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (1, 1, 3, 52) at 2019 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (2, 1, 0, 52) at 2028 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (2, 1, 1, 52) at 2029 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (2, 1, 2, 52) at 2031 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (2, 1, 3, 52) at 2033 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (3, 1, 0, 52) at 2037 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (3, 1, 1, 52) at 2040 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (3, 1, 2, 52) at 2043 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
# Checking (3, 1, 3, 52) at 2046 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.5555530476190474 MAE and 0.5976209356296261 RMSE.
#
# The final model for energy is SARIMAX(2, 0, 2)x(0, 0, 3, 51).

# %%
# Note: This was ran when tempo was included instead of energy; now I am using energy, and the `alltime_rw_italy` run uses energy 
for feature in five_features: 
    find_sarima_parameters(it_rw_17, feature)
# Out:
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.02535439624913416 MAE and 0.03235024699693846 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.02530012454173834 MAE and 0.03235445125658867 RMSE.
# Checking (0, 0, 2, 48) at 1 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.02522953394499224 MAE and 0.03231597528729935 RMSE.
# Checking (0, 0, 3, 48) at 4 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.025200232385478194 MAE and 0.032300443440283794 RMSE.
# Checking (1, 0, 0, 48) at 12 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.025351736406543812 MAE and 0.03236137962655508 RMSE.
# Checking (1, 0, 1, 48) at 14 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.025072120974000744 MAE and 0.032271091282727773 RMSE.
# Checking (1, 0, 2, 48) at 15 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.028274897847032503 MAE and 0.03342957279344675 RMSE.
# Checking (1, 0, 3, 48) at 22 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.025241856689102653 MAE and 0.03234808952142124 RMSE.
# Checking (2, 0, 0, 48) at 39 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.025259122547373464 MAE and 0.032335647188633874 RMSE.
# Checking (2, 0, 1, 48) at 43 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.0251268780151687 MAE and 0.03228949860650226 RMSE.
# Checking (2, 0, 2, 48) at 49 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.025203422436217166 MAE and 0.03230994245824189 RMSE.
# Checking (2, 0, 3, 48) at 56 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.02519002478635753 MAE and 0.03232772000835487 RMSE.
# Checking (3, 0, 0, 48) at 76 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.025220076801639364 MAE and 0.03231127875675823 RMSE.
# Checking (3, 0, 1, 48) at 92 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.02522250979834025 MAE and 0.03233667919080725 RMSE.
# Checking (3, 0, 2, 48) at 107 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.02514408437655602 MAE and 0.0323037323198783 RMSE.
# Checking (3, 0, 3, 48) at 133 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.025158168627575528 MAE and 0.0323144249424731 RMSE.
# Checking (0, 1, 0, 48) at 157 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (0, 1, 1, 48) at 157 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (0, 1, 2, 48) at 157 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (0, 1, 3, 48) at 158 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (1, 1, 0, 48) at 159 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (1, 1, 1, 48) at 160 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (1, 1, 2, 48) at 160 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (1, 1, 3, 48) at 161 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (2, 1, 0, 48) at 163 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (2, 1, 1, 48) at 163 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (2, 1, 2, 48) at 164 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (2, 1, 3, 48) at 165 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (3, 1, 0, 48) at 167 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (3, 1, 1, 48) at 168 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (3, 1, 2, 48) at 170 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (3, 1, 3, 48) at 172 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 48) model with 0.25510084028565216 MAE and 0.26973669270026995 RMSE.
# Checking (0, 0, 0, 49) at 174 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 49) model with 0.02535439624913416 MAE and 0.03235024699693846 RMSE.
# Checking (0, 0, 1, 49) at 174 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 49) model with 0.025392788757609752 MAE and 0.03237649651782271 RMSE.
# Checking (0, 0, 2, 49) at 175 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 49) model with 0.025278982042080417 MAE and 0.0323108101250986 RMSE.
# Checking (0, 0, 3, 49) at 178 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 49) model with 0.025321884272008727 MAE and 0.03233435559327194 RMSE.
# Checking (1, 0, 0, 49) at 186 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 49) model with 0.025379016140978688 MAE and 0.03236929743852974 RMSE.
# Checking (1, 0, 1, 49) at 187 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 49) model with 0.02533275297722361 MAE and 0.032343282592310965 RMSE.
# Checking (1, 0, 2, 49) at 188 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 49) model with 0.025316851489192698 MAE and 0.03233362268021307 RMSE.
# Checking (1, 0, 3, 49) at 192 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 49) model with 0.02533076458653616 MAE and 0.03234126347287201 RMSE.
# Checking (2, 0, 0, 49) at 202 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 49) model with 0.025304849714075168 MAE and 0.03232557814397112 RMSE.
# Checking (2, 0, 1, 49) at 206 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 49) model with 0.025324967512441992 MAE and 0.0323381125236775 RMSE.
# Checking (2, 0, 2, 49) at 213 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 49) model with 0.025413226458356048 MAE and 0.03238179017555167 RMSE.
# Checking (2, 0, 3, 49) at 219 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 49) model with 0.025363095793192885 MAE and 0.032358980048078904 RMSE.
# Checking (3, 0, 0, 49) at 240 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 49) model with 0.0253599113172658 MAE and 0.032355598993722444 RMSE.
# Checking (3, 0, 1, 49) at 253 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 49) model with 0.02532125183863206 MAE and 0.03233446641839484 RMSE.
# Checking (3, 0, 2, 49) at 269 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 49) model with 0.025288165475004492 MAE and 0.032317242292652495 RMSE.
# Checking (3, 0, 3, 49) at 288 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 49) model with 0.025315887973235623 MAE and 0.03233396768756183 RMSE.
# Checking (0, 1, 0, 49) at 305 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (0, 1, 1, 49) at 306 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (0, 1, 2, 49) at 306 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (0, 1, 3, 49) at 306 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (1, 1, 0, 49) at 308 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (1, 1, 1, 49) at 308 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (1, 1, 2, 49) at 308 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (1, 1, 3, 49) at 309 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (2, 1, 0, 49) at 311 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (2, 1, 1, 49) at 311 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (2, 1, 2, 49) at 312 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (2, 1, 3, 49) at 313 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (3, 1, 0, 49) at 314 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (3, 1, 1, 49) at 316 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (3, 1, 2, 49) at 318 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (3, 1, 3, 49) at 320 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 0.2139074817523315 MAE and 0.24463742708481925 RMSE.
# Checking (0, 0, 0, 50) at 321 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 0.02535439624913416 MAE and 0.03235024699693846 RMSE.
# Checking (0, 0, 1, 50) at 322 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 0.02538978970093601 MAE and 0.0323704753392564 RMSE.
# Checking (0, 0, 2, 50) at 322 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 0.02532059998902488 MAE and 0.03233306024953163 RMSE.
# Checking (0, 0, 3, 50) at 325 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 0.02532377384996537 MAE and 0.03233477206303241 RMSE.
# Checking (1, 0, 0, 50) at 341 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 0.025315048518873895 MAE and 0.032330077504549644 RMSE.
# Checking (1, 0, 1, 50) at 343 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 0.025325785586386762 MAE and 0.0323364253715664 RMSE.
# Checking (1, 0, 2, 50) at 344 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 0.025338433160128664 MAE and 0.032343238177757416 RMSE.
# Checking (1, 0, 3, 50) at 351 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 0.02526781531025668 MAE and 0.03230437597584912 RMSE.
# Checking (2, 0, 0, 50) at 364 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 0.025329380567375954 MAE and 0.03233821250201542 RMSE.
# Checking (2, 0, 1, 50) at 370 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 0.02528805945455002 MAE and 0.03231514524159395 RMSE.
# Checking (2, 0, 2, 50) at 376 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 0.025330226028121943 MAE and 0.03233837529671063 RMSE.
# Checking (2, 0, 3, 50) at 381 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 0.025396467022955838 MAE and 0.032377645730469445 RMSE.
# Checking (3, 0, 0, 50) at 399 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 0.025393146625616165 MAE and 0.032374232324229715 RMSE.
# Checking (3, 0, 1, 50) at 412 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 0.025312095821763414 MAE and 0.03232696861677002 RMSE.
# Checking (3, 0, 2, 50) at 428 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 0.025349534235054483 MAE and 0.032351169113024304 RMSE.
# Checking (3, 0, 3, 50) at 444 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 0.025392429011893314 MAE and 0.03238184261077159 RMSE.
# Checking (0, 1, 0, 50) at 457 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (0, 1, 1, 50) at 458 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (0, 1, 2, 50) at 458 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (0, 1, 3, 50) at 459 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (1, 1, 0, 50) at 460 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (1, 1, 1, 50) at 460 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (1, 1, 2, 50) at 461 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (1, 1, 3, 50) at 461 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (2, 1, 0, 50) at 463 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (2, 1, 1, 50) at 464 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (2, 1, 2, 50) at 464 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (2, 1, 3, 50) at 465 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (3, 1, 0, 50) at 467 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (3, 1, 1, 50) at 469 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (3, 1, 2, 50) at 471 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (3, 1, 3, 50) at 473 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 0.16918078988567734 MAE and 0.21583917605508476 RMSE.
# Checking (0, 0, 0, 51) at 475 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 0.02535439624913416 MAE and 0.03235024699693846 RMSE.
# Checking (0, 0, 1, 51) at 475 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 0.02531723674223681 MAE and 0.03233155495630678 RMSE.
# Checking (0, 0, 2, 51) at 476 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 0.025274043609027408 MAE and 0.032307714830352594 RMSE.
# Checking (0, 0, 3, 51) at 479 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 0.025387252788801495 MAE and 0.03237053028971841 RMSE.
# Checking (1, 0, 0, 51) at 489 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 0.025372853701454996 MAE and 0.032361967733038316 RMSE.
# Checking (1, 0, 1, 51) at 490 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 0.025283577521413025 MAE and 0.03231253646402225 RMSE.
# Checking (1, 0, 2, 51) at 491 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 0.025375740189543694 MAE and 0.0323651572423947 RMSE.
# Checking (1, 0, 3, 51) at 495 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 0.025284449850438966 MAE and 0.032313467181444254 RMSE.
# Checking (2, 0, 0, 51) at 507 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 0.025363470666648458 MAE and 0.03235780404050126 RMSE.
# Checking (2, 0, 1, 51) at 516 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 0.02530698570075751 MAE and 0.03232700038137552 RMSE.
# Checking (2, 0, 2, 51) at 522 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 0.025322247012638688 MAE and 0.03233413200233519 RMSE.
# Checking (2, 0, 3, 51) at 528 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 0.025351011162502563 MAE and 0.032350243670528765 RMSE.
# Checking (3, 0, 0, 51) at 544 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 0.025269174561547685 MAE and 0.03230492314500484 RMSE.
# Checking (3, 0, 1, 51) at 558 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 0.025269491534856876 MAE and 0.032304735868342475 RMSE.
# Checking (3, 0, 2, 51) at 575 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 0.025354767989829458 MAE and 0.032352304134526895 RMSE.
# Checking (3, 0, 3, 51) at 591 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 0.02534713925558263 MAE and 0.03234906108187883 RMSE.
# Checking (0, 1, 0, 51) at 618 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (0, 1, 1, 51) at 618 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (0, 1, 2, 51) at 619 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (0, 1, 3, 51) at 619 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (1, 1, 0, 51) at 621 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (1, 1, 1, 51) at 621 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (1, 1, 2, 51) at 622 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (1, 1, 3, 51) at 622 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (2, 1, 0, 51) at 624 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (2, 1, 1, 51) at 625 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (2, 1, 2, 51) at 625 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (2, 1, 3, 51) at 626 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (3, 1, 0, 51) at 628 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (3, 1, 1, 51) at 630 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (3, 1, 2, 51) at 632 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (3, 1, 3, 51) at 634 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.12115385992378506 MAE and 0.17873797581450168 RMSE.
# Checking (0, 0, 0, 52) at 636 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.02535439624913416 MAE and 0.03235024699693846 RMSE.
# Checking (0, 0, 1, 52) at 636 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.02526210209787037 MAE and 0.032299449137227855 RMSE.
# Checking (0, 0, 2, 52) at 637 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.025372610307519233 MAE and 0.0323622086314413 RMSE.
# Checking (0, 0, 3, 52) at 641 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.025316522217513793 MAE and 0.03233117673895322 RMSE.
# Checking (1, 0, 0, 52) at 650 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.025305666855863867 MAE and 0.03232464895605698 RMSE.
# Checking (1, 0, 1, 52) at 651 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.025304061313167536 MAE and 0.032326331853629084 RMSE.
# Checking (1, 0, 2, 52) at 653 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.02532646883536795 MAE and 0.032337535370139926 RMSE.
# Checking (1, 0, 3, 52) at 657 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.02533212825157623 MAE and 0.03233980181822933 RMSE.
# Checking (2, 0, 0, 52) at 680 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.025321106431077194 MAE and 0.03233376614135919 RMSE.
# Checking (2, 0, 1, 52) at 686 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.02535353660236232 MAE and 0.03235092439932566 RMSE.
# Checking (2, 0, 2, 52) at 693 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.02530497696828865 MAE and 0.03232336358433965 RMSE.
# Checking (2, 0, 3, 52) at 700 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.025298446248626705 MAE and 0.03232508019894517 RMSE.
# Checking (3, 0, 0, 52) at 728 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.025291148043998752 MAE and 0.03231702136533982 RMSE.
# Checking (3, 0, 1, 52) at 740 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.025298311153811832 MAE and 0.03232090571666844 RMSE.
# Checking (3, 0, 2, 52) at 759 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.025407933698350427 MAE and 0.03238393960101903 RMSE.
# Checking (3, 0, 3, 52) at 779 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.025318175456889525 MAE and 0.03233166081515402 RMSE.
# Checking (0, 1, 0, 52) at 797 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (0, 1, 1, 52) at 797 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (0, 1, 2, 52) at 797 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (0, 1, 3, 52) at 798 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (1, 1, 0, 52) at 800 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (1, 1, 1, 52) at 800 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (1, 1, 2, 52) at 800 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (1, 1, 3, 52) at 801 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (2, 1, 0, 52) at 803 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (2, 1, 1, 52) at 803 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (2, 1, 2, 52) at 804 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (2, 1, 3, 52) at 805 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (3, 1, 0, 52) at 807 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (3, 1, 1, 52) at 808 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (3, 1, 2, 52) at 810 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
# Checking (3, 1, 3, 52) at 811 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.07274907281903563 MAE and 0.13104112426083286 RMSE.
#
# The final model for danceability is SARIMAX(2, 0, 2)x(1, 0, 1, 48).
#
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.06640142056855042 MAE and 0.07407738986529605 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.07092223771785762 MAE and 0.08111464162465999 RMSE.
# Checking (0, 0, 2, 48) at 2 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.06962607088710332 MAE and 0.08004288761099934 RMSE.
# Checking (0, 0, 3, 48) at 40 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.07066034603540038 MAE and 0.08289370254675885 RMSE.
# Checking (1, 0, 0, 48) at 69 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.06817815116856263 MAE and 0.07796753218459013 RMSE.
# Checking (1, 0, 1, 48) at 72 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.07645535286856485 MAE and 0.08869873733684837 RMSE.
# Checking (1, 0, 2, 48) at 73 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.07426134499917846 MAE and 0.0846768010167048 RMSE.
# Checking (1, 0, 3, 48) at 81 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.07699411561762869 MAE and 0.08807216165317328 RMSE.
# Checking (2, 0, 0, 48) at 227 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.07704035236679747 MAE and 0.08837164274125965 RMSE.
# Checking (2, 0, 1, 48) at 238 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.07538925010005686 MAE and 0.08588380075725563 RMSE.
# Checking (2, 0, 2, 48) at 248 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.07418939683076346 MAE and 0.08472736416311255 RMSE.
# Checking (2, 0, 3, 48) at 257 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.07544392067720253 MAE and 0.08570467652596934 RMSE.
# Checking (3, 0, 0, 48) at 287 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.06960303440611404 MAE and 0.08035469635234611 RMSE.
# Checking (3, 0, 1, 48) at 317 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.07197383484255594 MAE and 0.08266271153959803 RMSE.
# Checking (3, 0, 2, 48) at 343 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.07201793536888708 MAE and 0.08261468099884031 RMSE.
# Checking (3, 0, 3, 48) at 368 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.07519745203966406 MAE and 0.08559740099972896 RMSE.
# Checking (0, 1, 0, 48) at 394 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (0, 1, 1, 48) at 394 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (0, 1, 2, 48) at 395 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (0, 1, 3, 48) at 395 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (1, 1, 0, 48) at 397 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (1, 1, 1, 48) at 398 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (1, 1, 2, 48) at 398 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (1, 1, 3, 48) at 399 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (2, 1, 0, 48) at 401 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (2, 1, 1, 48) at 402 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (2, 1, 2, 48) at 403 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (2, 1, 3, 48) at 404 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (3, 1, 0, 48) at 406 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (3, 1, 1, 48) at 408 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (3, 1, 2, 48) at 410 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (3, 1, 3, 48) at 412 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 48) model with 0.381428696428509 MAE and 0.4048062955601532 RMSE.
# Checking (0, 0, 0, 49) at 415 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 49) model with 0.06640142056855042 MAE and 0.07407738986529605 RMSE.
# Checking (0, 0, 1, 49) at 415 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 49) model with 0.09197709665837354 MAE and 0.10054410961179923 RMSE.
# Checking (0, 0, 2, 49) at 417 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 49) model with 0.08388185959524708 MAE and 0.09222199608479033 RMSE.
# Checking (0, 0, 3, 49) at 423 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 49) model with 0.09212024093270653 MAE and 0.0995979977860969 RMSE.
# Checking (1, 0, 0, 49) at 438 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 49) model with 0.0922278460838244 MAE and 0.10270087105879709 RMSE.
# Checking (1, 0, 1, 49) at 440 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 49) model with 0.08923182265832948 MAE and 0.09878489343740432 RMSE.
# Checking (1, 0, 2, 49) at 442 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 49) model with 0.08906825569762966 MAE and 0.09685546800481573 RMSE.
# Checking (1, 0, 3, 49) at 450 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 49) model with 0.0871254851905852 MAE and 0.09506880930672669 RMSE.
# Checking (2, 0, 0, 49) at 467 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 49) model with 0.09572418292010727 MAE and 0.10354924749423285 RMSE.
# Checking (2, 0, 1, 49) at 476 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 49) model with 0.08752134625424716 MAE and 0.09556346085017753 RMSE.
# Checking (2, 0, 2, 49) at 487 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 49) model with 0.0878715187813202 MAE and 0.09509181637822522 RMSE.
# Checking (2, 0, 3, 49) at 496 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 49) model with 0.09009815168247765 MAE and 0.09795062925575113 RMSE.
# Checking (3, 0, 0, 49) at 519 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 49) model with 0.09159295660998795 MAE and 0.10050243971368726 RMSE.
# Checking (3, 0, 1, 49) at 542 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 49) model with 0.0881714591717871 MAE and 0.09551456218703834 RMSE.
# Checking (3, 0, 2, 49) at 565 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 49) model with 0.08902664241966236 MAE and 0.09640386660511227 RMSE.
# Checking (3, 0, 3, 49) at 590 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 49) model with 0.08914637082652273 MAE and 0.09662560811549285 RMSE.
# Checking (0, 1, 0, 49) at 619 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (0, 1, 1, 49) at 619 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (0, 1, 2, 49) at 619 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (0, 1, 3, 49) at 620 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (1, 1, 0, 49) at 622 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (1, 1, 1, 49) at 622 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (1, 1, 2, 49) at 623 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (1, 1, 3, 49) at 624 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (2, 1, 0, 49) at 626 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (2, 1, 1, 49) at 627 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (2, 1, 2, 49) at 628 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (2, 1, 3, 49) at 629 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (3, 1, 0, 49) at 631 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (3, 1, 1, 49) at 633 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (3, 1, 2, 49) at 636 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (3, 1, 3, 49) at 638 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 0.3138096238094739 MAE and 0.35206883492263674 RMSE.
# Checking (0, 0, 0, 50) at 641 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 0.06640142056855042 MAE and 0.07407738986529605 RMSE.
# Checking (0, 0, 1, 50) at 641 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 0.06587695518613 MAE and 0.07432211917917114 RMSE.
# Checking (0, 0, 2, 50) at 643 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 0.06544995388760043 MAE and 0.07359325276451191 RMSE.
# Checking (0, 0, 3, 50) at 653 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 0.06681256433579445 MAE and 0.07451889421857494 RMSE.
# Checking (1, 0, 0, 50) at 670 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 0.06462560892193663 MAE and 0.07434537680755847 RMSE.
# Checking (1, 0, 1, 50) at 672 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 0.0669082363896133 MAE and 0.07537965772158048 RMSE.
# Checking (1, 0, 2, 50) at 675 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 0.06776020804084891 MAE and 0.0760919078441534 RMSE.
# Checking (1, 0, 3, 50) at 683 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 0.0679288208326184 MAE and 0.07601693920066535 RMSE.
# Checking (2, 0, 0, 50) at 702 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 0.06624828339172757 MAE and 0.07508638728825559 RMSE.
# Checking (2, 0, 1, 50) at 711 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 0.06800142210444456 MAE and 0.07624240201372129 RMSE.
# Checking (2, 0, 2, 50) at 721 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 0.06774218357567487 MAE and 0.07599737489451731 RMSE.
# Checking (2, 0, 3, 50) at 732 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 0.06831175205154105 MAE and 0.07677878856937709 RMSE.
# Checking (3, 0, 0, 50) at 756 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 0.06695742547096707 MAE and 0.07460908986024371 RMSE.
# Checking (3, 0, 1, 50) at 780 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 0.06641396781747332 MAE and 0.07470242667245676 RMSE.
# Checking (3, 0, 2, 50) at 806 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 0.06838930029506736 MAE and 0.07783261297047168 RMSE.
# Checking (3, 0, 3, 50) at 833 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 0.06788341241719394 MAE and 0.07639040870719632 RMSE.
# Checking (0, 1, 0, 50) at 866 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (0, 1, 1, 50) at 866 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (0, 1, 2, 50) at 867 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (0, 1, 3, 50) at 868 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (1, 1, 0, 50) at 870 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (1, 1, 1, 50) at 871 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (1, 1, 2, 50) at 871 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (1, 1, 3, 50) at 872 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (2, 1, 0, 50) at 874 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (2, 1, 1, 50) at 875 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (2, 1, 2, 50) at 876 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (2, 1, 3, 50) at 877 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (3, 1, 0, 50) at 880 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (3, 1, 1, 50) at 882 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (3, 1, 2, 50) at 884 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (3, 1, 3, 50) at 887 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 0.2657143607142483 MAE and 0.3142685002969446 RMSE.
# Checking (0, 0, 0, 51) at 889 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 0.06640142056855042 MAE and 0.07407738986529605 RMSE.
# Checking (0, 0, 1, 51) at 889 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 0.06616117053344307 MAE and 0.07405741039749293 RMSE.
# Checking (0, 0, 2, 51) at 891 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 0.06653328117384506 MAE and 0.07427749113195843 RMSE.
# Checking (0, 0, 3, 51) at 898 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 0.06638130078733379 MAE and 0.07515114378851766 RMSE.
# Checking (1, 0, 0, 51) at 916 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 0.06869850751915839 MAE and 0.07853815276327777 RMSE.
# Checking (1, 0, 1, 51) at 919 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 0.06565514415188621 MAE and 0.07746335154270594 RMSE.
# Checking (1, 0, 2, 51) at 922 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 0.0672866258448807 MAE and 0.07677854298551968 RMSE.
# Checking (1, 0, 3, 51) at 930 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 0.07233063997954486 MAE and 0.08352967796437333 RMSE.
# Checking (2, 0, 0, 51) at 950 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 0.06636061754617432 MAE and 0.0751102017594782 RMSE.
# Checking (2, 0, 1, 51) at 959 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 0.10040014625903154 MAE and 0.10783779778777032 RMSE.
# Checking (2, 0, 2, 51) at 971 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 0.06811208625624315 MAE and 0.07820666082717784 RMSE.
# Checking (2, 0, 3, 51) at 982 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 0.07014139941616483 MAE and 0.08106225755415597 RMSE.
# Checking (3, 0, 0, 51) at 1009 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 0.06681703706143578 MAE and 0.07591091005973999 RMSE.
# Checking (3, 0, 1, 51) at 1033 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 0.06788829122882688 MAE and 0.07665883850960518 RMSE.
# Checking (3, 0, 2, 51) at 1059 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 0.06861799057599038 MAE and 0.07763547042474729 RMSE.
# Checking (3, 0, 3, 51) at 1088 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 0.0735177580079144 MAE and 0.08363065868326995 RMSE.
# Checking (0, 1, 0, 51) at 1121 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (0, 1, 1, 51) at 1121 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (0, 1, 2, 51) at 1121 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (0, 1, 3, 51) at 1122 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (1, 1, 0, 51) at 1125 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (1, 1, 1, 51) at 1125 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (1, 1, 2, 51) at 1125 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (1, 1, 3, 51) at 1127 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (2, 1, 0, 51) at 1129 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (2, 1, 1, 51) at 1130 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (2, 1, 2, 51) at 1131 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (2, 1, 3, 51) at 1132 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (3, 1, 0, 51) at 1135 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (3, 1, 1, 51) at 1137 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (3, 1, 2, 51) at 1139 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (3, 1, 3, 51) at 1142 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.2114286214285465 MAE and 0.2591877182516632 RMSE.
# Checking (0, 0, 0, 52) at 1145 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.06640142056855042 MAE and 0.07407738986529605 RMSE.
# Checking (0, 0, 1, 52) at 1145 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.06861022152972583 MAE and 0.0767263258495838 RMSE.
# Checking (0, 0, 2, 52) at 1147 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.06633680914997546 MAE and 0.07373796689523328 RMSE.
# Checking (0, 0, 3, 52) at 1154 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.06612856969066218 MAE and 0.07372926367384784 RMSE.
# Checking (1, 0, 0, 52) at 1173 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.06562375975582198 MAE and 0.07345326650937295 RMSE.
# Checking (1, 0, 1, 52) at 1176 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.06337950601941077 MAE and 0.07243004970348325 RMSE.
# Checking (1, 0, 2, 52) at 1178 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.06644142011242855 MAE and 0.0734629997434216 RMSE.
# Checking (1, 0, 3, 52) at 1186 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.06550609296059821 MAE and 0.0728678057105335 RMSE.
# Checking (2, 0, 0, 52) at 1208 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.06640542944111011 MAE and 0.07421432010291944 RMSE.
# Checking (2, 0, 1, 52) at 1219 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.0656880987495476 MAE and 0.07310420992114423 RMSE.
# Checking (2, 0, 2, 52) at 1234 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.06692320025987608 MAE and 0.07510339603269178 RMSE.
# Checking (2, 0, 3, 52) at 1247 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.06642547925781929 MAE and 0.07348081619428343 RMSE.
# Checking (3, 0, 0, 52) at 1273 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.06569961456964367 MAE and 0.07661976778400843 RMSE.
# Checking (3, 0, 1, 52) at 1300 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.06551081648501124 MAE and 0.0727606208037546 RMSE.
# Checking (3, 0, 2, 52) at 1327 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.06434892728677606 MAE and 0.0713354223924528 RMSE.
# Checking (3, 0, 3, 52) at 1358 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.065583291749516 MAE and 0.07321434910005048 RMSE.
# Checking (0, 1, 0, 52) at 1391 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (0, 1, 1, 52) at 1391 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (0, 1, 2, 52) at 1392 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (0, 1, 3, 52) at 1393 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (1, 1, 0, 52) at 1395 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (1, 1, 1, 52) at 1396 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (1, 1, 2, 52) at 1396 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (1, 1, 3, 52) at 1397 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (2, 1, 0, 52) at 1400 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (2, 1, 1, 52) at 1400 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (2, 1, 2, 52) at 1402 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (2, 1, 3, 52) at 1403 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (3, 1, 0, 52) at 1405 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (3, 1, 1, 52) at 1408 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (3, 1, 2, 52) at 1410 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
# Checking (3, 1, 3, 52) at 1413 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.14190478690474945 MAE and 0.16934452546839998 RMSE.
#
# The final model for mode is SARIMAX(2, 0, 2)x(1, 0, 1, 52).
#
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.039104233489283324 MAE and 0.04425607370325876 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# ...
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (1, 1, 0, 49) at 390 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (1, 1, 1, 49) at 390 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (1, 1, 2, 49) at 390 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (1, 1, 3, 49) at 391 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (2, 1, 0, 49) at 393 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (2, 1, 1, 49) at 394 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (2, 1, 2, 49) at 395 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (2, 1, 3, 49) at 396 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (3, 1, 0, 49) at 1027 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (3, 1, 1, 49) at 1043 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (3, 1, 2, 49) at 1045 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (3, 1, 3, 49) at 1047 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 45.16105904761906 MAE and 70.99887044750093 RMSE.
# Checking (0, 0, 0, 50) at 1049 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 91.47032826495507 MAE and 97.43873815073329 RMSE.
# Checking (0, 0, 1, 50) at 1049 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 128.89500119764287 MAE and 139.0101091910033 RMSE.
# Checking (0, 0, 2, 50) at 1050 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 36.456446957372094 MAE and 37.472679720662505 RMSE.
# Checking (0, 0, 3, 50) at 1056 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 123.52236287023582 MAE and 127.47643203599424 RMSE.
# Checking (1, 0, 0, 50) at 2201 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 157.02799436483596 MAE and 169.5042751513273 RMSE.
# Checking (1, 0, 1, 50) at 2217 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 157.24351328584905 MAE and 169.73577086041536 RMSE.
# Checking (1, 0, 2, 50) at 2232 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 163.86489175195928 MAE and 170.1437050995257 RMSE.
# Checking (1, 0, 3, 50) at 2246 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 25.63158578699124 MAE and 26.65368186235578 RMSE.
# Checking (2, 0, 0, 50) at 2289 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 40.95827099117722 MAE and 42.1561754494978 RMSE.
# Checking (2, 0, 1, 50) at 2303 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 31.599546734328026 MAE and 32.281559445712446 RMSE.
# Checking (2, 0, 2, 50) at 2317 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 7.376618025545184 MAE and 9.498763193277613 RMSE.
# Checking (2, 0, 3, 50) at 2338 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 7.352514283158108 MAE and 9.419341971755443 RMSE.
# Checking (3, 0, 0, 50) at 2380 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 158.09947828300767 MAE and 170.64934633475724 RMSE.
# Checking (3, 0, 1, 50) at 2428 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 20.0270115939936 MAE and 21.33423592351419 RMSE.
# Checking (3, 0, 2, 50) at 2473 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 7.5044958678846285 MAE and 9.473841481608487 RMSE.
# Checking (3, 0, 3, 50) at 2526 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 7.355303459824692 MAE and 10.069978514114476 RMSE.
# Checking (0, 1, 0, 50) at 2586 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (0, 1, 1, 50) at 2586 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (0, 1, 2, 50) at 2586 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (0, 1, 3, 50) at 2588 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (1, 1, 0, 50) at 2591 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (1, 1, 1, 50) at 2592 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (1, 1, 2, 50) at 2593 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (1, 1, 3, 50) at 2594 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (2, 1, 0, 50) at 2598 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (2, 1, 1, 50) at 2600 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (2, 1, 2, 50) at 2601 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (2, 1, 3, 50) at 2603 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (3, 1, 0, 50) at 2608 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (3, 1, 1, 50) at 2611 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (3, 1, 2, 50) at 2615 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (3, 1, 3, 50) at 2619 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 61.54564904761909 MAE and 83.72183734774462 RMSE.
# Checking (0, 0, 0, 51) at 2623 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 91.47032826495507 MAE and 97.43873815073329 RMSE.
# Checking (0, 0, 1, 51) at 2624 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 42.55415088498204 MAE and 44.619982668046575 RMSE.
# Checking (0, 0, 2, 51) at 2627 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 147.6531601332098 MAE and 155.58344990840257 RMSE.
# Checking (0, 0, 3, 51) at 2635 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 82.2295745970293 MAE and 83.3710263398015 RMSE.
# Checking (1, 0, 0, 51) at 2657 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 16.340932333802304 MAE and 19.63667081458534 RMSE.
# Checking (1, 0, 1, 51) at 2659 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 24.32058359070778 MAE and 26.25631754565669 RMSE.
# Checking (1, 0, 2, 51) at 2662 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 105.52334684340373 MAE and 108.37504948395681 RMSE.
# Checking (1, 0, 3, 51) at 2674 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 43.141402109101286 MAE and 47.512033022868366 RMSE.
# Checking (2, 0, 0, 51) at 2707 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 15.316375512009058 MAE and 18.935344114611773 RMSE.
# Checking (2, 0, 1, 51) at 2722 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 121.83989248458414 MAE and 126.36139089765152 RMSE.
# Checking (2, 0, 2, 51) at 2737 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 92.88999345657372 MAE and 94.60927066227629 RMSE.
# Checking (2, 0, 3, 51) at 2754 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 54.884041978462186 MAE and 56.98462413479826 RMSE.
# Checking (3, 0, 0, 51) at 2813 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 17.04076965465306 MAE and 20.16148209033537 RMSE.
# Checking (3, 0, 1, 51) at 3064 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 115.30064513364933 MAE and 119.12652728923207 RMSE.
# Checking (3, 0, 2, 51) at 3375 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 106.6968250106733 MAE and 109.57434063876107 RMSE.
# Checking (3, 0, 3, 51) at 3469 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 51.83048404240707 MAE and 54.45815878568772 RMSE.
# Checking (0, 1, 0, 51) at 3568 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (0, 1, 1, 51) at 3568 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (0, 1, 2, 51) at 3569 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (0, 1, 3, 51) at 3571 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (1, 1, 0, 51) at 3579 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (1, 1, 1, 51) at 3580 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (1, 1, 2, 51) at 3581 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (1, 1, 3, 51) at 3584 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (2, 1, 0, 51) at 3590 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (2, 1, 1, 51) at 3592 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (2, 1, 2, 51) at 3595 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (2, 1, 3, 51) at 3598 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (3, 1, 0, 51) at 3605 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (3, 1, 1, 51) at 3610 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (3, 1, 2, 51) at 3616 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (3, 1, 3, 51) at 3622 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 79.09675857142861 MAE and 95.28627082639339 RMSE.
# Checking (0, 0, 0, 52) at 3630 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 91.47032826495507 MAE and 97.43873815073329 RMSE.
# Checking (0, 0, 1, 52) at 3631 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 77.35047599419401 MAE and 79.02435732575982 RMSE.
# Checking (0, 0, 2, 52) at 3637 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 66.73872067015098 MAE and 69.69177729011393 RMSE.
# Checking (0, 0, 3, 52) at 3654 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 98.6771375179377 MAE and 100.82403754614708 RMSE.
# Checking (1, 0, 0, 52) at 3705 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 126.04110470774826 MAE and 139.79381847514227 RMSE.
# Checking (1, 0, 1, 52) at 3710 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 130.9446269526487 MAE and 146.436952314977 RMSE.
# Checking (1, 0, 2, 52) at 3717 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 147.54480606622144 MAE and 158.37344260796854 RMSE.
# Checking (1, 0, 3, 52) at 3739 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 103.9572699833028 MAE and 114.2855734612019 RMSE.
# Checking (2, 0, 0, 52) at 3796 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 95.26763973077875 MAE and 97.0582377206088 RMSE.
# Checking (2, 0, 1, 52) at 3821 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 79.39924989734665 MAE and 85.92964042410628 RMSE.
# Checking (2, 0, 2, 52) at 3849 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 79.95801392528263 MAE and 86.74366539151822 RMSE.
# Checking (2, 0, 3, 52) at 3882 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 130.4327359708586 MAE and 137.53993282705292 RMSE.
# Checking (3, 0, 0, 52) at 3962 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 57.43321600956822 MAE and 60.47754173943205 RMSE.
# Checking (3, 0, 1, 52) at 4046 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 101.37487618187902 MAE and 103.72500580471993 RMSE.
# Checking (3, 0, 2, 52) at 4143 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 112.53519683213806 MAE and 116.52397496139676 RMSE.
# Checking (3, 0, 3, 52) at 4265 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 90.06179216881598 MAE and 97.5157718366908 RMSE.
# Checking (0, 1, 0, 52) at 4453 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (0, 1, 1, 52) at 4454 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (0, 1, 2, 52) at 4455 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (0, 1, 3, 52) at 4466 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (1, 1, 0, 52) at 4478 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (1, 1, 1, 52) at 4479 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (1, 1, 2, 52) at 4480 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (1, 1, 3, 52) at 4483 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (2, 1, 0, 52) at 4496 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (2, 1, 1, 52) at 4499 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (2, 1, 2, 52) at 4501 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (2, 1, 3, 52) at 4510 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (3, 1, 0, 52) at 4523 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (3, 1, 1, 52) at 4535 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (3, 1, 2, 52) at 4547 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
# Checking (3, 1, 3, 52) at 4559 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 95.95981380952384 MAE and 105.08803272388077 RMSE.
#
# The final model for tempo is SARIMAX(2, 0, 2)x(2, 0, 0, 49).

# %% [markdown]
# Results SARIMA seasonal order grid search using only 2017 data:
# + The final model for danceability is SARIMAX(2, 0, 2)x(3, 0, 0, 48).
# + The final model for mode is SARIMAX(2, 0, 2)x(1, 0, 1, 52).
# + The final model for acousticness is SARIMAX(2, 0, 2)x(1, 0, 2, 48).
# + The final model for valence is SARIMAX(2, 0, 2)x(0, 0, 1, 49).
# + The final model for energy is SARIMAX(2, 0, 2)x(0, 0, 3, 51).

# %% [markdown]
# #### _Adding Seasonal Orders to `arima_param_df`_

# %% [markdown]
# citation: converting string to tuple https://www.geeksforgeeks.org/python-convert-string-to-tuple/

# %%
arima_param_df.loc[arima_param_df['audio_feature'] == 'danceability', 'seasonal_order'] = '3, 0, 0, 48'
arima_param_df.loc[arima_param_df['audio_feature'] == 'mode', 'seasonal_order'] = '1, 0, 1, 52'
arima_param_df.loc[arima_param_df['audio_feature'] == 'acousticness', 'seasonal_order'] = '1, 0, 2, 48'
arima_param_df.loc[arima_param_df['audio_feature'] == 'valence', 'seasonal_order'] = '0, 0, 1, 49'
arima_param_df.loc[arima_param_df['audio_feature'] == 'energy', 'seasonal_order'] = '0, 0, 3, 51'

# %% [markdown]
# #### _Updated `arima_param_df`_

# %%
arima_param_df
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
# 1          mode          1       4       3  (4, 1, 3)  ARIMA(4,1,3)
# 2  acousticness          0       3       2  (3, 0, 2)  ARIMA(3,0,2)
# 3       valence          0       2       2  (2, 0, 2)  ARIMA(2,0,2)
# 4         tempo          0       0       5  (0, 0, 5)  ARIMA(0,0,5)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order
# 0 -726.878719          0.026156         0.012448    3, 0, 0, 48
# 1 -430.794979          0.069307         0.145383    1, 0, 1, 52
# 2 -600.573624          0.038503         0.031290    1, 0, 2, 48
# 3 -627.919164          0.035573         0.033325    0, 0, 1, 49
# 4  780.783703          2.937925         7.120252    2, 0, 0, 49

# %% [markdown]
# #### _Function for SARIMA w/ seasonal components, no exogenous variables:_

# %%
def sarima_predict_plot_seasonal(df, feature, year, output_df, title='title', figsize=(15,5), order=None, d=None, seasonal_order=None, ci=True):
  
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    # find order from arima parameters dataframe 
    if order is None:
        order = arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
    
    # find seasonal order from arima parameters dataframe 
    if seasonal_order is None: 
        sea_string = arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'seasonal_order'].iloc[0]
        seasonal_order = tuple(map(int, sea_string.split(', '))) 
    print(f'seasonal order = {seasonal_order}')
    
    # instantiate and fit SARIMAX model 
    sarima = SARIMAX(endog=train, order=order, seasonal_order=seasonal_order).fit()

    # get predictions for train and test sets 
    preds_train = sarima.predict(start=train.index[d], end=train.index[-1], typ='levels')
    preds_test = sarima.predict(start=test.index[0], end=test.index[-1], typ='levels')
    
    # calculate and print RMSE for train and test setes 
    train_rmse = mean_squared_error(train[d::], preds_train)**0.5
    print(f'{feature.capitalize()} train RMSE ({year}) - SARIMA({order}): {train_rmse}')

    test_rmse = mean_squared_error(test, preds_test)**0.5
    print(f'{feature.capitalize()} test RMSE ({year}) - SARIMA({order}): {test_rmse}')    
    
    # add RMSEs to arima parameters dataframe 
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'sarima_train_rmse'] = train_rmse    
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'sarima_test_rmse'] = test_rmse
    
    # calculate residuals
    # residuals = test - preds_test
    
    # set up plot
    plt.figure(figsize=figsize)
    
    # plot training data 
    plt.plot(train, color='blue')
    
    # plot testing data 
    plt.plot(test.index, test, color='orange')
    
    # plot predicted values for test set 
    plt.plot(test.index, preds_test, color='green')
    
    # add line for the baseline model (mean value of feature)
    plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')
    
    # plot confidence interval 
    if ci:
        ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
        plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 
    
    # make plot with title! 
    plt.title(title, fontsize=16)
    plt.show() ;

# %%
for feature in five_features:
    sarima_predict_plot_seasonal(it_rw_17, feature, 2017, title=f'Mean {feature.capitalize()} Score, Italy 2017 (SARIMA w/0 exog variables)')
# Out:
# d = 1
# order = (2, 1, 1)
# seasonal order = (3, 0, 0, 48)
# Danceability train RMSE (2017) - SARIMA((2, 1, 1)): 0.02604860270283264
# Danceability test RMSE (2017) - SARIMA((2, 1, 1)): 0.02129312854030801
# d = 1
# order = (4, 1, 3)
# seasonal order = (1, 0, 1, 52)
# Mode train RMSE (2017) - SARIMA((4, 1, 3)): 0.06662545896440102
# Mode test RMSE (2017) - SARIMA((4, 1, 3)): 0.10908603704861933
# d = 0
# order = (3, 0, 2)
# seasonal order = (1, 0, 2, 48)
# Acousticness train RMSE (2017) - SARIMA((3, 0, 2)): 0.0599604383435671
# Acousticness test RMSE (2017) - SARIMA((3, 0, 2)): 0.01943910236962413
# d = 0
# order = (2, 0, 2)
# seasonal order = (0, 0, 1, 49)
# Valence train RMSE (2017) - SARIMA((2, 0, 2)): 0.0762942717827684
# Valence test RMSE (2017) - SARIMA((2, 0, 2)): 0.025510262698733292
# d = 0
# order = (0, 0, 5)
# seasonal order = (2, 0, 0, 49)
# Tempo train RMSE (2017) - SARIMA((0, 0, 5)): 21.276842071246342
# Tempo test RMSE (2017) - SARIMA((0, 0, 5)): 14.1784468298147

# %% [markdown]
# #### _Updated `arima_param_df`_

# %%
arima_param_df
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
# 1          mode          1       4       3  (4, 1, 3)  ARIMA(4,1,3)
# 2  acousticness          0       3       2  (3, 0, 2)  ARIMA(3,0,2)
# 3       valence          0       2       2  (2, 0, 2)  ARIMA(2,0,2)
# 4         tempo          0       0       5  (0, 0, 5)  ARIMA(0,0,5)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -726.878719          0.026156         0.012448    3, 0, 0, 48
# 1 -430.794979          0.069307         0.145383    1, 0, 1, 52
# 2 -600.573624          0.038503         0.031290    1, 0, 2, 48
# 3 -627.919164          0.035573         0.033325    0, 0, 1, 49
# 4  780.783703          2.937925         7.120252    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse
# 0           0.026049          0.021293
# 1           0.066625          0.109086
# 2           0.059960          0.019439
# 3           0.076294          0.025510
# 4          21.276842         14.178447

# %% [markdown]
# #### _Incorporating Exogenous Variables in SARIMAX models_

# %%
def sarima_predict_plot_exog(df, feature, year, exog_var, title='title', figsize=(15,5), order=None, d=None, seasonal_order=None, ci=True):

    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    # find order from arima parameters dataframe 
    if order is None:
        order = arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
    
    # find seasonal order from arima parameters dataframe 
    if seasonal_order is None: 
        sea_string = arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'seasonal_order'].iloc[0]
        seasonal_order = tuple(map(int, sea_string.split(', '))) 
    print(f'seasonal order = {seasonal_order}')
    
    # reshape exogenous features to pass to the model 
    exog = df.loc[:, exog_var]   
   
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # instantiate and fit SARIMAX model 
    sarima = SARIMAX(endog=train, exog=exog[0:n_rows], order=order, seasonal_order=seasonal_order).fit()

    # get predictions for train and test sets 
    preds_train = sarima.predict(start=train.index[d], end=train.index[-1], typ='levels', exog=exog[0:n_rows])
    preds_test = sarima.predict(start=test.index[0], end=test.index[-1], typ='levels', exog=exog[n_rows:])
    
    # calculate and print RMSE for train and test setes 
    train_rmse = mean_squared_error(train[d::], preds_train)**0.5
    print(f'{feature.capitalize()} train RMSE ({year}) - SARIMAX({seasonal_order}) w/ exogenous variables: {train_rmse}')

    test_rmse = mean_squared_error(test, preds_test)**0.5
    print(f'{feature.capitalize()} test RMSE ({year}) - SARIMAX({seasonal_order}) w/ exogenous variables: {test_rmse}')    
    
    # add RMSEs to arima parameters dataframe 
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'exog_train_rmse'] = train_rmse    
    arima_param_df.loc[arima_param_df['audio_feature'] == feature, 'exog_test_rmse'] = test_rmse

    # calculate residuals
    # residuals = test - preds_test
    
    # set up plot
    plt.figure(figsize=figsize)
    
    # plot training data 
    plt.plot(train, color='blue')
    
    # plot testing data 
    plt.plot(test.index, test, color='orange')
    
    # plot predicted values for test set 
    plt.plot(test.index, preds_test, color='green')
    
    # add line for the baseline model (mean value of feature)
    plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')
    
    # plot confidence interval 
    if ci:
        ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
        plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 
    
    # make plot with title! 
    plt.title(title, fontsize=16)
    plt.show() ;

# %% [markdown]
# _Identifying exogenous variables for each of the five main features, which for each of them is the other four audio features_

# %%
five_features = ['danceability', 'mode', 'acousticness', 'valence', 'energy']

exog_danceability = ['mode', 'acousticness', 'valence', 'energy']
exog_mode = ['danceability', 'acousticness', 'valence', 'energy']
exog_acousticness = ['danceability', 'mode', 'valence', 'energy']
exog_valence = ['danceability', 'mode', 'acousticness', 'energy']
exog_energy = ['danceability', 'mode', 'acousticness', 'valence']

# %%
sarima_predict_plot_exog(it_rw_17, 'danceability', 2017, exog_var=exog_danceability, title=f'Mean Danceability Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (2, 1, 1)
# seasonal order = (3, 0, 0, 48)
# Danceability train RMSE (2017) - SARIMAX((3, 0, 0, 48)) w/ exogenous variables: 0.020428213079817507
# Danceability test RMSE (2017) - SARIMAX((3, 0, 0, 48)) w/ exogenous variables: 0.011168623038644306

# %%
# for feature in five_features:
#     sarima_predict_plot_exog(it_rw_17, feature, 2017, exog_var=f'exog_{feature}', title=f'Mean {feature} Score, Italy 2017 (SARIMA w/ exog variables)')

# %%
sarima_predict_plot_exog(it_rw_17, 'mode', 2017, exog_var=exog_mode, title=f'Mean Mode Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (4, 1, 3)
# seasonal order = (1, 0, 1, 52)
# Mode train RMSE (2017) - SARIMAX((1, 0, 1, 52)) w/ exogenous variables: 0.06968925672683578
# Mode test RMSE (2017) - SARIMAX((1, 0, 1, 52)) w/ exogenous variables: 0.09483950188720432

# %%
sarima_predict_plot_exog(it_rw_17, 'acousticness', 2017, exog_var=exog_acousticness, title=f'Mean Acousticness Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 0
# order = (3, 0, 2)
# seasonal order = (1, 0, 2, 48)
# Acousticness train RMSE (2017) - SARIMAX((1, 0, 2, 48)) w/ exogenous variables: 0.04714988549963703
# Acousticness test RMSE (2017) - SARIMAX((1, 0, 2, 48)) w/ exogenous variables: 0.061274495809004396

# %%
sarima_predict_plot_exog(it_rw_17, 'valence', 2017, exog_var=exog_valence, title=f'Mean Valence Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 0
# order = (2, 0, 2)
# seasonal order = (0, 0, 1, 49)
# Valence train RMSE (2017) - SARIMAX((0, 0, 1, 49)) w/ exogenous variables: 0.028125600997224418
# Valence test RMSE (2017) - SARIMAX((0, 0, 1, 49)) w/ exogenous variables: 0.03764422244628678

# %%
sarima_predict_plot_exog(it_rw_17, 'energy', 2017, exog_var=exog_energy, title=f'Mean energy Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 0
# order = (0, 0, 5)
# seasonal order = (2, 0, 0, 49)
# Tempo train RMSE (2017) - SARIMAX((2, 0, 0, 49)) w/ exogenous variables: 4.990740543623975
# Tempo test RMSE (2017) - SARIMAX((2, 0, 0, 49)) w/ exogenous variables: 9.196512674501086

# %% [markdown]
# #### _Updated `arima_param_df`_

# %%
arima_param_df
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
# 1          mode          1       4       3  (4, 1, 3)  ARIMA(4,1,3)
# 2  acousticness          0       3       2  (3, 0, 2)  ARIMA(3,0,2)
# 3       valence          0       2       2  (2, 0, 2)  ARIMA(2,0,2)
# 4         tempo          0       0       5  (0, 0, 5)  ARIMA(0,0,5)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -726.878719          0.026156         0.012448    3, 0, 0, 48
# 1 -430.794979          0.069307         0.145383    1, 0, 1, 52
# 2 -600.573624          0.038503         0.031290    1, 0, 2, 48
# 3 -627.919164          0.035573         0.033325    0, 0, 1, 49
# 4  780.783703          2.937925         7.120252    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse  exog_train_rmse  exog_test_rmse
# 0           0.026049          0.021293         0.020428        0.011169
# 1           0.066625          0.109086         0.069689        0.094840
# 2           0.059960          0.019439         0.047150        0.061274
# 3           0.076294          0.025510         0.028126        0.037644
# 4          21.276842         14.178447         4.990741        9.196513

# %% [markdown]
# #### _Pickling 2017 `arima_param_df` to compare with other years in another notebook_

# %%
arima_param_df.to_pickle('./metrics/2017_sarima_param_df.pkl')

# %% [markdown]
# # Trying functions with scaled data

# %%
from sklearn.preprocessing import StandardScaler

# %%
def arima_predict_plot_scaled(df, feature, year, param_df, title='title', figsize=(15,5), order=None, d=None, ci=True):

    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
        
    sc = StandardScaler()
    train = sc.fit_transform(train)
    test = sc.transform(test)
    
    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    if order is None:
        # find order from arima parameters dataframe 
        order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
   
    try: 
        # instantiate ARIMA model
        model = ARIMA(train, order=order)

        # fit ARIMA model
        arima = model.fit()

        # get predictions for train and test sets 
        preds_train = model.predict(params=arima.params, start=train.index[d], end=train.index[-1], typ='levels')
        preds_test = model.predict(params=arima.params, start=test.index[0], end=test.index[-1], typ='levels')

        # calculate and print RMSE for train and test setes 
        train_rmse = mean_squared_error(train[d::], preds_train)**0.5
        print(f'{feature.capitalize()} train RMSE ({year}) - ARIMA({order}): {train_rmse}')

        test_rmse = mean_squared_error(test, preds_test)**0.5
        print(f'{feature.capitalize()} test RMSE ({year}) - ARIMA({order}): {test_rmse}')

        # add RMSEs to arima parameters dataframe 
#         param_df.loc[param_df['audio_feature'] == feature, 'arima_train_rmse'] = train_rmse    
#         param_df.loc[param_df['audio_feature'] == feature, 'arima_test_rmse'] = test_rmse

          # set up plot
        plt.figure(figsize=figsize)

        # plot training data 
        plt.plot(train, color='blue')

        # plot testing data 
        plt.plot(test.index, test, color='orange')

        # plot predicted values for test set 
        plt.plot(test.index, preds_test, color='green')

        # add line for the baseline model (mean value of feature)
        plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')

        # plot confidence interval
        if ci:
            ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
            plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 

        # make plot with title! 
        plt.title(title, fontsize=16)
        plt.show() ; 
        
    except:
        print(ValueError)
        pass

# %%
arima_predict_plot_scaled(it_rw_17, 'danceability', 2017, arima_param_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-e0819d9673da> in <module>
# ----> 1 arima_predict_plot_scaled(it_rw_17, 'danceability', 2017, arima_param_df)
#
# <ipython-input-150-5b5e9fbfa3b9> in arima_predict_plot_scaled(df, feature, year, param_df, title, figsize, order, d, ci)
#       7
#       8     sc = StandardScaler()
# ----> 9     train = sc.fit_transform(train)
#      10     test = sc.transform(test)
#      11
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     635             # If input is 1D raise error
#     636             if array.ndim == 1:
# --> 637                 raise ValueError(
#     638                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     639                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.6048     0.59282857 0.59056143 0.57076    0.54956    0.52865429
#  0.56985714 0.56230857 0.58576571 0.61315143 0.57696771 0.58668714
#  0.57350286 0.60964857 0.64549714 0.63646571 0.64266286 0.62128571
#  0.61599429 0.60939429 0.56203143 0.58959143 0.64360667 0.60387714
#  0.64027714 0.66729714 0.69654857 0.68593429 0.66042    0.63507047
#  0.62148    0.66491714 0.66260857 0.66802571 0.64213429 0.62415543
#  0.66210286 0.60948    0.61487429 0.62222    0.62969143 0.64987714
#  0.62521714 0.61349143 0.59064571 0.61590286 0.62035143 0.55434571].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# _Instead of scaling, which didn't work, I will instead add a note about why I don't need to scale._

# %% [markdown]
# ## Attempting double axis plot

# %%
pwd
# Out:
# '/Users/emilynaftalin/Data_Science/General Assembly/dsi/capstone/code'

# %%
covid_global = pd.read_csv('../data/covid_csse_jhu/time_series_covid19_confirmed_global.csv')
covid_global.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/11/21  2/12/21  2/13/21  \
# 0        0        0        0        0  ...    55420    55445    55473
# 1        0        0        0        0  ...    89776    90835    91987
# 2        0        0        0        0  ...   110049   110303   110513
# 3        0        0        0        0  ...    10391    10427    10463
# 4        0        0        0        0  ...    20261    20294    20329
#
#    2/14/21  2/15/21  2/16/21  2/17/21  2/18/21  2/19/21  2/20/21
# 0    55492    55514    55518    55540    55557    55575    55580
# 1    93075    93850    94651    95726    96838    97909    99062
# 2   110711   110894   111069   111247   111418   111600   111764
# 3    10503    10538    10555    10583    10610    10645    10672
# 4    20366    20381    20389    20400    20452    20478    20499
#
# [5 rows x 400 columns]

# %%
covid_global.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '2/11/21', '2/12/21', '2/13/21', '2/14/21', '2/15/21', '2/16/21',
#        '2/17/21', '2/18/21', '2/19/21', '2/20/21'],
#       dtype='object', length=400)

# %%
type(covid_global[covid_global['Country/Region']=='Italy'])
# Out:
# pandas.core.frame.DataFrame

# %%
covid_italy = covid_global[covid_global['Country/Region']=='Italy']
covid_italy
# Out:
#     Province/State Country/Region       Lat      Long  1/22/20  1/23/20  \
# 152            NaN          Italy  41.87194  12.56738        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  2/11/21  2/12/21  2/13/21  \
# 152        0        0        0        0  ...  2683403  2697296  2710819
#
#      2/14/21  2/15/21  2/16/21  2/17/21  2/18/21  2/19/21  2/20/21
# 152  2721879  2729223  2739591  2751657  2765412  2780882  2795796
#
# [1 rows x 400 columns]

# %%
# covid_global.T

# %%
covid_italy = covid_italy.T

# %%
covid_italy.drop(['Province/State', 'Country/Region', 'Lat', 'Long'], axis=0, inplace=True)
covid_italy.head()
# Out:
#         152
# 1/22/20   0
# 1/23/20   0
# 1/24/20   0
# 1/25/20   0
# 1/26/20   0

# %%
type(covid_italy.index[0])
# Out:
# str

# %%
covid_italy.index = pd.to_datetime(covid_italy.index)

# %%
type(covid_italy.index[1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
covid_italy.rename(columns={152:'num_confirmed'}, inplace=True)
covid_italy.head(3)
# Out:
#            num_confirmed
# 2020-01-22             0
# 2020-01-23             0
# 2020-01-24             0

# %%
covid_italy.tail(2)
# Out:
#            num_confirmed
# 2021-02-19       2780882
# 2021-02-20       2795796

# %%
rw_italy_20[['danceability']].head()
# Out:
#             danceability
# date
# 2020-01-05      0.696228
# 2020-01-12      0.668417
# 2020-01-19      0.665220
# 2020-01-26      0.666346
# 2020-02-02      0.663640

# %%
fig, axs = plt.subplots(nrows=11, ncols=1, figsize=(12,50))
fig.subplots_adjust(hspace=.5,wspace=0.4)

for i, feature in enumerate(audio_features): 

    axs[i].plot(rw_italy_20[feature], label='Italy')
    axs[i].plot(rw_spain_20[feature], label='Spain')
    axs[i].plot(rw_greece_20[feature], label='Greece')
    axs[i].set_title(f'{feature.upper()}')
    axs[i].legend()
    
fig.tight_layout()
fig.subplots_adjust(top=.96)
fig.suptitle('Presence of Audio Features in Daily Viral 50 Tracks, Mean Rating (2020)')
plt.show()

# %%
data1 =  rw_italy_20['valence']
data2 =  covid_italy['num_confirmed']

# %%
data3 =  alltime_rw_italy['valence']

# %%
fig, ax1 = plt.subplots(figsize=(20,5))

color = 'tab:red'
ax1.set_xlabel('time (w)')
ax1.set_ylabel('valence', color=color)
ax1.plot(data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()

color = 'tab:blue'
ax2.set_ylabel('confirmed_cases', color=color)
ax2.plot(data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %%
arima_predict_plot(rw_italy_20, 'valence', 2020, title = "valence predictions 2020 arima")
# Out:
# d = 0
# order = (2, 0, 2)
# Valence train RMSE (2020) - ARIMA((2, 0, 2)): 0.029338298297183936
# Valence test RMSE (2020) - ARIMA((2, 0, 2)): 0.025052731068752162

# %%
first_half_2020_it = rw_italy_20[0:27]
second_half_2020_it = rw_italy_20[27:53]

# %%
first_half_2020_it.tail(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2020-06-28      25.5      0.714257  0.651620  5.737143 -6.640754  0.425714
# 2020-07-05      25.5      0.704480  0.649531  5.637143 -6.707834  0.414286
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2020-06-28     0.121798      0.234739          0.001665  0.167322  0.524307
# 2020-07-05     0.130966      0.216730          0.001636  0.164571  0.525042
#
#                  tempo    duration_ms  time_signature
# date
# 2020-06-28  116.294129  186867.488571        3.971429
# 2020-07-05  118.932386  188436.971429        3.937143

# %%
second_half_2020_it.tail()
# Out:
#              Position  danceability    energy       key  loudness      mode  \
# date
# 2020-12-06  25.514286      0.635391  0.586877  5.448571 -8.045040  0.534286
# 2020-12-13  25.865714      0.658663  0.606386  5.334286 -7.434363  0.605714
# 2020-12-20  25.771429      0.649389  0.601711  5.185714 -7.288403  0.617143
# 2020-12-27  26.111429      0.658540  0.601163  5.225714 -7.301663  0.620000
# 2021-01-03  25.948571      0.663151  0.618714  5.782857 -7.345991  0.582857
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2020-12-06     0.109029      0.332617          0.020756  0.174773  0.451704
# 2020-12-13     0.097016      0.330153          0.019915  0.155027  0.480546
# 2020-12-20     0.101651      0.337039          0.018042  0.157806  0.474697
# 2020-12-27     0.099900      0.313663          0.036708  0.155573  0.494371
# 2021-01-03     0.104829      0.309551          0.028036  0.173735  0.492659
#
#                  tempo    duration_ms  time_signature
# date
# 2020-12-06  120.883214  198297.631429        3.951429
# 2020-12-13  121.218346  198129.382857        3.945714
# 2020-12-20  117.303751  194437.685714        3.888571
# 2020-12-27  117.747651  190622.557143        3.894286
# 2021-01-03  115.925700  194482.251429        3.942857

# %%
arima_predict_plot(first_half_2020_it, 'valence', 2020, title = "valence predictions first half 2020 arima")
# Out:
# d = 0
# order = (2, 0, 2)
# Valence train RMSE (2020) - ARIMA((2, 0, 2)): 0.029092776787653662
# Valence test RMSE (2020) - ARIMA((2, 0, 2)): 0.06322185487351153

# %%
arima_predict_plot(second_half_2020_it, 'valence', 2020, title = "valence predictions second half 2020 arima")
# Out:
# d = 0
# order = (2, 0, 2)
# Valence train RMSE (2020) - ARIMA((2, 0, 2)): 0.03053081538287687
# Valence test RMSE (2020) - ARIMA((2, 0, 2)): 0.029379726738894902

# %%
arima_predict_plot(second_half_2020_it, 'acousticness', 2020, title = "acousticness predictions first half 2020 arima")
# Out:
# d = 0
# order = (3, 0, 2)
# Acousticness train RMSE (2020) - ARIMA((3, 0, 2)): 0.04062328768938417
# Acousticness test RMSE (2020) - ARIMA((3, 0, 2)): 0.048182469384413
