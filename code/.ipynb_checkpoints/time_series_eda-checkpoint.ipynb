# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

import json

from fycharts.SpotifyCharts import SpotifyCharts
import sqlalchemy

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# #### reading in data with song info and audio features via pickle

# %%
italy_17_19_df = pd.read_pickle('../data/it_17_19_feat.pkl')
italy_17_19_df.head()
# Out:
#             Position                               Track Name  \
# date
# 2017-01-06         1                             Shape of You
# 2017-01-06         2  Rockabye (feat. Sean Paul & Anne-Marie)
# 2017-01-06         3                       Castle on the Hill
# 2017-01-06         4                                   Closer
# 2017-01-06         5         Assenzio (feat. Stash & Levante)
#
#                       Artist  Streams region              spotify_id  \
# date
# 2017-01-06        Ed Sheeran  1051142     it  7qiZfU4dY1lWllzX7mPBI3
# 2017-01-06      Clean Bandit   759626     it  5knuzwU65gJK7IF5yJsuaW
# 2017-01-06        Ed Sheeran   715171     it  6PCUP3dWmTjcTtXY02oFdT
# 2017-01-06  The Chainsmokers   504232     it  7BKLCZ1jbUBVqRi2FVlTVw
# 2017-01-06              J-AX   478975     it  0DRKnh0BloxJHyhXkfbiX8
#
#             danceability  energy  key  loudness  mode  speechiness  \
# date
# 2017-01-06         0.825   0.652    1    -3.183     0       0.0802
# 2017-01-06         0.720   0.763    9    -4.068     0       0.0523
# 2017-01-06         0.461   0.834    2    -4.868     1       0.0989
# 2017-01-06         0.748   0.524    8    -5.599     1       0.0338
# 2017-01-06         0.554   0.640    0    -7.587     1       0.1870
#
#             acousticness  instrumentalness  liveness  valence    tempo  \
# date
# 2017-01-06        0.5810          0.000000    0.0931    0.931   95.977
# 2017-01-06        0.4060          0.000000    0.1800    0.742  101.965
# 2017-01-06        0.0232          0.000011    0.1400    0.471  135.007
# 2017-01-06        0.4140          0.000000    0.1110    0.661   95.010
# 2017-01-06        0.3410          0.000000    0.1080    0.641  160.009
#
#             duration_ms  time_signature
# date
# 2017-01-06       233713               4
# 2017-01-06       251088               4
# 2017-01-06       261154               4
# 2017-01-06       244960               4
# 2017-01-06       250533               4

# %%
type(italy_17_19_df.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
spain_17_19_df = pd.read_pickle('../data/sp_17_19_feat.pkl')
spain_17_19_df.head(2)
# Out:
#             Position                  Track Name   Artist  Streams region  \
# date
# 2017-01-06         1     Chantaje (feat. Maluma)  Shakira  1423583     es
# 2017-01-06         2  Reggaetón Lento (Bailemos)     CNCO  1339834     es
#
#                         spotify_id  danceability  energy  key  loudness  mode  \
# date
# 2017-01-06  6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773    8    -2.921     0
# 2017-01-06  3AEZUABDXNtecAOSC1qTfo         0.761   0.838    4    -3.073     0
#
#             speechiness  acousticness  instrumentalness  liveness  valence  \
# date
# 2017-01-06       0.0776         0.187           0.00003     0.159    0.907
# 2017-01-06       0.0502         0.400           0.00000     0.176    0.710
#
#               tempo  duration_ms  time_signature
# date
# 2017-01-06  102.034       195840               4
# 2017-01-06   93.974       222560               4

# %%
greece_17_19_df = pd.read_pickle('../data/gr_17_19_feat.pkl')
greece_17_19_df.head(2)
# Out:
#             Position          Track Name      Artist  Streams region  \
# date
# 2017-01-06         1        Shape of You  Ed Sheeran    76164     gr
# 2017-01-06         2  Castle on the Hill  Ed Sheeran    37779     gr
#
#                         spotify_id  danceability  energy  key  loudness  mode  \
# date
# 2017-01-06  7qiZfU4dY1lWllzX7mPBI3         0.825   0.652    1    -3.183     0
# 2017-01-06  6PCUP3dWmTjcTtXY02oFdT         0.461   0.834    2    -4.868     1
#
#             speechiness  acousticness  instrumentalness  liveness  valence  \
# date
# 2017-01-06       0.0802        0.5810          0.000000    0.0931    0.931
# 2017-01-06       0.0989        0.0232          0.000011    0.1400    0.471
#
#               tempo  duration_ms  time_signature
# date
# 2017-01-06   95.977       233713               4
# 2017-01-06  135.007       261154               4

# %%
italy_20 = pd.read_pickle('../data/it_20_feat.pkl')

# %%
spain_20 = pd.read_pickle('../data/sp_20_feat.pkl')
greece_20 = pd.read_pickle('../data/gr_20_feat.pkl')

# %% [markdown]
# #### Using resample to convert frequency of time series, starting with monthly

# %% [markdown]
# _`rm` denotes resampling by month._

# %%
rm_italy_17_19_df = italy_17_19_df.resample("M").mean()

# %%
rm_spain_17_19_df = spain_17_19_df.resample("M").mean()

# %%
rm_greece_17_19_df = greece_17_19_df.resample("M").mean()

# %%
rm_italy_20 = italy_20.resample("M").mean()
rm_spain_20 = spain_20.resample("M").mean()
rm_greece_20 = greece_20.resample("M").mean()

# %%
rm_greece_17_19_df.head()
# Out:
#             Position     Streams  danceability    energy      key  loudness  \
# date
# 2017-01-31     100.5  7193.47875      0.643614  0.630956  5.20250 -6.674871
# 2017-02-28     100.5  7331.57875      0.644566  0.640034  5.36500 -6.318109
# 2017-03-31     100.5  7863.31400      0.660192  0.636054  5.38300 -6.258354
# 2017-04-30     100.5  7758.23000      0.672605  0.648561  4.98750 -6.151649
# 2017-05-31     100.5  8586.86375      0.674911  0.658356  5.06875 -5.940126
#
#                mode  speechiness  acousticness  instrumentalness  liveness  \
# date
# 2017-01-31  0.54875     0.109130      0.217906          0.027511  0.173735
# 2017-02-28  0.56625     0.107799      0.207795          0.018806  0.178180
# 2017-03-31  0.56900     0.115756      0.199541          0.012383  0.173420
# 2017-04-30  0.56500     0.118953      0.170326          0.014233  0.174701
# 2017-05-31  0.55625     0.108032      0.171582          0.011527  0.169889
#
#              valence       tempo  duration_ms  time_signature
# date
# 2017-01-31  0.455753  121.198466  223695.6375         3.99875
# 2017-02-28  0.457992  120.024129  225033.1975         4.00375
# 2017-03-31  0.463586  119.493961  221623.0640         3.98900
# 2017-04-30  0.471611  121.850534  222375.2525         3.97750
# 2017-05-31  0.488221  120.985329  218295.7500         3.97000

# %% [markdown]
# ### EDA

# %%
# artists danceability scores (mean across all their songs)
italy_17_19_df.groupby('Artist')[['danceability']].mean().sort_values(by='danceability', ascending=False)[:10]
# Out:
#                 danceability
# Artist
# Samuel Heron        0.952769
# VillaBanks          0.950000
# Priestess           0.944000
# Tredici Pietro      0.944000
# Lil Pump            0.930273
# BlocBoy JB          0.922000
# Nuela               0.919000
# Dj Kass             0.909500
# Wolfine             0.909000
# Blueface            0.906000

# %%
# for each artist, times in the top 200 from 2017-10
italy_17_19_df.groupby('Artist').count().sort_values(by='Position', ascending=False)[:10]
# Out:
#                Position  Track Name  Streams  region  spotify_id  \
# Artist
# Capo Plaza          864         864      864     864         864
# Sfera Ebbasta       864         864      864     864         864
# Ultimo              773         773      773     773         773
# Gemitaiz            615         615      615     615         615
# Guè Pequeno         581         581      581     581         581
# Coez                561         561      561     561         561
# Ghali               539         539      539     539         539
# Salmo               506         506      506     506         506
# Ed Sheeran          474         474      474     474         474
# Rkomi               449         449      449     449         449
#
#                danceability  energy  key  loudness  mode  speechiness  \
# Artist
# Capo Plaza              864     864  864       864   864          864
# Sfera Ebbasta           864     864  864       864   864          864
# Ultimo                  773     773  773       773   773          773
# Gemitaiz                615     615  615       615   615          615
# Guè Pequeno             581     581  581       581   581          581
# Coez                    561     561  561       561   561          561
# Ghali                   539     539  539       539   539          539
# Salmo                   506     506  506       506   506          506
# Ed Sheeran              474     474  474       474   474          474
# Rkomi                   449     449  449       449   449          449
#
#                acousticness  instrumentalness  liveness  valence  tempo  \
# Artist
# Capo Plaza              864               864       864      864    864
# Sfera Ebbasta           864               864       864      864    864
# Ultimo                  773               773       773      773    773
# Gemitaiz                615               615       615      615    615
# Guè Pequeno             581               581       581      581    581
# Coez                    561               561       561      561    561
# Ghali                   539               539       539      539    539
# Salmo                   506               506       506      506    506
# Ed Sheeran              474               474       474      474    474
# Rkomi                   449               449       449      449    449
#
#                duration_ms  time_signature
# Artist
# Capo Plaza             864             864
# Sfera Ebbasta          864             864
# Ultimo                 773             773
# Gemitaiz               615             615
# Guè Pequeno            581             581
# Coez                   561             561
# Ghali                  539             539
# Salmo                  506             506
# Ed Sheeran             474             474
# Rkomi                  449             449

# %% [markdown]
# ### Time Series Plotting

# %%
rm_italy_17_19_df['danceability'].plot(figsize=(8,3))
plt.title("Average Monthly Danceability Score for Songs on the Top 200 Weekliy Chart in Italy")
# Out:
# Text(0.5, 1.0, 'Average Monthly Danceability Score for Songs on the Top 200 Weekliy Chart in Italy')

# %%
rm_italy_17_19_df.columns
# Out:
# Index(['Position', 'Streams', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
audio_features = ['danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo']

# %%
fig, axs= plt.subplots(11,1, figsize=(12, 50))

# for i, features in enumerate(audio_features):
#     axs[i].plot(rm_italy_17_19_df[feature])

# fig, axs= plt.subplots(11,1, figsize=(10,20))

axs[0].plot(rm_italy_17_19_df['danceability'])
axs[0].set_title('Danceability')
axs[1].plot(rm_italy_17_19_df['energy'])
axs[1].set_title('Energy')
axs[2].plot(rm_italy_17_19_df['key'])
axs[2].set_title('Key')
axs[3].plot(rm_italy_17_19_df['loudness']) 
axs[3].set_title('Loudness')
axs[4].plot(rm_italy_17_19_df['mode'])
axs[4].set_title('Mode')
axs[5].plot(rm_italy_17_19_df['speechiness'])
axs[5].set_title('Speechiness i.e. Has Spoken Words')
axs[6].plot(rm_italy_17_19_df['acousticness'])
axs[6].set_title('Acousticness')
axs[7].plot(rm_italy_17_19_df['instrumentalness'])
axs[7].set_title('Instrumentalness i.e. Contains No Vocals')
axs[8].plot(rm_italy_17_19_df['liveness'])
axs[8].set_title('Liveness i.e. Presence of Live Audience ')
axs[9].plot(rm_italy_17_19_df['valence'])
axs[9].set_title('Valence i.e. Positive Vibes')
axs[10].plot(rm_italy_17_19_df['tempo'])
axs[10].set_title('Tempo (BPM)')


fig.tight_layout()
fig.subplots_adjust(top=.95)
fig.suptitle('Audio Feature Mean Scores - Italy, 2017-2019')
plt.show()

# %% [markdown]
# From [linear-ts-modeling-lesson-notebook](10-week/10.02-linear-timeseries-modeling/linear-ts-modeling-starter-code.ipynb):

# %%
# Write function called plot_series that takes in 
# a dataframe, a list of column names to plot, the 
# plot title and the axis labels as arguments,
# then displays the line plot with a figure size
# of 18 horizontal inches by 9 vertical inches.

# Matthew Garton - BOS



def plot_series(df, cols=None, title='Title', xlab=None, ylab=None, figsize=(18,9)):
    
    # Set figure size to be (18, 9).
    plt.figure(figsize=figsize)
    
    # Iterate through each column name.
    for col in cols:
        
        # Generate a line plot of the column name.
        # You only have to specify Y, since our
        # index will be a datetime index.
        plt.plot(df[col])
        
    # Generate title and labels.
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18);

# %%
audio_features
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo']

# %%
# plot_series(rm_italy_17_19_df, ['danceability'], title='Dancebility', figsize=(15,4))

# %%
for col in audio_features:
    plot_series(rm_italy_17_19_df, [col], title=col, figsize=(15,4))

# %%
# rm_italy_17_19_df['danceability'].plot(figsize=(20,10))
# plt.title("Average Monthly Danceability Score for Songs on the Top 200 Weekliy Chart in Italy")

# %%
# fig, axs= plt.subplots(11,1, figsize=(15, 50))

# # for i, features in enumerate(audio_features):
# #     axs[i].plot(rm_italy_17_19_df[feature])

# # fig, axs= plt.subplots(11,1, figsize=(10,20))

# axs[0].plot(italy_17_19_df['danceability'])
# axs[0].set_title('Danceability')
# axs[1].plot(italy_17_19_df['energy'])
# axs[1].set_title('Energy')
# axs[2].plot(italy_17_19_df['key'])
# axs[2].set_title('Key')
# axs[3].plot(italy_17_19_df['loudness']) 
# axs[3].set_title('Loudness')
# axs[4].plot(italy_17_19_df['mode'])
# axs[4].set_title('Mode')
# axs[5].plot(italy_17_19_df['speechiness'])
# axs[5].set_title('Speechiness i.e. Has Spoken Words')
# axs[6].plot(italy_17_19_df['acousticness'])
# axs[6].set_title('Acousticness')
# axs[7].plot(italy_17_19_df['instrumentalness'])
# axs[7].set_title('Instrumentalness i.e. Contains No Vocals')
# axs[8].plot(italy_17_19_df['liveness'])
# axs[8].set_title('Liveness i.e. Presence of Live Audience ')
# axs[9].plot(italy_17_19_df['valence'])
# axs[9].set_title('Valence i.e. Positive Vibes')
# axs[10].plot(italy_17_19_df['tempo'])
# axs[10].set_title('Tempo (BPM)')


# fig.tight_layout()
# fig.subplots_adjust(top=.95)
# fig.suptitle('Audio Feature Mean Scores - Italy, 2017-2019')
# plt.show()

# %%
rw_italy_17_19_df = italy_17_19_df.resample("W").mean()
rw_italy_17_19_df.head()
# Out:
#             Position     Streams  danceability    energy    key  loudness  \
# date
# 2017-01-08     100.5  145502.475       0.64154  0.693575  5.240 -5.822415
# 2017-01-15     100.5  158424.445       0.63785  0.695850  4.905 -5.922195
# 2017-01-22     100.5  166912.255       0.64331  0.706035  5.185 -5.789885
# 2017-01-29     100.5  169132.215       0.64082  0.689941  5.110 -6.047320
# 2017-02-05     100.5  181889.905       0.64247  0.693566  5.250 -5.921840
#
#              mode  speechiness  acousticness  instrumentalness  liveness  \
# date
# 2017-01-08  0.570     0.099410      0.194297          0.010463  0.164927
# 2017-01-15  0.565     0.105253      0.195347          0.016614  0.156222
# 2017-01-22  0.600     0.104810      0.189541          0.010576  0.157828
# 2017-01-29  0.595     0.101993      0.189309          0.011057  0.154504
# 2017-02-05  0.565     0.104047      0.193047          0.014126  0.151522
#
#              valence       tempo  duration_ms  time_signature
# date
# 2017-01-08  0.500168  116.706005    219129.85           3.995
# 2017-01-15  0.483813  116.596895    215693.64           3.975
# 2017-01-22  0.503616  117.256720    216752.93           4.000
# 2017-01-29  0.495657  117.879770    215713.19           4.000
# 2017-02-05  0.488651  116.862095    213350.36           3.990

# %%
# italy_17_19_df.head()

# %%
lag_df = rw_italy_17_19_df[audio_features].copy()
lag_df.head()
# Out:
#             danceability    energy    key  loudness   mode  speechiness  \
# date
# 2017-01-08       0.64154  0.693575  5.240 -5.822415  0.570     0.099410
# 2017-01-15       0.63785  0.695850  4.905 -5.922195  0.565     0.105253
# 2017-01-22       0.64331  0.706035  5.185 -5.789885  0.600     0.104810
# 2017-01-29       0.64082  0.689941  5.110 -6.047320  0.595     0.101993
# 2017-02-05       0.64247  0.693566  5.250 -5.921840  0.565     0.104047
#
#             acousticness  instrumentalness  liveness   valence       tempo
# date
# 2017-01-08      0.194297          0.010463  0.164927  0.500168  116.706005
# 2017-01-15      0.195347          0.016614  0.156222  0.483813  116.596895
# 2017-01-22      0.189541          0.010576  0.157828  0.503616  117.256720
# 2017-01-29      0.189309          0.011057  0.154504  0.495657  117.879770
# 2017-02-05      0.193047          0.014126  0.151522  0.488651  116.862095

# %%
lag_df['one_week_lag_dance'] = lag_df['danceability'].diff(1).fillna(0)

# %%
lag_df.head()
# Out:
#             danceability    energy    key  loudness   mode  speechiness  \
# date
# 2017-01-08       0.64154  0.693575  5.240 -5.822415  0.570     0.099410
# 2017-01-15       0.63785  0.695850  4.905 -5.922195  0.565     0.105253
# 2017-01-22       0.64331  0.706035  5.185 -5.789885  0.600     0.104810
# 2017-01-29       0.64082  0.689941  5.110 -6.047320  0.595     0.101993
# 2017-02-05       0.64247  0.693566  5.250 -5.921840  0.565     0.104047
#
#             acousticness  instrumentalness  liveness   valence       tempo  \
# date
# 2017-01-08      0.194297          0.010463  0.164927  0.500168  116.706005
# 2017-01-15      0.195347          0.016614  0.156222  0.483813  116.596895
# 2017-01-22      0.189541          0.010576  0.157828  0.503616  117.256720
# 2017-01-29      0.189309          0.011057  0.154504  0.495657  117.879770
# 2017-02-05      0.193047          0.014126  0.151522  0.488651  116.862095
#
#             one_week_lag_dance
# date
# 2017-01-08             0.00000
# 2017-01-15            -0.00369
# 2017-01-22             0.00546
# 2017-01-29            -0.00249
# 2017-02-05             0.00165

# %%
lag_df_dance = rw_italy_17_19_df[['danceability']].copy()
lag_df_dance.head()
# Out:
#             danceability
# date
# 2017-01-08       0.64154
# 2017-01-15       0.63785
# 2017-01-22       0.64331
# 2017-01-29       0.64082
# 2017-02-05       0.64247

# %%
lag_df_dance['one_week_lag'] = lag_df_dance['danceability'].diff(1).fillna(0)
lag_df_dance['two_week_lag'] = lag_df_dance['danceability'].diff(2).fillna(0)
lag_df_dance['one_month_lag'] = lag_df_dance['danceability'].diff(4).fillna(0)
lag_df_dance['quarterly_lag'] = lag_df_dance['danceability'].diff(13).fillna(0)
lag_df_dance['one_year_lag'] = lag_df_dance['danceability'].diff(52).fillna(0)

# %%
lag_df_dance.corr()
# Out:
#                danceability  one_week_lag  two_week_lag  one_month_lag  \
# danceability       1.000000      0.220996      0.202721       0.232749
# one_week_lag       0.220996      1.000000      0.649125       0.567718
# two_week_lag       0.202721      0.649125      1.000000       0.683829
# one_month_lag      0.232749      0.567718      0.683829       1.000000
# quarterly_lag      0.303589      0.441910      0.424737       0.543525
# one_year_lag       0.133327      0.075968      0.141290       0.204321
#
#                quarterly_lag  one_year_lag
# danceability        0.303589      0.133327
# one_week_lag        0.441910      0.075968
# two_week_lag        0.424737      0.141290
# one_month_lag       0.543525      0.204321
# quarterly_lag       1.000000     -0.003687
# one_year_lag       -0.003687      1.000000

# %%
fig, ax = plt.subplots(figsize=(10,8))  
sns.heatmap(lag_df_dance.corr(), cmap='summer_r') ;

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(df['co2'], lags=20);

# %%
rw_italy_17_19_df[rw_italy_17_19_df['danceability'].isnull()]
# Out:
#             Position  Streams  danceability  energy  key  loudness  mode  \
# date
# 2017-12-31       NaN      NaN           NaN     NaN  NaN       NaN   NaN
# 2018-12-30       NaN      NaN           NaN     NaN  NaN       NaN   NaN
#
#             speechiness  acousticness  instrumentalness  liveness  valence  \
# date
# 2017-12-31          NaN           NaN               NaN       NaN      NaN
# 2018-12-30          NaN           NaN               NaN       NaN      NaN
#
#             tempo  duration_ms  time_signature
# date
# 2017-12-31    NaN          NaN             NaN
# 2018-12-30    NaN          NaN             NaN

# %%
rw_italy_17_19_df

# %%
plot_acf(rw_italy_17_19_df['danceability'].dropna(), lags=52) ;

# %%
plot_pacf(rw_italy_17_19_df['danceability'].dropna(), lags=52) ;

# %%
sns.heatmap(rw_italy_17_19_df.corr())
# Out:
#                   Position   Streams  danceability    energy       key  \
# Position               NaN       NaN           NaN       NaN       NaN
# Streams                NaN  1.000000      0.588749 -0.610352  0.045631
# danceability           NaN  0.588749      1.000000 -0.146250  0.223910
# energy                 NaN -0.610352     -0.146250  1.000000 -0.052296
# key                    NaN  0.045631      0.223910 -0.052296  1.000000
# loudness               NaN -0.586934     -0.052400  0.903344  0.026161
# mode                   NaN -0.093789     -0.480334 -0.148182 -0.436724
# speechiness            NaN  0.856929      0.592952 -0.618897 -0.005220
# acousticness           NaN  0.581395     -0.100976 -0.751658 -0.173336
# instrumentalness       NaN -0.472489     -0.672037  0.138850 -0.383618
# liveness               NaN  0.697995      0.415774 -0.362849  0.050980
# valence                NaN -0.108060      0.133795  0.450112 -0.286542
# tempo                  NaN  0.446277      0.339771 -0.335738  0.066736
# duration_ms            NaN -0.912973     -0.655164  0.612908 -0.102313
# time_signature         NaN  0.008255      0.330497  0.279133 -0.261405
#
#                   loudness      mode  speechiness  acousticness  \
# Position               NaN       NaN          NaN           NaN
# Streams          -0.586934 -0.093789     0.856929      0.581395
# danceability     -0.052400 -0.480334     0.592952     -0.100976
# energy            0.903344 -0.148182    -0.618897     -0.751658
# key               0.026161 -0.436724    -0.005220     -0.173336
# loudness          1.000000 -0.183218    -0.647571     -0.685868
# mode             -0.183218  1.000000    -0.089000      0.282013
# speechiness      -0.647571 -0.089000     1.000000      0.527186
# acousticness     -0.685868  0.282013     0.527186      1.000000
# instrumentalness  0.099906  0.404018    -0.428650      0.004542
# liveness         -0.246216 -0.014652     0.615452      0.525882
# valence           0.248229 -0.119653    -0.108718     -0.298297
# tempo            -0.191126 -0.039852     0.422924      0.385707
# duration_ms       0.621792  0.114405    -0.854756     -0.516133
# time_signature    0.271017 -0.351349     0.097315     -0.179227
#
#                   instrumentalness  liveness   valence     tempo  duration_ms  \
# Position                       NaN       NaN       NaN       NaN          NaN
# Streams                  -0.472489  0.697995 -0.108060  0.446277    -0.912973
# danceability             -0.672037  0.415774  0.133795  0.339771    -0.655164
# energy                    0.138850 -0.362849  0.450112 -0.335738     0.612908
# key                      -0.383618  0.050980 -0.286542  0.066736    -0.102313
# loudness                  0.099906 -0.246216  0.248229 -0.191126     0.621792
# mode                      0.404018 -0.014652 -0.119653 -0.039852     0.114405
# speechiness              -0.428650  0.615452 -0.108718  0.422924    -0.854756
# acousticness              0.004542  0.525882 -0.298297  0.385707    -0.516133
# instrumentalness          1.000000 -0.316228 -0.072539 -0.379139     0.547916
# liveness                 -0.316228  1.000000 -0.052990  0.541035    -0.593308
# valence                  -0.072539 -0.052990  1.000000 -0.104350    -0.028766
# tempo                    -0.379139  0.541035 -0.104350  1.000000    -0.476568
# duration_ms               0.547916 -0.593308 -0.028766 -0.476568     1.000000
# time_signature           -0.041087  0.088649  0.403833 -0.052103     0.027085
#
#                   time_signature
# Position                     NaN
# Streams                 0.008255
# danceability            0.330497
# energy                  0.279133
# key                    -0.261405
# loudness                0.271017
# mode                   -0.351349
# speechiness             0.097315
# acousticness           -0.179227
# instrumentalness       -0.041087
# liveness                0.088649
# valence                 0.403833
# tempo                  -0.052103
# duration_ms             0.027085
# time_signature          1.000000

# %% [markdown]
# ## Comparing Italy, Greece, Spain 2017-19

# %%
# fig, axs= plt.subplots(11,1, figsize=(12, 50))

# for i, features in enumerate(audio_features):
#     axs[i].plot(rm_italy_17_19_df[feature])

fig, axs= plt.subplots(1,1, figsize=(15,5))
# fig, ax = plt.plot(figsize=(10,5))
plt.plot(rm_italy_17_19_df['danceability'], label='Italy')
plt.plot(rm_spain_17_19_df['danceability'], label='Spain')
plt.plot(rm_greece_17_19_df['danceability'], label='Greece')

plt.legend()
# plt.set_title('Danceability')

# %%
fig, axs= plt.subplots(1,1, figsize=(15,5))
# fig, ax = plt.plot(figsize=(10,5))
plt.plot(rm_italy_20['danceability'], label='Italy')
plt.plot(rm_spain_20['danceability'], label='Spain')
plt.plot(rm_greece_20['danceability'], label='Greece')

plt.legend()
# plt.set_title('Danceability')

# %%
fig, axs= plt.subplots(11,1, figsize=(12, 50))

# for i, features in enumerate(audio_features):
#     axs[i].plot(rm_italy_17_19_df[feature])

# fig, axs= plt.subplots(11,1, figsize=(10,20))

axs[0].plot(rm_italy_17_19_df['danceability'])
axs[0].plot(rm_spain_17_19_df['danceability'])
axs[0].plot(rm_greece_17_19_df['danceability'])
axs[0].set_title('Danceability')
# axs[1].plot(rm_italy_17_19_df['energy'])
# axs[1].set_title('Energy')
# axs[2].plot(rm_italy_17_19_df['key'])
# axs[2].set_title('Key')
# axs[3].plot(rm_italy_17_19_df['loudness']) 
# axs[3].set_title('Loudness')
# axs[4].plot(rm_italy_17_19_df['mode'])
# axs[4].set_title('Mode')
# axs[5].plot(rm_italy_17_19_df['speechiness'])
# axs[5].set_title('Speechiness i.e. Has Spoken Words')
# axs[6].plot(rm_italy_17_19_df['acousticness'])
# axs[6].set_title('Acousticness')
# axs[7].plot(rm_italy_17_19_df['instrumentalness'])
# axs[7].set_title('Instrumentalness i.e. Contains No Vocals')
# axs[8].plot(rm_italy_17_19_df['liveness'])
# axs[8].set_title('Liveness i.e. Presence of Live Audience ')
# axs[9].plot(rm_italy_17_19_df['valence'])
# axs[9].set_title('Valence i.e. Positive Vibes')
# axs[10].plot(rm_italy_17_19_df['tempo'])
# axs[10].set_title('Tempo (BPM)')


fig.tight_layout()
fig.subplots_adjust(top=.95)
fig.suptitle('Audio Feature Mean Scores - Italy, 2017-2019')
plt.show()
