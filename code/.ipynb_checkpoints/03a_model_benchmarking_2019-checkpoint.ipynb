# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

import json

from fycharts.SpotifyCharts import SpotifyCharts
import sqlalchemy

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from datetime import datetime
from sklearn.model_selection import train_test_split

import statsmodels.api as sm

# We are required to do this in order to avoid "FutureWarning" issues.
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller  

from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %matplotlib inline

import warnings
warnings.simplefilter(action="ignore")

# %% [markdown]
# # Reading in data

# %%
italy_17_19 = pd.read_pickle('../data/it_17_19_v50_feat.pkl')
spain_17_19 = pd.read_pickle('../data/sp_17_19_v50_feat.pkl')
greece_17_19 = pd.read_pickle('../data/gr_17_19_v50_feat.pkl')

italy_20 = pd.read_pickle('../data/it_20_v50_feat.pkl')
spain_20 = pd.read_pickle('../data/sp_20_v50_feat.pkl')
greece_20 = pd.read_pickle('../data/gr_20_v50_feat.pkl')

# %%
spain_20.tail(2)
# Out:
#             Position                Track Name               Artist region  \
# date
# 2021-02-13        49    La Luz - A COLORS SHOW    María José Llergo     es
# 2021-02-13        50  Boku no Sensou - TV Size  Shinsei Kamattechan     es
#
#                         spotify_id  danceability  energy  key  loudness  mode  \
# date
# 2021-02-13  5jRnVQbjB6qgN3MARS4xw7         0.722   0.357    9   -10.487     0
# 2021-02-13  3tRPfCFAEv6wWyQO0YnGGV         0.447   0.891    9    -4.776     1
#
#             speechiness  acousticness  instrumentalness  liveness  valence  \
# date
# 2021-02-13       0.0996       0.81400          0.155000    0.0863    0.641
# 2021-02-13       0.0788       0.00447          0.000905    0.3900    0.517
#
#               tempo  duration_ms  time_signature
# date
# 2021-02-13  149.895       191599               4
# 2021-02-13  143.976        90960               4

# %% [markdown]
# # Preprocessing data

# %% [markdown]
# #### _Data for each country is split into different dataframes as different combinations and aggregations are needed for different functions._

# %% [markdown]
# **Resampling by month**
#
# _`rm` denotes resampling by month._

# %%
rm_italy_17_19 = italy_17_19.resample("M").mean()
rm_spain_17_19 = spain_17_19.resample("M").mean()
rm_greece_17_19 = greece_17_19.resample("M").mean()

rm_italy_20 = italy_20.resample("M").mean()
rm_spain_20 = spain_20.resample("M").mean()
rm_greece_20 = greece_20.resample("M").mean()

# %% [markdown]
# **Resampling by week**
#
# _`rw` denotes resampling by week._

# %%
rw_italy_17_19 = italy_17_19.resample("W").mean()
rw_spain_17_19 = spain_17_19.resample("W").mean()
rw_greece_17_19 = greece_17_19.resample("W").mean()

rw_italy_20 = italy_20.resample("W").mean()
rw_spain_20 = spain_20.resample("W").mean()
rw_greece_20 = greece_20.resample("W").mean()

# %% [markdown]
# #### Combining weekly resampled data for all years (2017-2020)

# %%
alltime_italy = pd.concat([italy_17_19, italy_20])
alltime_spain = pd.concat([spain_17_19, spain_20])
alltime_greece = pd.concat([greece_17_19, greece_20])

alltime_rw_italy = alltime_italy.resample("W").mean()
alltime_rw_spain = alltime_spain.resample("W").mean()
alltime_rw_greece = alltime_greece.resample("W").mean()

# %% [markdown]
# #### Splitting into dataframes for each year!

# %%
it_rw_17 = alltime_rw_italy[0:53]
it_rw_18 = alltime_rw_italy[53:105]
it_rw_19 = alltime_rw_italy[105:158]

# %%
it_rw_18.tail(2)
# Out:
#             Position  danceability   energy       key  loudness      mode  \
# date
# 2018-12-23      25.5      0.652526  0.62446  5.345714 -7.126363  0.548571
# 2018-12-30      25.5      0.637171  0.63514  4.971429 -6.814571  0.528571
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2018-12-23     0.098575      0.315516          0.058491  0.126928  0.464983
# 2018-12-30     0.104640      0.342631          0.066215  0.139117  0.460786
#
#                  tempo    duration_ms  time_signature
# date
# 2018-12-23  117.940511  209852.965714        3.985714
# 2018-12-30  121.689883  216545.840000        3.934286

# %% [markdown]
# # Differencing Data for Stationarity

# %% [markdown]
# ### Augmented Dickey-Fuller test to estimate whether data are stationary.

# %%
audio_features = [
'danceability', 
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo']

# %%
# Code by Joseph Nelson! 

def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:3], index=['Test Statistic', 'p-value', 'lags_used'])
    return dfoutput

# %% [markdown]
# _Dickey-Fuller on original dataframes_

# %%
for feature in audio_features:
    print(f'Dickey-Fuller Interpretation for {feature}:\n{interpret_dftest(adfuller(it_rw_18[feature]))}')
# Out:
# Dickey-Fuller Interpretation for danceability:
# Test Statistic   -2.978150
# p-value           0.036986
# lags_used         1.000000
# dtype: float64
# Dickey-Fuller Interpretation for energy:
# Test Statistic   -3.24877
# p-value           0.01733
# lags_used         0.00000
# dtype: float64
# Dickey-Fuller Interpretation for key:
# Test Statistic   -3.469608
# p-value           0.008803
# lags_used         4.000000
# dtype: float64
# Dickey-Fuller Interpretation for loudness:
# Test Statistic   -3.003203
# p-value           0.034596
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for mode:
# Test Statistic   -4.432011
# p-value           0.000260
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for speechiness:
# Test Statistic    -1.736793
# p-value            0.412262
# lags_used         10.000000
# dtype: float64
# Dickey-Fuller Interpretation for acousticness:
# Test Statistic   -2.390354
# p-value           0.144477
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for instrumentalness:
# Test Statistic   -2.806893
# p-value           0.057296
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for liveness:
# Test Statistic   -2.267119
# p-value           0.182792
# lags_used         1.000000
# dtype: float64
# Dickey-Fuller Interpretation for valence:
# Test Statistic   -4.109533
# p-value           0.000934
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for tempo:
# Test Statistic   -3.917986
# p-value           0.001906
# lags_used         0.000000
# dtype: float64

# %% [markdown]
# ### DataFrame with once-differenced data

# %%
lag_df_italy = alltime_rw_italy.copy()

# %%
for feature in audio_features: 
    lag_df_italy[f'{feature}_once_differenced'] = lag_df_italy[feature].diff(1).fillna(0)

# %%
lag_df_italy.tail(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2021-02-07      25.5      0.666561  0.634389  5.402857 -6.677991  0.680000
# 2021-02-14      25.5      0.671104  0.647343  5.516667 -6.842603  0.656667
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2021-02-07     0.109192      0.268234          0.035348  0.223654  ...
# 2021-02-14     0.120716      0.277941          0.054173  0.220087  ...
#
#             energy_once_differenced  key_once_differenced  \
# date
# 2021-02-07                 0.029374               0.18000
# 2021-02-14                 0.012955               0.11381
#
#             loudness_once_differenced  mode_once_differenced  \
# date
# 2021-02-07                   0.314663               0.031429
# 2021-02-14                  -0.164612              -0.023333
#
#             speechiness_once_differenced  acousticness_once_differenced  \
# date
# 2021-02-07                     -0.001159                      -0.073344
# 2021-02-14                      0.011523                       0.009707
#
#             instrumentalness_once_differenced  liveness_once_differenced  \
# date
# 2021-02-07                          -0.001695                   0.005719
# 2021-02-14                           0.018826                  -0.003567
#
#             valence_once_differenced  tempo_once_differenced
# date
# 2021-02-07                 -0.006398                3.285271
# 2021-02-14                  0.049983                1.041837
#
# [2 rows x 25 columns]

# %% [markdown]
# _Dickey-Fuller on lag dataframe_

# %%
for feature in audio_features:
    print(f'Dickey-Fuller Interpretation for {feature}, once-differenced:\n{interpret_dftest(adfuller(lag_df_italy[feature].diff(1).fillna(0)))}')
# Out:
# Dickey-Fuller Interpretation for danceability, once-differenced:
# Test Statistic   -9.142255e+00
# p-value           2.828632e-15
# lags_used         5.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for energy, once-differenced:
# Test Statistic   -6.782611e+00
# p-value           2.477455e-09
# lags_used         7.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for key, once-differenced:
# Test Statistic   -8.518281e+00
# p-value           1.118537e-13
# lags_used         7.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for loudness, once-differenced:
# Test Statistic   -7.002232e+00
# p-value           7.272028e-10
# lags_used         6.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for mode, once-differenced:
# Test Statistic   -9.845662e+00
# p-value           4.627101e-17
# lags_used         4.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for speechiness, once-differenced:
# Test Statistic   -8.291616e+00
# p-value           4.246658e-13
# lags_used         5.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for acousticness, once-differenced:
# Test Statistic   -1.160866e+01
# p-value           2.544491e-21
# lags_used         2.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for instrumentalness, once-differenced:
# Test Statistic   -7.471488e+00
# p-value           5.041115e-11
# lags_used         6.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for liveness, once-differenced:
# Test Statistic   -7.236294e+00
# p-value           1.935642e-10
# lags_used         8.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for valence, once-differenced:
# Test Statistic    -5.043085
# p-value            0.000018
# lags_used         12.000000
# dtype: float64
# Dickey-Fuller Interpretation for tempo, once-differenced:
# Test Statistic   -6.454214e+00
# p-value           1.497350e-08
# lags_used         1.400000e+01
# dtype: float64

# %% [markdown]
# _Checking that these are the same_

# %%
interpret_dftest(adfuller(lag_df_italy['tempo_once_differenced']))
# Out:
# Test Statistic   -6.454214e+00
# p-value           1.497350e-08
# lags_used         1.400000e+01
# dtype: float64

# %%
interpret_dftest(adfuller(lag_df_italy['tempo'].diff(1).fillna(0)))
# Out:
# Test Statistic   -6.454214e+00
# p-value           1.497350e-08
# lags_used         1.400000e+01
# dtype: float64

# %% [markdown]
# ### Using `ndiffs` to figure out how many orders of difference $d$ I need in oder to have stationarity

# %% [markdown]
# #### _Running `ndiff` and `p,d,q` functions just on 2018 Italy data instead of alltime Italy data; however I will just be checking it out; will leave the `ndiff_dict` and `ndiff_df` as is because that is use in models. Will use 2018 data to build the `ndiff_df` to see if this yields better results for this year._

# %%
from pmdarima.arima.utils import ndiffs

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ adf test: {ndiffs(alltime_italy[feature], test= "adf")}')
# Out:
# ndiffs for danceability stationarity w/ adf test: 0
# ndiffs for energy stationarity w/ adf test: 0
# ndiffs for key stationarity w/ adf test: 0
# ndiffs for loudness stationarity w/ adf test: 0
# ndiffs for mode stationarity w/ adf test: 0
# ndiffs for speechiness stationarity w/ adf test: 0
# ndiffs for acousticness stationarity w/ adf test: 0
# ndiffs for instrumentalness stationarity w/ adf test: 0
# ndiffs for liveness stationarity w/ adf test: 0
# ndiffs for valence stationarity w/ adf test: 0
# ndiffs for tempo stationarity w/ adf test: 0

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ adf test: {ndiffs(it_rw_18[feature], test= "adf")}')
# Out:
# ndiffs for danceability stationarity w/ adf test: 1
# ndiffs for energy stationarity w/ adf test: 1
# ndiffs for key stationarity w/ adf test: 1
# ndiffs for loudness stationarity w/ adf test: 1
# ndiffs for mode stationarity w/ adf test: 1
# ndiffs for speechiness stationarity w/ adf test: 1
# ndiffs for acousticness stationarity w/ adf test: 1
# ndiffs for instrumentalness stationarity w/ adf test: 1
# ndiffs for liveness stationarity w/ adf test: 1
# ndiffs for valence stationarity w/ adf test: 1
# ndiffs for tempo stationarity w/ adf test: 1

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ kpss test: {ndiffs(alltime_italy[feature])}')
# Out:
# ndiffs for danceability stationarity w/ kpss test: 1
# ndiffs for energy stationarity w/ kpss test: 1
# ndiffs for key stationarity w/ kpss test: 1
# ndiffs for loudness stationarity w/ kpss test: 1
# ndiffs for mode stationarity w/ kpss test: 1
# ndiffs for speechiness stationarity w/ kpss test: 1
# ndiffs for acousticness stationarity w/ kpss test: 1
# ndiffs for instrumentalness stationarity w/ kpss test: 1
# ndiffs for liveness stationarity w/ kpss test: 1
# ndiffs for valence stationarity w/ kpss test: 1
# ndiffs for tempo stationarity w/ kpss test: 1

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ kpss test: {ndiffs(it_rw_18[feature])}')
# Out:
# ndiffs for danceability stationarity w/ kpss test: 1
# ndiffs for energy stationarity w/ kpss test: 0
# ndiffs for key stationarity w/ kpss test: 0
# ndiffs for loudness stationarity w/ kpss test: 0
# ndiffs for mode stationarity w/ kpss test: 0
# ndiffs for speechiness stationarity w/ kpss test: 0
# ndiffs for acousticness stationarity w/ kpss test: 1
# ndiffs for instrumentalness stationarity w/ kpss test: 1
# ndiffs for liveness stationarity w/ kpss test: 1
# ndiffs for valence stationarity w/ kpss test: 0
# ndiffs for tempo stationarity w/ kpss test: 0

# %% [markdown]
# ### Finding `p`, `d`, and `q` values

# %% [markdown]
# _Using only the five audio features that are the most relevant or show some sort of pattern_

# %%
five_features = ['danceability', 'mode', 'acousticness', 'valence', 'tempo']

# %% [markdown]
# _Building dataframe with `ndifffs` for stationarity for each feature_
#
# _This time using `it_rw_18` instead of `alltime_rw_italy`._

# %%
ndiff_dict = {
    'audio_feature':[],
    'ndiffs for stationarity':[]    
}

for feature in five_features:
    ndiff_dict['audio_feature'].append(feature)
    ndiff_dict['ndiffs for stationarity'].append(ndiffs(it_rw_18[feature], test= "adf"))

ndiff_df = pd.DataFrame(ndiff_dict)
ndiff_df
# Out:
#   audio_feature  ndiffs for stationarity
# 0  danceability                        1
# 1          mode                        1
# 2  acousticness                        1
# 3       valence                        1
# 4         tempo                        1

# %%
arima_dict_18 = {
    'audio_feature':[],
    'ndiffs(d)':[],
    'best_p':[],
    'best_q':[],
    'order':[],
    'ARIMA_model':[],
    'ARIMA_AIC':[]
}

def find_p_and_q(df, feature, arima_dict, n=6):
    
    train = df[feature][0:162]
    
    d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]

    # starting with large start AIC
    best_aic = 99 * (10 * 16)
    # creating variables to store best values ofd p and q 
    best_p = 0
    best_q = 0 

    # use nested for loop to iterate over values of p and q
    for p in range(n):

        for q in range(n):

            # insert try and and except statements
            try: 

                # fitting on ARIMA(p, 1, q) model 
                print(f'Attempting to fit ARIMA({p}, {d}, {q})')

                # instantiate ARIMA model
                arima = ARIMA(train, order=(p,d,q))

                # fit ARIMA model 
                model = arima.fit()

                # print out AIC for ARIMA(p, 1, q) model 
                print(f'For {feature}, the AIC for ARIMA({p},{d},{q}) is: {model.aic}')

                # Is this current model's AIC better than the OF best_aic? 
                if model.aic < best_aic:
                    # we want aic to be lower so we are setting a high aic and hoping for something lower 

                    # if it is, we overwrite the best_aic, best_p, and best_q
                    best_aic = model.aic
                    best_p = p 
                    best_q = q

            except:
                pass 

        order = (best_p, d, best_q)
    
    arima_dict['audio_feature'].append(feature)
    arima_dict['ndiffs(d)'].append(d)
    arima_dict['best_p'].append(best_p)
    arima_dict['best_q'].append(best_q)
    arima_dict['order'].append(order)
    arima_dict['ARIMA_model'].append(f'ARIMA({best_p},{d},{best_q})')
    arima_dict['ARIMA_AIC'].append(best_aic)

    print()
    print(f'{feature.upper()} MODEL FINISHED!')
    print(f'The model for {feature} that minimizes AIC on the training data is the ARIMA({best_p},{d},{best_q}).')
    print(f'The model has an aIC of {best_aic}.')
    print()

# %%
arima_dict_18
# Out:
# {'audio_feature': [],
#  'ndiffs(d)': [],
#  'best_p': [],
#  'best_q': [],
#  'order': [],
#  'ARIMA_model': [],
#  'ARIMA_AIC': []}

# %%
for feature in five_features:
    find_p_and_q(it_rw_18, feature, arima_dict_18)
# Out:
# Attempting to fit ARIMA(0, 1, 0)
# For danceability, the AIC for ARIMA(0,1,0) is: -208.1953537460845
# Attempting to fit ARIMA(0, 1, 1)
# For danceability, the AIC for ARIMA(0,1,1) is: -217.46053918380267
# Attempting to fit ARIMA(0, 1, 2)
# For danceability, the AIC for ARIMA(0,1,2) is: -215.5403946382255
# Attempting to fit ARIMA(0, 1, 3)
# For danceability, the AIC for ARIMA(0,1,3) is: -213.59537392598708
# Attempting to fit ARIMA(0, 1, 4)
# For danceability, the AIC for ARIMA(0,1,4) is: -211.7479708394353
# Attempting to fit ARIMA(0, 1, 5)
# For danceability, the AIC for ARIMA(0,1,5) is: -209.95290478242964
# Attempting to fit ARIMA(1, 1, 0)
# For danceability, the AIC for ARIMA(1,1,0) is: -216.14528638421535
# Attempting to fit ARIMA(1, 1, 1)
# For danceability, the AIC for ARIMA(1,1,1) is: -215.54781502403603
# Attempting to fit ARIMA(1, 1, 2)
# For danceability, the AIC for ARIMA(1,1,2) is: -213.54938129555666
# Attempting to fit ARIMA(1, 1, 3)
# Attempting to fit ARIMA(1, 1, 4)
# Attempting to fit ARIMA(1, 1, 5)
# Attempting to fit ARIMA(2, 1, 0)
# For danceability, the AIC for ARIMA(2,1,0) is: -215.4372188594259
# Attempting to fit ARIMA(2, 1, 1)
# For danceability, the AIC for ARIMA(2,1,1) is: -213.93538775289403
# Attempting to fit ARIMA(2, 1, 2)
# For danceability, the AIC for ARIMA(2,1,2) is: -212.39973461507827
# Attempting to fit ARIMA(2, 1, 3)
# For danceability, the AIC for ARIMA(2,1,3) is: -210.65397821548544
# Attempting to fit ARIMA(2, 1, 4)
# For danceability, the AIC for ARIMA(2,1,4) is: -211.40200925144842
# Attempting to fit ARIMA(2, 1, 5)
# Attempting to fit ARIMA(3, 1, 0)
# For danceability, the AIC for ARIMA(3,1,0) is: -213.4539133270133
# Attempting to fit ARIMA(3, 1, 1)
# For danceability, the AIC for ARIMA(3,1,1) is: -212.45705087713304
# Attempting to fit ARIMA(3, 1, 2)
# For danceability, the AIC for ARIMA(3,1,2) is: -209.80374356400597
# Attempting to fit ARIMA(3, 1, 3)
# For danceability, the AIC for ARIMA(3,1,3) is: -209.54479410022333
# Attempting to fit ARIMA(3, 1, 4)
# For danceability, the AIC for ARIMA(3,1,4) is: -209.6028405730451
# Attempting to fit ARIMA(3, 1, 5)
# Attempting to fit ARIMA(4, 1, 0)
# For danceability, the AIC for ARIMA(4,1,0) is: -211.93021596240658
# Attempting to fit ARIMA(4, 1, 1)
# For danceability, the AIC for ARIMA(4,1,1) is: -210.62208971056083
# Attempting to fit ARIMA(4, 1, 2)
# For danceability, the AIC for ARIMA(4,1,2) is: -209.53134568616002
# Attempting to fit ARIMA(4, 1, 3)
# For danceability, the AIC for ARIMA(4,1,3) is: -207.54696920570518
# Attempting to fit ARIMA(4, 1, 4)
# For danceability, the AIC for ARIMA(4,1,4) is: -204.84588980986075
# Attempting to fit ARIMA(4, 1, 5)
# For danceability, the AIC for ARIMA(4,1,5) is: -202.83206038969382
# Attempting to fit ARIMA(5, 1, 0)
# For danceability, the AIC for ARIMA(5,1,0) is: -209.93339658748783
# Attempting to fit ARIMA(5, 1, 1)
# For danceability, the AIC for ARIMA(5,1,1) is: -208.09386675249021
# Attempting to fit ARIMA(5, 1, 2)
# For danceability, the AIC for ARIMA(5,1,2) is: -207.5503616432934
# Attempting to fit ARIMA(5, 1, 3)
# Attempting to fit ARIMA(5, 1, 4)
# For danceability, the AIC for ARIMA(5,1,4) is: -204.71169562271172
# Attempting to fit ARIMA(5, 1, 5)
# For danceability, the AIC for ARIMA(5,1,5) is: -202.7176187019311
#
# DANCEABILITY MODEL FINISHED!
# The model for danceability that minimizes AIC on the training data is the ARIMA(0,1,1).
# The model has an aIC of -217.46053918380267.
#
# Attempting to fit ARIMA(0, 1, 0)
# For mode, the AIC for ARIMA(0,1,0) is: -137.02097486390662
# Attempting to fit ARIMA(0, 1, 1)
# For mode, the AIC for ARIMA(0,1,1) is: -143.95294729237605
# Attempting to fit ARIMA(0, 1, 2)
# For mode, the AIC for ARIMA(0,1,2) is: -143.9630634386608
# Attempting to fit ARIMA(0, 1, 3)
# For mode, the AIC for ARIMA(0,1,3) is: -142.7837310540238
# Attempting to fit ARIMA(0, 1, 4)
# For mode, the AIC for ARIMA(0,1,4) is: -145.22095187693162
# Attempting to fit ARIMA(0, 1, 5)
# For mode, the AIC for ARIMA(0,1,5) is: -143.49620877044492
# Attempting to fit ARIMA(1, 1, 0)
# For mode, the AIC for ARIMA(1,1,0) is: -139.1279029408733
# Attempting to fit ARIMA(1, 1, 1)
# For mode, the AIC for ARIMA(1,1,1) is: -143.1016679718722
# Attempting to fit ARIMA(1, 1, 2)
# For mode, the AIC for ARIMA(1,1,2) is: -141.440921241715
# Attempting to fit ARIMA(1, 1, 3)
# For mode, the AIC for ARIMA(1,1,3) is: -140.7385553953245
# Attempting to fit ARIMA(1, 1, 4)
# For mode, the AIC for ARIMA(1,1,4) is: -143.84503585553892
# Attempting to fit ARIMA(1, 1, 5)
# Attempting to fit ARIMA(2, 1, 0)
# For mode, the AIC for ARIMA(2,1,0) is: -138.87278399869058
# Attempting to fit ARIMA(2, 1, 1)
# For mode, the AIC for ARIMA(2,1,1) is: -142.37212384994206
# Attempting to fit ARIMA(2, 1, 2)
# For mode, the AIC for ARIMA(2,1,2) is: -139.0994770954262
# Attempting to fit ARIMA(2, 1, 3)
# For mode, the AIC for ARIMA(2,1,3) is: -143.90644295485663
# Attempting to fit ARIMA(2, 1, 4)
# For mode, the AIC for ARIMA(2,1,4) is: -142.3329453378151
# Attempting to fit ARIMA(2, 1, 5)
# For mode, the AIC for ARIMA(2,1,5) is: -134.1572639518496
# Attempting to fit ARIMA(3, 1, 0)
# For mode, the AIC for ARIMA(3,1,0) is: -146.88951614891624
# Attempting to fit ARIMA(3, 1, 1)
# For mode, the AIC for ARIMA(3,1,1) is: -144.94212387839337
# Attempting to fit ARIMA(3, 1, 2)
# For mode, the AIC for ARIMA(3,1,2) is: -143.32961996705552
# Attempting to fit ARIMA(3, 1, 3)
# For mode, the AIC for ARIMA(3,1,3) is: -141.72760030617474
# Attempting to fit ARIMA(3, 1, 4)
# For mode, the AIC for ARIMA(3,1,4) is: -140.42501787724018
# Attempting to fit ARIMA(3, 1, 5)
# For mode, the AIC for ARIMA(3,1,5) is: -136.76908688673473
# Attempting to fit ARIMA(4, 1, 0)
# For mode, the AIC for ARIMA(4,1,0) is: -144.92047118585594
# Attempting to fit ARIMA(4, 1, 1)
# For mode, the AIC for ARIMA(4,1,1) is: -144.01693885703446
# Attempting to fit ARIMA(4, 1, 2)
# For mode, the AIC for ARIMA(4,1,2) is: -142.33229212915018
# Attempting to fit ARIMA(4, 1, 3)
# For mode, the AIC for ARIMA(4,1,3) is: -140.37512281325928
# Attempting to fit ARIMA(4, 1, 4)
# For mode, the AIC for ARIMA(4,1,4) is: -137.83495462607232
# Attempting to fit ARIMA(4, 1, 5)
# For mode, the AIC for ARIMA(4,1,5) is: -136.34678710447002
# Attempting to fit ARIMA(5, 1, 0)
# For mode, the AIC for ARIMA(5,1,0) is: -143.37873577859716
# Attempting to fit ARIMA(5, 1, 1)
# For mode, the AIC for ARIMA(5,1,1) is: -140.95212176684413
# Attempting to fit ARIMA(5, 1, 2)
# For mode, the AIC for ARIMA(5,1,2) is: -140.02581350534507
# Attempting to fit ARIMA(5, 1, 3)
# Attempting to fit ARIMA(5, 1, 4)
# For mode, the AIC for ARIMA(5,1,4) is: -133.0250443209673
# Attempting to fit ARIMA(5, 1, 5)
# For mode, the AIC for ARIMA(5,1,5) is: -132.55554048955497
#
# MODE MODEL FINISHED!
# The model for mode that minimizes AIC on the training data is the ARIMA(3,1,0).
# The model has an aIC of -146.88951614891624.
#
# Attempting to fit ARIMA(0, 1, 0)
# For acousticness, the AIC for ARIMA(0,1,0) is: -181.50128714233554
# Attempting to fit ARIMA(0, 1, 1)
# For acousticness, the AIC for ARIMA(0,1,1) is: -181.08046653567948
# Attempting to fit ARIMA(0, 1, 2)
# For acousticness, the AIC for ARIMA(0,1,2) is: -184.36910955580225
# Attempting to fit ARIMA(0, 1, 3)
# For acousticness, the AIC for ARIMA(0,1,3) is: -182.91156316521733
# Attempting to fit ARIMA(0, 1, 4)
# For acousticness, the AIC for ARIMA(0,1,4) is: -181.19032950856365
# Attempting to fit ARIMA(0, 1, 5)
# For acousticness, the AIC for ARIMA(0,1,5) is: -180.02706131933974
# Attempting to fit ARIMA(1, 1, 0)
# For acousticness, the AIC for ARIMA(1,1,0) is: -180.30930755107988
# Attempting to fit ARIMA(1, 1, 1)
# For acousticness, the AIC for ARIMA(1,1,1) is: -180.64380125981472
# Attempting to fit ARIMA(1, 1, 2)
# For acousticness, the AIC for ARIMA(1,1,2) is: -178.67277088226274
# Attempting to fit ARIMA(1, 1, 3)
# For acousticness, the AIC for ARIMA(1,1,3) is: -180.5840654172713
# Attempting to fit ARIMA(1, 1, 4)
# For acousticness, the AIC for ARIMA(1,1,4) is: -179.1540247278295
# Attempting to fit ARIMA(1, 1, 5)
# For acousticness, the AIC for ARIMA(1,1,5) is: -181.14613341738112
# Attempting to fit ARIMA(2, 1, 0)
# For acousticness, the AIC for ARIMA(2,1,0) is: -181.8501299668091
# Attempting to fit ARIMA(2, 1, 1)
# For acousticness, the AIC for ARIMA(2,1,1) is: -181.41481460536784
# Attempting to fit ARIMA(2, 1, 2)
# For acousticness, the AIC for ARIMA(2,1,2) is: -181.24509870615213
# Attempting to fit ARIMA(2, 1, 3)
# For acousticness, the AIC for ARIMA(2,1,3) is: -179.2454109408639
# Attempting to fit ARIMA(2, 1, 4)
# For acousticness, the AIC for ARIMA(2,1,4) is: -178.33262167247943
# Attempting to fit ARIMA(2, 1, 5)
# For acousticness, the AIC for ARIMA(2,1,5) is: -179.56758731809617
# Attempting to fit ARIMA(3, 1, 0)
# For acousticness, the AIC for ARIMA(3,1,0) is: -179.9914207585806
# Attempting to fit ARIMA(3, 1, 1)
# For acousticness, the AIC for ARIMA(3,1,1) is: -178.73425172850784
# Attempting to fit ARIMA(3, 1, 2)
# Attempting to fit ARIMA(3, 1, 3)
# For acousticness, the AIC for ARIMA(3,1,3) is: -173.3431732521562
# Attempting to fit ARIMA(3, 1, 4)
# For acousticness, the AIC for ARIMA(3,1,4) is: -174.29978367973587
# Attempting to fit ARIMA(3, 1, 5)
# For acousticness, the AIC for ARIMA(3,1,5) is: -177.1834477206408
# Attempting to fit ARIMA(4, 1, 0)
# For acousticness, the AIC for ARIMA(4,1,0) is: -182.4824567544474
# Attempting to fit ARIMA(4, 1, 1)
# For acousticness, the AIC for ARIMA(4,1,1) is: -181.27289239432776
# Attempting to fit ARIMA(4, 1, 2)
# For acousticness, the AIC for ARIMA(4,1,2) is: -179.3165860969745
# Attempting to fit ARIMA(4, 1, 3)
# For acousticness, the AIC for ARIMA(4,1,3) is: -173.06982304603503
# Attempting to fit ARIMA(4, 1, 4)
# Attempting to fit ARIMA(4, 1, 5)
# Attempting to fit ARIMA(5, 1, 0)
# For acousticness, the AIC for ARIMA(5,1,0) is: -180.7540796051549
# Attempting to fit ARIMA(5, 1, 1)
# For acousticness, the AIC for ARIMA(5,1,1) is: -179.2823624485439
# Attempting to fit ARIMA(5, 1, 2)
# For acousticness, the AIC for ARIMA(5,1,2) is: -177.55799233902047
# Attempting to fit ARIMA(5, 1, 3)
# Attempting to fit ARIMA(5, 1, 4)
# For acousticness, the AIC for ARIMA(5,1,4) is: -175.26222148186054
# Attempting to fit ARIMA(5, 1, 5)
# For acousticness, the AIC for ARIMA(5,1,5) is: -182.91654192182972
#
# ACOUSTICNESS MODEL FINISHED!
# The model for acousticness that minimizes AIC on the training data is the ARIMA(0,1,2).
# The model has an aIC of -184.36910955580225.
#
# Attempting to fit ARIMA(0, 1, 0)
# For valence, the AIC for ARIMA(0,1,0) is: -181.98465994554988
# Attempting to fit ARIMA(0, 1, 1)
# For valence, the AIC for ARIMA(0,1,1) is: -187.82112982368238
# Attempting to fit ARIMA(0, 1, 2)
# For valence, the AIC for ARIMA(0,1,2) is: -188.62663672866535
# Attempting to fit ARIMA(0, 1, 3)
# For valence, the AIC for ARIMA(0,1,3) is: -186.6684796445544
# Attempting to fit ARIMA(0, 1, 4)
# For valence, the AIC for ARIMA(0,1,4) is: -186.79857438490944
# Attempting to fit ARIMA(0, 1, 5)
# For valence, the AIC for ARIMA(0,1,5) is: -186.71162607921985
# Attempting to fit ARIMA(1, 1, 0)
# For valence, the AIC for ARIMA(1,1,0) is: -184.6386228337945
# Attempting to fit ARIMA(1, 1, 1)
# For valence, the AIC for ARIMA(1,1,1) is: -188.9349774886058
# Attempting to fit ARIMA(1, 1, 2)
# For valence, the AIC for ARIMA(1,1,2) is: -186.62688397325388
# Attempting to fit ARIMA(1, 1, 3)
# For valence, the AIC for ARIMA(1,1,3) is: -185.94274302939073
# Attempting to fit ARIMA(1, 1, 4)
# For valence, the AIC for ARIMA(1,1,4) is: -186.08478999969572
# Attempting to fit ARIMA(1, 1, 5)
# For valence, the AIC for ARIMA(1,1,5) is: -184.77964210935113
# Attempting to fit ARIMA(2, 1, 0)
# For valence, the AIC for ARIMA(2,1,0) is: -184.98034620837507
# Attempting to fit ARIMA(2, 1, 1)
# For valence, the AIC for ARIMA(2,1,1) is: -187.00532698844063
# Attempting to fit ARIMA(2, 1, 2)
# For valence, the AIC for ARIMA(2,1,2) is: -185.8795618611614
# Attempting to fit ARIMA(2, 1, 3)
# For valence, the AIC for ARIMA(2,1,3) is: -184.80450370669314
# Attempting to fit ARIMA(2, 1, 4)
# For valence, the AIC for ARIMA(2,1,4) is: -191.96729101002404
# Attempting to fit ARIMA(2, 1, 5)
# For valence, the AIC for ARIMA(2,1,5) is: -191.74207827418002
# Attempting to fit ARIMA(3, 1, 0)
# For valence, the AIC for ARIMA(3,1,0) is: -183.0194044644541
# Attempting to fit ARIMA(3, 1, 1)
# For valence, the AIC for ARIMA(3,1,1) is: -184.9425674806164
# Attempting to fit ARIMA(3, 1, 2)
# For valence, the AIC for ARIMA(3,1,2) is: -184.81033190447272
# Attempting to fit ARIMA(3, 1, 3)
# Attempting to fit ARIMA(3, 1, 4)
# For valence, the AIC for ARIMA(3,1,4) is: -186.81734182293036
# Attempting to fit ARIMA(3, 1, 5)
# For valence, the AIC for ARIMA(3,1,5) is: -185.80592439980734
# Attempting to fit ARIMA(4, 1, 0)
# For valence, the AIC for ARIMA(4,1,0) is: -188.89979737228458
# Attempting to fit ARIMA(4, 1, 1)
# For valence, the AIC for ARIMA(4,1,1) is: -186.9264514258847
# Attempting to fit ARIMA(4, 1, 2)
# For valence, the AIC for ARIMA(4,1,2) is: -185.0420822886789
# Attempting to fit ARIMA(4, 1, 3)
# For valence, the AIC for ARIMA(4,1,3) is: -186.85263265546945
# Attempting to fit ARIMA(4, 1, 4)
# For valence, the AIC for ARIMA(4,1,4) is: -185.22566540454693
# Attempting to fit ARIMA(4, 1, 5)
# Attempting to fit ARIMA(5, 1, 0)
# For valence, the AIC for ARIMA(5,1,0) is: -186.93259427544132
# Attempting to fit ARIMA(5, 1, 1)
# For valence, the AIC for ARIMA(5,1,1) is: -186.25725389878284
# Attempting to fit ARIMA(5, 1, 2)
# For valence, the AIC for ARIMA(5,1,2) is: -189.3402199699504
# Attempting to fit ARIMA(5, 1, 3)
# For valence, the AIC for ARIMA(5,1,3) is: -185.2002556423467
# Attempting to fit ARIMA(5, 1, 4)
# For valence, the AIC for ARIMA(5,1,4) is: -183.4687729316671
# Attempting to fit ARIMA(5, 1, 5)
# For valence, the AIC for ARIMA(5,1,5) is: -183.44192937564696
#
# VALENCE MODEL FINISHED!
# The model for valence that minimizes AIC on the training data is the ARIMA(2,1,4).
# The model has an aIC of -191.96729101002404.
#
# Attempting to fit ARIMA(0, 1, 0)
# For tempo, the AIC for ARIMA(0,1,0) is: 250.64349319249462
# Attempting to fit ARIMA(0, 1, 1)
# For tempo, the AIC for ARIMA(0,1,1) is: 252.1999614434232
# Attempting to fit ARIMA(0, 1, 2)
# For tempo, the AIC for ARIMA(0,1,2) is: 247.15700606079426
# Attempting to fit ARIMA(0, 1, 3)
# For tempo, the AIC for ARIMA(0,1,3) is: 247.34637221663849
# Attempting to fit ARIMA(0, 1, 4)
# For tempo, the AIC for ARIMA(0,1,4) is: 248.83496748350424
# Attempting to fit ARIMA(0, 1, 5)
# For tempo, the AIC for ARIMA(0,1,5) is: 250.32619129035578
# Attempting to fit ARIMA(1, 1, 0)
# For tempo, the AIC for ARIMA(1,1,0) is: 252.36641760977216
# Attempting to fit ARIMA(1, 1, 1)
# For tempo, the AIC for ARIMA(1,1,1) is: 254.57200781787188
# Attempting to fit ARIMA(1, 1, 2)
# For tempo, the AIC for ARIMA(1,1,2) is: 247.16317354787847
# Attempting to fit ARIMA(1, 1, 3)
# For tempo, the AIC for ARIMA(1,1,3) is: 250.80656601263408
# Attempting to fit ARIMA(1, 1, 4)
# For tempo, the AIC for ARIMA(1,1,4) is: 250.6373496548901
# Attempting to fit ARIMA(1, 1, 5)
# For tempo, the AIC for ARIMA(1,1,5) is: 252.83229633715828
# Attempting to fit ARIMA(2, 1, 0)
# For tempo, the AIC for ARIMA(2,1,0) is: 252.22723104270432
# Attempting to fit ARIMA(2, 1, 1)
# For tempo, the AIC for ARIMA(2,1,1) is: 246.97424067334418
# Attempting to fit ARIMA(2, 1, 2)
# For tempo, the AIC for ARIMA(2,1,2) is: 248.9737805059172
# Attempting to fit ARIMA(2, 1, 3)
# For tempo, the AIC for ARIMA(2,1,3) is: 255.81693279427418
# Attempting to fit ARIMA(2, 1, 4)
# For tempo, the AIC for ARIMA(2,1,4) is: 253.41379216427086
# Attempting to fit ARIMA(2, 1, 5)
# For tempo, the AIC for ARIMA(2,1,5) is: 254.53450322326967
# Attempting to fit ARIMA(3, 1, 0)
# For tempo, the AIC for ARIMA(3,1,0) is: 252.20992276949403
# Attempting to fit ARIMA(3, 1, 1)
# For tempo, the AIC for ARIMA(3,1,1) is: 248.97353941718634
# Attempting to fit ARIMA(3, 1, 2)
# For tempo, the AIC for ARIMA(3,1,2) is: 248.5651691291814
# Attempting to fit ARIMA(3, 1, 3)
# For tempo, the AIC for ARIMA(3,1,3) is: 251.9736428191449
# Attempting to fit ARIMA(3, 1, 4)
# For tempo, the AIC for ARIMA(3,1,4) is: 253.13811592486041
# Attempting to fit ARIMA(3, 1, 5)
# Attempting to fit ARIMA(4, 1, 0)
# For tempo, the AIC for ARIMA(4,1,0) is: 250.56773868521648
# Attempting to fit ARIMA(4, 1, 1)
# For tempo, the AIC for ARIMA(4,1,1) is: 252.19216559154896
# Attempting to fit ARIMA(4, 1, 2)
# For tempo, the AIC for ARIMA(4,1,2) is: 254.18115539305163
# Attempting to fit ARIMA(4, 1, 3)
# For tempo, the AIC for ARIMA(4,1,3) is: 254.41288614974636
# Attempting to fit ARIMA(4, 1, 4)
# For tempo, the AIC for ARIMA(4,1,4) is: 255.06978699716836
# Attempting to fit ARIMA(4, 1, 5)
# For tempo, the AIC for ARIMA(4,1,5) is: 253.509739233945
# Attempting to fit ARIMA(5, 1, 0)
# For tempo, the AIC for ARIMA(5,1,0) is: 252.3035484276738
# Attempting to fit ARIMA(5, 1, 1)
# For tempo, the AIC for ARIMA(5,1,1) is: 254.19547019103618
# Attempting to fit ARIMA(5, 1, 2)
# Attempting to fit ARIMA(5, 1, 3)
# For tempo, the AIC for ARIMA(5,1,3) is: 285.12550791681736
# Attempting to fit ARIMA(5, 1, 4)
# For tempo, the AIC for ARIMA(5,1,4) is: 257.06482021200213
# Attempting to fit ARIMA(5, 1, 5)
# For tempo, the AIC for ARIMA(5,1,5) is: 254.6655200067977
#
# TEMPO MODEL FINISHED!
# The model for tempo that minimizes AIC on the training data is the ARIMA(2,1,1).
# The model has an aIC of 246.97424067334418.

# %%
arima_param_df_18 = pd.DataFrame(arima_dict_18)
arima_param_df_18
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       0       1  (0, 1, 1)  ARIMA(0,1,1)
# 1          mode          1       3       0  (3, 1, 0)  ARIMA(3,1,0)
# 2  acousticness          1       0       2  (0, 1, 2)  ARIMA(0,1,2)
# 3       valence          1       2       4  (2, 1, 4)  ARIMA(2,1,4)
# 4         tempo          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
#
#     ARIMA_AIC
# 0 -217.460539
# 1 -146.889516
# 2 -184.369110
# 3 -191.967291
# 4  246.974241

# %% [markdown]
# # ARIMA Models

# %% [markdown]
# ### Function to create, evaluate, and plot `ARIMA` models

# %%
def arima_predict_plot(df, feature, year, param_df, title='title', figsize=(15,5), order=None, d=None, ci=True):
  
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    if order is None:
        # find order from arima parameters dataframe 
        order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
   
    try: 
        # instantiate ARIMA model
        model = ARIMA(train, order=order)

        # fit ARIMA model
        arima = model.fit()

        # get predictions for train and test sets 
        preds_train = model.predict(params=arima.params, start=train.index[d], end=train.index[-1], typ='levels')
        preds_test = model.predict(params=arima.params, start=test.index[0], end=test.index[-1], typ='levels')

        # calculate and print RMSE for train and test setes 
        train_rmse = mean_squared_error(train[d::], preds_train)**0.5
        print(f'{feature.capitalize()} train RMSE ({year}) - ARIMA({order}): {train_rmse}')

        test_rmse = mean_squared_error(test, preds_test)**0.5
        print(f'{feature.capitalize()} test RMSE ({year}) - ARIMA({order}): {test_rmse}')

        # add RMSEs to arima parameters dataframe 
        param_df.loc[param_df['audio_feature'] == feature, 'arima_train_rmse'] = train_rmse    
        param_df.loc[param_df['audio_feature'] == feature, 'arima_test_rmse'] = test_rmse

          # set up plot
        plt.figure(figsize=figsize)

        # plot training data 
        plt.plot(train, color='blue')

        # plot testing data 
        plt.plot(test.index, test, color='orange')

        # plot predicted values for test set 
        plt.plot(test.index, preds_test, color='green')

        # add line for the baseline model (mean value of feature)
        plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')

        # plot confidence interval
        if ci:
            ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
            plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 

        # make plot with title! 
        plt.title(title, fontsize=16)
        plt.show() ; 
        
    except:
        print(ValueError)
        pass

# %% [markdown]
# _Function soley for plotting to be used when needed._

# %%
def arima_plot(train, test, preds_test, title='title', figsize=(15,5), ci=True):
    
    # set up plot
    plt.figure(figsize=figsize)
    
    # plot training data 
    plt.plot(train, color='blue')
    
    # plot testing data 
    plt.plot(test.index, test, color='orange')
    
    # plot predicted values for test set 
    plt.plot(test.index, preds_test, color='green')
    
    # add line for the baseline model (mean value of feature)
    # plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')
    
    # plot confidence interval 
    if ci:
        ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
        plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 
    
    # make plot with title! 
    plt.title(title, fontsize=16)
    plt.show() ;

# %% [markdown]
# ### ARIMA Models - 2018
#
# _Using `arima_predict_plot` function to run ARIMA model for each feature and show plot of actual vs. test._
#
# _This will also add columns for `arima_train_rmse` and `arima_test_rmse`._

# %%
it_rw_18.head(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2018-01-07      25.5      0.585277  0.553841  5.585714 -8.274331  0.722857
# 2018-01-14      25.5      0.572549  0.554074  4.854286 -8.483963  0.662857
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2018-01-07     0.095949      0.327071          0.035985  0.160532  0.430290
# 2018-01-14     0.082705      0.292300          0.025686  0.148855  0.441377
#
#                 tempo    duration_ms  time_signature
# date
# 2018-01-07  114.93042  213619.057143        3.911429
# 2018-01-14  114.26098  210318.791429        3.962857

# %%
it_rw_18.tail(2)
# Out:
#             Position  danceability   energy       key  loudness      mode  \
# date
# 2018-12-23      25.5      0.652526  0.62446  5.345714 -7.126363  0.548571
# 2018-12-30      25.5      0.637171  0.63514  4.971429 -6.814571  0.528571
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2018-12-23     0.098575      0.315516          0.058491  0.126928  0.464983
# 2018-12-30     0.104640      0.342631          0.066215  0.139117  0.460786
#
#                  tempo    duration_ms  time_signature
# date
# 2018-12-23  117.940511  209852.965714        3.985714
# 2018-12-30  121.689883  216545.840000        3.934286

# %%
for feature in five_features: 
    arima_predict_plot(it_rw_18, feature, 2018, arima_param_df_18, title=f'Mean {feature.capitalize()} Score, Italy 2018 (ARIMA, custom d)')
# Out:
# d = 1
# order = (0, 1, 1)
# Danceability train RMSE (2018) - ARIMA((0, 1, 1)): 0.028160797322810252
# Danceability test RMSE (2018) - ARIMA((0, 1, 1)): 0.010787127076728645
# d = 1
# order = (3, 1, 0)
# Mode train RMSE (2018) - ARIMA((3, 1, 0)): 0.05356106305997141
# Mode test RMSE (2018) - ARIMA((3, 1, 0)): 0.04275150664738172
# d = 1
# order = (0, 1, 2)
# Acousticness train RMSE (2018) - ARIMA((0, 1, 2)): 0.03635108301796731
# Acousticness test RMSE (2018) - ARIMA((0, 1, 2)): 0.05726829580318497
# d = 1
# order = (2, 1, 4)
# <class 'ValueError'>
# d = 1
# order = (2, 1, 1)
# Tempo train RMSE (2018) - ARIMA((2, 1, 1)): 2.545530275670421
# Tempo test RMSE (2018) - ARIMA((2, 1, 1)): 3.0226685288840085

# %% [markdown]
# _redoing valence because the AR/MA coefficients needed to be changed_

# %%
arima_predict_plot(it_rw_18, 'valence', 2018, arima_param_df_18, title=f'Mean {feature.capitalize()} Score, Italy 2018 (ARIMA)', order=(2,1,2,), d=1)
# Out:
# d = 1
# order = (2, 1, 2)
# Valence train RMSE (2018) - ARIMA((2, 1, 2)): 0.035609520861555256
# Valence test RMSE (2018) - ARIMA((2, 1, 2)): 0.04809084411253774

# %% [markdown]
# #### _Updated `arima_param_df_18`_

# %%
arima_param_df_18
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       0       1  (0, 1, 1)  ARIMA(0,1,1)
# 1          mode          1       3       0  (3, 1, 0)  ARIMA(3,1,0)
# 2  acousticness          1       0       2  (0, 1, 2)  ARIMA(0,1,2)
# 3       valence          1       2       4  (2, 1, 4)  ARIMA(2,1,4)
# 4         tempo          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse
# 0 -217.460539          0.028161         0.010787
# 1 -146.889516          0.053561         0.042752
# 2 -184.369110          0.036351         0.057268
# 3 -191.967291          0.035610         0.048091
# 4  246.974241          2.545530         3.022669

# %% [markdown]
# # SARIMAX models

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# #### _As baseline, Fitting SARIMAX with `seasonal_order = (2, 0, 2, 52)` and no exogenous variables before incorporating/engineering those components._

# %%
P, D, Q, S = 2, 0 ,2, 52
train_val = it_rw_18['valence'][0:48]
test_val = it_rw_18['valence'][48:]

sarima_val = SARIMAX(endog = train_val, order = (2, 0, 2), seasonal_order = (P, D, Q, S)).fit()
# sarima_pred = sarima.predict(start=start, end = end)

preds_train_sarima_val = sarima_val.predict(start=train_val.index[0], end=train_val.index[-1])
preds_test_sarima_val = sarima_val.predict(start=test_val.index[0], end=test_val.index[-1])

print(f'RMSE = {round(mean_squared_error(test_val, preds_test_sarima_val)**.5, 2)}')

arima_plot(train_val, test_val, preds_test_sarima_val, title="Basic SARIMA model - Valence, Italy 2018", figsize=(10,3))
# Out:
# RMSE = 0.02

# %% [markdown]
# #### Plotting ARIMA plot from above again, for comparison:

# %%
arima_predict_plot(it_rw_17, 'valence', 2018, arima_param_df_18, title=f'Mean Valence Score, Italy 2017', figsize=(10,3), order=(2,1,2))
# Out:
# d = 1
# order = (2, 1, 2)
# Valence train RMSE (2018) - ARIMA((2, 1, 2)): 0.036157040161561356
# Valence test RMSE (2018) - ARIMA((2, 1, 2)): 0.04017210751841029

# %% [markdown]
# ### SARIMAX Seasonal Parameters

# %% [markdown]
# #### _Grid search to find best `P`, `D`, `Q`, and `s` values_

# %%
def find_sarima_parameters(df, feature, param_df, n_rows=47):    
    
    import time
    t0 = time.time()
    final_mae = 1000000000000
    final_S = 0
    final_D = 0
    final_P = 0
    final_Q = 0
    
    # find order from arima parameters dataframe 
    order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]

    train_values = df[feature][0:n_rows]
    test_values = df[feature][n_rows:]

    for S in range(48,53):
        for D in range(2):
            for P in range(4):
                for Q in range(4):
                    print(f'Checking ({P}, {D}, {Q}, {S}) at {round(time.time() - t0)} seconds.')
                    try:
                        sarima = SARIMAX(endog = train_values,
                                         order = order,
                                         seasonal_order = (P, D, Q, S)).fit()

                        sarima_pred = sarima.predict(start=test_values.index[0], end=test_values.index[-1], typ='levels')

                        if mean_absolute_error(test_values, sarima_pred) < final_mae:
                            final_mae = mean_absolute_error(test_values, sarima_pred)
                            final_S = S
                            final_D = D
                            final_P = P
                            final_Q = Q

                        print(f'We just fit a SARIMAX(2, 0, 2)x({P}, {D}, {Q}, {S}) model with {mean_absolute_error(test_values, sarima_pred)} MAE and {mean_squared_error(test_values, sarima_pred)**0.5} RMSE.')

                    except:
                        print('problem!')
                        raise

    print()
    print(f'The final model for {feature} is SARIMAX(2, 0, 2)x({final_P}, {final_D}, {final_Q}, {final_S}).')
    print()

# %%
five_features
# Out:
# ['danceability', 'mode', 'acousticness', 'valence', 'tempo']

# %%
for feature in five_features: 
    find_sarima_parameters(it_rw_18, feature, arima_param_df_18)
# Out:
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.007984165432778712 MAE and 0.00944698202598367 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.007984167629510175 MAE and 0.00944698135425775 RMSE.
# Checking (0, 0, 2, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.0079841676380475 MAE and 0.009446981354522085 RMSE.
# Checking (0, 0, 3, 48) at 1 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.007984167644560137 MAE and 0.009446981353715802 RMSE.
# Checking (1, 0, 0, 48) at 4 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.007984163218706809 MAE and 0.009446982698023174 RMSE.
# Checking (1, 0, 1, 48) at 5 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.00798416542584568 MAE and 0.009446982025665573 RMSE.
# Checking (1, 0, 2, 48) at 6 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.007984165420891354 MAE and 0.009446982025660626 RMSE.
# Checking (1, 0, 3, 48) at 7 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.007984165418996114 MAE and 0.009446982024631751 RMSE.
# Checking (2, 0, 0, 48) at 10 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.007984163212982098 MAE and 0.009446982696829427 RMSE.
# Checking (2, 0, 1, 48) at 11 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.007984165428111067 MAE and 0.009446982026051508 RMSE.
# Checking (2, 0, 2, 48) at 14 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.00798416543559175 MAE and 0.009446982025233265 RMSE.
# Checking (2, 0, 3, 48) at 16 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.007984165431929858 MAE and 0.00944698202639745 RMSE.
# Checking (3, 0, 0, 48) at 20 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.007984163228073115 MAE and 0.009446982696611407 RMSE.
# Checking (3, 0, 1, 48) at 23 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.00798416541832252 MAE and 0.009446982024845186 RMSE.
# Checking (3, 0, 2, 48) at 26 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.00798416541916589 MAE and 0.009446982026212235 RMSE.
# Checking (3, 0, 3, 48) at 30 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.007984165414888422 MAE and 0.00944698202588459 RMSE.
# Checking (0, 1, 0, 48) at 35 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (0, 1, 1, 48) at 35 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (0, 1, 2, 48) at 35 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (0, 1, 3, 48) at 36 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (1, 1, 0, 48) at 37 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (1, 1, 1, 48) at 37 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (1, 1, 2, 48) at 37 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (1, 1, 3, 48) at 38 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (2, 1, 0, 48) at 39 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (2, 1, 1, 48) at 40 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (2, 1, 2, 48) at 40 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (2, 1, 3, 48) at 41 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (3, 1, 0, 48) at 43 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (3, 1, 1, 48) at 44 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (3, 1, 2, 48) at 46 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (3, 1, 3, 48) at 47 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 48) model with 0.2517035456267993 MAE and 0.28041700942677 RMSE.
# Checking (0, 0, 0, 49) at 49 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 49) model with 0.007984165432778712 MAE and 0.00944698202598367 RMSE.
# Checking (0, 0, 1, 49) at 49 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 49) model with 0.007984166637104972 MAE and 0.009446982820814454 RMSE.
# Checking (0, 0, 2, 49) at 49 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 49) model with 0.00798416663302024 MAE and 0.009446982820358845 RMSE.
# Checking (0, 0, 3, 49) at 50 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 49) model with 0.007984166642573554 MAE and 0.009446982821773347 RMSE.
# Checking (1, 0, 0, 49) at 53 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 49) model with 0.007984164229634882 MAE and 0.009446981231431022 RMSE.
# Checking (1, 0, 1, 49) at 53 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 49) model with 0.007984165419100898 MAE and 0.009446982026275981 RMSE.
# Checking (1, 0, 2, 49) at 53 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 49) model with 0.00798416542415612 MAE and 0.009446982024897722 RMSE.
# Checking (1, 0, 3, 49) at 54 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 49) model with 0.007984165433008682 MAE and 0.009446982025988496 RMSE.
# Checking (2, 0, 0, 49) at 61 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 49) model with 0.007984164220412615 MAE and 0.009446981229838542 RMSE.
# Checking (2, 0, 1, 49) at 63 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 49) model with 0.007984165429715006 MAE and 0.009446982025938518 RMSE.
# Checking (2, 0, 2, 49) at 70 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 49) model with 0.007984165421609579 MAE and 0.009446982025506936 RMSE.
# Checking (2, 0, 3, 49) at 73 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 49) model with 0.007984165421836952 MAE and 0.00944698202581717 RMSE.
# Checking (3, 0, 0, 49) at 77 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 49) model with 0.007984164208836252 MAE and 0.009446981230448416 RMSE.
# Checking (3, 0, 1, 49) at 80 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 49) model with 0.007984165421399347 MAE and 0.009446982025369078 RMSE.
# Checking (3, 0, 2, 49) at 85 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 49) model with 0.007984165426665624 MAE and 0.009446982026120964 RMSE.
# Checking (3, 0, 3, 49) at 92 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 49) model with 0.007984165425269451 MAE and 0.009446982025647855 RMSE.
# Checking (0, 1, 0, 49) at 98 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (0, 1, 1, 49) at 98 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (0, 1, 2, 49) at 98 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (0, 1, 3, 49) at 98 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (1, 1, 0, 49) at 99 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (1, 1, 1, 49) at 100 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (1, 1, 2, 49) at 100 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (1, 1, 3, 49) at 100 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (2, 1, 0, 49) at 102 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (2, 1, 1, 49) at 102 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (2, 1, 2, 49) at 103 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (2, 1, 3, 49) at 104 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (3, 1, 0, 49) at 106 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (3, 1, 1, 49) at 107 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (3, 1, 2, 49) at 109 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (3, 1, 3, 49) at 110 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 0.17937008779152772 MAE and 0.22588349014691742 RMSE.
# Checking (0, 0, 0, 50) at 113 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 0.007984165432778712 MAE and 0.00944698202598367 RMSE.
# Checking (0, 0, 1, 50) at 113 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 0.007984164915221203 MAE and 0.009446982014987195 RMSE.
# Checking (0, 0, 2, 50) at 113 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 0.007984164907079695 MAE and 0.009446982014655212 RMSE.
# Checking (0, 0, 3, 50) at 114 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 0.007984164911118063 MAE and 0.009446982014827509 RMSE.
# Checking (1, 0, 0, 50) at 116 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 0.007984165940397237 MAE and 0.009446982036563722 RMSE.
# Checking (1, 0, 1, 50) at 117 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 0.007984165416546386 MAE and 0.009446982025319592 RMSE.
# Checking (1, 0, 2, 50) at 117 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 0.00798416541290874 MAE and 0.009446982025171935 RMSE.
# Checking (1, 0, 3, 50) at 118 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 0.00798416542610474 MAE and 0.009446982025707285 RMSE.
# Checking (2, 0, 0, 50) at 121 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 0.007984165944278842 MAE and 0.009446982036719615 RMSE.
# Checking (2, 0, 1, 50) at 122 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 0.007984165421322853 MAE and 0.009446982025517768 RMSE.
# Checking (2, 0, 2, 50) at 124 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 0.007984165412541077 MAE and 0.0094469820251612 RMSE.
# Checking (2, 0, 3, 50) at 126 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 0.007984165417193512 MAE and 0.009446982025344957 RMSE.
# Checking (3, 0, 0, 50) at 132 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 0.007984165943799536 MAE and 0.009446982036707775 RMSE.
# Checking (3, 0, 1, 50) at 136 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 0.007984165416995093 MAE and 0.009446982025333799 RMSE.
# Checking (3, 0, 2, 50) at 140 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 0.00798416543715148 MAE and 0.009446982026162424 RMSE.
# Checking (3, 0, 3, 50) at 145 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 0.007984165417555023 MAE and 0.009446982025349328 RMSE.
# Checking (0, 1, 0, 50) at 151 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (0, 1, 1, 50) at 151 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (0, 1, 2, 50) at 151 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (0, 1, 3, 50) at 151 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (1, 1, 0, 50) at 153 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (1, 1, 1, 50) at 153 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (1, 1, 2, 50) at 153 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (1, 1, 3, 50) at 154 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (2, 1, 0, 50) at 155 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (2, 1, 1, 50) at 156 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (2, 1, 2, 50) at 157 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (2, 1, 3, 50) at 158 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (3, 1, 0, 50) at 159 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (3, 1, 1, 50) at 161 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (3, 1, 2, 50) at 164 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (3, 1, 3, 50) at 166 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 0.11625777281339955 MAE and 0.17368286021847745 RMSE.
# Checking (0, 0, 0, 51) at 168 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 0.007984165432778712 MAE and 0.00944698202598367 RMSE.
# Checking (0, 0, 1, 51) at 168 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 0.007984165181055491 MAE and 0.009446981924374114 RMSE.
# Checking (0, 0, 2, 51) at 168 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 0.007984165181039038 MAE and 0.00944698192436967 RMSE.
# Checking (0, 0, 3, 51) at 169 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 0.007984165164448376 MAE and 0.009446981923646007 RMSE.
# Checking (1, 0, 0, 51) at 172 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 0.007984165673668709 MAE and 0.00944698212708404 RMSE.
# Checking (1, 0, 1, 51) at 172 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 0.007984165412218113 MAE and 0.009446982025020569 RMSE.
# Checking (1, 0, 2, 51) at 172 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 0.007984165412830691 MAE and 0.00944698202515184 RMSE.
# Checking (1, 0, 3, 51) at 173 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 0.00798416542966116 MAE and 0.00944698202583598 RMSE.
# Checking (2, 0, 0, 51) at 177 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 0.007984165673994204 MAE and 0.009446982127050049 RMSE.
# Checking (2, 0, 1, 51) at 178 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 0.00798416542553244 MAE and 0.00944698202576072 RMSE.
# Checking (2, 0, 2, 51) at 180 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 0.007984165433085088 MAE and 0.009446982025982322 RMSE.
# Checking (2, 0, 3, 51) at 182 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 0.007984165417220579 MAE and 0.009446982025366282 RMSE.
# Checking (3, 0, 0, 51) at 187 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 0.007984165673824007 MAE and 0.009446982127243276 RMSE.
# Checking (3, 0, 1, 51) at 192 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 0.007984165425197576 MAE and 0.009446982025760197 RMSE.
# Checking (3, 0, 2, 51) at 197 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 0.007984165417220112 MAE and 0.009446982025379566 RMSE.
# Checking (3, 0, 3, 51) at 203 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 0.007984165429292344 MAE and 0.009446982025853453 RMSE.
# Checking (0, 1, 0, 51) at 209 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (0, 1, 1, 51) at 209 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (0, 1, 2, 51) at 209 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (0, 1, 3, 51) at 210 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (1, 1, 0, 51) at 211 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (1, 1, 1, 51) at 211 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (1, 1, 2, 51) at 212 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (1, 1, 3, 51) at 213 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (2, 1, 0, 51) at 215 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (2, 1, 1, 51) at 216 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (2, 1, 2, 51) at 216 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (2, 1, 3, 51) at 217 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (3, 1, 0, 51) at 219 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (3, 1, 1, 51) at 220 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (3, 1, 2, 51) at 222 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (3, 1, 3, 51) at 224 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.06815002926384232 MAE and 0.12953017272669354 RMSE.
# Checking (0, 0, 0, 52) at 226 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.007984165432778712 MAE and 0.00944698202598367 RMSE.
# Checking (0, 0, 1, 52) at 226 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.007984165421758106 MAE and 0.009446982025532215 RMSE.
# Checking (0, 0, 2, 52) at 227 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.00798416543004803 MAE and 0.009446982025871808 RMSE.
# Checking (0, 0, 3, 52) at 228 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.007984165433450485 MAE and 0.00944698202601119 RMSE.
# Checking (1, 0, 0, 52) at 232 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.00798416541763929 MAE and 0.009446982025363487 RMSE.
# Checking (1, 0, 1, 52) at 232 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.007984165421485234 MAE and 0.009446982025521036 RMSE.
# Checking (1, 0, 2, 52) at 232 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.007984165408279731 MAE and 0.009446982024980075 RMSE.
# Checking (1, 0, 3, 52) at 234 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.00798416542921856 MAE and 0.00944698202583783 RMSE.
# Checking (2, 0, 0, 52) at 239 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.007984165437236856 MAE and 0.009446982026166296 RMSE.
# Checking (2, 0, 1, 52) at 241 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.007984165421109735 MAE and 0.009446982025505654 RMSE.
# Checking (2, 0, 2, 52) at 242 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.007984165404381138 MAE and 0.009446982024820371 RMSE.
# Checking (2, 0, 3, 52) at 244 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.007984165416552048 MAE and 0.00944698202531895 RMSE.
# Checking (3, 0, 0, 52) at 249 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.007984165436484659 MAE and 0.009446982026135482 RMSE.
# Checking (3, 0, 1, 52) at 254 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.007984165417716692 MAE and 0.009446982025366658 RMSE.
# Checking (3, 0, 2, 52) at 260 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.007984165425461588 MAE and 0.009446982025683925 RMSE.
# Checking (3, 0, 3, 52) at 265 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.007984165416951416 MAE and 0.00944698202533531 RMSE.
# Checking (0, 1, 0, 52) at 272 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (0, 1, 1, 52) at 272 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (0, 1, 2, 52) at 272 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (0, 1, 3, 52) at 273 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (1, 1, 0, 52) at 274 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (1, 1, 1, 52) at 275 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (1, 1, 2, 52) at 275 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (1, 1, 3, 52) at 276 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (2, 1, 0, 52) at 278 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (2, 1, 1, 52) at 279 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (2, 1, 2, 52) at 279 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (2, 1, 3, 52) at 280 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (3, 1, 0, 52) at 282 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (3, 1, 1, 52) at 285 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (3, 1, 2, 52) at 286 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
# Checking (3, 1, 3, 52) at 288 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.011354857142856578 MAE and 0.01255385609512585 RMSE.
#
# The final model for danceability is SARIMAX(2, 0, 2)x(2, 0, 0, 48).
#
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.042422040978769206 MAE and 0.049463884434573446 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.05242907368514005 MAE and 0.060408177591665224 RMSE.
# Checking (0, 0, 2, 48) at 1 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.05361907638202275 MAE and 0.061743725739079144 RMSE.
# Checking (0, 0, 3, 48) at 9 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.05317882865694048 MAE and 0.06127856508679465 RMSE.
# Checking (1, 0, 0, 48) at 34 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.06020482630339963 MAE and 0.06958708424452789 RMSE.
# Checking (1, 0, 1, 48) at 35 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.05948320023999778 MAE and 0.06867728837113184 RMSE.
# Checking (1, 0, 2, 48) at 37 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.059632768979944406 MAE and 0.06884162954385414 RMSE.
# Checking (1, 0, 3, 48) at 41 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.05926680606902588 MAE and 0.06847385128889522 RMSE.
# Checking (2, 0, 0, 48) at 57 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.060487527117243436 MAE and 0.06990614599435045 RMSE.
# Checking (2, 0, 1, 48) at 63 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.0593146202118537 MAE and 0.06850295163402854 RMSE.
# Checking (2, 0, 2, 48) at 69 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.05975210583055555 MAE and 0.06894715224437213 RMSE.
# Checking (2, 0, 3, 48) at 76 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.059373638103735395 MAE and 0.06863072977921214 RMSE.
# Checking (3, 0, 0, 48) at 105 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.06075137380438458 MAE and 0.07017960559117868 RMSE.
# Checking (3, 0, 1, 48) at 126 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.058977098518542645 MAE and 0.06804905505778573 RMSE.
# Checking (3, 0, 2, 48) at 151 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.05879550869919285 MAE and 0.06781829285836273 RMSE.
# Checking (3, 0, 3, 48) at 179 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.05949047378347572 MAE and 0.06867546160298882 RMSE.
# Checking (0, 1, 0, 48) at 216 seconds.
# problem!
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-78-ccbaece5ed65> in <module>
#       1 for feature in five_features:
# ----> 2     find_sarima_parameters(it_rw_18, feature, arima_param_df_18)
#
# <ipython-input-76-75307609aae9> in find_sarima_parameters(df, feature, param_df, n_rows)
#      21                     print(f'Checking ({P}, {D}, {Q}, {S}) at {round(time.time() - t0)} seconds.')
#      22                     try:
# ---> 23                         sarima = SARIMAX(endog = train_values,
#      24                                          order = order,
#      25                                          seasonal_order = (P, D, Q, S)).fit()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     688                 flags['hessian_method'] = optim_hessian
#     689             fargs = (flags,)
# --> 690             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     691                                                fargs=fargs,
#     692                                                maxiter=maxiter,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     517         warn_convergence = kwargs.pop('warn_convergence', True)
#     518         optimizer = Optimizer()
# --> 519         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     520                                                        fargs, kwargs,
#     521                                                        hessian=hess,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     222
#     223         func = fit_funcs[method]
# --> 224         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     225                             disp=disp, maxiter=maxiter, callback=callback,
#     226                             retall=retall, full_output=full_output,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     627         func = f
#     628
# --> 629     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     630                                      callback=callback, args=fargs,
#     631                                      bounds=bounds, disp=disp,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py in f(params, *args)
#     499
#     500         def f(params, *args):
# --> 501             return -self.loglike(params, *args) / nobs
#     502
#     503         if method == 'newton':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     923             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     924
# --> 925         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     926
#     927         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     981         kwargs.setdefault('conserve_memory',
#     982                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983         kfilter = self._filter(**kwargs)
#     984         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                         self.loglikelihood_burn)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     901
#     902         # Initialize the state
# --> 903         self._initialize_state(prefix=prefix, complex_step=complex_step)
#     904
#     905         # Run the filter
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/representation.py in _initialize_state(self, prefix, complex_step)
#     983             if not self.initialization.initialized:
#     984                 raise RuntimeError('Initialization is incomplete.')
# --> 985             self._statespaces[prefix].initialize(self.initialization,
#     986                                                  complex_step=complex_step)
#     987         else:
#
# statsmodels/tsa/statespace/_representation.pyx in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# statsmodels/tsa/statespace/_representation.pyx in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# statsmodels/tsa/statespace/_initialization.pyx in statsmodels.tsa.statespace._initialization.dInitialization.initialize()
#
# statsmodels/tsa/statespace/_initialization.pyx in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov()
#
# statsmodels/tsa/statespace/_tools.pyx in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov()
#
# LinAlgError: Schur decomposition solver error.

# %% [markdown]
# Because of `linalgerror` while trying to run `find_sarima_parameters` on 2018 Italy data (`it_rw_18`) I will use the same `seasonal_order` for each the audio as was determined by the 2017 data (`it_rw_18`).

# %% [markdown]
# Results from above for 2017 data:
# + The final model for danceability is SARIMAX(2, 0, 2)x(3, 0, 0, 48).
# + The final model for mode is SARIMAX(2, 0, 2)x(1, 0, 1, 52).
# + The final model for acousticness is SARIMAX(2, 0, 2)x(1, 0, 2, 48).
# + The final model for valence is SARIMAX(2, 0, 2)x(0, 0, 1, 49).
# + The final model for tempo is SARIMAX(2, 0, 2)x(2, 0, 0, 49).

# %% [markdown]
# #### _Adding Seasonal Orders to `param_df`_

# %% [markdown]
# citation: converting string to tuple https://www.geeksforgeeks.org/python-convert-string-to-tuple/

# %%
arima_param_df_18.loc[arima_param_df_18['audio_feature'] == 'danceability', 'seasonal_order'] = '3, 0, 0, 48'
arima_param_df_18.loc[arima_param_df_18['audio_feature'] == 'mode', 'seasonal_order'] = '1, 0, 1, 52'
arima_param_df_18.loc[arima_param_df_18['audio_feature'] == 'acousticness', 'seasonal_order'] = '1, 0, 2, 48'
arima_param_df_18.loc[arima_param_df_18['audio_feature'] == 'valence', 'seasonal_order'] = '0, 0, 1, 49'
arima_param_df_18.loc[arima_param_df_18['audio_feature'] == 'tempo', 'seasonal_order'] = '2, 0, 0, 49'

# %% [markdown]
# #### _Updated `arima_param_df_18`_

# %%
arima_param_df_18
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       0       1  (0, 1, 1)  ARIMA(0,1,1)
# 1          mode          1       3       0  (3, 1, 0)  ARIMA(3,1,0)
# 2  acousticness          1       0       2  (0, 1, 2)  ARIMA(0,1,2)
# 3       valence          1       2       4  (2, 1, 4)  ARIMA(2,1,4)
# 4         tempo          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order
# 0 -217.460539          0.028161         0.010787    3, 0, 0, 48
# 1 -146.889516          0.053561         0.042752    1, 0, 1, 52
# 2 -184.369110          0.036351         0.057268    1, 0, 2, 48
# 3 -191.967291          0.036157         0.040172    0, 0, 1, 49
# 4  246.974241          2.545530         3.022669    2, 0, 0, 49

# %% [markdown]
# #### _Function for SARIMA w/ seasonal components, no exogenous variables:_

# %%
def sarima_predict_plot_seasonal(df, feature, year, param_df, title='title', figsize=(15,5), order=None, d=None, seasonal_order=None, ci=True):
  
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    # find order from arima parameters dataframe 
    if order is None:
        order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
    
    # find seasonal order from arima parameters dataframe 
    if seasonal_order is None: 
        sea_string = param_df.loc[param_df['audio_feature'] == feature, 'seasonal_order'].iloc[0]
        seasonal_order = tuple(map(int, sea_string.split(', '))) 
    print(f'seasonal order = {seasonal_order}')
    
    try: 

        # instantiate and fit SARIMAX model 
        sarima = SARIMAX(endog=train, order=order, seasonal_order=seasonal_order).fit()

        # get predictions for train and test sets 
        preds_train = sarima.predict(start=train.index[d], end=train.index[-1], typ='levels')
        preds_test = sarima.predict(start=test.index[0], end=test.index[-1], typ='levels')

        # calculate and print RMSE for train and test setes 
        train_rmse = mean_squared_error(train[d::], preds_train)**0.5
        print(f'{feature.capitalize()} train RMSE ({year}) - SARIMA({order}): {train_rmse}')

        test_rmse = mean_squared_error(test, preds_test)**0.5
        print(f'{feature.capitalize()} test RMSE ({year}) - SARIMA({order}): {test_rmse}')    

        # add RMSEs to arima parameters dataframe 
        param_df.loc[param_df['audio_feature'] == feature, 'sarima_train_rmse'] = train_rmse    
        param_df.loc[param_df['audio_feature'] == feature, 'sarima_test_rmse'] = test_rmse

        # calculate residuals
        # residuals = test - preds_test

        # set up plot
        plt.figure(figsize=figsize)

        # plot training data 
        plt.plot(train, color='blue')

        # plot testing data 
        plt.plot(test.index, test, color='orange')

        # plot predicted values for test set 
        plt.plot(test.index, preds_test, color='green')

        # add line for the baseline model (mean value of feature)
        plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')

        # plot confidence interval 
        if ci:
            ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
            plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 

        # make plot with title! 
        plt.title(title, fontsize=16)
        plt.show() ; 
        
    
    except ValueError as ve:
        print(ve)
        pass

# %%
for feature in five_features:
    sarima_predict_plot_seasonal(it_rw_18, feature, 2018, arima_param_df_18, title=f'Mean {feature.capitalize()} Score, Italy 2018 (SARIMA w/o exog variables)')
# Out:
# d = 1
# order = (0, 1, 1)
# seasonal order = (3, 0, 0, 48)
# Danceability train RMSE (2018) - SARIMA((0, 1, 1)): 0.028235980451850932
# Danceability test RMSE (2018) - SARIMA((0, 1, 1)): 0.009446982696611407
# d = 1
# order = (3, 1, 0)
# seasonal order = (1, 0, 1, 52)
# Mode train RMSE (2018) - SARIMA((3, 1, 0)): 0.05366373069312147
# Mode test RMSE (2018) - SARIMA((3, 1, 0)): 0.05203894653955396
# d = 1
# order = (0, 1, 2)
# seasonal order = (1, 0, 2, 48)
# Acousticness train RMSE (2018) - SARIMA((0, 1, 2)): 0.036374265288011735
# Acousticness test RMSE (2018) - SARIMA((0, 1, 2)): 0.060643236332092065
# d = 1
# order = (2, 1, 4)
# seasonal order = (0, 0, 1, 49)
# Valence train RMSE (2018) - SARIMA((2, 1, 4)): 0.03280168646918084
# Valence test RMSE (2018) - SARIMA((2, 1, 4)): 0.031699263515060555
# d = 1
# order = (2, 1, 1)
# seasonal order = (2, 0, 0, 49)
# Tempo train RMSE (2018) - SARIMA((2, 1, 1)): 2.552847963660704
# Tempo test RMSE (2018) - SARIMA((2, 1, 1)): 7.328389632627043

# %% [markdown]
# #### _Updated `arima_param_df_18`_

# %%
arima_param_df_18
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       0       1  (0, 1, 1)  ARIMA(0,1,1)
# 1          mode          1       3       0  (3, 1, 0)  ARIMA(3,1,0)
# 2  acousticness          1       0       2  (0, 1, 2)  ARIMA(0,1,2)
# 3       valence          1       2       4  (2, 1, 4)  ARIMA(2,1,4)
# 4         tempo          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -217.460539          0.028161         0.010787    3, 0, 0, 48
# 1 -146.889516          0.053561         0.042752    1, 0, 1, 52
# 2 -184.369110          0.036351         0.057268    1, 0, 2, 48
# 3 -191.967291          0.036157         0.040172    0, 0, 1, 49
# 4  246.974241          2.545530         3.022669    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse
# 0           0.028236          0.009447
# 1           0.053664          0.052039
# 2           0.036374          0.060643
# 3           0.032802          0.031699
# 4           2.552848          7.328390

# %% [markdown]
# #### _Incorporating Exogenous Variables in SARIMAX models_

# %%
def sarima_predict_plot_exog(df, feature, year, param_df, exog_var, title='title', figsize=(15,5), order=None, d=None, seasonal_order=None, ci=True):

    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    # find order from arima parameters dataframe 
    if order is None:
        order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
    
    # find seasonal order from arima parameters dataframe 
    if seasonal_order is None: 
        sea_string = param_df.loc[param_df['audio_feature'] == feature, 'seasonal_order'].iloc[0]
        seasonal_order = tuple(map(int, sea_string.split(', '))) 
    print(f'seasonal order = {seasonal_order}')
    
    # reshape exogenous features to pass to the model 
    exog = df.loc[:, exog_var]   
   
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
  
    try:
        # instantiate and fit SARIMAX model 
        sarima = SARIMAX(endog=train, exog=exog[0:n_rows], order=order, seasonal_order=seasonal_order).fit()

        # get predictions for train and test sets 
        preds_train = sarima.predict(start=train.index[d], end=train.index[-1], typ='levels', exog=exog[0:n_rows])
        preds_test = sarima.predict(start=test.index[0], end=test.index[-1], typ='levels', exog=exog[n_rows:])

        # calculate and print RMSE for train and test setes 
        train_rmse = mean_squared_error(train[d::], preds_train)**0.5
        print(f'{feature.capitalize()} train RMSE ({year}) - SARIMAX({seasonal_order}) w/ exogenous variables: {train_rmse}')

        test_rmse = mean_squared_error(test, preds_test)**0.5
        print(f'{feature.capitalize()} test RMSE ({year}) - SARIMAX({seasonal_order}) w/ exogenous variables: {test_rmse}')    

        # add RMSEs to arima parameters dataframe 
        param_df.loc[param_df['audio_feature'] == feature, 'exog_train_rmse'] = train_rmse    
        param_df.loc[param_df['audio_feature'] == feature, 'exog_test_rmse'] = test_rmse

        # calculate residuals
        # residuals = test - preds_test

        # set up plot
        plt.figure(figsize=figsize)

        # plot training data 
        plt.plot(train, color='blue')

        # plot testing data 
        plt.plot(test.index, test, color='orange')

        # plot predicted values for test set 
        plt.plot(test.index, preds_test, color='green')

        # add line for the baseline model (mean value of feature)
        plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')

        # plot confidence interval 
        if ci:
            ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
            plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 

        # make plot with title! 
        plt.title(title, fontsize=16)
        plt.show() ; 
        
    except ValueError as ve:
        print(ve)
        pass

# %% [markdown]
# _Identifying exogenous variables for each of the five main features, which for each of them is the other four audio features_

# %%
five_features = ['danceability', 'mode', 'acousticness', 'valence', 'tempo']

exog_danceability = ['mode', 'acousticness', 'valence', 'tempo']
exog_mode = ['danceability', 'acousticness', 'valence', 'tempo']
exog_acousticness = ['danceability', 'mode', 'valence', 'tempo']
exog_valence = ['danceability', 'mode', 'acousticness', 'tempo']
exog_tempo = ['danceability', 'mode', 'acousticness', 'valence']

# %%
sarima_predict_plot_exog(it_rw_18, 'danceability', 2018, arima_param_df_18, exog_var=exog_danceability, title=f'Mean Danceability Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (0, 1, 1)
# seasonal order = (3, 0, 0, 48)
# Danceability train RMSE (2018) - SARIMAX((3, 0, 0, 48)) w/ exogenous variables: 0.02113170441657163
# Danceability test RMSE (2018) - SARIMAX((3, 0, 0, 48)) w/ exogenous variables: 0.017356817337586507

# %%
# for feature in five_features:
#     sarima_predict_plot_exog(it_rw_17, feature, 2017, exog_var=f'exog_{feature}', title=f'Mean {feature} Score, Italy 2017 (SARIMA w/ exog variables)')

# %%
sarima_predict_plot_exog(it_rw_18, 'mode', 2018, arima_param_df_18, exog_var=exog_mode, title=f'Mean Mode Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (3, 1, 0)
# seasonal order = (1, 0, 1, 52)
# Mode train RMSE (2018) - SARIMAX((1, 0, 1, 52)) w/ exogenous variables: 0.04891683300186803
# Mode test RMSE (2018) - SARIMAX((1, 0, 1, 52)) w/ exogenous variables: 0.05377603463339627

# %%
sarima_predict_plot_exog(it_rw_18, 'acousticness', 2018, arima_param_df_18, exog_var=exog_acousticness, title=f'Mean Acousticness Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (0, 1, 2)
# seasonal order = (1, 0, 2, 48)
# Acousticness train RMSE (2018) - SARIMAX((1, 0, 2, 48)) w/ exogenous variables: 0.0334902033369984
# Acousticness test RMSE (2018) - SARIMAX((1, 0, 2, 48)) w/ exogenous variables: 0.05256163120685573

# %%
sarima_predict_plot_exog(it_rw_18, 'valence', 2018, arima_param_df_18, exog_var=exog_valence, title=f'Mean Valence Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (2, 1, 4)
# seasonal order = (0, 0, 1, 49)
# Valence train RMSE (2018) - SARIMAX((0, 0, 1, 49)) w/ exogenous variables: 0.02517707755017696
# Valence test RMSE (2018) - SARIMAX((0, 0, 1, 49)) w/ exogenous variables: 0.026906063730887452

# %%
sarima_predict_plot_exog(it_rw_18, 'tempo', 2018, arima_param_df_18, exog_var=exog_tempo, title=f'Mean Tempo Score, Italy 2017 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (2, 1, 1)
# seasonal order = (2, 0, 0, 49)
# Tempo train RMSE (2018) - SARIMAX((2, 0, 0, 49)) w/ exogenous variables: 2.3411517686755934
# Tempo test RMSE (2018) - SARIMAX((2, 0, 0, 49)) w/ exogenous variables: 2.9713771039902763

# %% [markdown]
# #### _Updated `arima_param_df_18`_

# %%
arima_param_df_18
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       0       1  (0, 1, 1)  ARIMA(0,1,1)
# 1          mode          1       3       0  (3, 1, 0)  ARIMA(3,1,0)
# 2  acousticness          1       0       2  (0, 1, 2)  ARIMA(0,1,2)
# 3       valence          1       2       4  (2, 1, 4)  ARIMA(2,1,4)
# 4         tempo          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -217.460539          0.028161         0.010787    3, 0, 0, 48
# 1 -146.889516          0.053561         0.042752    1, 0, 1, 52
# 2 -184.369110          0.036351         0.057268    1, 0, 2, 48
# 3 -191.967291          0.036157         0.040172    0, 0, 1, 49
# 4  246.974241          2.545530         3.022669    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse  exog_train_rmse  exog_test_rmse
# 0           0.028236          0.009447         0.021132        0.017357
# 1           0.053664          0.052039         0.048917        0.053776
# 2           0.036374          0.060643         0.033490        0.052562
# 3           0.032802          0.031699         0.025177        0.026906
# 4           2.552848          7.328390         2.341152        2.971377
