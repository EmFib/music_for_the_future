# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

import json

from fycharts.SpotifyCharts import SpotifyCharts
import sqlalchemy

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from datetime import datetime
from sklearn.model_selection import train_test_split

import statsmodels.api as sm

# We are required to do this in order to avoid "FutureWarning" issues.
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller  

from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %matplotlib inline

import warnings
warnings.simplefilter(action="ignore")

# %% [markdown]
# # Reading in data

# %%
italy_17_19 = pd.read_pickle('../data/it_17_19_v50_feat.pkl')
spain_17_19 = pd.read_pickle('../data/sp_17_19_v50_feat.pkl')
greece_17_19 = pd.read_pickle('../data/gr_17_19_v50_feat.pkl')

italy_20 = pd.read_pickle('../data/it_20_v50_feat.pkl')
spain_20 = pd.read_pickle('../data/sp_20_v50_feat.pkl')
greece_20 = pd.read_pickle('../data/gr_20_v50_feat.pkl')

# %%
spain_20.tail(2)
# Out:
#             Position                Track Name               Artist region  \
# date
# 2021-02-13        49    La Luz - A COLORS SHOW    María José Llergo     es
# 2021-02-13        50  Boku no Sensou - TV Size  Shinsei Kamattechan     es
#
#                         spotify_id  danceability  energy  key  loudness  mode  \
# date
# 2021-02-13  5jRnVQbjB6qgN3MARS4xw7         0.722   0.357    9   -10.487     0
# 2021-02-13  3tRPfCFAEv6wWyQO0YnGGV         0.447   0.891    9    -4.776     1
#
#             speechiness  acousticness  instrumentalness  liveness  valence  \
# date
# 2021-02-13       0.0996       0.81400          0.155000    0.0863    0.641
# 2021-02-13       0.0788       0.00447          0.000905    0.3900    0.517
#
#               tempo  duration_ms  time_signature
# date
# 2021-02-13  149.895       191599               4
# 2021-02-13  143.976        90960               4

# %% [markdown]
# # Preprocessing data

# %% [markdown]
# #### _Data for each country is split into different dataframes as different combinations and aggregations are needed for different functions._

# %% [markdown]
# **Resampling by month**
#
# _`rm` denotes resampling by month._

# %%
rm_italy_17_19 = italy_17_19.resample("M").mean()
rm_spain_17_19 = spain_17_19.resample("M").mean()
rm_greece_17_19 = greece_17_19.resample("M").mean()

rm_italy_20 = italy_20.resample("M").mean()
rm_spain_20 = spain_20.resample("M").mean()
rm_greece_20 = greece_20.resample("M").mean()

# %% [markdown]
# **Resampling by week**
#
# _`rw` denotes resampling by week._

# %%
rw_italy_17_19 = italy_17_19.resample("W").mean()
rw_spain_17_19 = spain_17_19.resample("W").mean()
rw_greece_17_19 = greece_17_19.resample("W").mean()

rw_italy_20 = italy_20.resample("W").mean()
rw_spain_20 = spain_20.resample("W").mean()
rw_greece_20 = greece_20.resample("W").mean()

# %% [markdown]
# #### Combining weekly resampled data for all years (2017-2020)

# %%
alltime_italy = pd.concat([italy_17_19, italy_20])
alltime_spain = pd.concat([spain_17_19, spain_20])
alltime_greece = pd.concat([greece_17_19, greece_20])

alltime_rw_italy = alltime_italy.resample("W").mean()
alltime_rw_spain = alltime_spain.resample("W").mean()
alltime_rw_greece = alltime_greece.resample("W").mean()

# %% [markdown]
# #### Splitting into dataframes for each year!

# %%
it_rw_17 = alltime_rw_italy[0:53]
it_rw_18 = alltime_rw_italy[53:105]
it_rw_19 = alltime_rw_italy[105:158]

# %%
it_rw_19.tail(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2019-12-29      25.5      0.666363  0.610831  6.125714 -7.189337  0.637143
# 2020-01-05      25.5      0.695900  0.643483  6.314286 -6.612169  0.634286
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2019-12-29     0.109331      0.278767          0.041290  0.171111  0.460510
# 2020-01-05     0.127259      0.225605          0.030068  0.184051  0.476149
#
#                  tempo    duration_ms  time_signature
# date
# 2019-12-29  117.949174  190365.777143        3.965714
# 2020-01-05  118.608006  188407.960000        3.962857

# %% [markdown]
# # Differencing Data for Stationarity

# %% [markdown]
# ### Augmented Dickey-Fuller test to estimate whether data are stationary.

# %%
audio_features = [
'danceability', 
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'energy']

# %%
# Code by Joseph Nelson! 

def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:3], index=['Test Statistic', 'p-value', 'lags_used'])
    return dfoutput

# %% [markdown]
# _Dickey-Fuller on original dataframes_

# %%
for feature in audio_features:
    print(f'Dickey-Fuller Interpretation for {feature}:\n{interpret_dftest(adfuller(it_rw_18[feature]))}')
# Out:
# Dickey-Fuller Interpretation for danceability:
# Test Statistic   -2.978150
# p-value           0.036986
# lags_used         1.000000
# dtype: float64
# Dickey-Fuller Interpretation for energy:
# Test Statistic   -3.24877
# p-value           0.01733
# lags_used         0.00000
# dtype: float64
# Dickey-Fuller Interpretation for key:
# Test Statistic   -3.469608
# p-value           0.008803
# lags_used         4.000000
# dtype: float64
# Dickey-Fuller Interpretation for loudness:
# Test Statistic   -3.003203
# p-value           0.034596
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for mode:
# Test Statistic   -4.432011
# p-value           0.000260
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for speechiness:
# Test Statistic    -1.736793
# p-value            0.412262
# lags_used         10.000000
# dtype: float64
# Dickey-Fuller Interpretation for acousticness:
# Test Statistic   -2.390354
# p-value           0.144477
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for instrumentalness:
# Test Statistic   -2.806893
# p-value           0.057296
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for liveness:
# Test Statistic   -2.267119
# p-value           0.182792
# lags_used         1.000000
# dtype: float64
# Dickey-Fuller Interpretation for valence:
# Test Statistic   -4.109533
# p-value           0.000934
# lags_used         0.000000
# dtype: float64
# Dickey-Fuller Interpretation for tempo:
# Test Statistic   -3.917986
# p-value           0.001906
# lags_used         0.000000
# dtype: float64

# %% [markdown]
# ### DataFrame with once-differenced data

# %%
lag_df_italy = alltime_rw_italy.copy()

# %%
for feature in audio_features: 
    lag_df_italy[f'{feature}_once_differenced'] = lag_df_italy[feature].diff(1).fillna(0)

# %%
lag_df_italy.tail(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2021-02-07      25.5      0.666561  0.634389  5.402857 -6.677991  0.680000
# 2021-02-14      25.5      0.671104  0.647343  5.516667 -6.842603  0.656667
#
#             speechiness  acousticness  instrumentalness  liveness  ...  \
# date                                                               ...
# 2021-02-07     0.109192      0.268234          0.035348  0.223654  ...
# 2021-02-14     0.120716      0.277941          0.054173  0.220087  ...
#
#             energy_once_differenced  key_once_differenced  \
# date
# 2021-02-07                 0.029374               0.18000
# 2021-02-14                 0.012955               0.11381
#
#             loudness_once_differenced  mode_once_differenced  \
# date
# 2021-02-07                   0.314663               0.031429
# 2021-02-14                  -0.164612              -0.023333
#
#             speechiness_once_differenced  acousticness_once_differenced  \
# date
# 2021-02-07                     -0.001159                      -0.073344
# 2021-02-14                      0.011523                       0.009707
#
#             instrumentalness_once_differenced  liveness_once_differenced  \
# date
# 2021-02-07                          -0.001695                   0.005719
# 2021-02-14                           0.018826                  -0.003567
#
#             valence_once_differenced  tempo_once_differenced
# date
# 2021-02-07                 -0.006398                3.285271
# 2021-02-14                  0.049983                1.041837
#
# [2 rows x 25 columns]

# %% [markdown]
# _Dickey-Fuller on lag dataframe_

# %%
for feature in audio_features:
    print(f'Dickey-Fuller Interpretation for {feature}, once-differenced:\n{interpret_dftest(adfuller(lag_df_italy[feature].diff(1).fillna(0)))}')
# Out:
# Dickey-Fuller Interpretation for danceability, once-differenced:
# Test Statistic   -9.142255e+00
# p-value           2.828632e-15
# lags_used         5.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for energy, once-differenced:
# Test Statistic   -6.782611e+00
# p-value           2.477455e-09
# lags_used         7.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for key, once-differenced:
# Test Statistic   -8.518281e+00
# p-value           1.118537e-13
# lags_used         7.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for loudness, once-differenced:
# Test Statistic   -7.002232e+00
# p-value           7.272028e-10
# lags_used         6.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for mode, once-differenced:
# Test Statistic   -9.845662e+00
# p-value           4.627101e-17
# lags_used         4.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for speechiness, once-differenced:
# Test Statistic   -8.291616e+00
# p-value           4.246658e-13
# lags_used         5.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for acousticness, once-differenced:
# Test Statistic   -1.160866e+01
# p-value           2.544491e-21
# lags_used         2.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for instrumentalness, once-differenced:
# Test Statistic   -7.471488e+00
# p-value           5.041115e-11
# lags_used         6.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for liveness, once-differenced:
# Test Statistic   -7.236294e+00
# p-value           1.935642e-10
# lags_used         8.000000e+00
# dtype: float64
# Dickey-Fuller Interpretation for valence, once-differenced:
# Test Statistic    -5.043085
# p-value            0.000018
# lags_used         12.000000
# dtype: float64
# Dickey-Fuller Interpretation for tempo, once-differenced:
# Test Statistic   -6.454214e+00
# p-value           1.497350e-08
# lags_used         1.400000e+01
# dtype: float64

# %% [markdown]
# _Checking that these are the same_

# %%
interpret_dftest(adfuller(lag_df_italy['energy_once_differenced']))
# Out:
# Test Statistic   -6.454214e+00
# p-value           1.497350e-08
# lags_used         1.400000e+01
# dtype: float64

# %%
interpret_dftest(adfuller(lag_df_italy['energy'].diff(1).fillna(0)))
# Out:
# Test Statistic   -6.454214e+00
# p-value           1.497350e-08
# lags_used         1.400000e+01
# dtype: float64

# %% [markdown]
# ### Using `ndiffs` to figure out how many orders of difference $d$ I need in oder to have stationarity

# %% [markdown]
# #### _Running `ndiff` and `p,d,q` functions just on 2019 Italy data instead of alltime Italy data; however I will just be checking it out; will leave the `ndiff_dict` and `ndiff_df` as is because that is use in models. Will use 2019 data to build the `ndiff_df` to see if this yields better results for this year._

# %%
from pmdarima.arima.utils import ndiffs

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ adf test: {ndiffs(alltime_italy[feature], test= "adf")}')
# Out:
# ndiffs for danceability stationarity w/ adf test: 0
# ndiffs for energy stationarity w/ adf test: 0
# ndiffs for key stationarity w/ adf test: 0
# ndiffs for loudness stationarity w/ adf test: 0
# ndiffs for mode stationarity w/ adf test: 0
# ndiffs for speechiness stationarity w/ adf test: 0
# ndiffs for acousticness stationarity w/ adf test: 0
# ndiffs for instrumentalness stationarity w/ adf test: 0
# ndiffs for liveness stationarity w/ adf test: 0
# ndiffs for valence stationarity w/ adf test: 0
# ndiffs for tempo stationarity w/ adf test: 0

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ adf test: {ndiffs(it_rw_19[feature], test= "adf")}')
# Out:
# ndiffs for danceability stationarity w/ adf test: 1
# ndiffs for energy stationarity w/ adf test: 1
# ndiffs for key stationarity w/ adf test: 1
# ndiffs for loudness stationarity w/ adf test: 1
# ndiffs for mode stationarity w/ adf test: 2
# ndiffs for speechiness stationarity w/ adf test: 1
# ndiffs for acousticness stationarity w/ adf test: 2
# ndiffs for instrumentalness stationarity w/ adf test: 1
# ndiffs for liveness stationarity w/ adf test: 1
# ndiffs for valence stationarity w/ adf test: 1
# ndiffs for tempo stationarity w/ adf test: 1

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ kpss test: {ndiffs(alltime_italy[feature])}')
# Out:
# ndiffs for danceability stationarity w/ kpss test: 1
# ndiffs for energy stationarity w/ kpss test: 1
# ndiffs for key stationarity w/ kpss test: 1
# ndiffs for loudness stationarity w/ kpss test: 1
# ndiffs for mode stationarity w/ kpss test: 1
# ndiffs for speechiness stationarity w/ kpss test: 1
# ndiffs for acousticness stationarity w/ kpss test: 1
# ndiffs for instrumentalness stationarity w/ kpss test: 1
# ndiffs for liveness stationarity w/ kpss test: 1
# ndiffs for valence stationarity w/ kpss test: 1
# ndiffs for tempo stationarity w/ kpss test: 1

# %%
for feature in audio_features:
    print(f'ndiffs for {feature} stationarity w/ kpss test: {ndiffs(it_rw_19[feature])}')
# Out:
# ndiffs for danceability stationarity w/ kpss test: 0
# ndiffs for energy stationarity w/ kpss test: 1
# ndiffs for key stationarity w/ kpss test: 1
# ndiffs for loudness stationarity w/ kpss test: 1
# ndiffs for mode stationarity w/ kpss test: 1
# ndiffs for speechiness stationarity w/ kpss test: 0
# ndiffs for acousticness stationarity w/ kpss test: 0
# ndiffs for instrumentalness stationarity w/ kpss test: 0
# ndiffs for liveness stationarity w/ kpss test: 0
# ndiffs for valence stationarity w/ kpss test: 0
# ndiffs for tempo stationarity w/ kpss test: 1

# %% [markdown]
# ### Finding `p`, `d`, and `q` values

# %% [markdown]
# _Using only the five audio features that are the most relevant or show some sort of pattern_

# %%
five_features = ['danceability', 'mode', 'acousticness', 'valence', 'energy']

# %% [markdown]
# _Building dataframe with `ndifffs` for stationarity for each feature_
#
# _This time using `it_rw_19` instead of `alltime_rw_italy`._

# %%
ndiff_dict = {
    'audio_feature':[],
    'ndiffs for stationarity':[]    
}

for feature in five_features:
    ndiff_dict['audio_feature'].append(feature)
    ndiff_dict['ndiffs for stationarity'].append(ndiffs(it_rw_19[feature], test= "adf"))

ndiff_df = pd.DataFrame(ndiff_dict)
ndiff_df
# Out:
#   audio_feature  ndiffs for stationarity
# 0  danceability                        1
# 1          mode                        2
# 2  acousticness                        2
# 3       valence                        1
# 4         tempo                        1

# %%
arima_dict_19 = {
    'audio_feature':[],
    'ndiffs(d)':[],
    'best_p':[],
    'best_q':[],
    'order':[],
    'ARIMA_model':[],
    'ARIMA_AIC':[]
}

def find_p_and_q(df, feature, arima_dict, n=6):
    
    train = df[feature][0:162]
    
    d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]

    # starting with large start AIC
    best_aic = 99 * (10 * 16)
    # creating variables to store best values ofd p and q 
    best_p = 0
    best_q = 0 

    # use nested for loop to iterate over values of p and q
    for p in range(n):

        for q in range(n):

            # insert try and and except statements
            try: 

                # fitting on ARIMA(p, 1, q) model 
                print(f'Attempting to fit ARIMA({p}, {d}, {q})')

                # instantiate ARIMA model
                arima = ARIMA(train, order=(p,d,q))

                # fit ARIMA model 
                model = arima.fit()

                # print out AIC for ARIMA(p, 1, q) model 
                print(f'For {feature}, the AIC for ARIMA({p},{d},{q}) is: {model.aic}')

                # Is this current model's AIC better than the OF best_aic? 
                if model.aic < best_aic:
                    # we want aic to be lower so we are setting a high aic and hoping for something lower 

                    # if it is, we overwrite the best_aic, best_p, and best_q
                    best_aic = model.aic
                    best_p = p 
                    best_q = q

            except:
                pass 

        order = (best_p, d, best_q)
    
    arima_dict['audio_feature'].append(feature)
    arima_dict['ndiffs(d)'].append(d)
    arima_dict['best_p'].append(best_p)
    arima_dict['best_q'].append(best_q)
    arima_dict['order'].append(order)
    arima_dict['ARIMA_model'].append(f'ARIMA({best_p},{d},{best_q})')
    arima_dict['ARIMA_AIC'].append(best_aic)

    print()
    print(f'{feature.upper()} MODEL FINISHED!')
    print(f'The model for {feature} that minimizes AIC on the training data is the ARIMA({best_p},{d},{best_q}).')
    print(f'The model has an aIC of {best_aic}.')
    print()

# %%
arima_dict_19
# Out:
# {'audio_feature': [],
#  'ndiffs(d)': [],
#  'best_p': [],
#  'best_q': [],
#  'order': [],
#  'ARIMA_model': [],
#  'ARIMA_AIC': []}

# %%
for feature in five_features:
    find_p_and_q(it_rw_19, feature, arima_dict_19)
# Out:
# Attempting to fit ARIMA(0, 1, 0)
# For danceability, the AIC for ARIMA(0,1,0) is: -270.9695108618981
# Attempting to fit ARIMA(0, 1, 1)
# For danceability, the AIC for ARIMA(0,1,1) is: -270.3370488579727
# Attempting to fit ARIMA(0, 1, 2)
# For danceability, the AIC for ARIMA(0,1,2) is: -268.66695046927464
# Attempting to fit ARIMA(0, 1, 3)
# For danceability, the AIC for ARIMA(0,1,3) is: -267.83224464657917
# Attempting to fit ARIMA(0, 1, 4)
# For danceability, the AIC for ARIMA(0,1,4) is: -266.225159275186
# Attempting to fit ARIMA(0, 1, 5)
# For danceability, the AIC for ARIMA(0,1,5) is: -267.7595910879961
# Attempting to fit ARIMA(1, 1, 0)
# For danceability, the AIC for ARIMA(1,1,0) is: -270.13342080415975
# Attempting to fit ARIMA(1, 1, 1)
# For danceability, the AIC for ARIMA(1,1,1) is: -271.8078318641607
# Attempting to fit ARIMA(1, 1, 2)
# For danceability, the AIC for ARIMA(1,1,2) is: -269.8464154808887
# Attempting to fit ARIMA(1, 1, 3)
# For danceability, the AIC for ARIMA(1,1,3) is: -266.92848156776665
# Attempting to fit ARIMA(1, 1, 4)
# For danceability, the AIC for ARIMA(1,1,4) is: -265.18774190906015
# Attempting to fit ARIMA(1, 1, 5)
# For danceability, the AIC for ARIMA(1,1,5) is: -266.4823857204025
# Attempting to fit ARIMA(2, 1, 0)
# For danceability, the AIC for ARIMA(2,1,0) is: -268.32097872820066
# Attempting to fit ARIMA(2, 1, 1)
# For danceability, the AIC for ARIMA(2,1,1) is: -269.85118569930626
# Attempting to fit ARIMA(2, 1, 2)
# For danceability, the AIC for ARIMA(2,1,2) is: -268.2674424716266
# Attempting to fit ARIMA(2, 1, 3)
# For danceability, the AIC for ARIMA(2,1,3) is: -265.76268098896435
# Attempting to fit ARIMA(2, 1, 4)
# For danceability, the AIC for ARIMA(2,1,4) is: -267.20091162199117
# Attempting to fit ARIMA(2, 1, 5)
# For danceability, the AIC for ARIMA(2,1,5) is: -264.83541239719966
# Attempting to fit ARIMA(3, 1, 0)
# For danceability, the AIC for ARIMA(3,1,0) is: -267.80347411923526
# Attempting to fit ARIMA(3, 1, 1)
# For danceability, the AIC for ARIMA(3,1,1) is: -266.30426620464834
# Attempting to fit ARIMA(3, 1, 2)
# For danceability, the AIC for ARIMA(3,1,2) is: -264.0434763224292
# Attempting to fit ARIMA(3, 1, 3)
# For danceability, the AIC for ARIMA(3,1,3) is: -265.0333398236063
# Attempting to fit ARIMA(3, 1, 4)
# For danceability, the AIC for ARIMA(3,1,4) is: -264.72977186876415
# Attempting to fit ARIMA(3, 1, 5)
# For danceability, the AIC for ARIMA(3,1,5) is: -261.55869102161535
# Attempting to fit ARIMA(4, 1, 0)
# For danceability, the AIC for ARIMA(4,1,0) is: -266.1673173078383
# Attempting to fit ARIMA(4, 1, 1)
# For danceability, the AIC for ARIMA(4,1,1) is: -264.36433201733587
# Attempting to fit ARIMA(4, 1, 2)
# For danceability, the AIC for ARIMA(4,1,2) is: -262.1056255811768
# Attempting to fit ARIMA(4, 1, 3)
# For danceability, the AIC for ARIMA(4,1,3) is: -263.42817595232725
# Attempting to fit ARIMA(4, 1, 4)
# For danceability, the AIC for ARIMA(4,1,4) is: -261.9833285949778
# Attempting to fit ARIMA(4, 1, 5)
# For danceability, the AIC for ARIMA(4,1,5) is: -260.1968281922143
# Attempting to fit ARIMA(5, 1, 0)
# For danceability, the AIC for ARIMA(5,1,0) is: -264.78958328572594
# Attempting to fit ARIMA(5, 1, 1)
# For danceability, the AIC for ARIMA(5,1,1) is: -265.8461693960013
# Attempting to fit ARIMA(5, 1, 2)
# For danceability, the AIC for ARIMA(5,1,2) is: -261.3785136373025
# Attempting to fit ARIMA(5, 1, 3)
# For danceability, the AIC for ARIMA(5,1,3) is: -261.7291844948476
# Attempting to fit ARIMA(5, 1, 4)
# For danceability, the AIC for ARIMA(5,1,4) is: -261.01810812180497
# Attempting to fit ARIMA(5, 1, 5)
# For danceability, the AIC for ARIMA(5,1,5) is: -263.672486690809
#
# DANCEABILITY MODEL FINISHED!
# The model for danceability that minimizes AIC on the training data is the ARIMA(1,1,1).
# The model has an aIC of -271.8078318641607.
#
# Attempting to fit ARIMA(0, 2, 0)
# For mode, the AIC for ARIMA(0,2,0) is: -116.99603908438715
# Attempting to fit ARIMA(0, 2, 1)
# For mode, the AIC for ARIMA(0,2,1) is: -157.3284231267557
# Attempting to fit ARIMA(0, 2, 2)
# For mode, the AIC for ARIMA(0,2,2) is: -157.3720532841598
# Attempting to fit ARIMA(0, 2, 3)
# For mode, the AIC for ARIMA(0,2,3) is: -156.43518261906985
# Attempting to fit ARIMA(0, 2, 4)
# For mode, the AIC for ARIMA(0,2,4) is: -154.6096929338088
# Attempting to fit ARIMA(0, 2, 5)
# For mode, the AIC for ARIMA(0,2,5) is: -153.40220792855547
# Attempting to fit ARIMA(1, 2, 0)
# For mode, the AIC for ARIMA(1,2,0) is: -142.90952277692463
# Attempting to fit ARIMA(1, 2, 1)
# For mode, the AIC for ARIMA(1,2,1) is: -157.8908653333948
# Attempting to fit ARIMA(1, 2, 2)
# For mode, the AIC for ARIMA(1,2,2) is: -157.73596738578738
# Attempting to fit ARIMA(1, 2, 3)
# Attempting to fit ARIMA(1, 2, 4)
# Attempting to fit ARIMA(1, 2, 5)
# For mode, the AIC for ARIMA(1,2,5) is: -155.58582513494258
# Attempting to fit ARIMA(2, 2, 0)
# For mode, the AIC for ARIMA(2,2,0) is: -147.1651104036917
# Attempting to fit ARIMA(2, 2, 1)
# For mode, the AIC for ARIMA(2,2,1) is: -156.4063965694487
# Attempting to fit ARIMA(2, 2, 2)
# Attempting to fit ARIMA(2, 2, 3)
# Attempting to fit ARIMA(2, 2, 4)
# Attempting to fit ARIMA(2, 2, 5)
# Attempting to fit ARIMA(3, 2, 0)
# For mode, the AIC for ARIMA(3,2,0) is: -152.75969523608092
# Attempting to fit ARIMA(3, 2, 1)
# For mode, the AIC for ARIMA(3,2,1) is: -150.78680287944456
# Attempting to fit ARIMA(3, 2, 2)
# Attempting to fit ARIMA(3, 2, 3)
# Attempting to fit ARIMA(3, 2, 4)
# Attempting to fit ARIMA(3, 2, 5)
# Attempting to fit ARIMA(4, 2, 0)
# For mode, the AIC for ARIMA(4,2,0) is: -150.75994235877016
# Attempting to fit ARIMA(4, 2, 1)
# For mode, the AIC for ARIMA(4,2,1) is: -154.08616060355888
# Attempting to fit ARIMA(4, 2, 2)
# For mode, the AIC for ARIMA(4,2,2) is: -153.78745274331652
# Attempting to fit ARIMA(4, 2, 3)
# For mode, the AIC for ARIMA(4,2,3) is: -156.60059584209142
# Attempting to fit ARIMA(4, 2, 4)
# For mode, the AIC for ARIMA(4,2,4) is: -154.78856555844618
# Attempting to fit ARIMA(4, 2, 5)
# For mode, the AIC for ARIMA(4,2,5) is: -152.8491603585652
# Attempting to fit ARIMA(5, 2, 0)
# For mode, the AIC for ARIMA(5,2,0) is: -150.69150027414918
# Attempting to fit ARIMA(5, 2, 1)
# For mode, the AIC for ARIMA(5,2,1) is: -153.6610362355387
# Attempting to fit ARIMA(5, 2, 2)
# For mode, the AIC for ARIMA(5,2,2) is: -153.93183496427724
# Attempting to fit ARIMA(5, 2, 3)
# For mode, the AIC for ARIMA(5,2,3) is: -152.57070543180578
# Attempting to fit ARIMA(5, 2, 4)
# For mode, the AIC for ARIMA(5,2,4) is: -149.9276915533647
# Attempting to fit ARIMA(5, 2, 5)
# For mode, the AIC for ARIMA(5,2,5) is: -146.49294479360304
#
# MODE MODEL FINISHED!
# The model for mode that minimizes AIC on the training data is the ARIMA(1,2,1).
# The model has an aIC of -157.8908653333948.
#
# Attempting to fit ARIMA(0, 2, 0)
# For acousticness, the AIC for ARIMA(0,2,0) is: -188.66197022550543
# Attempting to fit ARIMA(0, 2, 1)
# For acousticness, the AIC for ARIMA(0,2,1) is: -219.1987376447546
# Attempting to fit ARIMA(0, 2, 2)
# For acousticness, the AIC for ARIMA(0,2,2) is: -217.297651396915
# Attempting to fit ARIMA(0, 2, 3)
# For acousticness, the AIC for ARIMA(0,2,3) is: -215.34955774245833
# Attempting to fit ARIMA(0, 2, 4)
# For acousticness, the AIC for ARIMA(0,2,4) is: -220.71695475846923
# Attempting to fit ARIMA(0, 2, 5)
# For acousticness, the AIC for ARIMA(0,2,5) is: -220.81190755415054
# Attempting to fit ARIMA(1, 2, 0)
# For acousticness, the AIC for ARIMA(1,2,0) is: -204.91023185367078
# Attempting to fit ARIMA(1, 2, 1)
# For acousticness, the AIC for ARIMA(1,2,1) is: -217.30575284811238
# Attempting to fit ARIMA(1, 2, 2)
# For acousticness, the AIC for ARIMA(1,2,2) is: -221.8122733507576
# Attempting to fit ARIMA(1, 2, 3)
# For acousticness, the AIC for ARIMA(1,2,3) is: -195.70832852283115
# Attempting to fit ARIMA(1, 2, 4)
# For acousticness, the AIC for ARIMA(1,2,4) is: -220.19348650214658
# Attempting to fit ARIMA(1, 2, 5)
# For acousticness, the AIC for ARIMA(1,2,5) is: -218.21832613291247
# Attempting to fit ARIMA(2, 2, 0)
# For acousticness, the AIC for ARIMA(2,2,0) is: -204.85365966772986
# Attempting to fit ARIMA(2, 2, 1)
# For acousticness, the AIC for ARIMA(2,2,1) is: -215.42002640489136
# Attempting to fit ARIMA(2, 2, 2)
# For acousticness, the AIC for ARIMA(2,2,2) is: -212.30072860112034
# Attempting to fit ARIMA(2, 2, 3)
# For acousticness, the AIC for ARIMA(2,2,3) is: -219.72173174626852
# Attempting to fit ARIMA(2, 2, 4)
# For acousticness, the AIC for ARIMA(2,2,4) is: -219.32101778143965
# Attempting to fit ARIMA(2, 2, 5)
# For acousticness, the AIC for ARIMA(2,2,5) is: -220.1063667275501
# Attempting to fit ARIMA(3, 2, 0)
# For acousticness, the AIC for ARIMA(3,2,0) is: -211.31347359592854
# Attempting to fit ARIMA(3, 2, 1)
# For acousticness, the AIC for ARIMA(3,2,1) is: -211.407723268898
# Attempting to fit ARIMA(3, 2, 2)
# Attempting to fit ARIMA(3, 2, 3)
# For acousticness, the AIC for ARIMA(3,2,3) is: -221.30869732741047
# Attempting to fit ARIMA(3, 2, 4)
# Attempting to fit ARIMA(3, 2, 5)
# For acousticness, the AIC for ARIMA(3,2,5) is: -219.94046734576222
# Attempting to fit ARIMA(4, 2, 0)
# For acousticness, the AIC for ARIMA(4,2,0) is: -210.6866434133314
# Attempting to fit ARIMA(4, 2, 1)
# For acousticness, the AIC for ARIMA(4,2,1) is: -209.54159951978062
# Attempting to fit ARIMA(4, 2, 2)
# For acousticness, the AIC for ARIMA(4,2,2) is: -203.14664988258386
# Attempting to fit ARIMA(4, 2, 3)
# Attempting to fit ARIMA(4, 2, 4)
# Attempting to fit ARIMA(4, 2, 5)
# For acousticness, the AIC for ARIMA(4,2,5) is: -215.23958764193407
# Attempting to fit ARIMA(5, 2, 0)
# For acousticness, the AIC for ARIMA(5,2,0) is: -213.34225665165172
# Attempting to fit ARIMA(5, 2, 1)
# For acousticness, the AIC for ARIMA(5,2,1) is: -223.19215937791125
# Attempting to fit ARIMA(5, 2, 2)
# For acousticness, the AIC for ARIMA(5,2,2) is: -221.27282235024705
# Attempting to fit ARIMA(5, 2, 3)
# For acousticness, the AIC for ARIMA(5,2,3) is: -222.73948086452378
# Attempting to fit ARIMA(5, 2, 4)
# For acousticness, the AIC for ARIMA(5,2,4) is: -222.01396563008888
# Attempting to fit ARIMA(5, 2, 5)
# For acousticness, the AIC for ARIMA(5,2,5) is: -221.81481145029534
#
# ACOUSTICNESS MODEL FINISHED!
# The model for acousticness that minimizes AIC on the training data is the ARIMA(5,2,1).
# The model has an aIC of -223.19215937791125.
#
# Attempting to fit ARIMA(0, 1, 0)
# For valence, the AIC for ARIMA(0,1,0) is: -255.84898238769892
# Attempting to fit ARIMA(0, 1, 1)
# For valence, the AIC for ARIMA(0,1,1) is: -253.85196987135805
# Attempting to fit ARIMA(0, 1, 2)
# For valence, the AIC for ARIMA(0,1,2) is: -251.900277663741
# Attempting to fit ARIMA(0, 1, 3)
# For valence, the AIC for ARIMA(0,1,3) is: -250.86155868032836
# Attempting to fit ARIMA(0, 1, 4)
# For valence, the AIC for ARIMA(0,1,4) is: -248.862078281427
# Attempting to fit ARIMA(0, 1, 5)
# For valence, the AIC for ARIMA(0,1,5) is: -248.94394503442766
# Attempting to fit ARIMA(1, 1, 0)
# For valence, the AIC for ARIMA(1,1,0) is: -253.85214290394526
# Attempting to fit ARIMA(1, 1, 1)
# For valence, the AIC for ARIMA(1,1,1) is: -253.13910538237144
# Attempting to fit ARIMA(1, 1, 2)
# For valence, the AIC for ARIMA(1,1,2) is: -251.18792786480083
# Attempting to fit ARIMA(1, 1, 3)
# For valence, the AIC for ARIMA(1,1,3) is: -249.00427793229278
# Attempting to fit ARIMA(1, 1, 4)
# For valence, the AIC for ARIMA(1,1,4) is: -247.80693468777076
# Attempting to fit ARIMA(1, 1, 5)
# For valence, the AIC for ARIMA(1,1,5) is: -247.51168194233298
# Attempting to fit ARIMA(2, 1, 0)
# For valence, the AIC for ARIMA(2,1,0) is: -251.89848857820846
# Attempting to fit ARIMA(2, 1, 1)
# For valence, the AIC for ARIMA(2,1,1) is: -250.58270617268136
# Attempting to fit ARIMA(2, 1, 2)
# For valence, the AIC for ARIMA(2,1,2) is: -251.30501528629497
# Attempting to fit ARIMA(2, 1, 3)
# For valence, the AIC for ARIMA(2,1,3) is: -250.0061278554257
# Attempting to fit ARIMA(2, 1, 4)
# For valence, the AIC for ARIMA(2,1,4) is: -248.0372207805342
# Attempting to fit ARIMA(2, 1, 5)
# For valence, the AIC for ARIMA(2,1,5) is: -246.35120920011934
# Attempting to fit ARIMA(3, 1, 0)
# For valence, the AIC for ARIMA(3,1,0) is: -250.9909828270563
# Attempting to fit ARIMA(3, 1, 1)
# For valence, the AIC for ARIMA(3,1,1) is: -249.28807025103742
# Attempting to fit ARIMA(3, 1, 2)
# For valence, the AIC for ARIMA(3,1,2) is: -247.46681857254873
# Attempting to fit ARIMA(3, 1, 3)
# For valence, the AIC for ARIMA(3,1,3) is: -249.01572381431106
# Attempting to fit ARIMA(3, 1, 4)
# For valence, the AIC for ARIMA(3,1,4) is: -247.22801172624497
# Attempting to fit ARIMA(3, 1, 5)
# For valence, the AIC for ARIMA(3,1,5) is: -241.60293695977896
# Attempting to fit ARIMA(4, 1, 0)
# For valence, the AIC for ARIMA(4,1,0) is: -249.05917691602292
# Attempting to fit ARIMA(4, 1, 1)
# For valence, the AIC for ARIMA(4,1,1) is: -247.28813555731438
# Attempting to fit ARIMA(4, 1, 2)
# For valence, the AIC for ARIMA(4,1,2) is: -245.53860847598207
# Attempting to fit ARIMA(4, 1, 3)
# For valence, the AIC for ARIMA(4,1,3) is: -245.33990492222063
# Attempting to fit ARIMA(4, 1, 4)
# For valence, the AIC for ARIMA(4,1,4) is: -241.3233937460884
# Attempting to fit ARIMA(4, 1, 5)
# For valence, the AIC for ARIMA(4,1,5) is: -239.48845506212126
# Attempting to fit ARIMA(5, 1, 0)
# For valence, the AIC for ARIMA(5,1,0) is: -248.2180148692188
# Attempting to fit ARIMA(5, 1, 1)
# For valence, the AIC for ARIMA(5,1,1) is: -246.28864680638765
# Attempting to fit ARIMA(5, 1, 2)
# For valence, the AIC for ARIMA(5,1,2) is: -252.9132687183493
# Attempting to fit ARIMA(5, 1, 3)
# For valence, the AIC for ARIMA(5,1,3) is: -250.97492434116066
# Attempting to fit ARIMA(5, 1, 4)
# For valence, the AIC for ARIMA(5,1,4) is: -239.42468598135667
# Attempting to fit ARIMA(5, 1, 5)
# For valence, the AIC for ARIMA(5,1,5) is: -240.83128645921488
#
# VALENCE MODEL FINISHED!
# The model for valence that minimizes AIC on the training data is the ARIMA(0,1,0).
# The model has an aIC of -255.84898238769892.
#
# Attempting to fit ARIMA(0, 1, 0)
# For tempo, the AIC for ARIMA(0,1,0) is: 211.17304379125483
# Attempting to fit ARIMA(0, 1, 1)
# For tempo, the AIC for ARIMA(0,1,1) is: 212.5664501497136
# Attempting to fit ARIMA(0, 1, 2)
# For tempo, the AIC for ARIMA(0,1,2) is: 213.20421500069028
# Attempting to fit ARIMA(0, 1, 3)
# For tempo, the AIC for ARIMA(0,1,3) is: 215.04407811615525
# Attempting to fit ARIMA(0, 1, 4)
# For tempo, the AIC for ARIMA(0,1,4) is: 215.65529389904376
# Attempting to fit ARIMA(0, 1, 5)
# For tempo, the AIC for ARIMA(0,1,5) is: 214.49940704374478
# Attempting to fit ARIMA(1, 1, 0)
# For tempo, the AIC for ARIMA(1,1,0) is: 212.78038358258857
# Attempting to fit ARIMA(1, 1, 1)
# For tempo, the AIC for ARIMA(1,1,1) is: 213.03889182434756
# Attempting to fit ARIMA(1, 1, 2)
# For tempo, the AIC for ARIMA(1,1,2) is: 215.12995847297336
# Attempting to fit ARIMA(1, 1, 3)
# For tempo, the AIC for ARIMA(1,1,3) is: 214.9211744117535
# Attempting to fit ARIMA(1, 1, 4)
# For tempo, the AIC for ARIMA(1,1,4) is: 215.7282816384726
# Attempting to fit ARIMA(1, 1, 5)
# For tempo, the AIC for ARIMA(1,1,5) is: 216.42380670561846
# Attempting to fit ARIMA(2, 1, 0)
# For tempo, the AIC for ARIMA(2,1,0) is: 213.11377952227681
# Attempting to fit ARIMA(2, 1, 1)
# For tempo, the AIC for ARIMA(2,1,1) is: 215.02986393105525
# Attempting to fit ARIMA(2, 1, 2)
# For tempo, the AIC for ARIMA(2,1,2) is: 216.18157045667277
# Attempting to fit ARIMA(2, 1, 3)
# For tempo, the AIC for ARIMA(2,1,3) is: 217.77448442566748
# Attempting to fit ARIMA(2, 1, 4)
# For tempo, the AIC for ARIMA(2,1,4) is: 215.25020667193124
# Attempting to fit ARIMA(2, 1, 5)
# For tempo, the AIC for ARIMA(2,1,5) is: 217.04321261472097
# Attempting to fit ARIMA(3, 1, 0)
# For tempo, the AIC for ARIMA(3,1,0) is: 214.95852051180754
# Attempting to fit ARIMA(3, 1, 1)
# For tempo, the AIC for ARIMA(3,1,1) is: 215.28024341030095
# Attempting to fit ARIMA(3, 1, 2)
# For tempo, the AIC for ARIMA(3,1,2) is: 237.56280571297987
# Attempting to fit ARIMA(3, 1, 3)
# For tempo, the AIC for ARIMA(3,1,3) is: 218.2801954196895
# Attempting to fit ARIMA(3, 1, 4)
# For tempo, the AIC for ARIMA(3,1,4) is: 216.47537288504356
# Attempting to fit ARIMA(3, 1, 5)
# For tempo, the AIC for ARIMA(3,1,5) is: 218.274164692652
# Attempting to fit ARIMA(4, 1, 0)
# For tempo, the AIC for ARIMA(4,1,0) is: 216.27986824180127
# Attempting to fit ARIMA(4, 1, 1)
# For tempo, the AIC for ARIMA(4,1,1) is: 216.54830009464933
# Attempting to fit ARIMA(4, 1, 2)
# For tempo, the AIC for ARIMA(4,1,2) is: 219.41670580263818
# Attempting to fit ARIMA(4, 1, 3)
# For tempo, the AIC for ARIMA(4,1,3) is: 216.21904772223266
# Attempting to fit ARIMA(4, 1, 4)
# For tempo, the AIC for ARIMA(4,1,4) is: 221.5909182946622
# Attempting to fit ARIMA(4, 1, 5)
# For tempo, the AIC for ARIMA(4,1,5) is: 219.8450940816099
# Attempting to fit ARIMA(5, 1, 0)
# For tempo, the AIC for ARIMA(5,1,0) is: 215.25826160366492
# Attempting to fit ARIMA(5, 1, 1)
# For tempo, the AIC for ARIMA(5,1,1) is: 217.1171440119823
# Attempting to fit ARIMA(5, 1, 2)
# For tempo, the AIC for ARIMA(5,1,2) is: 216.15514950300326
# Attempting to fit ARIMA(5, 1, 3)
# For tempo, the AIC for ARIMA(5,1,3) is: 217.37033145632972
# Attempting to fit ARIMA(5, 1, 4)
# Attempting to fit ARIMA(5, 1, 5)
# For tempo, the AIC for ARIMA(5,1,5) is: 219.99262651153845
#
# TEMPO MODEL FINISHED!
# The model for tempo that minimizes AIC on the training data is the ARIMA(0,1,0).
# The model has an aIC of 211.17304379125483.

# %%
arima_param_df_19 = pd.DataFrame(arima_dict_19)
arima_param_df_19
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       1       1  (1, 1, 1)  ARIMA(1,1,1)
# 1          mode          2       1       1  (1, 2, 1)  ARIMA(1,2,1)
# 2  acousticness          2       5       1  (5, 2, 1)  ARIMA(5,2,1)
# 3       valence          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
# 4         tempo          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
#
#     ARIMA_AIC
# 0 -271.807832
# 1 -157.890865
# 2 -223.192159
# 3 -255.848982
# 4  211.173044

# %% [markdown]
# # ARIMA Models

# %% [markdown]
# ### Function to create, evaluate, and plot `ARIMA` models

# %%
def arima_predict_plot(df, feature, year, param_df, title='title', figsize=(15,5), order=None, d=None, ci=True):
  
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    if order is None:
        # find order from arima parameters dataframe 
        order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
   
    try: 
        # instantiate ARIMA model
        model = ARIMA(train, order=order)

        # fit ARIMA model
        arima = model.fit()

        # get predictions for train and test sets 
        preds_train = model.predict(params=arima.params, start=train.index[d], end=train.index[-1], typ='levels')
        preds_test = model.predict(params=arima.params, start=test.index[0], end=test.index[-1], typ='levels')

        # calculate and print RMSE for train and test setes 
        train_rmse = mean_squared_error(train[d::], preds_train)**0.5
        print(f'{feature.capitalize()} train RMSE ({year}) - ARIMA({order}): {train_rmse}')

        test_rmse = mean_squared_error(test, preds_test)**0.5
        print(f'{feature.capitalize()} test RMSE ({year}) - ARIMA({order}): {test_rmse}')

        # add RMSEs to arima parameters dataframe 
        param_df.loc[param_df['audio_feature'] == feature, 'arima_train_rmse'] = train_rmse    
        param_df.loc[param_df['audio_feature'] == feature, 'arima_test_rmse'] = test_rmse

          # set up plot
        plt.figure(figsize=figsize)

        # plot training data 
        plt.plot(train, color='blue')

        # plot testing data 
        plt.plot(test.index, test, color='orange')

        # plot predicted values for test set 
        plt.plot(test.index, preds_test, color='green')

        # add line for the baseline model (mean value of feature)
        plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')

        # plot confidence interval
        if ci:
            ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
            plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 

        # make plot with title! 
        plt.title(title, fontsize=16)
        plt.show() ; 
        
    except:
        print(ValueError)
        pass

# %% [markdown]
# _Function soley for plotting to be used when needed._

# %%
def arima_plot(train, test, preds_test, title='title', figsize=(15,5), ci=True):
    
    # set up plot
    plt.figure(figsize=figsize)
    
    # plot training data 
    plt.plot(train, color='blue')
    
    # plot testing data 
    plt.plot(test.index, test, color='orange')
    
    # plot predicted values for test set 
    plt.plot(test.index, preds_test, color='green')
    
    # add line for the baseline model (mean value of feature)
    # plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')
    
    # plot confidence interval 
    if ci:
        ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
        plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 
    
    # make plot with title! 
    plt.title(title, fontsize=16)
    plt.show() ;

# %% [markdown]
# ### ARIMA Models - 2019
#
# _Using `arima_predict_plot` function to run ARIMA model for each feature and show plot of actual vs. test._
#
# _This will also add columns for `arima_train_rmse` and `arima_test_rmse`._

# %%
it_rw_19.head(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2019-01-06      25.5      0.668231  0.680805  4.580000 -6.478111  0.514286
# 2019-01-13      25.5      0.673357  0.677388  4.211429 -6.407583  0.522857
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2019-01-06     0.113994      0.288621          0.100187  0.153183  0.466531
# 2019-01-13     0.099184      0.289861          0.089097  0.150668  0.508239
#
#                  tempo    duration_ms  time_signature
# date
# 2019-01-06  126.070511  219218.028571        3.885714
# 2019-01-13  124.737909  219014.757143        3.925714

# %%
it_rw_19.tail(2)
# Out:
#             Position  danceability    energy       key  loudness      mode  \
# date
# 2019-12-29      25.5      0.666363  0.610831  6.125714 -7.189337  0.637143
# 2020-01-05      25.5      0.695900  0.643483  6.314286 -6.612169  0.634286
#
#             speechiness  acousticness  instrumentalness  liveness   valence  \
# date
# 2019-12-29     0.109331      0.278767          0.041290  0.171111  0.460510
# 2020-01-05     0.127259      0.225605          0.030068  0.184051  0.476149
#
#                  tempo    duration_ms  time_signature
# date
# 2019-12-29  117.949174  190365.777143        3.965714
# 2020-01-05  118.608006  188407.960000        3.962857

# %%
for feature in five_features: 
    arima_predict_plot(it_rw_19, feature, 2019, arima_param_df_19, title=f'Mean {feature.capitalize()} Score, Italy 2019 (ARIMA, custom d)')
# Out:
# d = 1
# order = (1, 1, 1)
# Danceability train RMSE (2019) - ARIMA((1, 1, 1)): 0.015253564823005793
# Danceability test RMSE (2019) - ARIMA((1, 1, 1)): 0.03758443837442127
# d = 2
# order = (1, 2, 1)
# Mode train RMSE (2019) - ARIMA((1, 2, 1)): 0.04616828639340792
# Mode test RMSE (2019) - ARIMA((1, 2, 1)): 0.0813707111767709
# d = 2
# order = (5, 2, 1)
# Acousticness train RMSE (2019) - ARIMA((5, 2, 1)): 0.022119110081141393
# Acousticness test RMSE (2019) - ARIMA((5, 2, 1)): 0.049119387814322735
# d = 1
# order = (0, 1, 0)
# Valence train RMSE (2019) - ARIMA((0, 1, 0)): 0.020456899728477224
# Valence test RMSE (2019) - ARIMA((0, 1, 0)): 0.019087534748622053
# d = 1
# order = (0, 1, 0)
# Tempo train RMSE (2019) - ARIMA((0, 1, 0)): 1.8589980387595524
# Tempo test RMSE (2019) - ARIMA((0, 1, 0)): 1.1600104175888954

# %% [markdown]
# #### _Updated `arima_param_df_19`_

# %%
arima_param_df_19
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       1       1  (1, 1, 1)  ARIMA(1,1,1)
# 1          mode          2       1       1  (1, 2, 1)  ARIMA(1,2,1)
# 2  acousticness          2       5       1  (5, 2, 1)  ARIMA(5,2,1)
# 3       valence          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
# 4         tempo          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse
# 0 -271.807832          0.015254         0.037584
# 1 -157.890865          0.046168         0.081371
# 2 -223.192159          0.022119         0.049119
# 3 -255.848982          0.019904         0.020889
# 4  211.173044          1.858998         1.160010

# %% [markdown]
# # SARIMAX models

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# #### _As baseline, Fitting SARIMAX with `seasonal_order = (2, 0, 2, 52)` and no exogenous variables before incorporating/engineering those components._

# %%
P, D, Q, S = 2, 0 ,2, 52
train_val = it_rw_19['valence'][0:48]
test_val = it_rw_19['valence'][48:]

sarima_val = SARIMAX(endog = train_val, order = (2, 0, 2), seasonal_order = (P, D, Q, S)).fit()
# sarima_pred = sarima.predict(start=start, end = end)

preds_train_sarima_val = sarima_val.predict(start=train_val.index[0], end=train_val.index[-1])
preds_test_sarima_val = sarima_val.predict(start=test_val.index[0], end=test_val.index[-1])

print(f'RMSE = {round(mean_squared_error(test_val, preds_test_sarima_val)**.5, 2)}')

arima_plot(train_val, test_val, preds_test_sarima_val, title="Basic SARIMA model - Valence, Italy 2019", figsize=(10,3))
# Out:
# RMSE = 0.02

# %% [markdown]
# #### Plotting ARIMA plot from above again, for comparison:

# %%
arima_predict_plot(it_rw_17, 'valence', 2019, arima_param_df_19, title=f'Mean Valence Score, Italy 2019', figsize=(10,3), order=(2,1,2))
# Out:
# d = 1
# order = (2, 1, 2)
# Valence train RMSE (2019) - ARIMA((2, 1, 2)): 0.036157040161561356
# Valence test RMSE (2019) - ARIMA((2, 1, 2)): 0.04017210751841029

# %% [markdown]
# ### SARIMAX Seasonal Parameters

# %% [markdown]
# #### _Grid search to find best `P`, `D`, `Q`, and `s` values_

# %%
def find_sarima_parameters(df, feature, param_df, n_rows=47):    
    
    import time
    t0 = time.time()
    final_mae = 1000000000000
    final_S = 0
    final_D = 0
    final_P = 0
    final_Q = 0
    
    # find order from arima parameters dataframe 
    order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]

    train_values = df[feature][0:n_rows]
    test_values = df[feature][n_rows:]

    for S in range(48,53):
        for D in range(2):
            for P in range(4):
                for Q in range(4):
                    print(f'Checking ({P}, {D}, {Q}, {S}) at {round(time.time() - t0)} seconds.')
                    try:
                        sarima = SARIMAX(endog = train_values,
                                         order = order,
                                         seasonal_order = (P, D, Q, S)).fit()

                        sarima_pred = sarima.predict(start=test_values.index[0], end=test_values.index[-1], typ='levels')

                        if mean_absolute_error(test_values, sarima_pred) < final_mae:
                            final_mae = mean_absolute_error(test_values, sarima_pred)
                            final_S = S
                            final_D = D
                            final_P = P
                            final_Q = Q

                        print(f'We just fit a SARIMAX(2, 0, 2)x({P}, {D}, {Q}, {S}) model with {mean_absolute_error(test_values, sarima_pred)} MAE and {mean_squared_error(test_values, sarima_pred)**0.5} RMSE.')

                    except:
                        print('problem!')
                        raise

    print()
    print(f'The final model for {feature} is SARIMAX(2, 0, 2)x({final_P}, {final_D}, {final_Q}, {final_S}).')
    print()

# %%
five_features
# Out:
# ['danceability', 'mode', 'acousticness', 'valence', 'tempo']

# %%
for feature in five_features: 
    find_sarima_parameters(it_rw_19, feature, arima_param_df_19)
# Out:
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.027260504173661937 MAE and 0.032652715228373624 RMSE.
# Checking (0, 0, 1, 48) at 1 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.025691939643951 MAE and 0.031669066324842156 RMSE.
# Checking (0, 0, 2, 48) at 3 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.025635477025914972 MAE and 0.03162409177593319 RMSE.
# Checking (0, 0, 3, 48) at 7 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.025507070619369836 MAE and 0.031522852315217176 RMSE.
# Checking (1, 0, 0, 48) at 24 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.02591354350353059 MAE and 0.031855115282942964 RMSE.
# Checking (1, 0, 1, 48) at 27 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.024847494048446994 MAE and 0.03132382049439144 RMSE.
# Checking (1, 0, 2, 48) at 29 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.025166871679624225 MAE and 0.031575227893368266 RMSE.
# Checking (1, 0, 3, 48) at 37 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.025118260994023072 MAE and 0.03153579538173051 RMSE.
# Checking (2, 0, 0, 48) at 52 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.02583562749006285 MAE and 0.03179024244637921 RMSE.
# Checking (2, 0, 1, 48) at 63 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.024808597815506133 MAE and 0.03129644443788672 RMSE.
# Checking (2, 0, 2, 48) at 71 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.024839649678880676 MAE and 0.031322549576111434 RMSE.
# Checking (2, 0, 3, 48) at 81 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.0247731057684261 MAE and 0.03126908170111221 RMSE.
# Checking (3, 0, 0, 48) at 102 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.024152659821424765 MAE and 0.03212452612315902 RMSE.
# Checking (3, 0, 1, 48) at 130 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.025080525626517507 MAE and 0.03150350039354818 RMSE.
# Checking (3, 0, 2, 48) at 151 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.024717722808205184 MAE and 0.031228574946080452 RMSE.
# Checking (3, 0, 3, 48) at 177 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.02482541688607463 MAE and 0.031310282937601804 RMSE.
# Checking (0, 1, 0, 48) at 212 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (0, 1, 1, 48) at 212 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (0, 1, 2, 48) at 212 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (0, 1, 3, 48) at 213 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (1, 1, 0, 48) at 215 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (1, 1, 1, 48) at 216 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (1, 1, 2, 48) at 216 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (1, 1, 3, 48) at 217 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (2, 1, 0, 48) at 219 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (2, 1, 1, 48) at 220 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (2, 1, 2, 48) at 220 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (2, 1, 3, 48) at 221 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (3, 1, 0, 48) at 223 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (3, 1, 1, 48) at 224 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (3, 1, 2, 48) at 225 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (3, 1, 3, 48) at 227 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 48) model with 0.3139905677862394 MAE and 0.34242965391440267 RMSE.
# Checking (0, 0, 0, 49) at 230 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 49) model with 0.027260504173661937 MAE and 0.032652715228373624 RMSE.
# Checking (0, 0, 1, 49) at 230 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 49) model with 0.026248493395752026 MAE and 0.0316749633582897 RMSE.
# Checking (0, 0, 2, 49) at 231 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 49) model with 0.0260785109848448 MAE and 0.03151652344443549 RMSE.
# Checking (0, 0, 3, 49) at 234 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 49) model with 0.026073834850752913 MAE and 0.03151208424435667 RMSE.
# Checking (1, 0, 0, 49) at 253 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 49) model with 0.02614996250169623 MAE and 0.031577847252221194 RMSE.
# Checking (1, 0, 1, 49) at 255 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 49) model with 0.024878321832459045 MAE and 0.030376522489980108 RMSE.
# Checking (1, 0, 2, 49) at 256 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 49) model with 0.024411862269444844 MAE and 0.02995724319105366 RMSE.
# Checking (1, 0, 3, 49) at 262 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 49) model with 0.024929724129768422 MAE and 0.030420400302569064 RMSE.
# Checking (2, 0, 0, 49) at 278 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 49) model with 0.026939340375949878 MAE and 0.032284424703942105 RMSE.
# Checking (2, 0, 1, 49) at 283 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 49) model with 0.024343751977958922 MAE and 0.029896229757523138 RMSE.
# Checking (2, 0, 2, 49) at 291 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 49) model with 0.021245225456374323 MAE and 0.027412120297857702 RMSE.
# Checking (2, 0, 3, 49) at 305 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 49) model with 0.024237312362927865 MAE and 0.029798379756075258 RMSE.
# Checking (3, 0, 0, 49) at 334 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 49) model with 0.02618969298514499 MAE and 0.03161222121280089 RMSE.
# Checking (3, 0, 1, 49) at 350 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 49) model with 0.02431394041319292 MAE and 0.029869335575244824 RMSE.
# Checking (3, 0, 2, 49) at 373 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 49) model with 0.02447804397156676 MAE and 0.030016693763773382 RMSE.
# Checking (3, 0, 3, 49) at 397 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 49) model with 0.024695250870126546 MAE and 0.03020842819528972 RMSE.
# Checking (0, 1, 0, 49) at 422 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (0, 1, 1, 49) at 422 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (0, 1, 2, 49) at 423 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (0, 1, 3, 49) at 424 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (1, 1, 0, 49) at 425 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (1, 1, 1, 49) at 426 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (1, 1, 2, 49) at 426 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (1, 1, 3, 49) at 427 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (2, 1, 0, 49) at 429 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (2, 1, 1, 49) at 430 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (2, 1, 2, 49) at 431 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (2, 1, 3, 49) at 432 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (3, 1, 0, 49) at 435 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (3, 1, 1, 49) at 437 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (3, 1, 2, 49) at 439 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (3, 1, 3, 49) at 441 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 0.2570669685147056 MAE and 0.3102860518485156 RMSE.
# Checking (0, 0, 0, 50) at 444 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 0.027260504173661937 MAE and 0.032652715228373624 RMSE.
# Checking (0, 0, 1, 50) at 444 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 0.023315670264597615 MAE and 0.028654468087404666 RMSE.
# Checking (0, 0, 2, 50) at 446 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 0.023392634476977463 MAE and 0.02873932966913 RMSE.
# Checking (0, 0, 3, 50) at 449 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 0.023197000381701933 MAE and 0.02853289046430694 RMSE.
# Checking (1, 0, 0, 50) at 460 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 0.025851492957312466 MAE and 0.031151405336009422 RMSE.
# Checking (1, 0, 1, 50) at 462 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 0.026438797210013503 MAE and 0.031538086902773835 RMSE.
# Checking (1, 0, 2, 50) at 463 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 0.02546448623608664 MAE and 0.03060788134702858 RMSE.
# Checking (1, 0, 3, 50) at 469 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 0.025729810014857746 MAE and 0.030839953109149467 RMSE.
# Checking (2, 0, 0, 50) at 484 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 0.026454609097198673 MAE and 0.03171492079186175 RMSE.
# Checking (2, 0, 1, 50) at 498 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 0.025818452114897084 MAE and 0.030948425135659763 RMSE.
# Checking (2, 0, 2, 50) at 506 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 0.025655114382820587 MAE and 0.03079365737881673 RMSE.
# Checking (2, 0, 3, 50) at 516 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 0.026570139351652516 MAE and 0.03166373674668084 RMSE.
# Checking (3, 0, 0, 50) at 532 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 0.02334528462725477 MAE and 0.028689813165523225 RMSE.
# Checking (3, 0, 1, 50) at 551 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 0.025768701443633652 MAE and 0.030902328557710357 RMSE.
# Checking (3, 0, 2, 50) at 574 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 0.023492973240306803 MAE and 0.028405136894143757 RMSE.
# Checking (3, 0, 3, 50) at 605 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 0.025814888446131373 MAE and 0.03094569096191308 RMSE.
# Checking (0, 1, 0, 50) at 632 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (0, 1, 1, 50) at 632 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (0, 1, 2, 50) at 632 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (0, 1, 3, 50) at 633 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (1, 1, 0, 50) at 635 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (1, 1, 1, 50) at 635 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (1, 1, 2, 50) at 636 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (1, 1, 3, 50) at 637 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (2, 1, 0, 50) at 639 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (2, 1, 1, 50) at 640 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (2, 1, 2, 50) at 642 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (2, 1, 3, 50) at 644 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (3, 1, 0, 50) at 647 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (3, 1, 1, 50) at 650 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (3, 1, 2, 50) at 653 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (3, 1, 3, 50) at 656 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 0.198986226386029 MAE and 0.2634665769266242 RMSE.
# Checking (0, 0, 0, 51) at 659 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 0.027260504173661937 MAE and 0.032652715228373624 RMSE.
# Checking (0, 0, 1, 51) at 659 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 0.026686311963890746 MAE and 0.0321332239121862 RMSE.
# Checking (0, 0, 2, 51) at 660 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 0.02665373253261971 MAE and 0.032105131476669636 RMSE.
# Checking (0, 0, 3, 51) at 666 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 0.026705921487608197 MAE and 0.03215084294173032 RMSE.
# Checking (1, 0, 0, 51) at 686 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 0.026094478239801638 MAE and 0.031606705383347505 RMSE.
# Checking (1, 0, 1, 51) at 688 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 0.022437433188959355 MAE and 0.028452642899940882 RMSE.
# Checking (1, 0, 2, 51) at 691 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 0.022347390635621373 MAE and 0.028377418347481722 RMSE.
# Checking (1, 0, 3, 51) at 700 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 0.022311847668318157 MAE and 0.028348442305491665 RMSE.
# Checking (2, 0, 0, 51) at 716 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 0.026751051124222196 MAE and 0.03219042753361504 RMSE.
# Checking (2, 0, 1, 51) at 721 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 0.022236988086811887 MAE and 0.028275789710908904 RMSE.
# Checking (2, 0, 2, 51) at 728 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 0.021987648345267046 MAE and 0.027893221198915213 RMSE.
# Checking (2, 0, 3, 51) at 738 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 0.02235733176047816 MAE and 0.028387004698010178 RMSE.
# Checking (3, 0, 0, 51) at 765 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 0.027121757930381667 MAE and 0.03251583903677866 RMSE.
# Checking (3, 0, 1, 51) at 795 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 0.022256332139000874 MAE and 0.028298855778316347 RMSE.
# Checking (3, 0, 2, 51) at 850 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 0.02209732617010396 MAE and 0.028061474731579997 RMSE.
# Checking (3, 0, 3, 51) at 910 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 0.0239362723914963 MAE and 0.0296885435785189 RMSE.
# Checking (0, 1, 0, 51) at 932 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (0, 1, 1, 51) at 932 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (0, 1, 2, 51) at 932 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (0, 1, 3, 51) at 933 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (1, 1, 0, 51) at 935 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (1, 1, 1, 51) at 936 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (1, 1, 2, 51) at 936 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (1, 1, 3, 51) at 938 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (2, 1, 0, 51) at 941 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (2, 1, 1, 51) at 942 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (2, 1, 2, 51) at 943 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (2, 1, 3, 51) at 944 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (3, 1, 0, 51) at 947 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (3, 1, 1, 51) at 952 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (3, 1, 2, 51) at 956 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (3, 1, 3, 51) at 959 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.13847481759068578 MAE and 0.20818546929014253 RMSE.
# Checking (0, 0, 0, 52) at 962 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.027260504173661937 MAE and 0.032652715228373624 RMSE.
# Checking (0, 0, 1, 52) at 962 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.028710061931741266 MAE and 0.033936167233701936 RMSE.
# Checking (0, 0, 2, 52) at 963 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.02871006192969085 MAE and 0.03393616723207805 RMSE.
# Checking (0, 0, 3, 52) at 964 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.028710061931684277 MAE and 0.03393616723381065 RMSE.
# Checking (1, 0, 0, 52) at 969 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.0287100633675485 MAE and 0.033936168294592985 RMSE.
# Checking (1, 0, 1, 52) at 969 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.028631811068657864 MAE and 0.03377813091621654 RMSE.
# Checking (1, 0, 2, 52) at 971 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.02870519235603893 MAE and 0.03385126695334706 RMSE.
# Checking (1, 0, 3, 52) at 980 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.028660376265489507 MAE and 0.033803482836970204 RMSE.
# Checking (2, 0, 0, 52) at 997 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.028710063366231536 MAE and 0.03393616829341471 RMSE.
# Checking (2, 0, 1, 52) at 1000 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.028820757034869138 MAE and 0.03396672872363437 RMSE.
# Checking (2, 0, 2, 52) at 1013 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.028407812659541638 MAE and 0.033590848438885726 RMSE.
# Checking (2, 0, 3, 52) at 1035 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.02871231147221065 MAE and 0.0338544658783419 RMSE.
# Checking (3, 0, 0, 52) at 1078 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.028710063365286698 MAE and 0.033936168292591606 RMSE.
# Checking (3, 0, 1, 52) at 1090 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.02796575116363222 MAE and 0.03321590834278133 RMSE.
# Checking (3, 0, 2, 52) at 1155 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.028733202629715182 MAE and 0.03387381528133052 RMSE.
# Checking (3, 0, 3, 52) at 1220 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.02871453481264713 MAE and 0.03385640005922676 RMSE.
# Checking (0, 1, 0, 52) at 1264 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (0, 1, 1, 52) at 1264 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (0, 1, 2, 52) at 1265 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (0, 1, 3, 52) at 1266 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (1, 1, 0, 52) at 1270 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (1, 1, 1, 52) at 1271 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (1, 1, 2, 52) at 1271 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (1, 1, 3, 52) at 1273 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (2, 1, 0, 52) at 1277 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (2, 1, 1, 52) at 1278 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (2, 1, 2, 52) at 1280 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (2, 1, 3, 52) at 1282 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (3, 1, 0, 52) at 1286 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (3, 1, 1, 52) at 1290 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (3, 1, 2, 52) at 1295 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
# Checking (3, 1, 3, 52) at 1300 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.08193455165248552 MAE and 0.14226090566039185 RMSE.
#
# The final model for danceability is SARIMAX(2, 0, 2)x(2, 0, 2, 49).
#
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.0492815647104452 MAE and 0.06065940859433034 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.05091012194955635 MAE and 0.06221453309101204 RMSE.
# Checking (0, 0, 2, 48) at 2 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.050103339415879446 MAE and 0.061627862842686454 RMSE.
# Checking (0, 0, 3, 48) at 8 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.05059045078525073 MAE and 0.061966771085481286 RMSE.
# Checking (1, 0, 0, 48) at 25 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.05014420030404695 MAE and 0.061525014247409276 RMSE.
# Checking (1, 0, 1, 48) at 28 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.044170619393600195 MAE and 0.055726225814815775 RMSE.
# Checking (1, 0, 2, 48) at 30 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.0458964897337279 MAE and 0.057341080930790114 RMSE.
# Checking (1, 0, 3, 48) at 36 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.044065471281551194 MAE and 0.055683021731659496 RMSE.
# Checking (2, 0, 0, 48) at 60 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.05159148411173916 MAE and 0.06304551495491587 RMSE.
# Checking (2, 0, 1, 48) at 68 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.041639661388133575 MAE and 0.05352480952563081 RMSE.
# Checking (2, 0, 2, 48) at 75 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.04497197426719557 MAE and 0.056521463876339266 RMSE.
# Checking (2, 0, 3, 48) at 81 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.05258001106487278 MAE and 0.06418858040489182 RMSE.
# Checking (3, 0, 0, 48) at 103 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.029375081912905793 MAE and 0.04556247878836706 RMSE.
# Checking (3, 0, 1, 48) at 128 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.05035605123066563 MAE and 0.06186023312569212 RMSE.
# Checking (3, 0, 2, 48) at 147 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.04540114211305992 MAE and 0.056884040335815254 RMSE.
# Checking (3, 0, 3, 48) at 165 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.04666459107418652 MAE and 0.05805449379892818 RMSE.
# Checking (0, 1, 0, 48) at 184 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (0, 1, 1, 48) at 184 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (0, 1, 2, 48) at 184 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (0, 1, 3, 48) at 185 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (1, 1, 0, 48) at 186 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (1, 1, 1, 48) at 187 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (1, 1, 2, 48) at 187 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (1, 1, 3, 48) at 188 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (2, 1, 0, 48) at 190 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (2, 1, 1, 48) at 190 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (2, 1, 2, 48) at 191 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (2, 1, 3, 48) at 192 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (3, 1, 0, 48) at 194 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (3, 1, 1, 48) at 196 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (3, 1, 2, 48) at 199 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (3, 1, 3, 48) at 201 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 48) model with 0.2622158085943922 MAE and 0.27417299287128233 RMSE.
# Checking (0, 0, 0, 49) at 203 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 49) model with 0.0492815647104452 MAE and 0.06065940859433034 RMSE.
# Checking (0, 0, 1, 49) at 203 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 49) model with 0.04896173231633796 MAE and 0.06032507114455126 RMSE.
# Checking (0, 0, 2, 49) at 204 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 49) model with 0.04861824608426041 MAE and 0.06001994779374219 RMSE.
# Checking (0, 0, 3, 49) at 208 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 49) model with 0.049248685457817076 MAE and 0.06062581799930235 RMSE.
# Checking (1, 0, 0, 49) at 219 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 49) model with 0.04737100392792901 MAE and 0.05878307925599164 RMSE.
# Checking (1, 0, 1, 49) at 221 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 49) model with 0.047768114493766944 MAE and 0.05920043808995992 RMSE.
# Checking (1, 0, 2, 49) at 223 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 49) model with 0.047434158744037246 MAE and 0.0588721121055434 RMSE.
# Checking (1, 0, 3, 49) at 228 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 49) model with 0.04894209492628474 MAE and 0.06033844470363532 RMSE.
# Checking (2, 0, 0, 49) at 253 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 49) model with 0.04930114932384586 MAE and 0.06073080547018869 RMSE.
# Checking (2, 0, 1, 49) at 258 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 49) model with 0.048629787021646186 MAE and 0.05999897630652534 RMSE.
# Checking (2, 0, 2, 49) at 265 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 49) model with 0.048809403196538724 MAE and 0.06018978939696443 RMSE.
# Checking (2, 0, 3, 49) at 272 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 49) model with 0.04835350107019901 MAE and 0.059759334990400086 RMSE.
# Checking (3, 0, 0, 49) at 312 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 49) model with 0.04953418715570975 MAE and 0.06087932796376061 RMSE.
# Checking (3, 0, 1, 49) at 329 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 49) model with 0.04863634854665544 MAE and 0.06003008851575907 RMSE.
# Checking (3, 0, 2, 49) at 355 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 49) model with 0.049147932463311526 MAE and 0.06067743627039081 RMSE.
# Checking (3, 0, 3, 49) at 385 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 49) model with 0.04901313846176716 MAE and 0.06038699403939719 RMSE.
# Checking (0, 1, 0, 49) at 418 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (0, 1, 1, 49) at 419 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (0, 1, 2, 49) at 419 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (0, 1, 3, 49) at 420 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (1, 1, 0, 49) at 422 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (1, 1, 1, 49) at 422 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (1, 1, 2, 49) at 423 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (1, 1, 3, 49) at 424 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (2, 1, 0, 49) at 426 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (2, 1, 1, 49) at 427 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (2, 1, 2, 49) at 429 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (2, 1, 3, 49) at 431 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (3, 1, 0, 49) at 437 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (3, 1, 1, 49) at 439 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (3, 1, 2, 49) at 447 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (3, 1, 3, 49) at 455 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 49) model with 0.30164436173724 MAE and 0.3263732971750626 RMSE.
# Checking (0, 0, 0, 50) at 461 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 50) model with 0.0492815647104452 MAE and 0.06065940859433034 RMSE.
# Checking (0, 0, 1, 50) at 461 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 50) model with 0.04792412657034915 MAE and 0.059408740711321885 RMSE.
# Checking (0, 0, 2, 50) at 463 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 50) model with 0.048303685922386964 MAE and 0.059745146688026274 RMSE.
# Checking (0, 0, 3, 50) at 469 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 50) model with 0.048175332863741795 MAE and 0.059627161241210626 RMSE.
# Checking (1, 0, 0, 50) at 495 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 50) model with 0.04820822394420027 MAE and 0.05963396913297655 RMSE.
# Checking (1, 0, 1, 50) at 497 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 50) model with 0.047951009058368965 MAE and 0.05940967555617757 RMSE.
# Checking (1, 0, 2, 50) at 499 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 50) model with 0.04921108360564876 MAE and 0.06058437867464172 RMSE.
# Checking (1, 0, 3, 50) at 511 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 50) model with 0.048130015079053644 MAE and 0.059581164402725977 RMSE.
# Checking (2, 0, 0, 50) at 537 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 50) model with 0.048497744013421586 MAE and 0.05992636105436906 RMSE.
# Checking (2, 0, 1, 50) at 544 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 50) model with 0.04809832634669956 MAE and 0.05954987523573042 RMSE.
# Checking (2, 0, 2, 50) at 553 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 50) model with 0.04874173088132794 MAE and 0.0601653547470501 RMSE.
# Checking (2, 0, 3, 50) at 566 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 50) model with 0.049554343011783485 MAE and 0.060851326291135495 RMSE.
# Checking (3, 0, 0, 50) at 602 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 50) model with 0.0483048810048052 MAE and 0.05975221596111254 RMSE.
# Checking (3, 0, 1, 50) at 655 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 50) model with 0.047919584465607436 MAE and 0.05938367676776559 RMSE.
# Checking (3, 0, 2, 50) at 693 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 50) model with 0.04847767023787906 MAE and 0.05988425211098387 RMSE.
# Checking (3, 0, 3, 50) at 714 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 50) model with 0.049632923077230086 MAE and 0.06100486798918017 RMSE.
# Checking (0, 1, 0, 50) at 745 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (0, 1, 1, 50) at 745 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (0, 1, 2, 50) at 745 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (0, 1, 3, 50) at 746 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (1, 1, 0, 50) at 748 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (1, 1, 1, 50) at 749 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (1, 1, 2, 50) at 749 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (1, 1, 3, 50) at 750 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (2, 1, 0, 50) at 752 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (2, 1, 1, 50) at 753 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (2, 1, 2, 50) at 754 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (2, 1, 3, 50) at 755 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (3, 1, 0, 50) at 758 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (3, 1, 1, 50) at 762 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (3, 1, 2, 50) at 764 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (3, 1, 3, 50) at 767 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 50) model with 0.3245967246896148 MAE and 0.3539745816058887 RMSE.
# Checking (0, 0, 0, 51) at 769 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 51) model with 0.0492815647104452 MAE and 0.06065940859433034 RMSE.
# Checking (0, 0, 1, 51) at 770 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 51) model with 0.04816618897348296 MAE and 0.05960359098119918 RMSE.
# Checking (0, 0, 2, 51) at 771 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 51) model with 0.04806802935572944 MAE and 0.059517149005842394 RMSE.
# Checking (0, 0, 3, 51) at 779 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 51) model with 0.04819107081873173 MAE and 0.05964071751151125 RMSE.
# Checking (1, 0, 0, 51) at 794 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 51) model with 0.04879143291597358 MAE and 0.06020550955849492 RMSE.
# Checking (1, 0, 1, 51) at 795 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 51) model with 0.04908250071547815 MAE and 0.06047591881176326 RMSE.
# Checking (1, 0, 2, 51) at 796 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 51) model with 0.04847420963725657 MAE and 0.05990771612326329 RMSE.
# Checking (1, 0, 3, 51) at 802 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 51) model with 0.047977440152134454 MAE and 0.05946709165987205 RMSE.
# Checking (2, 0, 0, 51) at 820 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 51) model with 0.04924477787660342 MAE and 0.060635070530181995 RMSE.
# Checking (2, 0, 1, 51) at 827 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 51) model with 0.04780799387468906 MAE and 0.059269876811970386 RMSE.
# Checking (2, 0, 2, 51) at 842 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 51) model with 0.04899269987748869 MAE and 0.06038477761619134 RMSE.
# Checking (2, 0, 3, 51) at 850 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 51) model with 0.049149808671198114 MAE and 0.060544232140210374 RMSE.
# Checking (3, 0, 0, 51) at 872 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 51) model with 0.04918839072123047 MAE and 0.06056425116179545 RMSE.
# Checking (3, 0, 1, 51) at 899 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 51) model with 0.04918696545146926 MAE and 0.0605748309356895 RMSE.
# Checking (3, 0, 2, 51) at 923 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 51) model with 0.04926459034280106 MAE and 0.06064943034876819 RMSE.
# Checking (3, 0, 3, 51) at 963 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 51) model with 0.04932187951064598 MAE and 0.060697295066739446 RMSE.
# Checking (0, 1, 0, 51) at 1020 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (0, 1, 1, 51) at 1020 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (0, 1, 2, 51) at 1021 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (0, 1, 3, 51) at 1022 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (1, 1, 0, 51) at 1026 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (1, 1, 1, 51) at 1026 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (1, 1, 2, 51) at 1028 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (1, 1, 3, 51) at 1030 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (2, 1, 0, 51) at 1040 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (2, 1, 1, 51) at 1044 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (2, 1, 2, 51) at 1049 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (2, 1, 3, 51) at 1051 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (3, 1, 0, 51) at 1061 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (3, 1, 1, 51) at 1066 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (3, 1, 2, 51) at 1076 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (3, 1, 3, 51) at 1088 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.3370728974515167 MAE and 0.37611969542215457 RMSE.
# Checking (0, 0, 0, 52) at 1096 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.0492815647104452 MAE and 0.06065940859433034 RMSE.
# Checking (0, 0, 1, 52) at 1098 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.04939300799277139 MAE and 0.06074810361241243 RMSE.
# Checking (0, 0, 2, 52) at 1103 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.04790365156678147 MAE and 0.05935716552179921 RMSE.
# Checking (0, 0, 3, 52) at 1116 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.04823173606214215 MAE and 0.059674221253363385 RMSE.
# Checking (1, 0, 0, 52) at 1145 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.0472471988975936 MAE and 0.05884089247115776 RMSE.
# Checking (1, 0, 1, 52) at 1147 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.05026462028642398 MAE and 0.0615965054664114 RMSE.
# Checking (1, 0, 2, 52) at 1150 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.04955831750107511 MAE and 0.060927024760073986 RMSE.
# Checking (1, 0, 3, 52) at 1164 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.04833112438801729 MAE and 0.05974268484941817 RMSE.
# Checking (2, 0, 0, 52) at 1199 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.04822137729704364 MAE and 0.0596674897618962 RMSE.
# Checking (2, 0, 1, 52) at 1213 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.04870487410570706 MAE and 0.060119021098048474 RMSE.
# Checking (2, 0, 2, 52) at 1229 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.04920671983686827 MAE and 0.0606191151826968 RMSE.
# Checking (2, 0, 3, 52) at 1246 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.04806277660273032 MAE and 0.05951122258474712 RMSE.
# Checking (3, 0, 0, 52) at 1292 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.048282467402413654 MAE and 0.05971834452313442 RMSE.
# Checking (3, 0, 1, 52) at 1327 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.049158527270016315 MAE and 0.06054447959681915 RMSE.
# Checking (3, 0, 2, 52) at 1344 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.048982210955714034 MAE and 0.06038474338584858 RMSE.
# Checking (3, 0, 3, 52) at 1372 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.04931589925888471 MAE and 0.06068013941785578 RMSE.
# Checking (0, 1, 0, 52) at 1398 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.33564430859437394 MAE and 0.3778654066919172 RMSE.
# Checking (0, 1, 1, 52) at 1398 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (0, 1, 2, 52) at 1398 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (0, 1, 3, 52) at 1399 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (1, 1, 0, 52) at 1402 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (1, 1, 1, 52) at 1402 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (1, 1, 2, 52) at 1402 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (1, 1, 3, 52) at 1404 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (2, 1, 0, 52) at 1406 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (2, 1, 1, 52) at 1407 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (2, 1, 2, 52) at 1408 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (2, 1, 3, 52) at 1410 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (3, 1, 0, 52) at 1413 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (3, 1, 1, 52) at 1416 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (3, 1, 2, 52) at 1419 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
# Checking (3, 1, 3, 52) at 1422 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.3356443085943741 MAE and 0.3778654066919173 RMSE.
#
# The final model for mode is SARIMAX(2, 0, 2)x(3, 0, 0, 48).
#
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.03187691195754296 MAE and 0.035530125727980526 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# ...
# Checking (3, 1, 0, 51) at 1795 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 51) model with 0.04254825766059681 MAE and 0.045573809342608636 RMSE.
# Checking (3, 1, 1, 51) at 1798 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 51) model with 0.04254825766059681 MAE and 0.045573809342608636 RMSE.
# Checking (3, 1, 2, 51) at 1802 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 51) model with 0.04254825766059681 MAE and 0.045573809342608636 RMSE.
# Checking (3, 1, 3, 51) at 1807 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 51) model with 0.04254825766059681 MAE and 0.045573809342608636 RMSE.
# Checking (0, 0, 0, 52) at 1811 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 52) model with 0.03187691195754296 MAE and 0.035530125727980526 RMSE.
# Checking (0, 0, 1, 52) at 1812 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 52) model with 0.031728418935316666 MAE and 0.03539414107494251 RMSE.
# Checking (0, 0, 2, 52) at 1814 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 52) model with 0.03172415137600201 MAE and 0.03546233996387103 RMSE.
# Checking (0, 0, 3, 52) at 1826 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 52) model with 0.03173914092651108 MAE and 0.03537954687820633 RMSE.
# Checking (1, 0, 0, 52) at 1855 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 52) model with 0.03168469841757384 MAE and 0.035380258310597885 RMSE.
# Checking (1, 0, 1, 52) at 1859 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 52) model with 0.031448385229642876 MAE and 0.03510205108776359 RMSE.
# Checking (1, 0, 2, 52) at 1863 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 52) model with 0.031418052785654536 MAE and 0.03516745453507446 RMSE.
# Checking (1, 0, 3, 52) at 1875 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 52) model with 0.03142493003403757 MAE and 0.03511190620216958 RMSE.
# Checking (2, 0, 0, 52) at 1911 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 52) model with 0.031525755124894465 MAE and 0.03546798092927381 RMSE.
# Checking (2, 0, 1, 52) at 1931 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 52) model with 0.0311042296194755 MAE and 0.034959972442066736 RMSE.
# Checking (2, 0, 2, 52) at 1947 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 52) model with 0.031510582668094415 MAE and 0.03540457374999595 RMSE.
# Checking (2, 0, 3, 52) at 1973 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 52) model with 0.03113423156271954 MAE and 0.03479143895354354 RMSE.
# Checking (3, 0, 0, 52) at 2049 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 52) model with 0.03154260574599283 MAE and 0.035261176007403444 RMSE.
# Checking (3, 0, 1, 52) at 2141 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 52) model with 0.03208085022893246 MAE and 0.03563425855932303 RMSE.
# Checking (3, 0, 2, 52) at 2222 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 52) model with 0.03134044645883693 MAE and 0.03499716955218067 RMSE.
# Checking (3, 0, 3, 52) at 2298 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 52) model with 0.03150681680517448 MAE and 0.03537491947444007 RMSE.
# Checking (0, 1, 0, 52) at 2385 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (0, 1, 1, 52) at 2385 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (0, 1, 2, 52) at 2386 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (0, 1, 3, 52) at 2388 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (1, 1, 0, 52) at 2392 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 0, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (1, 1, 1, 52) at 2393 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 1, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (1, 1, 2, 52) at 2394 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 2, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (1, 1, 3, 52) at 2397 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 1, 3, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (2, 1, 0, 52) at 2402 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 0, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (2, 1, 1, 52) at 2404 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 1, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (2, 1, 2, 52) at 2406 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 2, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (2, 1, 3, 52) at 2410 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 1, 3, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (3, 1, 0, 52) at 2415 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 0, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (3, 1, 1, 52) at 2420 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 1, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (3, 1, 2, 52) at 2425 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 2, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
# Checking (3, 1, 3, 52) at 2431 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 1, 3, 52) model with 0.05233179155298268 MAE and 0.054685509426114574 RMSE.
#
# The final model for acousticness is SARIMAX(2, 0, 2)x(1, 0, 1, 49).
#
# Checking (0, 0, 0, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 0, 48) model with 0.013911952380952228 MAE and 0.015889325756406218 RMSE.
# Checking (0, 0, 1, 48) at 0 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 1, 48) model with 0.013911952379456305 MAE and 0.015889325755536164 RMSE.
# Checking (0, 0, 2, 48) at 1 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 2, 48) model with 0.013911952378610306 MAE and 0.015889325755044103 RMSE.
# Checking (0, 0, 3, 48) at 3 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 0, 3, 48) model with 0.013911952378481446 MAE and 0.01588932575496915 RMSE.
# Checking (1, 0, 0, 48) at 8 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 0, 48) model with 0.013911952381491824 MAE and 0.015889325756720044 RMSE.
# Checking (1, 0, 1, 48) at 8 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 1, 48) model with 0.013911952380952488 MAE and 0.01588932575640636 RMSE.
# Checking (1, 0, 2, 48) at 10 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 2, 48) model with 0.013911952380951867 MAE and 0.015889325756405993 RMSE.
# Checking (1, 0, 3, 48) at 13 seconds.
# We just fit a SARIMAX(2, 0, 2)x(1, 0, 3, 48) model with 0.013911952380952228 MAE and 0.015889325756406218 RMSE.
# Checking (2, 0, 0, 48) at 22 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 0, 48) model with 0.013911952381491835 MAE and 0.01588932575672006 RMSE.
# Checking (2, 0, 1, 48) at 23 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 1, 48) model with 0.013911952380952136 MAE and 0.01588932575640617 RMSE.
# Checking (2, 0, 2, 48) at 26 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 2, 48) model with 0.013911952380951545 MAE and 0.01588932575640583 RMSE.
# Checking (2, 0, 3, 48) at 31 seconds.
# We just fit a SARIMAX(2, 0, 2)x(2, 0, 3, 48) model with 0.013911952380952247 MAE and 0.015889325756406225 RMSE.
# Checking (3, 0, 0, 48) at 36 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 0, 48) model with 0.01391195238149178 MAE and 0.01588932575672002 RMSE.
# Checking (3, 0, 1, 48) at 38 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 1, 48) model with 0.013911952380952173 MAE and 0.015889325756406197 RMSE.
# Checking (3, 0, 2, 48) at 44 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 2, 48) model with 0.01391195238095209 MAE and 0.015889325756406135 RMSE.
# Checking (3, 0, 3, 48) at 62 seconds.
# We just fit a SARIMAX(2, 0, 2)x(3, 0, 3, 48) model with 0.013911952380952821 MAE and 0.015889325756406572 RMSE.
# Checking (0, 1, 0, 48) at 73 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 0, 48) model with 0.21972749999999985 MAE and 0.2424579328481189 RMSE.
# Checking (0, 1, 1, 48) at 73 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 1, 48) model with 0.21972759719382026 MAE and 0.24245803821793782 RMSE.
# Checking (0, 1, 2, 48) at 73 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 2, 48) model with 0.21972759719382026 MAE and 0.24245803821793782 RMSE.
# Checking (0, 1, 3, 48) at 74 seconds.
# We just fit a SARIMAX(2, 0, 2)x(0, 1, 3, 48) model with 0.21972759719382026 MAE and 0.24245803821793782 RMSE.
# Checking (1, 1, 0, 48) at 76 seconds.
# problem!
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-46-058462c7f633> in <module>
#       1 for feature in five_features:
# ----> 2     find_sarima_parameters(it_rw_19, feature, arima_param_df_19)
#
# <ipython-input-44-75307609aae9> in find_sarima_parameters(df, feature, param_df, n_rows)
#      21                     print(f'Checking ({P}, {D}, {Q}, {S}) at {round(time.time() - t0)} seconds.')
#      22                     try:
# ---> 23                         sarima = SARIMAX(endog = train_values,
#      24                                          order = order,
#      25                                          seasonal_order = (P, D, Q, S)).fit()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     688                 flags['hessian_method'] = optim_hessian
#     689             fargs = (flags,)
# --> 690             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     691                                                fargs=fargs,
#     692                                                maxiter=maxiter,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     517         warn_convergence = kwargs.pop('warn_convergence', True)
#     518         optimizer = Optimizer()
# --> 519         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     520                                                        fargs, kwargs,
#     521                                                        hessian=hess,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     222
#     223         func = fit_funcs[method]
# --> 224         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     225                             disp=disp, maxiter=maxiter, callback=callback,
#     226                             retall=retall, full_output=full_output,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     627         func = f
#     628
# --> 629     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     630                                      callback=callback, args=fargs,
#     631                                      bounds=bounds, disp=disp,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py in f(params, *args)
#     499
#     500         def f(params, *args):
# --> 501             return -self.loglike(params, *args) / nobs
#     502
#     503         if method == 'newton':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     923             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     924
# --> 925         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     926
#     927         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     981         kwargs.setdefault('conserve_memory',
#     982                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983         kfilter = self._filter(**kwargs)
#     984         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                         self.loglikelihood_burn)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     901
#     902         # Initialize the state
# --> 903         self._initialize_state(prefix=prefix, complex_step=complex_step)
#     904
#     905         # Run the filter
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/representation.py in _initialize_state(self, prefix, complex_step)
#     983             if not self.initialization.initialized:
#     984                 raise RuntimeError('Initialization is incomplete.')
# --> 985             self._statespaces[prefix].initialize(self.initialization,
#     986                                                  complex_step=complex_step)
#     987         else:
#
# statsmodels/tsa/statespace/_representation.pyx in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# statsmodels/tsa/statespace/_representation.pyx in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# statsmodels/tsa/statespace/_initialization.pyx in statsmodels.tsa.statespace._initialization.dInitialization.initialize()
#
# statsmodels/tsa/statespace/_initialization.pyx in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov()
#
# statsmodels/tsa/statespace/_tools.pyx in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov()
#
# LinAlgError: Schur decomposition solver error.

# %% [markdown]
# Encounted `linalgerror` while trying to run `find_sarima_parameters` on 2019 Italy data (`it_rw_19`). It did run for danceability, mode, and acousticness, and the `seasonal_order` output was similar to that which I found for the 2017. I will therefore use the same `seasonal_order` for each the audio as was determined by the 2017 data (`it_rw_19`).

# %% [markdown]
# Results from the above for the 2017 data:
# + The final model for danceability is SARIMAX(2, 0, 2)x(3, 0, 0, 48).
# + The final model for mode is SARIMAX(2, 0, 2)x(1, 0, 1, 52).
# + The final model for acousticness is SARIMAX(2, 0, 2)x(1, 0, 2, 48).
# + The final model for valence is SARIMAX(2, 0, 2)x(0, 0, 1, 49).
# + The final model for energy is SARIMAX(2, 0, 2)x(2, 0, 0, 49).

# %% [markdown]
# Results from SARIMA seasonal order grid search using 2017-2020 data:
#
# + The final model for danceability is SARIMAX(2, 0, 2)x(2, 0, 3, 48).
# + The final model for mode is SARIMAX(2, 0, 2)x(0, 0, 0, 48).
# + The final model for acousticness is SARIMAX(2, 0, 2)x(0, 1, 0, 48).
# + The final model for valence is SARIMAX(2, 0, 2)x(1, 0, 3, 50).
# + The final model for energy is SARIMAX(2, 0, 2)x(0, 0, 2, 51).

# %% [markdown]
# #### _Adding Seasonal Orders to `param_df`_

# %% [markdown]
# citation: converting string to tuple https://www.geeksforgeeks.org/python-convert-string-to-tuple/

# %%
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'danceability', 'seasonal_order'] = '3, 0, 0, 48'
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'mode', 'seasonal_order'] = '1, 0, 1, 52'
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'acousticness', 'seasonal_order'] = '1, 0, 2, 48'
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'valence', 'seasonal_order'] = '0, 0, 1, 49'
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'energy', 'seasonal_order'] = '2, 0, 0, 49'

# %%
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'danceability', 'seasonal_order_all_data'] = '2, 0, 3, 48'
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'mode', 'seasonal_order_all_data'] = '0, 0, 0, 48'
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'acousticness', 'seasonal_order_all_data'] = '0, 1, 0, 48'
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'valence', 'seasonal_order_all_data'] = '1, 0, 3, 50'
arima_param_df_19.loc[arima_param_df_19['audio_feature'] == 'energy', 'seasonal_order_all_data'] = '0, 0, 2, 51'

# %% [markdown]
# #### _Updated `arima_param_df_19`_

# %%
arima_param_df_19
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       1       1  (1, 1, 1)  ARIMA(1,1,1)
# 1          mode          2       1       1  (1, 2, 1)  ARIMA(1,2,1)
# 2  acousticness          2       5       1  (5, 2, 1)  ARIMA(5,2,1)
# 3       valence          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
# 4         tempo          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -271.807832          0.015254         0.037584    3, 0, 0, 48
# 1 -157.890865          0.046168         0.081371    1, 0, 1, 52
# 2 -223.192159          0.022119         0.049119    1, 0, 2, 48
# 3 -255.848982          0.036157         0.040172    0, 0, 1, 49
# 4  211.173044          1.858998         1.160010    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse  exog_train_rmse  exog_test_rmse  \
# 0           0.015389          0.027644         0.012050        0.023621
# 1           0.046428          0.057129         0.042583        0.055264
# 2           0.022590          0.043639         0.019695        0.049889
# 3           0.020463          0.017995         0.016554        0.011461
# 4           1.867845          0.578958         1.787163        0.166477
#
#   seasonal_order_all_data
# 0             2, 0, 3, 48
# 1             0, 0, 0, 48
# 2             0, 1, 0, 48
# 3             1, 0, 3, 50
# 4                     NaN

# %% [markdown]
# #### _Function for SARIMA w/ seasonal components, no exogenous variables:_

# %%
def sarima_predict_plot_seasonal(df, feature, year, param_df, title='title', figsize=(15,5), order=None, d=None, seasonal_order=None, ci=True):
  
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
    
    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    # find order from arima parameters dataframe 
    if order is None:
        order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
    
    # find seasonal order from arima parameters dataframe 
    if seasonal_order is None: 
        sea_string = param_df.loc[param_df['audio_feature'] == feature, 'seasonal_order'].iloc[0]
        seasonal_order = tuple(map(int, sea_string.split(', '))) 
    print(f'seasonal order = {seasonal_order}')
    
    try: 

        # instantiate and fit SARIMAX model 
        sarima = SARIMAX(endog=train, order=order, seasonal_order=seasonal_order).fit()

        # get predictions for train and test sets 
        preds_train = sarima.predict(start=train.index[d], end=train.index[-1], typ='levels')
        preds_test = sarima.predict(start=test.index[0], end=test.index[-1], typ='levels')

        # calculate and print RMSE for train and test setes 
        train_rmse = mean_squared_error(train[d::], preds_train)**0.5
        print(f'{feature.capitalize()} train RMSE ({year}) - SARIMA({order}): {train_rmse}')

        test_rmse = mean_squared_error(test, preds_test)**0.5
        print(f'{feature.capitalize()} test RMSE ({year}) - SARIMA({order}): {test_rmse}')    

        # add RMSEs to arima parameters dataframe 
        param_df.loc[param_df['audio_feature'] == feature, 'sarima_train_rmse'] = train_rmse    
        param_df.loc[param_df['audio_feature'] == feature, 'sarima_test_rmse'] = test_rmse

        # calculate residuals
        # residuals = test - preds_test

        # set up plot
        plt.figure(figsize=figsize)

        # plot training data 
        plt.plot(train, color='blue')

        # plot testing data 
        plt.plot(test.index, test, color='orange')

        # plot predicted values for test set 
        plt.plot(test.index, preds_test, color='green')

        # add line for the baseline model (mean value of feature)
        plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')

        # plot confidence interval 
        if ci:
            ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
            plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 

        # make plot with title! 
        plt.title(title, fontsize=16)
        plt.show() ; 
        
    
    except ValueError as ve:
        print(ve)
        pass

# %%
for feature in five_features:
    sarima_predict_plot_seasonal(it_rw_19, feature, 2019, arima_param_df_19, title=f'Mean {feature.capitalize()} Score, Italy 2019 (SARIMA w/o exog variables)')
# Out:
# d = 1
# order = (1, 1, 1)
# seasonal order = (3, 0, 0, 48)
# Danceability train RMSE (2019) - SARIMA((1, 1, 1)): 0.0153888226349884
# Danceability test RMSE (2019) - SARIMA((1, 1, 1)): 0.027644122997596072
# d = 2
# order = (1, 2, 1)
# seasonal order = (1, 0, 1, 52)
# Mode train RMSE (2019) - SARIMA((1, 2, 1)): 0.046428113568152705
# Mode test RMSE (2019) - SARIMA((1, 2, 1)): 0.0571291659561067
# d = 2
# order = (5, 2, 1)
# seasonal order = (1, 0, 2, 48)
# Acousticness train RMSE (2019) - SARIMA((5, 2, 1)): 0.022589642169249923
# Acousticness test RMSE (2019) - SARIMA((5, 2, 1)): 0.04363887930115674
# d = 1
# order = (0, 1, 0)
# seasonal order = (0, 0, 1, 49)
# Valence train RMSE (2019) - SARIMA((0, 1, 0)): 0.020462893359187374
# Valence test RMSE (2019) - SARIMA((0, 1, 0)): 0.0179953092390978
# d = 1
# order = (0, 1, 0)
# seasonal order = (2, 0, 0, 49)
# Tempo train RMSE (2019) - SARIMA((0, 1, 0)): 1.8678450575591443
# Tempo test RMSE (2019) - SARIMA((0, 1, 0)): 0.5789584360730555

# %% [markdown]
# #### _Updated `arima_param_df_19`_

# %%
arima_param_df_19
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       1       1  (1, 1, 1)  ARIMA(1,1,1)
# 1          mode          2       1       1  (1, 2, 1)  ARIMA(1,2,1)
# 2  acousticness          2       5       1  (5, 2, 1)  ARIMA(5,2,1)
# 3       valence          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
# 4         tempo          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -271.807832          0.015254         0.037584    3, 0, 0, 48
# 1 -157.890865          0.046168         0.081371    1, 0, 1, 52
# 2 -223.192159          0.022119         0.049119    1, 0, 2, 48
# 3 -255.848982          0.036157         0.040172    0, 0, 1, 49
# 4  211.173044          1.858998         1.160010    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse
# 0           0.015389          0.027644
# 1           0.046428          0.057129
# 2           0.022590          0.043639
# 3           0.020463          0.017995
# 4           1.867845          0.578958

# %% [markdown]
# #### _Incorporating Exogenous Variables in SARIMAX models_

# %%
def sarima_predict_plot_exog(df, feature, year, param_df, exog_var, title='title', figsize=(15,5), order=None, d=None, seasonal_order=None, ci=True):

    # find ndiffs for stationarity from ndiff dataframe
    if d is None: 
        d = ndiff_df.loc[ndiff_df['audio_feature'] == feature, 'ndiffs for stationarity'].iloc[0]
    print(f'd = {d}')
    
    # find order from arima parameters dataframe 
    if order is None:
        order = param_df.loc[param_df['audio_feature'] == feature, 'order'].iloc[0]
    print(f'order = {order}')
    
    # find seasonal order from arima parameters dataframe 
    if seasonal_order is None: 
        sea_string = param_df.loc[param_df['audio_feature'] == feature, 'seasonal_order'].iloc[0]
        seasonal_order = tuple(map(int, sea_string.split(', '))) 
    print(f'seasonal order = {seasonal_order}')
    
    # reshape exogenous features to pass to the model 
    exog = df.loc[:, exog_var]   
   
    # create train and test sets
    n_rows = round(len(df)*0.9)
    train = df[feature][0:n_rows]
    test = df[feature][n_rows:]
  
    try:
        # instantiate and fit SARIMAX model 
        sarima = SARIMAX(endog=train, exog=exog[0:n_rows], order=order, seasonal_order=seasonal_order).fit()

        # get predictions for train and test sets 
        preds_train = sarima.predict(start=train.index[d], end=train.index[-1], typ='levels', exog=exog[0:n_rows])
        preds_test = sarima.predict(start=test.index[0], end=test.index[-1], typ='levels', exog=exog[n_rows:])

        # calculate and print RMSE for train and test setes 
        train_rmse = mean_squared_error(train[d::], preds_train)**0.5
        print(f'{feature.capitalize()} train RMSE ({year}) - SARIMAX({seasonal_order}) w/ exogenous variables: {train_rmse}')

        test_rmse = mean_squared_error(test, preds_test)**0.5
        print(f'{feature.capitalize()} test RMSE ({year}) - SARIMAX({seasonal_order}) w/ exogenous variables: {test_rmse}')    

        # add RMSEs to arima parameters dataframe 
        param_df.loc[param_df['audio_feature'] == feature, 'exog_train_rmse'] = train_rmse    
        param_df.loc[param_df['audio_feature'] == feature, 'exog_test_rmse'] = test_rmse

        # calculate residuals
        # residuals = test - preds_test

        # set up plot
        plt.figure(figsize=figsize)

        # plot training data 
        plt.plot(train, color='blue')

        # plot testing data 
        plt.plot(test.index, test, color='orange')

        # plot predicted values for test set 
        plt.plot(test.index, preds_test, color='green')

        # add line for the baseline model (mean value of feature)
        plt.hlines(df[feature].mean(), train.index[0], test.index[-1], color = 'grey')

        # plot confidence interval 
        if ci:
            ci = 1.96 * np.std(preds_test)/np.mean(preds_test)
            plt.fill_between(test.index, (preds_test - ci), (preds_test + ci), color='blue', alpha=.1) 

        # make plot with title! 
        plt.title(title, fontsize=16)
        plt.grid()
        plt.show() ; 
        
    except ValueError as ve:
        print(ve)
        pass

# %% [markdown]
# _Identifying exogenous variables for each of the five main features, which for each of them is the other four audio features_

# %%
five_features = ['danceability', 'mode', 'acousticness', 'valence', 'energy']

exog_danceability = ['mode', 'acousticness', 'valence', 'energy']
exog_mode = ['danceability', 'acousticness', 'valence', 'energy']
exog_acousticness = ['danceability', 'mode', 'valence', 'energy']
exog_valence = ['danceability', 'mode', 'acousticness', 'energy']
exog_energy = ['danceability', 'mode', 'acousticness', 'valence']

# %%
sarima_predict_plot_exog(it_rw_19, 'danceability', 2019, arima_param_df_19, exog_var=exog_danceability, title=f'Mean Danceability Score, Italy 2019 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (1, 1, 1)
# seasonal order = (3, 0, 0, 48)
# Danceability train RMSE (2019) - SARIMAX((3, 0, 0, 48)) w/ exogenous variables: 0.012049792583420637
# Danceability test RMSE (2019) - SARIMAX((3, 0, 0, 48)) w/ exogenous variables: 0.023621382727322806

# %%
# for feature in five_features:
#     sarima_predict_plot_exog(it_rw_17, feature, 2019, exog_var=f'exog_{feature}', title=f'Mean {feature} Score, Italy 2019 (SARIMA w/ exog variables)')

# %%
sarima_predict_plot_exog(it_rw_19, 'mode', 2019, arima_param_df_19, exog_var=exog_mode, title=f'Mean Mode Score, Italy 2019 (SARIMA w/ exog variables)')
# Out:
# d = 2
# order = (1, 2, 1)
# seasonal order = (1, 0, 1, 52)
# Mode train RMSE (2019) - SARIMAX((1, 0, 1, 52)) w/ exogenous variables: 0.04258281754234657
# Mode test RMSE (2019) - SARIMAX((1, 0, 1, 52)) w/ exogenous variables: 0.05526387553871458

# %%
sarima_predict_plot_exog(it_rw_19, 'acousticness', 2019, arima_param_df_19, exog_var=exog_acousticness, title=f'Mean Acousticness Score, Italy 2019 (SARIMA w/ exog variables)')
# Out:
# d = 2
# order = (5, 2, 1)
# seasonal order = (1, 0, 2, 48)
# Acousticness train RMSE (2019) - SARIMAX((1, 0, 2, 48)) w/ exogenous variables: 0.01969459421048415
# Acousticness test RMSE (2019) - SARIMAX((1, 0, 2, 48)) w/ exogenous variables: 0.049889414787317024

# %%
sarima_predict_plot_exog(it_rw_19, 'valence', 2019, arima_param_df_19, exog_var=exog_valence, title=f'Mean Valence Score, Italy 2019 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (0, 1, 0)
# seasonal order = (0, 0, 1, 49)
# Valence train RMSE (2019) - SARIMAX((0, 0, 1, 49)) w/ exogenous variables: 0.016554395063128308
# Valence test RMSE (2019) - SARIMAX((0, 0, 1, 49)) w/ exogenous variables: 0.011461499602793508

# %%
sarima_predict_plot_exog(it_rw_19, 'energy', 2019, arima_param_df_19, exog_var=exog_energy, title=f'Mean energy Score, Italy 2019 (SARIMA w/ exog variables)')
# Out:
# d = 1
# order = (0, 1, 0)
# seasonal order = (2, 0, 0, 49)
# Tempo train RMSE (2019) - SARIMAX((2, 0, 0, 49)) w/ exogenous variables: 1.7871629188073488
# Tempo test RMSE (2019) - SARIMAX((2, 0, 0, 49)) w/ exogenous variables: 0.1664770450958117

# %% [markdown]
# #### _Updated `arima_param_df_19`_

# %%
arima_param_df_19
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       1       1  (1, 1, 1)  ARIMA(1,1,1)
# 1          mode          2       1       1  (1, 2, 1)  ARIMA(1,2,1)
# 2  acousticness          2       5       1  (5, 2, 1)  ARIMA(5,2,1)
# 3       valence          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
# 4         tempo          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -271.807832          0.015254         0.037584    3, 0, 0, 48
# 1 -157.890865          0.046168         0.081371    1, 0, 1, 52
# 2 -223.192159          0.022119         0.049119    1, 0, 2, 48
# 3 -255.848982          0.036157         0.040172    0, 0, 1, 49
# 4  211.173044          1.858998         1.160010    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse  exog_train_rmse  exog_test_rmse
# 0           0.015389          0.027644         0.012050        0.023621
# 1           0.046428          0.057129         0.042583        0.055264
# 2           0.022590          0.043639         0.019695        0.049889
# 3           0.020463          0.017995         0.016554        0.011461
# 4           1.867845          0.578958         1.787163        0.166477

# %% [markdown]
# #### _Pickling 2019 `arima_param_df_19` to compare with other years in another notebook_

# %%
arima_param_df_19.to_pickle('./metrics/2019_sarima_param_df.pkl')
