# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/emilynaftalin/Data_Science/General Assembly/dsi/capstone/code/metrics'

# %%
sarimax_metrics_2017 = pd.read_pickle('2017_sarima_param_df.pkl')
sarimax_metrics_2017['year'] = 2017

# %%
sarimax_metrics_2018 = pd.read_pickle('2018_sarima_param_df_same_d.pkl')
sarimax_metrics_2018['year'] = 2018
sarimax_metrics_2018_d = pd.read_pickle('2018_sarima_param_df_custom_d.pkl') 
sarimax_metrics_2018_d['year'] = 2018
sarimax_metrics_2019 = pd.read_pickle('2019_sarima_param_df.pkl')
sarimax_metrics_2019['year'] = 2019
sarimax_metrics_2020 = pd.read_pickle('2020_sarima_param_df.pkl')
sarimax_metrics_2020['year'] = 2020

# %%
sarimax_metrics_2017
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
# 1          mode          1       4       3  (4, 1, 3)  ARIMA(4,1,3)
# 2  acousticness          0       3       2  (3, 0, 2)  ARIMA(3,0,2)
# 3       valence          0       2       2  (2, 0, 2)  ARIMA(2,0,2)
# 4         tempo          0       0       5  (0, 0, 5)  ARIMA(0,0,5)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -726.878719          0.026156         0.012448    3, 0, 0, 48
# 1 -430.794979          0.069307         0.145383    1, 0, 1, 52
# 2 -600.573624          0.040623         0.048182    1, 0, 2, 48
# 3 -627.919164          0.030531         0.029380    0, 0, 1, 49
# 4  780.783703          2.937925         7.120252    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse  exog_train_rmse  exog_test_rmse  year
# 0           0.026049          0.021293         0.020428        0.011169  2017
# 1           0.066625          0.109086         0.069689        0.094840  2017
# 2           0.059960          0.019439         0.047150        0.061274  2017
# 3           0.076294          0.025510         0.028126        0.037644  2017
# 4          21.276842         14.178447         4.990741        9.196513  2017

# %%
sarimax_metrics_2018
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       0       1  (0, 1, 1)  ARIMA(0,1,1)
# 1          mode          1       3       0  (3, 1, 0)  ARIMA(3,1,0)
# 2  acousticness          0       1       0  (1, 0, 0)  ARIMA(1,0,0)
# 3       valence          0       1       0  (1, 0, 0)  ARIMA(1,0,0)
# 4         tempo          0       1       0  (1, 0, 0)  ARIMA(1,0,0)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -217.460539          0.028161         0.010787    3, 0, 0, 48
# 1 -146.889516          0.053561         0.042752    1, 0, 1, 52
# 2 -187.125534          0.038007         0.083924    1, 0, 2, 48
# 3 -198.033593          0.034988         0.037454    0, 0, 1, 49
# 4  246.489753          2.464632         3.059656    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse  exog_train_rmse  exog_test_rmse  year
# 0           0.028236          0.009447         0.021132        0.017357  2018
# 1           0.053664          0.052039         0.048917        0.053776  2018
# 2           0.061046          0.093318         0.040060        0.112153  2018
# 3           0.074570          0.019938         0.026885        0.024913  2018
# 4          16.969873          2.196815         4.199196        7.811665  2018

# %%
sarimax_metrics_2018_d
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       0       1  (0, 1, 1)  ARIMA(0,1,1)
# 1          mode          1       3       0  (3, 1, 0)  ARIMA(3,1,0)
# 2  acousticness          1       0       2  (0, 1, 2)  ARIMA(0,1,2)
# 3       valence          1       2       4  (2, 1, 4)  ARIMA(2,1,4)
# 4         tempo          1       2       1  (2, 1, 1)  ARIMA(2,1,1)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -217.460539          0.028161         0.010787    3, 0, 0, 48
# 1 -146.889516          0.053561         0.042752    1, 0, 1, 52
# 2 -184.369110          0.036351         0.057268    1, 0, 2, 48
# 3 -191.967291          0.036157         0.040172    0, 0, 1, 49
# 4  246.974241          2.545530         3.022669    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse  exog_train_rmse  exog_test_rmse  year
# 0           0.028236          0.009447         0.021132        0.017357  2018
# 1           0.053664          0.052039         0.048917        0.053776  2018
# 2           0.036374          0.060643         0.033490        0.052562  2018
# 3           0.032802          0.031699         0.025177        0.026906  2018
# 4           2.552848          7.328390         2.341152        2.971377  2018

# %%
sarimax_metrics_2019
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       1       1  (1, 1, 1)  ARIMA(1,1,1)
# 1          mode          2       1       1  (1, 2, 1)  ARIMA(1,2,1)
# 2  acousticness          2       5       1  (5, 2, 1)  ARIMA(5,2,1)
# 3       valence          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
# 4         tempo          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -271.807832          0.015254         0.037584    3, 0, 0, 48
# 1 -157.890865          0.046168         0.081371    1, 0, 1, 52
# 2 -223.192159          0.022119         0.049119    1, 0, 2, 48
# 3 -255.848982          0.036157         0.040172    0, 0, 1, 49
# 4  211.173044          1.858998         1.160010    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse  exog_train_rmse  exog_test_rmse  year
# 0           0.015389          0.027644         0.012050        0.023621  2019
# 1           0.046428          0.057129         0.042583        0.055264  2019
# 2           0.022590          0.043639         0.019695        0.049889  2019
# 3           0.020463          0.017995         0.016554        0.011461  2019
# 4           1.867845          0.578958         1.787163        0.166477  2019

# %%
sarimax_metrics_2020
# Out:
#   audio_feature  ndiffs(d)  best_p  best_q      order   ARIMA_model  \
# 0  danceability          1       2       2  (2, 1, 2)  ARIMA(2,1,2)
# 1          mode          1       4       0  (4, 1, 0)  ARIMA(4,1,0)
# 2  acousticness          1       1       1  (1, 1, 1)  ARIMA(1,1,1)
# 3       valence          1       0       0  (0, 1, 0)  ARIMA(0,1,0)
# 4         tempo          2       0       1  (0, 2, 1)  ARIMA(0,2,1)
#
#     ARIMA_AIC  arima_train_rmse  arima_test_rmse seasonal_order  \
# 0 -214.352402          0.029955         0.031795    3, 0, 0, 48
# 1 -187.656554          0.036004         0.054158    1, 0, 1, 52
# 2 -170.836344          0.044908         0.031272    1, 0, 2, 48
# 3 -208.242293          0.036157         0.040172    0, 0, 1, 49
# 4  235.399507          2.298025         1.932611    2, 0, 0, 49
#
#    sarima_train_rmse  sarima_test_rmse  exog_train_rmse  exog_test_rmse  year
# 0           0.029155          0.006303         0.017313        0.026653  2020
# 1           0.036034          0.046978         0.031877        0.050937  2020
# 2           0.045349          0.035444         0.034245        0.035041  2020
# 3           0.032651          0.026011         0.016684        0.031002  2020
# 4           2.298156          2.277815         1.831272        2.867787  2020
